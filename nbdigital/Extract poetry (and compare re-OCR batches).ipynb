# %% [markdown]
# ## Extract poems based on filename

# %%
import re
from pathlib import Path

dirname = "old/20150526_nbdig_txt01/idetfrikorpus-dist-txt"
p = Path(dirname)

txts = [e for e in p.iterdir() if e.suffix == ".txt"]
dirs = [e for e in p.iterdir() if e.is_dir()]

txts += [t for d in dirs for t in d.iterdir()]

print(f"Number of books in corpus {len(txts)} (but website says 26.344)")

pattern = r".*[dD]i[g|k]t.*|.*[lL]yrik.*|.*[Ss]alme.*|.*[Ss]ang.*"

poems = [t for t in txts if re.match(pattern, t.name)]

print(f"# of books where filename matches: {len(poems)}")

def get_publication_year_and_sort(poems):
    years_str = [poem.name.split("digibok")[1].split("-")[1] for poem in poems]
    y = [int(y) if y else 0 for y in years_str]
    
    name_y = list(zip((poem.name for poem in poems), y))
    name_y.sort(key=lambda x: x[1])
    
    return name_y

name_y = get_publication_year_and_sort(poems)
_, y = zip(*name_y) 

i = y.index(1900)
newer_books = name_y[i:]
print(f"# of books where filename matches and newer than 1900: {len(newer_books)}")

i = y.index(1930)
even_newer_books = name_y[i:]
print(f"# of books where filename matches and newer than 1930: {len(even_newer_books)}")
# Out:
# Number of books in corpus 21483 (but website says 26.344)
# # of books where filename matches: 593
# # of books where filename matches and newer than 1900: 181
# # of books where filename matches and newer than 1930: 57

# %% [markdown]
# ## Same but without unpacking corpus (tarfile)

# %%
import tarfile
import re

tar = tarfile.open('20150526_nbdig_txt01.tar.gz')

pattern = r".*[dD]i[g|k]t.*|.*[lL]yrik.*|.*[Ss]alme.*|.*[Ss]ang.*"

i = 0
j = 0

for file in tar:
    if file.isfile():
        j += 1
        if re.match(pattern, file.name):
            i += 1
            
print(f"Total number of files: {j}\nNumber of files that match with pattern {i}")
# Out:
# Total number of files: 21483
# Number of files that match with pattern 593

# %% [markdown]
# ## Find out how many of the 593 where the title matches (not filename)

# %%
import json 
import requests

def get_code(filename):
    return filename.split("_")[1].split("-")[0]

def get_metadata(codes):
    metadata = {}
    base_api = "https://api.nb.no/catalog/v1/items/URN:NBN:no-nb_digibok_"
    for code in codes:
        response = requests.get(base_api+code)
        j = response.json()
        metadata[code] = j["metadata"]
    return metadata

# # uncomment this to call api (commexnted out to not run unecessarily many times)
# codes = [get_code(poem.name) for poem in poems]
# metadata = get_metadata(codes)

# with open("metadata_593.json", "w+") as f:
#     json.dump(metadata, f)

# %%
import pandas as pd

def metadata_to_df(metadata):
    d = []
    for code, data in metadata.items():
        lang = data["languages"][0]["code"]
        year = int(data["originInfo"]["issued"])
        title = data["title"]
        
        data_code = data["identifiers"]["urn"].split("_")[-1]
        if code != data_code:
            print(f"Received code: {code}, metadata code: {data_code}")

        if "people" in data:
            author = data["people"][0]["name"]
        elif "statementOfResponsibility" in data:
            author = data["statementOfResponsibility"][0]
        d.append({"year": year, "author": author, "title": title, "filename code": code, "api code": data_code, "lang": lang})
    return pd.DataFrame(d)

with open("metadata_593.json") as f:
    metadata = json.load(f)

df_593 = metadata_to_df(metadata)
# Out:
# Received code: 2008042303004, metadata code: 2021120826007
# Received code: 2009013010001, metadata code: 2010050510003
# Received code: 2012011012011, metadata code: 2012011712004
# Received code: 2008102303002, metadata code: 2015071427011
# Received code: 2012011012013, metadata code: 2012011712005
# Received code: 2006111600061, metadata code: 2017011248051
# Received code: 2008010704054, metadata code: 2014102306006
# Received code: 2012101224024, metadata code: 2012101224027
# Received code: 2009040212006, metadata code: 2009040212008
# Received code: 2007121410004, metadata code: 2008040800024
# Received code: 2012030212009, metadata code: 2013032526002
# Received code: 2008071410004, metadata code: 2014071728003
# Received code: 2008071610001, metadata code: 2019120928001
# Received code: 2009051513004, metadata code: 2011032412001
# Received code: 2013050224034, metadata code: 2013050224102
# Received code: 2010040912003, metadata code: 2017020748579
# Received code: 2010041612002, metadata code: 2010041612003
# Received code: 2010040912004, metadata code: 2010041212002
# Received code: 2013050224027, metadata code: 2013050224104
# Received code: 2013052824002, metadata code: 2014080424009
# Received code: 2009032603016, metadata code: 2010060420012
# Received code: 2010040912002, metadata code: 2017030148004
# Received code: 2010011312016, metadata code: 2010011312017
# Received code: 2010051412002, metadata code: 2010060420002
# Received code: 2010011312007, metadata code: 2010011312008
# Received code: 2010042712002, metadata code: 2010042812001
# Received code: 2008121603021, metadata code: 2016111748604
# Received code: 2012051113007, metadata code: 2014031028002
# Received code: 2007082703002, metadata code: 2020022648153
# Received code: 2008061913007, metadata code: 2008061913008
# Received code: 2008060613027, metadata code: 2008060613028
# Received code: 2008061913009, metadata code: 2008061913011
# Received code: 2011012412003, metadata code: 2018062148507
# Received code: 2009072713006, metadata code: 2009072713007
# Received code: 2011110724021, metadata code: 2011110724022
# Received code: 2013040824027, metadata code: 2015111826003
# Received code: 2007073010003, metadata code: 2011041820007
# Received code: 2006120701085, metadata code: 2007080110001

# %%
df_593
# Out:
#      year                        author  \
# 0    1830      Guldberg, O. Høegh (Ove)
# 1    1869      Guldberg, O. Høegh (Ove)
# 2    1862              Barfod, Frederik
# 3    1856              Barfod, Frederik
# 4    1834  Grøndahl, Chr. (Christopher)
# ..    ...                           ...
# 588  1925                Grieg, Nordahl
# 589  1947                Grieg, Nordahl
# 590  1950                Grieg, Nordahl
# 591  1912             Munthe, Margrethe
# 592  1862                   Johnsen, J.
#
#                                                  title  filename code  \
# 0    Psalmebog, eller En Samling af gamle og nye Ps...  2010063003020
# 1                      Fra nordiske Digtere : et Album  2006112101006
# 2    Ingemanns Jordefærd : Taler, Digte og Bladarti...  2009090403002
# 3                             Guds Man : en Psalme-Bog  2006111600006
# 4    Evangelisk-christelig Psalmebog, tilligemed Co...  2008051403001
# ..                                                 ...            ...
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
# 592  En aandelig Sangbog for angerfulde, bodfærdige...  2010092803011
#
#           api code lang
# 0    2010063003020  dan
# 1    2006112101006  dan
# 2    2009090403002  dan
# 3    2006111600006  nob
# 4    2008051403001  dan
# ..             ...  ...
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
# 592  2010092803011  nob
#
# [593 rows x 6 columns]

# %% [markdown]
# ## Count files where where codes differ and compare titles

# %%
d1 = set(df_593["api code"]) - set(df_593["filename code"])
d2 = set(df_593["filename code"]) - set(df_593["api code"])
len(d1), len(d2)
# Out:
# (38, 38)

# %%
diff_code_poems = [e.name for e in poems if get_code(e.name) in d2]

poem_codes = [get_code(e) for e in diff_code_poems]
poem_titles = [" ".join(e.split("-")[5][:-4].split("_")) for e in diff_code_poems]
poem_authors = [e.split("-")[4] for e in diff_code_poems]

check1_df = pd.DataFrame({"title":poem_titles, "author":poem_authors, "filename code": poem_codes })
#check1_df

# %%
check2_df = df_593.loc[df_593["api code"].isin(d1)]
#check2_df

# %% [markdown]
# Looks like they are the same!

# %%
for (title1, title2 ) in zip(check1_df["title"], check2_df["title"]):
    print(f"{title1}\n{title2}\n")
# Out:
# Psalme Skat et Udvalg af gamle Psalmer uddrag
# Psalme-Skat : Et Udvalg af gamle Psalmer, uddraget af Kingos, Pontoppidans og Brorsons Samlinger
#
# En Ny Danske oc Norske fuldkommen Psalme Bog
# En Ny Danske oc Norske fuldkommen Psalme-Bog : hvor udi findis et Tusinde Psalmer oc Sange, hvilcke med største Flijd ere samlede af Mester Hans Thomesøns, samt alleandre fornemste gamle oc beste nye, tryckte Danske aandeligePsalme-Bøger
#
# Melodier til Sangene i Lesebog for Folkeskole
# Melodier til Sangene i Læsebog for Folkeskolen og Folkehjemmet : udsatte for Sopran, Alt og Bass, tilligemed en Tenor efter Behag, : for Skoler og Sangforeninger : 1. Skoletrin
#
# Evangelisk christelig Psalmebog tilligemed Co
# Evangelisk-christelig Psalmebog, tilligemed Collecter, Epistler og Evangelier, Vor Herres Jesu Christi Lidelses-Historie, Kirke- samt andre Bønner, til Brug ved Kirke- og Huus-Andagt
#
# Melodier til Sangene i Lesebog for Folkeskole
# Melodier til Sangene i Læsebog for Folkeskolen og Folkehjemmet : udsatte for Sopran, Alt og Bass, tilligemed en Tenor efter Behag, : for Skoler og Sangforeninger : 3. Skoletrin
#
# Oversigt over Kirkens Salmesang dens Historie
# Oversigt over Kirkens Salmesang, dens Historie og om Kirkesalmebøgerne i de nordiske Lande
#
# Utvalgte dikt
# Utvalgte dikt
#
# Udvalg af eldre danske Digteres Verker
# Udvalg af ældre danske Digteres Værker. 2 H. 1 : Holberg Den politiske Kandestøber ; Barselstuen
#
# Den heldige Beslutning en Sang paa veledle ho
# Den hældige Beslutning : en Sang paa velædle, høyfornemme Hr. Friderich Hvids og velædle, høyfornemme Mad. Maria Christine Olsens Bryllupsfest den 24de Februarii 1801
#
# Den store Freden dramatisk Dikt
# Den store Freden : dramatisk Dikt
#
# Taler og Sange i Aggershuus Slotskirke paa de
# Taler og Sange i Aggershuus Slotskirke paa den anordnede høitidelige Bededag, den 25. Februar 1814
#
# Sielens Sang Offer Gudelige Sange paa de forn
# Siælens Sang-Offer. Gudelige Sange paa de fornemste Fæster om Syndernis Forladelse, Fortrøstning paa Guds Naade, mod Fortviflelse, Utaalmodighed, og saa fremdelis: med Afften og Morgen-Sang i Tallet 42 Morgen og Afften-Suk til hver Dag i Ugen, slutted med en Morgen og Afften Bøn. Enfoldig ved Guds Naade sammensat aff den Der Er Dig Høye Himmel-Gud som sin Siælis Brudgom, all Ære og Tieneste Skyldig
#
# Dorothe Engelbrets Datters Aandelige Sang og
# Dorothe Engelbrets-Datters Aandelige Sang- og Taare-Offer
#
# Sielens Sang Offer Indeholdende Gudelige Sang
# Siælens Sang-Offer Indeholdende Gudelige Sange paa de Fornemste Fester, tillige med andre sær Himmelske Sange, saa og om Syndernis Forladelse og Fortrøstning paa Guds Naade Mod Fortuilelse og Utaalmodighed, Verdens Omskiftelse og de Fortrædeligis Tunger: Trøst mod Døden og Dommen, og Glæden for de Vdvalde effter dennem begge: Afften- og Morgen-Sange, i Talletd 37, Item Morgen- og Afften-Sucke
#
# Digte
# Digte
#
# Digte
# Digte
#
# Digte
# Digte
#
# Udvalgte digte
# Udvalgte digte
#
# Peer Gynt et dramatisk Digt
# Peer Gynt : et dramatisk Digt
#
# Brand et dramatisk Digt
# Brand : et dramatisk Digt
#
# Brand et dramatisk digt
# Brand : et dramatisk digt
#
# Digte
# Digte
#
# Sang ved Studenternes Hjemkomst fra Modet i K
# Sang ved Studenternes Hjemkomst fra Mödet i Kjöbenhavn : den 22de Juni 1862
#
# Brand et dramatisk digt
# Brand : et dramatisk digt
#
# Fanesang
# Fanesang
#
# Digte
# Digte
#
# Sorg og Trost nogle Digte
# Sorg og Trøst : nogle Digte
#
# Nor et Digt
# Nor : et Digt
#
# Jens Zetlitz s samlede Digte
# Jens Zetlitz's samlede Digte : 1ste Deel
#
# Sang foredragen af Bergens Sangforeninger ved
# Sang : foredragen af Bergens Sangforeninger ved den Koncert, Ole Bull og Sangforeningerne gav til Eidsvoldsmanden Christies Monument den 17de Mai 1859
#
# Studenternes sang ved professor C Hansteens b
# Studenternes sang ved professor C. Hansteens båre i universitetets hal den 21de april 1873
#
# Ved Kong Oscars Dod Sang Prolog i Det norske
# Ved Kong Oscars Død : Sang-Prolog i "Det norske Theater" den 24de Juli 1859
#
# Sange og stemninger
# Sange og stemninger
#
# Peder Dass s Levnetslob i en Sang tilegnet ha
# Peder Dass's Levnetsløb : i en Sang, tilegnet hans kjære Menighed : [Min' elskelig' Tilhører' ...]
#
# Emilias Kilde et Digt
# Emilias Kilde : Et Digt
#
# Digte forste Ring
# Digte : Første Ring
#
# Menneskesonnen et digt
# Menneskesønnen : et digt
#
# Ildprofeten et episk digt
# Ildprofeten : et episk digt

# %% [markdown]
# ## Only match on title instead of filename
# 6 books were not match on title, but on author name

# %%
actual_poems = [t for t in df_593["title"] if re.match(pattern, t)]

# %%
df_ = df_593.loc[df_593["title"].isin(actual_poems)]
df_
# Out:
#      year                        author  \
# 0    1830      Guldberg, O. Høegh (Ove)
# 1    1869      Guldberg, O. Høegh (Ove)
# 2    1862              Barfod, Frederik
# 3    1856              Barfod, Frederik
# 4    1834  Grøndahl, Chr. (Christopher)
# ..    ...                           ...
# 588  1925                Grieg, Nordahl
# 589  1947                Grieg, Nordahl
# 590  1950                Grieg, Nordahl
# 591  1912             Munthe, Margrethe
# 592  1862                   Johnsen, J.
#
#                                                  title  filename code  \
# 0    Psalmebog, eller En Samling af gamle og nye Ps...  2010063003020
# 1                      Fra nordiske Digtere : et Album  2006112101006
# 2    Ingemanns Jordefærd : Taler, Digte og Bladarti...  2009090403002
# 3                             Guds Man : en Psalme-Bog  2006111600006
# 4    Evangelisk-christelig Psalmebog, tilligemed Co...  2008051403001
# ..                                                 ...            ...
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
# 592  En aandelig Sangbog for angerfulde, bodfærdige...  2010092803011
#
#           api code lang
# 0    2010063003020  dan
# 1    2006112101006  dan
# 2    2009090403002  dan
# 3    2006111600006  nob
# 4    2008051403001  dan
# ..             ...  ...
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
# 592  2010092803011  nob
#
# [587 rows x 6 columns]

# %% [markdown]
# ## Delete unwanted files

# %%
files_to_delete = df_593.loc[~df_593["title"].isin(actual_poems)]
files_to_delete
# Out:
#      year                  author  \
# 17   1860          Ahnfelt, Oscar
# 37   1786  Bach, Johann Sebastian
# 41   1814            Sohm, Peter.
# 256  1861  Runeberg, Johan Ludvig
# 512  1966           Jøsang, Ottar
# 548  1814   Valerius, Johan David
#
#                                                  title  filename code  \
# 17    Melodierna i sifferskrift till "Andeliga sånger"  2009101303013
# 37   Vierstimmige alte und neue Choralgesänge mit P...  2012012424002
# 41   Sång på Årsdagen af Bataillen vid Leipzig, den...  2013062726004
# 256                            Julqvällen : tre sånger  2009090203012
# 512  Geologiske og petrografiske undersøkelser i Mo...  2007042001008
# 548                                     Förenings-sång  2011112224037
#
#           api code lang
# 17   2009101303013  swe
# 37   2012012424002  ger
# 41   2013062726004  swe
# 256  2009090203012  swe
# 512  2007042001008  nob
# 548  2011112224037  mul

# %%
p = Path("old/dikt-idetfri/")
n = Path("old/not_poetry/")
l = list(files_to_delete["filename code"])
for f in p.iterdir():
    code = get_code(f.name)
    if code in l:
        f.rename(n / f.name)
print(len(list(p.iterdir())))
# Out:
# 587

# %% [markdown]
# ## Remove poems that are not Norwegian by filename

# %% [markdown]
# Of the 593 poems selected on filename, 452 of them have "nob", "nno" or "nor" in the filename.
# That means 141 are in different languages. However several of these are danish in the dataframe!

# %%
langs = [(e.name, e.name.split("-")[2]) for e in poems]
norw = [(name, lang) for name, lang in langs if lang in ("nob", "nno", "nor")]
len(norw)
# Out:
# 452

# %%
norw_codes = [get_code(name) for name, lang in norw]
norw_df = df_593.loc[df_593["filename code"].isin(norw_codes)]
norw_df
# Out:
#      year                        author  \
# 0    1830      Guldberg, O. Høegh (Ove)
# 3    1856              Barfod, Frederik
# 4    1834  Grøndahl, Chr. (Christopher)
# 5    1852          Fearnley, Henry Emil
# 6    1852             Hauge, A. Andreas
# ..    ...                           ...
# 588  1925                Grieg, Nordahl
# 589  1947                Grieg, Nordahl
# 590  1950                Grieg, Nordahl
# 591  1912             Munthe, Margrethe
# 592  1862                   Johnsen, J.
#
#                                                  title  filename code  \
# 0    Psalmebog, eller En Samling af gamle og nye Ps...  2010063003020
# 3                             Guds Man : en Psalme-Bog  2006111600006
# 4    Evangelisk-christelig Psalmebog, tilligemed Co...  2008051403001
# 5    Smaadigte til Udenadslæsning : til Brug ved de...  2010031003059
# 6    100 Missions-Psalmer ; med et Tillæg, indehold...  2006111400042
# ..                                                 ...            ...
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
# 592  En aandelig Sangbog for angerfulde, bodfærdige...  2010092803011
#
#           api code lang
# 0    2010063003020  dan
# 3    2006111600006  nob
# 4    2008051403001  dan
# 5    2010031003059  nob
# 6    2006111400042  nob
# ..             ...  ...
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
# 592  2010092803011  nob
#
# [452 rows x 6 columns]

# %% [markdown]
# If we also remove the ones that dont have a title match we get 451 books

# %%
norw_df = df_.loc[df_["filename code"].isin(norw_codes)]
norw_df
# Out:
#      year                        author  \
# 0    1830      Guldberg, O. Høegh (Ove)
# 3    1856              Barfod, Frederik
# 4    1834  Grøndahl, Chr. (Christopher)
# 5    1852          Fearnley, Henry Emil
# 6    1852             Hauge, A. Andreas
# ..    ...                           ...
# 588  1925                Grieg, Nordahl
# 589  1947                Grieg, Nordahl
# 590  1950                Grieg, Nordahl
# 591  1912             Munthe, Margrethe
# 592  1862                   Johnsen, J.
#
#                                                  title  filename code  \
# 0    Psalmebog, eller En Samling af gamle og nye Ps...  2010063003020
# 3                             Guds Man : en Psalme-Bog  2006111600006
# 4    Evangelisk-christelig Psalmebog, tilligemed Co...  2008051403001
# 5    Smaadigte til Udenadslæsning : til Brug ved de...  2010031003059
# 6    100 Missions-Psalmer ; med et Tillæg, indehold...  2006111400042
# ..                                                 ...            ...
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
# 592  En aandelig Sangbog for angerfulde, bodfærdige...  2010092803011
#
#           api code lang
# 0    2010063003020  dan
# 3    2006111600006  nob
# 4    2008051403001  dan
# 5    2010031003059  nob
# 6    2006111400042  nob
# ..             ...  ...
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
# 592  2010092803011  nob
#
# [451 rows x 6 columns]

# %% [markdown]
# Removing all books that are not listed as nob, nno, nor in metadata info. These are 46 books

# %%
not_norw = norw_df.loc[~norw_df["lang"].isin(("nob", "nno", "nor"))]
print(len(not_norw))
not_norw
# Out:
# 46
#      year                               author  \
# 0    1830             Guldberg, O. Høegh (Ove)
# 4    1834         Grøndahl, Chr. (Christopher)
# 8    1903                         Collin, Chr.
# 9    1922                      Hægstad, Marius
# 12   1843              Cappelen, Jørgen Wright
# 14   1834                        Kingo, Thomas
# 34   1796                        Madsen, Johan
# 49   1848              Cappelen, Jørgen Wright
# 50   1799                 Brorson, Hans Adolph
# 55   1844              Cappelen, Jørgen Wright
# 71   1845             Dahl, Chr. (Christopher)
# 82   1850                       Koren, Vilhelm
# 94   1883  Lindeman, Ludv. M. (Ludvig Mathias)
# 110  1848                    Heyerdahl, Halvor
# 117  1845     Welhaven, J.S. (Johan Sebastian)
# 128  1807                    Bonnevie, Andreas
# 154  1848                       Winsnes, Hanna
# 165  1816                Olsen, Andreas Schram
# 196  1801                    Schmidt, Frederik
# 201  1898                         Monrad, M.J.
# 241  1814                Wichne, Arne Erichsen
# 242  1814                        Pavels, Claus
# 243  1801                        Pavels, Claus
# 246  1845                 Wessel, Johan Herman
# 247  1801                  Heber, Carl Vilhelm
# 306  1816                      Hansen, Maurits
# 307  1825                      Hansen, Maurits
# 316  1891                     Hougen, Engebret
# 319  1847                       Kokk, Bernhard
# 329  1848                       Bion Smyrnaeus
# 346  1835                         Foss, Herman
# 358  1915                 Baumann, Julius Berg
# 376  1795                        Zetlitz, Jens
# 378  1795                        Zetlitz, Jens
# 423  1849            Andresen, Peter Rasmussen
# 431  1796                  Brun, Johan Nordahl
# 439  1956                         Dass, Petter
# 442  1736                         Dass, Petter
# 461  1897                        Jaastad, Lars
# 481  1851                       Harboe, Ludvig
# 498  1897                            Lie, John
# 510  1801                     Wulfsberg, Niels
# 522  1845                    Wergeland, Henrik
# 523  1846                    Wergeland, Henrik
# 526  1829                    Wergeland, Henrik
# 550  1864       Vinje, A.O. (Aasmund Olavsson)
#
#                                                  title  filename code  \
# 0    Psalmebog, eller En Samling af gamle og nye Ps...  2010063003020
# 4    Evangelisk-christelig Psalmebog, tilligemed Co...  2008051403001
# 8                              Engelske digte og sange  2012052505023
# 9                            Norsk diktning efter 1814  2006120101048
# 12   Evangelisk-christelig Psalmebog, tilligemed Co...  2008102303005
# 14   Psalme-Skat : Et Udvalg af gamle Psalmer, uddr...  2008042303004
# 34   Zions Chor-Sange mod Verdens Synge-Chor. Der e...  2009031610002
# 49   Evangelisk-christelig Psalmebog, tilligemed Co...  2008102303002
# 50   De Sande Christnes udvalgte Psalmebog, uddrage...  2009030610001
# 55   Evangelisk-christelig Psalmebog, tilligemed Co...  2008102303001
# 71                           Det Svundne Aar : Et Digt  2011081913004
# 82   Digte til Udenadlæsning, til Brug for Skolerne...  2008071700087
# 94   Koralbog : indeholdende de i Landstads Salmebo...  2012011012001
# 110                 Historiske Sange fra Norges Fortid  2010020103018
# 117                                        Nyere Digte  2010100608041
# 128               Krigs-Sang for Kronprinsens Livcorps  2012071113009
# 154                                         Smaa-Digte  2009111912011
# 165                                Digte : Første Deel  2011050308007
# 196            Sang for de danske og norske Søekrigere  2012071213004
# 201                                   Efterladte Digte  2008042812014
# 241                                      Normands-Sang  2008100110004
# 242  Taler og Sange i Aggershuus Slotskirke paa den...  2012030212009
# 243                                         Borgersang  2012071213001
# 246  Samlede digte af Johan Herman Wessel. Udgivne ...  2012070608276
# 247  Sang for danske Søemænd : af C. Heber, resider...  2012071113010
# 306                                         Digtninger  2011050308010
# 307                            Digtninger : Anden Deel  2007082703001
# 316                                              Digte  2006112401018
# 319                                              Digte  2007052210005
# 329                                    Idylliske Digte  2011050308009
# 346                   Tidsnornerne : Et Leilighedsdigt  2009061912002
# 358                           Fra vidderne : nye digte  2006120500055
# 376                   Sange for den norske Bonde-Stand  2012012813002
# 378                                            Psalmer  2009032710003
# 423  Bibelske Krønike-Riim, eller historiske Psalme...  2010042703061
# 431                      Jonathan : Et Digt i ti Sange  2009040112004
# 439    Herrens bøn, Fader vor : forfattet udi ni sange  2011121308005
# 442  En skiøn Aandelig Psalme : uddragen af Det syv...  2009072713011
# 461                                  Til Fjells : Dikt  2008040200055
# 481  Psalmebog, eller En Samling af gamle og nye Ps...  2008091503018
# 498                                   Aarolilja : Dikt  2006112300054
# 510                    Sang for Kronprindsens Livcorps  2012071213005
# 522                                Mennesket : Et Digt  2009091403003
# 523                             Udvalgte lyriske Digte  2012070608265
# 526                                Digte : Første Ring  2013040824027
# 550                                        Diktsamling  2009071303002
#
#           api code lang
# 0    2010063003020  dan
# 4    2008051403001  dan
# 8    2012052505023  mul
# 9    2006120101048  mul
# 12   2008102303005  dan
# 14   2021120826007  dan
# 34   2009031610002  dan
# 49   2015071427011  dan
# 50   2009030610001  dan
# 55   2008102303001  dan
# 71   2011081913004  dan
# 82   2008071700087  dan
# 94   2012011012001  mul
# 110  2010020103018  dan
# 117  2010100608041  dan
# 128  2012071113009  dan
# 154  2009111912011  dan
# 165  2011050308007  dan
# 196  2012071213004  dan
# 201  2008042812014  mul
# 241  2008100110004  dan
# 242  2013032526002  dan
# 243  2012071213001  dan
# 246  2012070608276  dan
# 247  2012071113010  dan
# 306  2011050308010  dan
# 307  2007082703001  dan
# 316  2006112401018  mul
# 319  2007052210005  dan
# 329  2011050308009  dan
# 346  2009061912002  dan
# 358  2006120500055  mul
# 376  2012012813002  dan
# 378  2009032710003  dan
# 423  2010042703061  dan
# 431  2009040112004  dan
# 439  2011121308005  mul
# 442  2009072713011  dan
# 461  2008040200055  mul
# 481  2008091503018  dan
# 498  2006112300054  mul
# 510  2012071213005  dan
# 522  2009091403003  dan
# 523  2012070608265  dan
# 526  2015111826003  dan
# 550  2009071303002  mul

# %% [markdown]
# In the end, selecting by filename first, and then by language, yields 405 books

# %%
small_norw = norw_df.loc[norw_df["lang"].isin(("nob", "nno", "nor"))]
small_norw
# Out:
#      year                author  \
# 3    1856      Barfod, Frederik
# 5    1852  Fearnley, Henry Emil
# 6    1852     Hauge, A. Andreas
# 10   1863       Hægstad, Marius
# 13   1898         Skard, Matias
# ..    ...                   ...
# 588  1925        Grieg, Nordahl
# 589  1947        Grieg, Nordahl
# 590  1950        Grieg, Nordahl
# 591  1912     Munthe, Margrethe
# 592  1862           Johnsen, J.
#
#                                                  title  filename code  \
# 3                             Guds Man : en Psalme-Bog  2006111600006
# 5    Smaadigte til Udenadslæsning : til Brug ved de...  2010031003059
# 6    100 Missions-Psalmer ; med et Tillæg, indehold...  2006111400042
# 10   Evangelisk-christelig Psalmebog : tilligemed C...  2008121003001
# 13   Norsk Digtning efter 1814 : et Udvalg til Brug...  2010081103001
# ..                                                 ...            ...
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
# 592  En aandelig Sangbog for angerfulde, bodfærdige...  2010092803011
#
#           api code lang
# 3    2006111600006  nob
# 5    2010031003059  nob
# 6    2006111400042  nob
# 10   2008121003001  nob
# 13   2010081103001  nob
# ..             ...  ...
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
# 592  2010092803011  nob
#
# [405 rows x 6 columns]

# %% [markdown]
# But only using language in df_ from the beginning yields 414!
# This means that 9 of the books that were removed based on filename were actually Norwegian according to the API?

# %%
bigger_norw = df_.loc[df_["lang"].isin(("nob", "nno", "nor"))]
bigger_norw
# Out:
#      year                author  \
# 3    1856      Barfod, Frederik
# 5    1852  Fearnley, Henry Emil
# 6    1852     Hauge, A. Andreas
# 10   1863       Hægstad, Marius
# 13   1898         Skard, Matias
# ..    ...                   ...
# 588  1925        Grieg, Nordahl
# 589  1947        Grieg, Nordahl
# 590  1950        Grieg, Nordahl
# 591  1912     Munthe, Margrethe
# 592  1862           Johnsen, J.
#
#                                                  title  filename code  \
# 3                             Guds Man : en Psalme-Bog  2006111600006
# 5    Smaadigte til Udenadslæsning : til Brug ved de...  2010031003059
# 6    100 Missions-Psalmer ; med et Tillæg, indehold...  2006111400042
# 10   Evangelisk-christelig Psalmebog : tilligemed C...  2008121003001
# 13   Norsk Digtning efter 1814 : et Udvalg til Brug...  2010081103001
# ..                                                 ...            ...
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
# 592  En aandelig Sangbog for angerfulde, bodfærdige...  2010092803011
#
#           api code lang
# 3    2006111600006  nob
# 5    2010031003059  nob
# 6    2006111400042  nob
# 10   2008121003001  nob
# 13   2010081103001  nob
# ..             ...  ...
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
# 592  2010092803011  nob
#
# [414 rows x 6 columns]

# %%
# av de i bigger, hvilke er ikke i smaller?
diff_codes = set(bigger_norw["filename code"]) - set(small_norw["filename code"])

# %%
code_names = [(get_code(e.name), e.name) for e in poems if get_code(e.name) in diff_codes]    
code_names
# Out:
# [('2008100603009',
#   'digibok_2008100603009-1851-und-946--Psalmernes_Bog_oversat_efter_Foranstaltning_a.txt'),
#  ('2009041603027',
#   'digibok_2009041603027-1898-und-891--Udvalgte_digte_for_middelskolen_og_gymnasiet_.txt'),
#  ('2011060804031',
#   'digibok_2011060804031-1922-und-743-Lindeman_Ludv_M_-Koralbog_indeholdende_de_i_Landstads_Salmebog.txt'),
#  ('2006112000053',
#   'digibok_2006112000053-1905-mul-955-Lassen_Helene-Selma_Lagerlof_og_hendes_digtning_.txt'),
#  ('2009080603025',
#   'digibok_2009080603025-1862-und-948-Sinding_Otto-Skovstjerner_en_liden_Digtsamling.txt'),
#  ('2013081206032',
#   'digibok_2013081206032-1921-und-917-Bull_Jacob_B_-Digte_.txt'),
#  ('2008032702005',
#   'digibok_2008032702005-1928-und-462-Backe_Stein-Gamle_tufter_dikt.txt'),
#  ('2008040404048',
#   'digibok_2008040404048-1912-und-970-Eskeland_Lars-Stykke_til_diktat_og_attforteljing_samla_og_t.txt'),
#  ('2012071208112',
#   'digibok_2012071208112-1911-und-882-Janson_Kristofer-Digte_utgivne_paa_hans_syttiaarige_fodselsdag.txt')]

# %%
keep_df = bigger_norw
keep_df
# Out:
#      year                author  \
# 3    1856      Barfod, Frederik
# 5    1852  Fearnley, Henry Emil
# 6    1852     Hauge, A. Andreas
# 10   1863       Hægstad, Marius
# 13   1898         Skard, Matias
# ..    ...                   ...
# 588  1925        Grieg, Nordahl
# 589  1947        Grieg, Nordahl
# 590  1950        Grieg, Nordahl
# 591  1912     Munthe, Margrethe
# 592  1862           Johnsen, J.
#
#                                                  title  filename code  \
# 3                             Guds Man : en Psalme-Bog  2006111600006
# 5    Smaadigte til Udenadslæsning : til Brug ved de...  2010031003059
# 6    100 Missions-Psalmer ; med et Tillæg, indehold...  2006111400042
# 10   Evangelisk-christelig Psalmebog : tilligemed C...  2008121003001
# 13   Norsk Digtning efter 1814 : et Udvalg til Brug...  2010081103001
# ..                                                 ...            ...
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
# 592  En aandelig Sangbog for angerfulde, bodfærdige...  2010092803011
#
#           api code lang
# 3    2006111600006  nob
# 5    2010031003059  nob
# 6    2006111400042  nob
# 10   2008121003001  nob
# 13   2010081103001  nob
# ..             ...  ...
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
# 592  2010092803011  nob
#
# [414 rows x 6 columns]

# %%
import numpy as np

years = [int(year) for year in keep_df["year"]]

def print_year_statistics(years):
    print(f"""
    Median: {np.median(years)}
    Mean: {np.mean(years)}
    Max: {np.max(years)}
    Min: {np.min(years)}
    # of books: {len(years)}
    """)

print_year_statistics(years)
# Out:
#     Median: 1890.0
#     Mean: 1886.9468599033817
#     Max: 2005
#     Min: 1790
#     # of books: 414

# %% [markdown]
# ## Delete unwanted files

# %%
files_to_delete = df_.loc[~df_["lang"].isin(("nob", "nno", "nor"))]
len(files_to_delete)
# Out:
# 173

# %%
print(len(list(p.iterdir())))
p = Path("old/dikt-idetfri/")
n = Path("old/not_norwegian/")
l = list(files_to_delete["filename code"])
for f in p.iterdir():
    code = get_code(f.name)
    if code in l:
        f.rename(n / f.name)
print(len(list(p.iterdir())))
# Out:
# 587
# 414

# %% [markdown]
# ## Count language distribution

# %%
def print_count_lang_dist(df):

    nob = df.loc[df["lang"] == "nob"]
    nno = df.loc[df["lang"] == "nno"]
    nor = df.loc[df["lang"] == "nor"]

    print(f"""
    Number of bokmål files {len(nob)}\tor {len(nob)/len(df)*100}%
    Number of nynorsk files {len(nno)}\tor {len(nno)/len(df)*100}%
    Number of norsk files {len(nor)}\tor {len(nor)/len(df)*100}%

    """)
    
print_count_lang_dist(keep_df)
# Out:
#     Number of bokmål files 380	or 91.78743961352657%
#     Number of nynorsk files 30	or 7.246376811594203%
#     Number of norsk files 4	or 0.966183574879227%

# %% [markdown]
# ## Get metadata for first batch
# This batch was selected by Språkbanken. Because we got it before we had sorted out irrelevant books the number of received book is higher than we use in our data set.

# %%
p = Path("old/ny-ocr-dikt-idetfri/")

codes = [e.name[:-4] for e in p.iterdir()]
print(len(codes))

fb_df = keep_df.loc[keep_df["filename code"].isin(codes)]
fb_df
# Out:
# 265
#      year                author  \
# 3    1856      Barfod, Frederik
# 5    1852  Fearnley, Henry Emil
# 6    1852     Hauge, A. Andreas
# 10   1863       Hægstad, Marius
# 13   1898         Skard, Matias
# ..    ...                   ...
# 575  1894         Nilsen, Karen
# 576  1859       Sundt, Johan L.
# 579  1866              Blom, P.
# 581  1854           Bentsen, H.
# 592  1862           Johnsen, J.
#
#                                                  title  filename code  \
# 3                             Guds Man : en Psalme-Bog  2006111600006
# 5    Smaadigte til Udenadslæsning : til Brug ved de...  2010031003059
# 6    100 Missions-Psalmer ; med et Tillæg, indehold...  2006111400042
# 10   Evangelisk-christelig Psalmebog : tilligemed C...  2008121003001
# 13   Norsk Digtning efter 1814 : et Udvalg til Brug...  2010081103001
# ..                                                 ...            ...
# 575           Gransus : nye Digte til beslægtede Sjæle  2013061308130
# 576                  Christkirken i Nidaros : digtning  2009082103026
# 579  Aandeligt Strengespil : en Samling Sange, Sukk...  2009090203007
# 581                Lyriske Smaadigte : en Prøvesamling  2009021812003
# 592  En aandelig Sangbog for angerfulde, bodfærdige...  2010092803011
#
#           api code lang
# 3    2006111600006  nob
# 5    2010031003059  nob
# 6    2006111400042  nob
# 10   2008121003001  nob
# 13   2010081103001  nob
# ..             ...  ...
# 575  2013061308130  nob
# 576  2009082103026  nob
# 579  2009090203007  nob
# 581  2009021812003  nob
# 592  2010092803011  nob
#
# [193 rows x 6 columns]

# %%
years = [int(year) for year in fb_df["year"]]
print_year_statistics(years)
# Out:
#     Median: 1875.0
#     Mean: 1875.2072538860104
#     Max: 1905
#     Min: 1814
#     # of books: 193

# %% [markdown]
# ## Delete unwanted files
# (We received re-ocr on some files we didn't need)

# %%
diff_ = set(codes) - set(fb_df["filename code"])
print(f"We received {len(diff_)} books we didn't need")

diff_df = df_593.loc[df_593["filename code"].isin(diff_)]
diff_df
# Out:
# We received 72 books we didn't need (and one is missing from the df)
# 72
#      year                        author  \
# 0    1830      Guldberg, O. Høegh (Ove)
# 1    1869      Guldberg, O. Høegh (Ove)
# 2    1862              Barfod, Frederik
# 4    1834  Grøndahl, Chr. (Christopher)
# 12   1843       Cappelen, Jørgen Wright
# ..    ...                           ...
# 539  1862          Wessel, Johan Herman
# 544  1855              Staffeldt, A. W.
# 549  1862                   Ploug, Carl
# 556  1867              Bergsøe, Vilhelm
# 585  1886             Ermoldus Nigellus
#
#                                                  title  filename code  \
# 0    Psalmebog, eller En Samling af gamle og nye Ps...  2010063003020
# 1                      Fra nordiske Digtere : et Album  2006112101006
# 2    Ingemanns Jordefærd : Taler, Digte og Bladarti...  2009090403002
# 4    Evangelisk-christelig Psalmebog, tilligemed Co...  2008051403001
# 12   Evangelisk-christelig Psalmebog, tilligemed Co...  2008102303005
# ..                                                 ...            ...
# 539                         J.H. Wessels samlede Digte  2009092103009
# 544                                              Digte  2010021003005
# 549                                      Samlede Digte  2009080703029
# 556                                 I Ny og Næ : Digte  2009080703028
# 585       Ermoldus Nigellus' Digt om kong Haralds Daab  2006112401026
#
#           api code lang
# 0    2010063003020  dan
# 1    2006112101006  dan
# 2    2009090403002  dan
# 4    2008051403001  dan
# 12   2008102303005  dan
# ..             ...  ...
# 539  2009092103009  dan
# 544  2010021003005  dan
# 549  2009080703029  dan
# 556  2009080703028  dan
# 585  2006112401026  dan
#
# [72 rows x 6 columns]

# %%
p = Path("old/ny-ocr-dikt-idetfri/")
n = Path("old/ny-ocr-neitakk/")

print(len(list(p.iterdir())))
for f in p.iterdir():
    code = f.name[:-4]
    if code in diff_:
        f.rename(n / f.name)
print(len(list(p.iterdir())))
# Out:
# 265
# 193

# %% [markdown]
# ## Sort on years and get all after 1900
# Selecting books for batch 2 of re-OCR

# %%
after_1900 = keep_df.loc[keep_df["year"] >= 1900]
after_1900
# Out:
#      year                                             author  \
# 30   1920                                     Klewe, Andreas
# 36   1900                                       Brun, Yngvar
# 46   1914  udgivet af Den Internasjonale bibelstudieforening
# 65   1901                                    Aarrestad, Sven
# 68   1906    udgivne af Kirke- og undervisningsdepartementet
# ..    ...                                                ...
# 587  1946                                     Grieg, Nordahl
# 588  1925                                     Grieg, Nordahl
# 589  1947                                     Grieg, Nordahl
# 590  1950                                     Grieg, Nordahl
# 591  1912                                  Munthe, Margrethe
#
#                                                  title  filename code  \
# 30   Religiøse korsange for sopran, alt, tenor og b...  2012052908151
# 36                                  Europæisk Digtning  2010070206172
# 46                                Norsk daggry-sangbog  2011051212004
# 65                       Sangbog for afholdsforeninger  2012051612001
# 68                                     Fædrelandssange  2006120101031
# ..                                                 ...            ...
# 587                                       Håbet : dikt  2013012806125
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
#
#           api code lang
# 30   2012052908151  nob
# 36   2010070206172  nob
# 46   2011051212004  nob
# 65   2012051612001  nob
# 68   2006120101031  nob
# ..             ...  ...
# 587  2013012806125  nob
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
#
# [165 rows x 6 columns]

# %% [markdown]
# ## Count language distribution pre- and post-1900

# %%
before_1900 = keep_df.loc[keep_df["year"] < 1900]

print("AFTER 1900")
print_count_lang_dist(after_1900)

print("BEFORE 1900")
print_count_lang_dist(before_1900)
# Out:
# AFTER 1900
#
#     Number of bokmål files 138	or 83.63636363636363%
#     Number of nynorsk files 27	or 16.363636363636363%
#     Number of norsk files 0	or 0.0%
#
#
# BEFORE 1900
#
#     Number of bokmål files 242	or 97.18875502008032%
#     Number of nynorsk files 3	or 1.2048192771084338%
#     Number of norsk files 4	or 1.6064257028112447%

# %% [markdown]
# ## Subtract the ones we already have

# %%
we_need = after_1900.loc[~after_1900["filename code"].isin(fb_df["filename code"])]
print(f"Of the {len(after_1900)} books we want, we already have {len(after_1900)-len(we_need)}")
we_need
# Out:
# Of the 165 books we want, we already have 17
#      year                                             author  \
# 30   1920                                     Klewe, Andreas
# 46   1914  udgivet af Den Internasjonale bibelstudieforening
# 68   1906    udgivne af Kirke- og undervisningsdepartementet
# 79   1925                                     Støylen, Bernt
# 84   1931                                     Luther, Martin
# ..    ...                                                ...
# 587  1946                                     Grieg, Nordahl
# 588  1925                                     Grieg, Nordahl
# 589  1947                                     Grieg, Nordahl
# 590  1950                                     Grieg, Nordahl
# 591  1912                                  Munthe, Margrethe
#
#                                                  title  filename code  \
# 30   Religiøse korsange for sopran, alt, tenor og b...  2012052908151
# 46                                Norsk daggry-sangbog  2011051212004
# 68                                     Fædrelandssange  2006120101031
# 79       Nynorsk salmebok : for kyrkja og heim og møte  2010102606030
# 84   Luthers lille katekisme med bibelord og salmevers  2009013000065
# ..                                                 ...            ...
# 587                                       Håbet : dikt  2013012806125
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
#
#           api code lang
# 30   2012052908151  nob
# 46   2011051212004  nob
# 68   2006120101031  nob
# 79   2010102606030  nno
# 84   2009013000065  nob
# ..             ...  ...
# 587  2013012806125  nob
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
#
# [148 rows x 6 columns]

# %%
years = we_need["year"]
print_year_statistics(years)
# Out:
#     Median: 1920.5
#     Mean: 1926.1756756756756
#     Max: 2005
#     Min: 1900
#     # of books: 148

# %% [markdown]
# ## Check diff we_need and actually received re-OCR
# We received 138 of the books we wanted

# %%
from pathlib import Path

p = Path("reocr_hocr/digibok/")
rec_codes = [e.name.split("_")[1] for e in p.iterdir()]

pp = Path("reocr_hocr_batch_2/")
rec_codes_2 = set([e.name.split("_")[1] for e in pp.iterdir()])
rec_codes += list(rec_codes_2)
rec_codes = set(rec_codes)

rec_df = we_need.loc[we_need["filename code"].isin(rec_codes)]
print(f"Of the {len(we_need)} books published after 1900, we got {len(rec_df)}, meaning we miss {len(we_need)-len(rec_df)}.")
rec_df
# Out:
# Of the 148 books published after 1900, we got 138, meaning we miss 10.
#      year                                             author  \
# 46   1914  udgivet af Den Internasjonale bibelstudieforening
# 79   1925                                     Støylen, Bernt
# 84   1931                                     Luther, Martin
# 87   1914                                     Jansen, Henrik
# 91   1926                                     Støylen, Bernt
# ..    ...                                                ...
# 587  1946                                     Grieg, Nordahl
# 588  1925                                     Grieg, Nordahl
# 589  1947                                     Grieg, Nordahl
# 590  1950                                     Grieg, Nordahl
# 591  1912                                  Munthe, Margrethe
#
#                                                  title  filename code  \
# 46                                Norsk daggry-sangbog  2011051212004
# 79       Nynorsk salmebok : for kyrkja og heim og møte  2010102606030
# 84   Luthers lille katekisme med bibelord og salmevers  2009013000065
# 87                            Bergen 1814-1914 : digte  2012022212004
# 91                      Utgreiding um nynorsk salmebok  2008022704011
# ..                                                 ...            ...
# 587                                       Håbet : dikt  2013012806125
# 588                           Stene i strømmen : digte  2013070308043
# 589                                       Samlede dikt  2012082408040
# 590                                       Samlede dikt  2011102708060
# 591  Aase fiskerpike : eventyrkomedie med sange til...  2013073008139
#
#           api code lang
# 46   2011051212004  nob
# 79   2010102606030  nno
# 84   2009013000065  nob
# 87   2012022212004  nob
# 91   2008022704011  nno
# ..             ...  ...
# 587  2013012806125  nob
# 588  2013070308043  nob
# 589  2012082408040  nob
# 590  2011102708060  nob
# 591  2013073008139  nob
#
# [138 rows x 6 columns]

# %%
rec_df.to_csv("batch2_info.tsv", sep="\t")

# %%
diff =  set(rec_codes) - set(rec_df["filename code"])
print(f"We got {len(diff)} books that we didn't need. (and one is missing from the df (??))")

diff_df = df_593.loc[df_593["filename code"].isin(diff)]
print(len(diff_df))
diff_df
# Out:
# We got 18 books that we didn't need. (and one is missing from the df (??))
# 17
#      year                       author  \
# 8    1903                 Collin, Chr.
# 9    1922              Hægstad, Marius
# 183  1946                  Aasen, Ivar
# 323  1911                    Munch, A.
# 338  1907            Nyrop, Kristoffer
# 339  1909            Nyrop, Kristoffer
# 340  1908            Nyrop, Kristoffer
# 358  1915         Baumann, Julius Berg
# 360  1922         Oehlenschläger, Adam
# 424  1957  Jacobsen, J.P. (Jens Peter)
# 439  1956                 Dass, Petter
# 468  1911            Drachmann, Holger
# 469  1913            Drachmann, Holger
# 484  1900               Landstad, M.B.
# 511  1910      Bratager, Laura Ringdal
# 540  1928         Wessel, Johan Herman
# 580  1907           Selmer, Ågot Gjems
#
#                                                  title  filename code  \
# 8                              Engelske digte og sange  2012052505023
# 9                            Norsk diktning efter 1814  2006120101048
# 183                                            Dikting  2010061806033
# 323  Kongedatterens Brudefart : et Digt i tolv Roma...  2008040704116
# 338          Fortids sagn og sange. 2 : Den evige jøde  2010070205055
# 339  Fortids sagn og sange. 5 : Grevinden med de 36...  2011050604018
# 340        Fortids sagn og sange. 3 : Sangerens hjerte  2010052806041
# 358                           Fra vidderne : nye digte  2006120500055
# 360                                     Udvalgte Digte  2008040904047
# 424                                      Dikt i utvalg  2007060701064
# 439    Herrens bøn, Fader vor : forfattet udi ni sange  2011121308005
# 468  Østen for Sol og vesten for Maane : Digte 1880...  2009072801107
# 469                                       Sangenes bog  2010053106058
# 484    M.B. Landstads Kirkesalmebog. Og "Nokre Salmar"  2012011110001
# 511                          Digte og Smaafortællinger  2013061408118
# 540                                              Digte  2008041100031
# 580             Kvinderne i Bjørnsons digtning : essay  2010070106216
#
#           api code lang
# 8    2012052505023  mul
# 9    2006120101048  mul
# 183  2010061806033  mul
# 323  2008040704116  dan
# 338  2010070205055  dan
# 339  2011050604018  dan
# 340  2010052806041  dan
# 358  2006120500055  mul
# 360  2008040904047  dan
# 424  2007060701064  dan
# 439  2011121308005  mul
# 468  2009072801107  dan
# 469  2010053106058  dan
# 484  2012011110001  mul
# 511  2013061408118  und
# 540  2008041100031  mul
# 580  2010070106216  dan

# %%
years = rec_df["year"]
print_year_statistics(years)
# Out:
#     Median: 1920.5
#     Mean: 1925.2173913043478
#     Max: 1981
#     Min: 1902
#     # of books: 138

# %% [markdown]
# ## Check if any of the books we already annotated are part of the ones we don't need
# Luckily, this is not the case

# %%
p = Path("../../norwegian_rhyme_scheme_corpus/annotation_tool/poems/bokmål")
codes = set([e.name.split("_")[0] for e in p.iterdir()])
diff_df.loc[diff_df["api code"].isin(codes)]
# Out:
# Empty DataFrame
# Columns: [year, author, title, filename code, api code, lang]
# Index: []

# %%
hmm = we_need.loc[we_need["api code"].isin(codes)]
print(f"We annotated {len(codes)} books. Of those, {len(hmm)} are in the ones we need")
hmm
# Out:
# We annotated 11 books. Of those, 11 are the ones we need
#      year                            author  \
# 84   1931                    Luther, Martin
# 115  1944  Welhaven, J.S. (Johan Sebastian)
# 190  1956                       Larsen, Alf
# 386  1914            Bjørnson, Bjørnstjerne
# 405  1950            Bjørnson, Bjørnstjerne
# 446  1950                    Nilsen, Rudolf
# 553  1941               Zwilgmeyer, Dagfinn
# 558  1934                       Holme, Edin
# 559  1934                       Holme, Edin
# 561  1934                       Holme, Edin
# 587  1946                    Grieg, Nordahl
#
#                                                  title  filename code  \
# 84   Luthers lille katekisme med bibelord og salmevers  2009013000065
# 115                     Norges demring : og andre dikt  2012032024065
# 190                                      Utvalgte dikt  2008010704054
# 386                                     Digte og Sange  2012102608111
# 405                          Dikte og sange : i utvalg  2006081000055
# 446                                       Samlede dikt  2011102708082
# 553           Nordlandssanger : i herr Petters fotefar  2007011001018
# 558     Dikterverker. 4 : Høvdinger ; Tonen fra himlen  2011041408047
# 559     Dikterverker. 1 : Ildprofeten ; Menneskesønnen  2011042608056
# 561                Dikterverker. 2 : Mannen fra Tarsus  2011041408091
# 587                                       Håbet : dikt  2013012806125
#
#           api code lang
# 84   2009013000065  nob
# 115  2012032024065  nob
# 190  2014102306006  nob
# 386  2012102608111  nob
# 405  2006081000055  nob
# 446  2011102708082  nob
# 553  2007011001018  nob
# 558  2011041408047  nob
# 559  2011042608056  nob
# 561  2011041408091  nob
# 587  2013012806125  nob

# %% [markdown]
# ## Check that examples from thesis are actually in our selection

# %%
hustru = "2009022603004" 
voler = "2010030903071"
keep_df.loc[keep_df["api code"].isin([hustru, voler])]
# Out:
#      year             author                               title  \
# 89   1893    Aagaard, Gustav           Sjøluft : billeder i digt
# 109  1857  Heyerdahl, Halvor  Historiske Sange fra Norges Fortid
#
#      filename code       api code lang
# 89   2009022603004  2009022603004  nob
# 109  2010030903071  2010030903071  nob

# %%
fb_df.loc[fb_df["api code"].isin([hustru, voler])]
# Out:
#      year             author                               title  \
# 89   1893    Aagaard, Gustav           Sjøluft : billeder i digt
# 109  1857  Heyerdahl, Halvor  Historiske Sange fra Norges Fortid
#
#      filename code       api code lang
# 89   2009022603004  2009022603004  nob
# 109  2010030903071  2010030903071  nob

# %% [markdown]
# ## Gather received re-OCR

# %%
re_ocr = pd.concat((rec_df, fb_df))
pre_1900 = re_ocr.loc[re_ocr["year"] < 1900]
post_1900 = re_ocr.loc[re_ocr["year"] >= 1900]

# %%
re_ocr.to_csv("re-ocr_info.tsv", sep="\t")

# %%
print("FULL re-OCR")
years = re_ocr["year"]
print_year_statistics(years)
print_count_lang_dist(re_ocr)
# Out:
# FULL re-OCR
#
#     Median: 1897.0
#     Mean: 1896.0574018126888
#     Max: 1981
#     Min: 1814
#     # of books: 331
#
#
#     Number of bokmål files 300	or 90.6344410876133%
#     Number of nynorsk files 30	or 9.06344410876133%
#     Number of norsk files 1	or 0.3021148036253776%

# %%
print("PRE-1900 re-OCR")
years = pre_1900["year"]
print_year_statistics(years)
print_count_lang_dist(pre_1900)
# Out:
# PRE-1900 re-OCR
#
#     Median: 1871.5
#     Mean: 1872.6761363636363
#     Max: 1899
#     Min: 1814
#     # of books: 176
#
#
#     Number of bokmål files 172	or 97.72727272727273%
#     Number of nynorsk files 3	or 1.7045454545454544%
#     Number of norsk files 1	or 0.5681818181818182%

# %%
print("POST-1900 re-OCR")
years = post_1900["year"]
print_year_statistics(years)
print_count_lang_dist(post_1900)
# Out:
# POST-1900 re-OCR
#
#     Median: 1920.0
#     Mean: 1922.6064516129031
#     Max: 1981
#     Min: 1900
#     # of books: 155
#
#
#     Number of bokmål files 128	or 82.58064516129032%
#     Number of nynorsk files 27	or 17.419354838709676%
#     Number of norsk files 0	or 0.0%
