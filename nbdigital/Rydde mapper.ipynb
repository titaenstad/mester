# %%
from pathlib import Path

p = Path("reocr_hocr/")
pp = Path("reocr_hocr_batch_2/")

for f in pp.iterdir():
    ff = p / f.name
    f.rename(ff)

# %%
def get_code(filename):
    return filename.split("_")[1]

unique_books = set([get_code(e.name) for e in p.iterdir() if e.is_file()])

# %%
for f in p.iterdir():
    if f.is_file():
        code = get_code(f.name)
        dp = p / f"digibok_{code}/{f.name}"
        f.rename(dp)

# %%
from pathlib import Path
import pandas as pd

p = Path("reocr_batch_2/digibok/")

df = pd.read_csv("batch2_info.tsv", sep="\t")

codes = [x.name.split("digibok_")[1] for x in p.iterdir()]
# Out:
# (156, 138)

# %%
import json 
import requests

def get_metadata(codes):
    metadata = {}
    base_api = "https://api.nb.no/catalog/v1/items/URN:NBN:no-nb_digibok_"
    for code in codes:
        response = requests.get(base_api+code)
        j = response.json()
        metadata[code] = j["metadata"]
    return metadata

def metadata_to_df(metadata):
    d = []
    for code, data in metadata.items():
        lang = data["languages"][0]["code"]
        year = int(data["originInfo"]["issued"])
        title = data["title"]
        
        data_code = data["identifiers"]["urn"].split("_")[-1]
        if code != data_code:
            print(f"Received code: {code}, metadata code: {data_code}")

        if "people" in data:
            author = data["people"][0]["name"]
        elif "statementOfResponsibility" in data:
            author = data["statementOfResponsibility"][0]
        d.append({"year": year, "author": author, "title": title, "filename code": code, "api code": data_code, "lang": lang})
    return pd.DataFrame(d)


# metadata = get_metadata(codes)

# with open("metadata_b2.json", "w+") as f:
#     json.dump(metadata, f)

# %%
metadata
# Out:
# {'2012082408040': {'title': 'Samlede dikt',
#   'titleInfos': [{'title': 'Samlede dikt'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Grieg, Nordahl',
#     'date': '1902-1943',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90057909'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1947',
#    'issuedUntouched': '1947',
#    'firstIndexTime': '2021-11-22T09:03:32.272Z',
#    'firstDigitalContentTime': '2016-01-21T22:24:46.403Z'},
#   'recordInfo': {'identifier': '999314449264702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150420'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': '98cd556a3d5235732cb58a6eb3fdc889',
#    'oaiId': 'oai:nb.bibsys.no:999314449264702202',
#    'urn': 'URN:NBN:no-nb_digibok_2012082408040'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2012-09-06'],
#   'subject': {'topics': ['lyrikk']},
#   'statementOfResponsibility': ['Nordahl Grieg'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 245,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'series': ['Lanterne-bøkene L 54'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '231 s.'}},
#  '2013012806125': {'title': 'Håbet : dikt',
#   'titleInfos': [{'title': 'Håbet', 'subTitle': 'dikt'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Grieg, Nordahl',
#     'date': '1902-1943',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90057909'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1946',
#    'issuedUntouched': '1946',
#    'firstIndexTime': '2021-11-22T09:02:42.045Z',
#    'firstDigitalContentTime': '2016-01-21T11:16:16.252Z'},
#   'recordInfo': {'identifier': '997521171064702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150722'},
#   'identifiers': {'sesamId': '284769eb4295587be39839a7b8063236',
#    'oaiId': 'oai:nb.bibsys.no:997521171064702202',
#    'urn': 'URN:NBN:no-nb_digibok_2013012806125'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2013-03-09'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 159,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '147 s.'}},
#  '2010082422026': {'title': 'Kæmpehøjen, dramatisk digtning i en akt ; og Olaf Liljekrans, skuespil i tre akter',
#   'titleInfos': [{'title': 'Kæmpehøjen, dramatisk digtning i en akt ; og Olaf Liljekrans, skuespil i tre akter'},
#    {'title': 'Olaf Liljekrans', 'type': 'alternative'},
#    {'title': 'Kæmpehøjen', 'type': 'alternative'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Ibsen, Henrik',
#     'date': '1828-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90061718'}],
#   'geographic': {'placeString': 'København ; Kristiania',
#    'city': 'København ; Kristiania'},
#   'originInfo': {'publisher': 'Gyldendalske Boghandel, Nordisk Forl.',
#    'issued': '1904',
#    'issuedUntouched': '1904',
#    'firstIndexTime': '2021-11-22T08:55:21.351Z',
#    'firstDigitalContentTime': '2016-01-21T14:10:04.695Z'},
#   'recordInfo': {'identifier': '999612302584702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150605'},
#   'identifiers': {'sesamId': '45b9cfd6641da2ba58d9238ac18cc781',
#    'oaiId': 'oai:nb.bibsys.no:999612302584702202',
#    'urn': 'URN:NBN:no-nb_digibok_2010082422026'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-09-11'],
#   'statementOfResponsibility': ['Henrik Ibsen'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 209,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '191 s.'}},
#  '2007092102002': {'title': 'Samlede digterverker. 3 : [Halvhundrede Digte]',
#   'titleInfos': [{'title': 'Samlede digterverker',
#     'partNumber': '3',
#     'partName': '[Halvhundrede Digte]'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Welhaven, J.S. (Johan Sebastian)',
#     'date': '1807-1873',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90087769'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Gyldendalske Boghandel',
#    'issued': '1921',
#    'issuedUntouched': '1921',
#    'edition': '3. udg.',
#    'firstIndexTime': '2021-12-03T08:06:09.349Z',
#    'firstDigitalContentTime': '2016-01-21T15:32:11.634Z'},
#   'recordInfo': {'identifier': '998111376354702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '130725'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': '52cd5932155eadc2066423de21d8dbea',
#    'oaiId': 'oai:nb.bibsys.no:998111376354702202',
#    'urn': 'URN:NBN:no-nb_digibok_2007092102002'},
#   'notes': ['Tittel fra s. [5]',
#    'Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-09-15'],
#   'subject': {'topics': ['dikt']},
#   'languages': [{'code': 'nob'}],
#   'pageCount': 277,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '266 s.'},
#   'relatedItems': [{'name': ['Welhaven, J.S., 1807-1873'], 'type': 'host'}]},
#  '2006120101048': {'title': 'Norsk diktning efter 1814',
#   'titleInfos': [{'title': 'Norsk diktning efter 1814'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Hægstad, Marius',
#     'date': '1850-1927',
#     'identifier': 'bibsys.no:authority:90142247'},
#    {'name': 'Skard, Matias',
#     'date': '1846-1927',
#     'identifier': 'bibsys.no:authority:90120065'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Aschehoug',
#    'issued': '1922',
#    'issuedUntouched': '1922',
#    'edition': '3. opl.',
#    'firstIndexTime': '2021-11-25T14:56:43.807Z',
#    'firstDigitalContentTime': '2016-01-22T05:47:20.960Z'},
#   'recordInfo': {'identifier': '990316654974702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '140624'},
#   'identifiers': {'sesamId': 'e288b2c28e84ed6aec849dd4ccd729ea',
#    'oaiId': 'oai:nb.bibsys.no:990316654974702202',
#    'urn': 'URN:NBN:no-nb_digibok_2006120101048'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2015-11-06'],
#   'subject': {'topics': ['Lesebøker']},
#   'statementOfResponsibility': ['ved Marius Hægstad og Matias Skard'],
#   'languages': [{'code': 'mul'}, {'code': 'nob'}, {'code': 'nno'}],
#   'pageCount': 369,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'targetAudienceNotes': ['juvenile'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '299 s. ill.'}},
#  '2010010713001': {'title': 'Samlede Digter-verker. 6 : Geografi og kjærlighed ; På Guds veje ; Et stygt barndomsminde ; Mors hænder ; En dag ; Ivar Bye',
#   'titleInfos': [{'title': 'Samlede Digter-verker',
#     'partNumber': '6',
#     'partName': 'Geografi og kjærlighed ; På Guds veje ; Et stygt barndomsminde ; Mors hænder ; En dag ; Ivar Bye'},
#    {'title': 'På Guds veje', 'type': 'alternative'},
#    {'title': 'Et stygt barndomsminde', 'type': 'alternative'},
#    {'title': 'Mors hænder', 'type': 'alternative'},
#    {'title': 'En dag', 'type': 'alternative'},
#    {'title': 'Ivar Bye', 'type': 'alternative'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Bjørnson, Bjørnstjerne',
#     'date': '1832-1910',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90056157'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'København',
#    'issued': '1919',
#    'issuedUntouched': '1919',
#    'edition': 'Standardutg. ved Francis Bull',
#    'firstIndexTime': '2021-11-22T08:53:36.110Z',
#    'firstDigitalContentTime': '2016-01-21T20:56:15.763Z'},
#   'recordInfo': {'identifier': '990016867804702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '140801'},
#   'identifiers': {'sesamId': '89e681f16856218dcea6e8ca79641ade',
#    'oaiId': 'oai:nb.bibsys.no:990016867804702202',
#    'urn': 'URN:NBN:no-nb_digibok_2010010713001'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-03-20'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 457,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': 'XXVII, 404 s.'},
#   'relatedItems': [{'name': ['Bjørnson, Bjørnstjerne, 1832-1910'],
#     'type': 'host'}]},
#  '2006081000055': {'title': 'Dikte og sange : i utvalg',
#   'titleInfos': [{'title': 'Dikte og sange', 'subTitle': 'i utvalg'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Bjørnson, Bjørnstjerne',
#     'date': '1832-1910',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90056157'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1950',
#    'issuedUntouched': '1950',
#    'edition': '3. oppl.',
#    'firstIndexTime': '2021-11-25T14:47:48.222Z',
#    'firstDigitalContentTime': '2016-01-22T01:53:53.869Z'},
#   'recordInfo': {'identifier': '999419405604702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '130806'},
#   'identifiers': {'sesamId': 'bc5c90cd72066887290720e1aaf218e4',
#    'oaiId': 'oai:nb.bibsys.no:999419405604702202',
#    'urn': 'URN:NBN:no-nb_digibok_2006081000055'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2007-03-13'],
#   'statementOfResponsibility': ['Bjørnstjerne Bjørnson ; med merknader av Sigurd Skonhoft'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 153,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'series': ['Gyldendals skoleutgaver av norske forfattere'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '147 s.'}},
#  '2010051412002': {'title': 'Brand : et dramatisk digt',
#   'titleInfos': [{'title': 'Brand', 'subTitle': 'et dramatisk digt'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Ibsen, Henrik',
#     'date': '1828-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90061718'}],
#   'geographic': {'placeString': 'København', 'city': 'København'},
#   'originInfo': {'publisher': 'Gyldendalske Boghandel, Nordisk Forl.',
#    'issued': '1905',
#    'issuedUntouched': '1905',
#    'edition': '16. Opl.',
#    'firstIndexTime': '2021-11-22T08:55:29.309Z',
#    'firstDigitalContentTime': '2016-01-22T00:10:58.222Z'},
#   'recordInfo': {'identifier': '999612306734702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150605'},
#   'identifiers': {'sesamId': 'aa383bbe0dd39c136af81da75d6eb6c3',
#    'oaiId': 'oai:nb.bibsys.no:999612306734702202',
#    'urn': 'URN:NBN:no-nb_digibok_2010060420002'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-05-30'],
#   'statementOfResponsibility': ['Henrik Ibsen'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 277,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '256 s.'}},
#  '2011050604050': {'title': 'Digte',
#   'titleInfos': [{'title': 'Digte'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Solstad, Einar',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90570243'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Aschehoug',
#    'issued': '1915',
#    'issuedUntouched': '1915',
#    'firstIndexTime': '2021-11-22T08:57:13.348Z',
#    'firstDigitalContentTime': '2016-01-21T10:58:02.430Z'},
#   'recordInfo': {'identifier': '990116677884702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150716'},
#   'identifiers': {'sesamId': '25387475668cb8d5657e7a522d83c79b',
#    'oaiId': 'oai:nb.bibsys.no:990116677884702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011050604050'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-05-28'],
#   'statementOfResponsibility': ['Einar Solstad'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 77,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '63 s.'}},
#  '2013012108002': {'title': 'Samlede digte',
#   'titleInfos': [{'title': 'Samlede digte'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Bull, Olaf',
#     'date': '1883-1933',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90115821'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1942',
#    'issuedUntouched': '1942',
#    'edition': '3. utg.',
#    'firstIndexTime': '2021-11-22T09:04:40.189Z',
#    'firstDigitalContentTime': '2016-01-21T11:07:35.054Z'},
#   'recordInfo': {'identifier': '999324599434702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150624'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': '2677ec2825ba22217d765b2003cf095c',
#    'oaiId': 'oai:nb.bibsys.no:999324599434702202',
#    'urn': 'URN:NBN:no-nb_digibok_2013012108002'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2013-04-12'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 461,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '446 s.'}},
#  '2011052404044': {'title': 'Samlede digte 1909-1919',
#   'titleInfos': [{'title': 'Samlede digte 1909-1919'},
#    {'title': 'Utvalg', 'type': 'uniform'}],
#   'typeOfResource': 'text',
#   'genres': ['fiction'],
#   'people': [{'name': 'Bull, Olaf',
#     'date': '1883-1933',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:1536145200375'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1919',
#    'issuedUntouched': '1919',
#    'firstIndexTime': '2021-11-22T08:57:38.037Z',
#    'firstDigitalContentTime': '2016-01-22T04:19:26.122Z'},
#   'recordInfo': {'identifier': '997820259514702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '131105'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': 'd49062f2ec905502a5bc564c716fa509',
#    'oaiId': 'oai:nb.bibsys.no:997820259514702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011052404044'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-06-29'],
#   'statementOfResponsibility': ['Olaf Bull'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 281,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Skjønnlitteratur',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '269 s.'}},
#  '2011121410001': {'title': 'Melodier til Brorsons Svanesang : for piano eller orgel : med underlagt tekst',
#   'titleInfos': [{'title': 'Melodier til Brorsons Svanesang',
#     'subTitle': 'for piano eller orgel : med underlagt tekst'}],
#   'typeOfResource': 'notated music',
#   'people': [{'name': 'Lindeman, Ludv. M. (Ludvig Mathias)',
#     'date': '1812-1887',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90099426'},
#    {'name': 'Brorson, Hans Adolph',
#     'date': '1694-1764',
#     'roles': [{'name': 'tekstforf.'},
#      {'name': 'aut', 'description': 'Forfatter'}],
#     'identifier': 'bibsys.no:authority:90244096'}],
#   'geographic': {'city': 'Kjøbenhavn'},
#   'originInfo': {'publisher': 'Julius Thømtes boktr.',
#    'issued': '1912',
#    'firstIndexTime': '2021-11-22T09:01:18.626Z',
#    'firstDigitalContentTime': '2016-01-22T08:30:56.149Z'},
#   'recordInfo': {'identifier': '990226046934702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150619'},
#   'classification': {'ddc': ['782.527', '782.527']},
#   'identifiers': {'sesamId': 'fec49b10814f98e04444c209fd825f5f',
#    'oaiId': 'oai:nb.bibsys.no:990226046934702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011121410001'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-12-22'],
#   'subject': {'topics': ['melodier', 'salmer', 'norge', 'dansk', 'språk']},
#   'statementOfResponsibility': ['Ludv. M. Lindeman'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 141,
#   'mediaTypes': ['noter'],
#   'contentClasses': ['public', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'musikktrykk',
#     'electronic resource',
#     'remote'],
#    'extent': '16, 108 s. ill.'},
#   'relatedItems': [{'name': ['Brorson, Hans Adolph', '1694-1764'],
#     'type': 'constituent'}]},
#  '2008022904012': {'title': 'Septemberbrand : Digte : sjette Samling',
#   'titleInfos': [{'title': 'Septemberbrand',
#     'subTitle': 'Digte : sjette Samling'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Vogt, Nils Collett',
#     'date': '1864-1937',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Aschehoug',
#    'issued': '1907',
#    'issuedUntouched': '1907',
#    'firstIndexTime': '2021-11-22T08:42:25.280Z',
#    'firstDigitalContentTime': '2016-01-22T05:31:45.229Z'},
#   'recordInfo': {'identifier': '999505590754702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '140624'},
#   'identifiers': {'sesamId': 'e081b491b1fd820b442ec6c347fc1a74',
#    'oaiId': 'oai:nb.bibsys.no:999505590754702202',
#    'urn': 'URN:NBN:no-nb_digibok_2008022904012'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2009-04-21'],
#   'statementOfResponsibility': ['Nils Collett Vogt'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 157,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '144 s.'}},
#  '2009070601033': {'title': 'Samlede digterverker. B. 1 : Noveletter ; Garman & Worse ; For scenen ; Nye noveletter',
#   'titleInfos': [{'title': 'Samlede digterverker',
#     'partNumber': 'B. 1',
#     'partName': 'Noveletter ; Garman & Worse ; For scenen ; Nye noveletter'},
#    {'title': 'Noveletter', 'type': 'alternative'},
#    {'title': 'Garman & Worse', 'type': 'alternative'},
#    {'title': 'For scenen', 'type': 'alternative'},
#    {'title': 'Nye noveletter', 'type': 'alternative'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Kielland, Alexander L.',
#     'date': '1849-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90077278'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1934',
#    'issuedUntouched': '1934',
#    'edition': '8. utg.',
#    'firstIndexTime': '2021-11-22T08:44:32.749Z',
#    'firstDigitalContentTime': '2016-01-21T17:38:20.748Z'},
#   'recordInfo': {'identifier': '999310388804702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150309'},
#   'identifiers': {'sesamId': '687f98ed29b87fc2e6bd64c35caf043f',
#    'oaiId': 'oai:nb.bibsys.no:999310388804702202',
#    'urn': 'URN:NBN:no-nb_digibok_2009070601033'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2009-09-21'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 433,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '420 s.'},
#   'relatedItems': [{'name': ['Kielland, Alexander L., 1849-1906'],
#     'type': 'host'}]},
#  '2011102524009': {'title': 'Efterladte Digte',
#   'titleInfos': [{'title': 'Efterladte Digte'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Sibbern, Georg',
#     'date': '1816-1901',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90321305'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Fabritius',
#    'issued': '1902',
#    'issuedUntouched': '1902',
#    'firstIndexTime': '2021-11-22T08:58:31.741Z',
#    'firstDigitalContentTime': '2016-01-22T07:23:35.845Z'},
#   'recordInfo': {'identifier': '999308982574702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '111130'},
#   'identifiers': {'sesamId': 'f2eadb2a85f9de5f3d275bc658997e12',
#    'oaiId': 'oai:nb.bibsys.no:999308982574702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011102524009'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-11-30'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 135,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '108 s. port.'}},
#  '2010051813001': {'title': 'Brand : et dramatisk digt',
#   'titleInfos': [{'title': 'Brand', 'subTitle': 'et dramatisk digt'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Ibsen, Henrik',
#     'date': '1828-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90061718'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Gyldendalske bokhandel',
#    'issued': '1922',
#    'issuedUntouched': '1922',
#    'edition': '20. opl.',
#    'firstIndexTime': '2021-11-22T08:55:29.311Z',
#    'firstDigitalContentTime': '2016-01-21T07:31:56.719Z'},
#   'recordInfo': {'identifier': '999818300304702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150605'},
#   'identifiers': {'sesamId': '01801e0003cd1748f9dc00876d611560',
#    'oaiId': 'oai:nb.bibsys.no:999818300304702202',
#    'urn': 'URN:NBN:no-nb_digibok_2010051813001'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-05-28'],
#   'statementOfResponsibility': ['Henrik Ibsen'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 141,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '250 s.'}},
#  '2011041408046': {'title': 'Dikterverker. 3 : Omkring nasareeren ; Ukjente verdener',
#   'titleInfos': [{'title': 'Dikterverker',
#     'partNumber': '3',
#     'partName': 'Omkring nasareeren ; Ukjente verdener'},
#    {'title': 'Ukjente verdener', 'type': 'alternative'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Holme, Edin',
#     'date': '1865-1927',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90078043'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Aschehoug',
#    'issued': '1934',
#    'issuedUntouched': '1934',
#    'firstIndexTime': '2021-11-22T08:59:55.014Z',
#    'firstDigitalContentTime': '2016-01-21T21:19:37.871Z'},
#   'recordInfo': {'identifier': '999811318084702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '131112'},
#   'identifiers': {'sesamId': '8df972e92c25e896d86db0ad0c7f56db',
#    'oaiId': 'oai:nb.bibsys.no:999811318084702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011041408046'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-05-13'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 359,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '201, 146 s.'},
#   'relatedItems': [{'name': ['Holme, Edin, 1865-1927'], 'type': 'host'}]},
#  '2008042104034': {'title': 'Samlede digterverker. B. 3',
#   'titleInfos': [{'title': 'Samlede digterverker', 'partNumber': 'B. 3'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Welhaven, J.S. (Johan Sebastian)',
#     'date': '1807-1873',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90087769'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1943',
#    'issuedUntouched': '1943',
#    'edition': '4. utg.',
#    'firstIndexTime': '2021-11-22T08:58:59.366Z',
#    'firstDigitalContentTime': '2016-01-22T06:35:11.086Z'},
#   'recordInfo': {'identifier': '997521915194702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '151019'},
#   'identifiers': {'sesamId': 'eb4fca272f3609e7541aff686d0e4b8d',
#    'oaiId': 'oai:nb.bibsys.no:997521915194702202',
#    'urn': 'URN:NBN:no-nb_digibok_2008042104034'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-01-09'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 361,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '350 s.'},
#   'relatedItems': [{'name': ['Welhaven, J.S., 1807-1873'], 'type': 'host'}]},
#  '2011050604061': {'title': 'På gjensyn : dikte',
#   'titleInfos': [{'title': 'På gjensyn', 'subTitle': 'dikte'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Nilsen, Rudolf',
#     'date': '1901-1929',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90079272'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Ny Tid',
#    'issued': '1926',
#    'issuedUntouched': '1926',
#    'firstIndexTime': '2021-11-22T08:57:13.522Z',
#    'firstDigitalContentTime': '2016-01-21T14:41:38.477Z'},
#   'recordInfo': {'identifier': '999412535544702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '140930'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': '4aa630194cee7b17a63b892a158a3d69',
#    'oaiId': 'oai:nb.bibsys.no:999412535544702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011050604061'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-05-28'],
#   'statementOfResponsibility': ['Rudolf Nilsen'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 97,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'epub', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '92 s.'}},
#  '2006083100012': {'title': 'Peer Gynt! : et dramatisk dikt',
#   'titleInfos': [{'title': 'Peer Gynt!', 'subTitle': 'et dramatisk dikt'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Ibsen, Henrik',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary'},
#    {'name': 'Pettersen, Sverre',
#     'roles': [{'name': 'ill', 'description': 'Illustratør'}]}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1950',
#    'issuedUntouched': '1950',
#    'firstIndexTime': '2021-11-25T14:46:58.469Z',
#    'firstDigitalContentTime': '2016-01-21T10:42:54.319Z'},
#   'recordInfo': {'identifier': '999425979074702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150212'},
#   'identifiers': {'sesamId': '226fb4ffa35641742e45e289088a933d',
#    'oaiId': 'oai:nb.bibsys.no:999425979074702202',
#    'urn': 'URN:NBN:no-nb_digibok_2006083100012'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2007-05-10'],
#   'statementOfResponsibility': ['Henrik Ibsen'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 229,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'series': ['Hjemmenes boksamling'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '223 s. ill.'}},
#  '2008052004044': {'title': 'Den store freden : dramatisk dikt',
#   'titleInfos': [{'title': 'store freden', 'subTitle': 'dramatisk dikt'}],
#   'typeOfResource': 'text',
#   'genres': ['fiction'],
#   'people': [{'name': 'Garborg, Hulda',
#     'date': '1862-1934',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90103600'}],
#   'geographic': {'placeString': '[Oslo', 'city': '[Oslo'},
#   'originInfo': {'issued': '1962',
#    'issuedUntouched': '1962',
#    'firstIndexTime': '2021-11-22T08:54:03.135Z',
#    'firstDigitalContentTime': '2016-01-22T02:27:26.449Z'},
#   'recordInfo': {'identifier': '990230418544702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '110826'},
#   'classification': {'ddc': [' 839.92']},
#   'identifiers': {'sesamId': 'c14f249c6e1bffc3d5cee6382006d499',
#    'oaiId': 'oai:nb.bibsys.no:990230418544702202',
#    'urn': 'URN:NBN:no-nb_digibok_2008052004044'},
#   'notes': ['Hørespill sendt av Norsk rikskringkasting 20. febr. 1962',
#    'Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-07-25'],
#   'statementOfResponsibility': ['av Hulda Garborg'],
#   'languages': [{'code': 'nno'}],
#   'pageCount': 83,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Skjønnlitteratur',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '81 bl. 4°'}},
#  '2006120501131': {'title': 'Paa fallreipe : dikt',
#   'titleInfos': [{'title': 'Paa fallreipe', 'subTitle': 'dikt'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Hovden, Anders',
#     'date': '1860-1943',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90080014'}],
#   'geographic': {'placeString': '[Kristiania]', 'city': '[Kristiania]'},
#   'originInfo': {'publisher': 'Cammermeyer',
#    'issued': '1917',
#    'issuedUntouched': '1917',
#    'firstIndexTime': '2021-11-25T14:37:14.998Z',
#    'firstDigitalContentTime': '2016-01-22T01:54:47.851Z'},
#   'recordInfo': {'identifier': '999407901904702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '131127'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': 'bc91e9b7cd3b9b1616551f53ef21fd8e',
#    'oaiId': 'oai:nb.bibsys.no:999407901904702202',
#    'urn': 'URN:NBN:no-nb_digibok_2006120501131'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-03-12'],
#   'statementOfResponsibility': ['Anders Hovden'],
#   'languages': [{'code': 'nno'}],
#   'pageCount': 195,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '188 s.'}},
#  '2013081206032': {'title': 'Digte',
#   'titleInfos': [{'title': 'Digte'}],
#   'typeOfResource': 'text',
#   'genres': ['fiction'],
#   'people': [{'name': 'Bull, Jacob B.',
#     'date': '1853-1930',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90081281'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1921',
#    'issuedUntouched': '1921',
#    'firstIndexTime': '2021-11-22T09:03:45.306Z',
#    'firstDigitalContentTime': '2016-01-21T15:26:13.178Z'},
#   'recordInfo': {'identifier': '999408296654702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '130904'},
#   'identifiers': {'sesamId': '5281407c0a771fce3e72160d740d5875',
#    'oaiId': 'oai:nb.bibsys.no:999408296654702202',
#    'urn': 'URN:NBN:no-nb_digibok_2013081206032'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2013-09-04'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 165,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Skjønnlitteratur',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '160 s.'}},
#  '2009070601030': {'title': 'Samlede digterverker. B. 2 : Arbeidsfolk ; Else ; Skipper Worse',
#   'titleInfos': [{'title': 'Samlede digterverker',
#     'partNumber': 'B. 2',
#     'partName': 'Arbeidsfolk ; Else ; Skipper Worse'},
#    {'title': 'Arbeidsfolk', 'type': 'alternative'},
#    {'title': 'Else', 'type': 'alternative'},
#    {'title': 'Skipper Worse', 'type': 'alternative'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Kielland, Alexander L.',
#     'date': '1849-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90077278'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1934',
#    'issuedUntouched': '1934',
#    'edition': '8. utg.',
#    'firstIndexTime': '2021-11-22T08:44:27.754Z',
#    'firstDigitalContentTime': '2016-01-21T22:15:45.528Z'},
#   'recordInfo': {'identifier': '999310389104702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150309'},
#   'identifiers': {'sesamId': '974306c5ecebddcebce0de11c28c0153',
#    'oaiId': 'oai:nb.bibsys.no:999310389104702202',
#    'urn': 'URN:NBN:no-nb_digibok_2009070601030'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2009-09-21'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 431,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '418 s.'},
#   'relatedItems': [{'name': ['Kielland, Alexander L., 1849-1906'],
#     'type': 'host'}]},
#  '2008041004045': {'title': 'Mands hjerte : digte',
#   'titleInfos': [{'title': 'Mands hjerte', 'subTitle': 'digte'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Kinck, Hans E.',
#     'date': '1865-1926',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90110918'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Aschehoug',
#    'issued': '1927',
#    'issuedUntouched': '1927',
#    'firstIndexTime': '2021-11-22T08:58:21.498Z',
#    'firstDigitalContentTime': '2016-01-21T12:31:13.509Z'},
#   'recordInfo': {'identifier': '998903676714702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150326'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': '34ca2d829c2f742781ff9e9429fcc96b',
#    'oaiId': 'oai:nb.bibsys.no:998903676714702202',
#    'urn': 'URN:NBN:no-nb_digibok_2008041004045'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-11-27'],
#   'statementOfResponsibility': ['Hans E. Kinck'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 99,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '85 s.'}},
#  '2013072208052': {'title': 'Samlede digterverker. 4',
#   'titleInfos': [{'title': 'Samlede digterverker', 'partNumber': '4'},
#    {'title': 'En folkefiende', 'type': 'alternative'},
#    {'title': 'Gengangere', 'type': 'alternative'},
#    {'title': 'Et dukkehjem', 'type': 'alternative'},
#    {'title': 'Samfundets støtter', 'type': 'alternative'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Ibsen, Henrik',
#     'date': '1828-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90061718'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1930',
#    'issuedUntouched': '1930',
#    'edition': '7. utg.',
#    'firstIndexTime': '2021-11-22T09:03:32.957Z',
#    'firstDigitalContentTime': '2016-01-21T12:34:28.773Z'},
#   'recordInfo': {'identifier': '990014821654702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150729'},
#   'identifiers': {'sesamId': '355c961462296bcf24218900001e7fb1',
#    'oaiId': 'oai:nb.bibsys.no:990014821654702202',
#    'urn': 'URN:NBN:no-nb_digibok_2013072208052'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2013-08-22'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 423,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'tableOfContents': ['Samfundets støtter ; Et dukkehjem ; Gengangere ; En folkefiende'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '406 s., pl.'},
#   'relatedItems': [{'name': ['Ibsen, Henrik, 1828-1906'], 'type': 'host'}]},
#  '2013072208051': {'title': 'Samlede digterverker. 5',
#   'titleInfos': [{'title': 'Samlede digterverker', 'partNumber': '5'},
#    {'title': 'Hedda Gabler', 'type': 'alternative'},
#    {'title': 'Fruen fra havet', 'type': 'alternative'},
#    {'title': 'Rosmersholm', 'type': 'alternative'},
#    {'title': 'Vildanden', 'type': 'alternative'}],
#   'typeOfResource': 'text',
#   'genres': ['fiction'],
#   'people': [{'name': 'Ibsen, Henrik',
#     'date': '1828-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90061718'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1930',
#    'issuedUntouched': '1930',
#    'edition': '7. utg.',
#    'firstIndexTime': '2021-11-22T09:03:32.935Z',
#    'firstDigitalContentTime': '2016-01-22T04:34:45.664Z'},
#   'recordInfo': {'identifier': '990014821904702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150729'},
#   'identifiers': {'sesamId': 'd715e06fd5e446762b858ccf2795a2b8',
#    'oaiId': 'oai:nb.bibsys.no:990014821904702202',
#    'urn': 'URN:NBN:no-nb_digibok_2013072208051'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2013-08-22'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 439,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'tableOfContents': ['Vildanden ; Rosmersholm ; Fruen fra havet ; Hedda Gabler'],
#   'literaryform': 'Skjønnlitteratur',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '422 s., pl.'},
#   'relatedItems': [{'name': ['Ibsen, Henrik, 1828-1906'], 'type': 'host'}]},
#  '2012100907178': {'title': 'Fra det blaa Bryggerhus : af en Digters Optegnelser',
#   'titleInfos': [{'title': 'Fra det blaa Bryggerhus',
#     'subTitle': 'af en Digters Optegnelser'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Krag, Vilhelm',
#     'date': '1871-1933',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90053015'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Aschehoug',
#    'issued': '1911',
#    'issuedUntouched': '1911',
#    'firstIndexTime': '2021-11-22T09:04:05.526Z',
#    'firstDigitalContentTime': '2016-01-21T11:43:09.518Z'},
#   'recordInfo': {'identifier': '999327779024702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150706'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': '2d41f82e785eea6e373934cb9e0b1818',
#    'oaiId': 'oai:nb.bibsys.no:999327779024702202',
#    'urn': 'URN:NBN:no-nb_digibok_2012100907178'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2012-10-21'],
#   'subject': {'topics': ['agderforfattere']},
#   'statementOfResponsibility': ['Vilhelm Krag'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 241,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '227 s.'}},
#  '2013053008130': {'title': 'Tilbageblik : Digte og Sange af Nordahl Rolfsen : samlede til vort Sølvbryllup Juli 1910 af hans Hustru',
#   'titleInfos': [{'title': 'Tilbageblik',
#     'subTitle': 'Digte og Sange af Nordahl Rolfsen : samlede til vort Sølvbryllup Juli 1910 af hans Hustru'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Rolfsen, Nordahl',
#     'date': '1848-1928',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90078109'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'issued': '1910',
#    'issuedUntouched': '1910',
#    'firstIndexTime': '2021-11-22T09:03:12.106Z',
#    'firstDigitalContentTime': '2016-01-21T13:20:38.835Z'},
#   'recordInfo': {'identifier': '990105846334702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '130923'},
#   'identifiers': {'sesamId': '3df1114352bd8406171b3bb690faf261',
#    'oaiId': 'oai:nb.bibsys.no:990105846334702202',
#    'urn': 'URN:NBN:no-nb_digibok_2013053008130'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2013-07-05'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 213,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '205 s.'}},
#  '2008041500060': {'title': 'Samlede digterverker. B. 1',
#   'titleInfos': [{'title': 'Samlede digterverker', 'partNumber': 'B. 1'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Welhaven, J.S. (Johan Sebastian)',
#     'date': '1807-1873',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90087769'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1943',
#    'issuedUntouched': '1943',
#    'edition': '4. utg.',
#    'firstIndexTime': '2021-11-22T08:59:00.290Z',
#    'firstDigitalContentTime': '2016-01-22T08:07:57.557Z'},
#   'recordInfo': {'identifier': '997521436384702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '151019'},
#   'identifiers': {'sesamId': 'faeb0e932b4f0ca0c78bfae38b9bf955',
#    'oaiId': 'oai:nb.bibsys.no:997521436384702202',
#    'urn': 'URN:NBN:no-nb_digibok_2008041500060'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-01-12'],
#   'subject': {'topics': ['dikt', 'lyrikk']},
#   'languages': [{'code': 'nob'}],
#   'pageCount': 261,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '247 s.'},
#   'relatedItems': [{'name': ['Welhaven, J.S., 1807-1873'], 'type': 'host'}]},
#  '2010060420014': {'title': 'Brand : et dramatisk digt',
#   'titleInfos': [{'title': 'Brand', 'subTitle': 'et dramatisk digt'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Ibsen, Henrik',
#     'date': '1828-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90061718'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Gyldendalske Boghandel',
#    'issued': '1920',
#    'issuedUntouched': '1920',
#    'edition': '15. opl. [i.e. 19. opl.]',
#    'firstIndexTime': '2021-11-22T08:52:31.060Z',
#    'firstDigitalContentTime': '2016-01-22T08:13:48.875Z'},
#   'recordInfo': {'identifier': '990003930884702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150605'},
#   'identifiers': {'sesamId': 'fb683ec485eaed516f7478cfd9fac860',
#    'oaiId': 'oai:nb.bibsys.no:990003930884702202',
#    'urn': 'URN:NBN:no-nb_digibok_2010060420014'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-06-16'],
#   'statementOfResponsibility': ['Henrik Ibsen'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 311,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '295 s.'}},
#  '2011040806110': {'title': 'Samlede dikt',
# ...
#   'recordInfo': {'identifier': '999310389874702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150309'},
#   'identifiers': {'sesamId': '538d77767347a169eb3896c6f986f8e1',
#    'oaiId': 'oai:nb.bibsys.no:999310389874702202',
#    'urn': 'URN:NBN:no-nb_digibok_2009070601034'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2009-09-21'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 355,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '342 s.'},
#   'relatedItems': [{'name': ['Kielland, Alexander L., 1849-1906'],
#     'type': 'host'}]},
#  '2010071323006': {'title': 'Samlede digterverker. 6 : Bygmester Solness ; Lille Eyolf ; John Gabriel Borkman ; Når vi døde vågner ; Digte',
#   'titleInfos': [{'title': 'Samlede digterverker',
#     'partNumber': '6',
#     'partName': 'Bygmester Solness ; Lille Eyolf ; John Gabriel Borkman ; Når vi døde vågner ; Digte'},
#    {'title': 'Lille Eyolf', 'type': 'alternative'},
#    {'title': 'John Gabriel Borkman', 'type': 'alternative'},
#    {'title': 'Når vi døde vågner', 'type': 'alternative'},
#    {'title': 'Digte / Henrik Ibsen', 'type': 'alternative'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Ibsen, Henrik',
#     'date': '1828-1906',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90061718'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1937',
#    'issuedUntouched': '1937',
#    'edition': '8. utg.',
#    'firstIndexTime': '2021-11-22T08:54:16.947Z',
#    'firstDigitalContentTime': '2016-01-21T11:14:51.478Z'},
#   'recordInfo': {'identifier': '999108322774702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150119'},
#   'identifiers': {'sesamId': '27a35e34d65f760e36c3cfc055bade29',
#    'oaiId': 'oai:nb.bibsys.no:999108322774702202',
#    'urn': 'URN:NBN:no-nb_digibok_2010071323006'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-08-01'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 511,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '486, III s.'},
#   'relatedItems': [{'name': ['Ibsen, Henrik, 1828-1906'], 'type': 'host'}]},
#  '2010011512002': {'title': 'Samlede Digter-verker. 9 : Varianter',
#   'titleInfos': [{'title': 'Samlede Digter-verker',
#     'partNumber': '9',
#     'partName': 'Varianter'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Bjørnson, Bjørnstjerne',
#     'date': '1832-1910',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90056157'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'København',
#    'issued': '1920',
#    'issuedUntouched': '1920',
#    'edition': 'Standardutg. ved Francis Bull',
#    'firstIndexTime': '2021-11-22T08:53:13.875Z',
#    'firstDigitalContentTime': '2016-01-21T17:38:01.664Z'},
#   'recordInfo': {'identifier': '999328088754702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '141127'},
#   'identifiers': {'sesamId': '6833e5d6771bbe97dddb7e9a1839ff45',
#    'oaiId': 'oai:nb.bibsys.no:999328088754702202',
#    'urn': 'URN:NBN:no-nb_digibok_2010011512002'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-03-15'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 485,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': 'XIV, 432 s.'},
#   'relatedItems': [{'name': ['Bjørnson, Bjørnstjerne, 1832-1910'],
#     'type': 'host'}]},
#  '2006082800028': {'title': '"Salomos høisang"',
#   'titleInfos': [{'title': '"Salomos høisang"'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Skredsvig, Christian',
#     'date': '1854-1924',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1918',
#    'issuedUntouched': '1918',
#    'firstIndexTime': '2021-11-25T14:44:16.993Z',
#    'firstDigitalContentTime': '2016-01-21T18:45:34.136Z'},
#   'recordInfo': {'identifier': '999428248814702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150623'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': '744ea251b1f63f209154af71b0ae7968',
#    'oaiId': 'oai:nb.bibsys.no:999428248814702202',
#    'urn': 'URN:NBN:no-nb_digibok_2006082800028'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2007-03-08'],
#   'statementOfResponsibility': ['Chr. Skredsvig'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 151,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '145 s.'}},
#  '2011071506014': {'title': 'Høk og due : nye digte',
#   'titleInfos': [{'title': 'Høk og due', 'subTitle': 'nye digte'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Hiorth-Schøyen, Rolf',
#     'date': '1887-1932',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90175467'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1922',
#    'issuedUntouched': '1922',
#    'firstIndexTime': '2021-11-22T08:58:05.421Z',
#    'firstDigitalContentTime': '2016-01-22T03:51:50.512Z'},
#   'recordInfo': {'identifier': '999511023034702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '140902'},
#   'identifiers': {'sesamId': 'cff6451d92e733e429d620a06241200b',
#    'oaiId': 'oai:nb.bibsys.no:999511023034702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011071506014'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-08-19'],
#   'subject': {'topics': ['dikt']},
#   'statementOfResponsibility': ['Rolf Hiorth-Schøyen'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 117,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '112 s.'}},
#  '2011051212004': {'title': 'Norsk daggry-sangbog',
#   'titleInfos': [{'title': 'Norsk daggry-sangbog'}],
#   'typeOfResource': 'text',
#   'corporates': [{'name': ['Den Internasjonale bibelstudieforening'],
#     'identifier': 'bibsys.no:authority:98053153'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Foreningen',
#    'issued': '1914',
#    'issuedUntouched': '1914',
#    'firstIndexTime': '2021-11-22T09:00:00.656Z',
#    'firstDigitalContentTime': '2016-01-21T16:31:56.863Z'},
#   'recordInfo': {'identifier': '990414787544702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '110605'},
#   'identifiers': {'sesamId': '5d380582cac72b55616081f8b62c0886',
#    'oaiId': 'oai:nb.bibsys.no:990414787544702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011051212004'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-06-05'],
#   'statementOfResponsibility': ['udgivet af Den Internasjonale bibelstudieforening'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 101,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '96 s.'}},
#  '2006090100024': {'title': 'Digtning og videnskap',
#   'titleInfos': [{'title': 'Digtning og videnskap'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Løchen, Arne',
#     'date': '1850-1930',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90136734'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Aschehoug',
#    'issued': '1913',
#    'issuedUntouched': '1913',
#    'firstIndexTime': '2021-11-25T14:44:26.521Z',
#    'firstDigitalContentTime': '2016-01-21T08:27:05.638Z'},
#   'recordInfo': {'identifier': '999111783334702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150213'},
#   'classification': {'udc': ['82.0(04)']},
#   'identifiers': {'sesamId': '0b4ad4f1457d37ddc09e77663502e626',
#    'oaiId': 'oai:nb.bibsys.no:999111783334702202',
#    'urn': 'URN:NBN:no-nb_digibok_2006090100024'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-02-21'],
#   'statementOfResponsibility': ['Arne Løchen'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 197,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '181 s.'}},
#  '2006082800020': {'title': 'Stammens røst : fem italienske digtere fra vor tid',
#   'titleInfos': [{'title': 'Stammens røst',
#     'subTitle': 'fem italienske digtere fra vor tid'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Kinck, Hans E.',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Aschehoug',
#    'issued': '1919',
#    'issuedUntouched': '1919',
#    'firstIndexTime': '2021-11-25T14:41:52.170Z',
#    'firstDigitalContentTime': '2016-01-21T22:46:35.911Z'},
#   'recordInfo': {'identifier': '999104284174702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '150303'},
#   'classification': {'udc': ['850.01']},
#   'identifiers': {'sesamId': '9cbe07062f890b16e402e182edacf96b',
#    'oaiId': 'oai:nb.bibsys.no:999104284174702202',
#    'urn': 'URN:NBN:no-nb_digibok_2006082800020'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2007-03-08'],
#   'subject': {'topics': ['Italiensk litteratur',
#     'Forfattere',
#     'diktere',
#     'italiensk',
#     'litteratur']},
#   'statementOfResponsibility': ['Hans E. Kinck'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 273,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '268 s.'}},
#  '2010053106046': {'title': 'Ungdom : dikt i utval',
#   'titleInfos': [{'title': 'Ungdom', 'subTitle': 'dikt i utval'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Eskeland, Lars',
#     'date': '1867-1942',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90543916'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Norli',
#    'issued': '1926',
#    'issuedUntouched': '1926',
#    'firstIndexTime': '2021-11-22T08:53:43.358Z',
#    'firstDigitalContentTime': '2016-01-21T21:49:14.383Z'},
#   'recordInfo': {'identifier': '999001943674702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '141202'},
#   'classification': {'udc': ['839.6']},
#   'identifiers': {'sesamId': '9236c9125304bf11980f52929e6a4114',
#    'oaiId': 'oai:nb.bibsys.no:999001943674702202',
#    'urn': 'URN:NBN:no-nb_digibok_2010053106046'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2010-07-17'],
#   'statementOfResponsibility': ['Lars Eskeland'],
#   'languages': [{'code': 'nno'}],
#   'pageCount': 125,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '117 s.'}},
#  '2008041500052': {'title': 'Samlede digterverker. B. 2',
#   'titleInfos': [{'title': 'Samlede digterverker', 'partNumber': 'B. 2'}],
#   'typeOfResource': 'text',
#   'genres': ['fiction'],
#   'people': [{'name': 'Welhaven, J.S. (Johan Sebastian)',
#     'date': '1807-1873',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:90087769'}],
#   'geographic': {'placeString': 'Oslo', 'city': 'Oslo'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1943',
#    'issuedUntouched': '1943',
#    'edition': '4. utg.',
#    'firstIndexTime': '2021-11-22T08:56:29.422Z',
#    'firstDigitalContentTime': '2016-01-21T07:38:04.979Z'},
#   'recordInfo': {'identifier': '997521382864702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '151019'},
#   'identifiers': {'sesamId': '0275a671e78fe2e3b83e0041a0dcca4b',
#    'oaiId': 'oai:nb.bibsys.no:997521382864702202',
#    'urn': 'URN:NBN:no-nb_digibok_2008041500052'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-01-18'],
#   'subject': {'topics': ['dikt', 'lyrikk']},
#   'languages': [{'code': 'nob'}],
#   'pageCount': 327,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Skjønnlitteratur',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '316 s.'},
#   'relatedItems': [{'name': ['Welhaven, J.S., 1807-1873'], 'type': 'host'}]},
#  '2011051604088': {'title': 'Digte og noveller',
#   'titleInfos': [{'title': 'Digte og noveller'}],
#   'typeOfResource': 'text',
#   'people': [{'name': 'Bull, Olaf',
#     'date': '1883-1933',
#     'roles': [{'name': 'cre', 'description': 'Opphavsmann'}],
#     'usage': 'primary',
#     'identifier': 'bibsys.no:authority:1536145200375'}],
#   'geographic': {'placeString': 'Kristiania', 'city': 'Kristiania'},
#   'originInfo': {'publisher': 'Gyldendal',
#    'issued': '1916',
#    'issuedUntouched': '1916',
#    'firstIndexTime': '2021-11-22T09:00:07.166Z',
#    'firstDigitalContentTime': '2016-01-21T12:04:58.006Z'},
#   'recordInfo': {'identifier': '999412501054702202',
#    'identifierSource': 'nb.bibsys.no',
#    'created': '140527'},
#   'classification': {'udc': ['839.6', '839.6 Bul-1']},
#   'identifiers': {'sesamId': '3009697306d79032a57c1eab559010d8',
#    'oaiId': 'oai:nb.bibsys.no:999412501054702202',
#    'urn': 'URN:NBN:no-nb_digibok_2011051604088'},
#   'notes': ['Elektronisk reproduksjon [Norge] Nasjonalbiblioteket Digital 2011-06-21'],
#   'subject': {'topics': ['dikt',
#     'norsk',
#     'litteratur',
#     'lyrikk',
#     'skjønnlitteratur']},
#   'statementOfResponsibility': ['Olaf Bull'],
#   'languages': [{'code': 'nob'}],
#   'pageCount': 97,
#   'mediaTypes': ['bøker'],
#   'contentClasses': ['public', 'legaldeposit', 'jp2', 'publicdomain'],
#   'metadataClasses': ['public'],
#   'literaryform': 'Uklassifisert',
#   'physicalDescription': {'form': ['print',
#     'electronic resource',
#     'remote',
#     'text',
#     'regular print'],
#    'extent': '93 s.'}}}

# %%
df2 = metadata_to_df(metadata)
df2
# Out:
# Received code: 2010051412002, metadata code: 2010060420002
# Received code: 2010041612002, metadata code: 2010041612003
# Received code: 2010040912004, metadata code: 2010041212002
# Received code: 2007073010003, metadata code: 2011041820007
# Received code: 2007121410004, metadata code: 2008040800024
# Received code: 2006120701085, metadata code: 2007080110001
#      year                            author  \
# 0    1947                    Grieg, Nordahl
# 1    1946                    Grieg, Nordahl
# 2    1904                     Ibsen, Henrik
# 3    1921  Welhaven, J.S. (Johan Sebastian)
# 4    1922                   Hægstad, Marius
# ..    ...                               ...
# 151  1913                      Løchen, Arne
# 152  1919                    Kinck, Hans E.
# 153  1926                    Eskeland, Lars
# 154  1943  Welhaven, J.S. (Johan Sebastian)
# 155  1916                        Bull, Olaf
#
#                                                  title  filename code  \
# 0                                         Samlede dikt  2012082408040
# 1                                         Håbet : dikt  2013012806125
# 2    Kæmpehøjen, dramatisk digtning i en akt ; og O...  2010082422026
# 3       Samlede digterverker. 3 : [Halvhundrede Digte]  2007092102002
# 4                            Norsk diktning efter 1814  2006120101048
# ..                                                 ...            ...
# 151                              Digtning og videnskap  2006090100024
# 152  Stammens røst : fem italienske digtere fra vor...  2006082800020
# 153                              Ungdom : dikt i utval  2010053106046
# 154                         Samlede digterverker. B. 2  2008041500052
# 155                                  Digte og noveller  2011051604088
#
#           api code lang
# 0    2012082408040  nob
# 1    2013012806125  nob
# 2    2010082422026  nob
# 3    2007092102002  nob
# 4    2006120101048  mul
# ..             ...  ...
# 151  2006090100024  nob
# 152  2006082800020  nob
# 153  2010053106046  nno
# 154  2008041500052  nob
# 155  2011051604088  nob
#
# [156 rows x 6 columns]

# %% [markdown]
# ## Find the files we want to remove

# %%
df2['filename code'] = df2['filename code'].astype('string')
df["filename code"] = df['filename code'].astype('string')
# Out:
# 0      2012082408040
# 1      2013012806125
# 2      2010082422026
# 3      2007092102002
# 4      2006120101048
#            ...
# 151    2006090100024
# 152    2006082800020
# 153    2010053106046
# 154    2008041500052
# 155    2011051604088
# Name: filename code, Length: 156, dtype: string

# %%
remove_these = set(df2["filename code"]) - set(df["filename code"])
remove_these
# Out:
# {'2006120101048',
#  '2006120500055',
#  '2007060701064',
#  '2008040704116',
#  '2008040904047',
#  '2008041100031',
#  '2009072801107',
#  '2010052806041',
#  '2010053106058',
#  '2010061806033',
#  '2010070106216',
#  '2010070205055',
#  '2011050604018',
#  '2011121308005',
#  '2012011110001',
#  '2012052505023',
#  '2013061408118',
#  '2014102306006'}

# %%
pp = Path("iranai_hocr/")
for x in p.iterdir():
    code = x.name.split("digibok_")[1]
    if code in remove_these:
        dp = pp / x.name
        x.rename(dp)

# %%
df.sort_values("year")
# Out:
#      Unnamed: 0  year              author  \
# 28          173  1902      Sibbern, Georg
# 97          453  1904  Vogt, Nils Collett
# 53          294  1904       Ibsen, Henrik
# 54          296  1905       Ibsen, Henrik
# 23          151  1905      Hovden, Anders
# ..          ...   ...                 ...
# 20          146  1959      Hovden, Anders
# 36          235  1962      Garborg, Hulda
# 95          451  1964  Vogt, Nils Collett
# 105         494  1976      Landstad, M.B.
# 129         572  1981     Birkeland, Rune
#
#                                                  title  filename code  \
# 28                                    Efterladte Digte  2011102524009
# 97                           Fra Vaar til Høst : Digte  2008022904013
# 53   Kæmpehøjen, dramatisk digtning i en akt ; og O...  2010082422026
# 54                           Brand : et dramatisk digt  2010051412002
# 23                                       Salme og Song  2008040201033
# ..                                                 ...            ...
# 20                                        Dikt i utval  2012012308310
# 36                   Den store freden : dramatisk dikt  2008052004044
# 95                                       Et liv i dikt  2010120606023
# 105  M.B. Landstads Kirkesalmebok : revidert og for...  2013012206081
# 129  Norsk salmebok : forslag til felles salmebok f...  2007062904043
#
#           api code lang
# 28   2011102524009  nob
# 97   2008022904013  nob
# 53   2010082422026  nob
# 54   2010060420002  nob
# 23   2008040201033  nno
# ..             ...  ...
# 20   2012012308310  nno
# 36   2008052004044  nno
# 95   2010120606023  nob
# 105  2013012206081  nob
# 129  2007062904043  nob
#
# [138 rows x 7 columns]

# %%
2011102524009 == 2011102524009
# Out:
# True

# %%
# Out:
# {2006081000055,
#  2006082800020,
#  2006082800028,
#  2006082800111,
#  2006083000125,
#  2006083100012,
#  2006083100021,
#  2006090100024,
#  2006113000043,
#  2006120101012,
#  2006120401055,
#  2006120501131,
#  2006120701085,
#  2006121301001,
#  2007011001018,
#  2007011701030,
#  2007062904043,
#  2007073010003,
#  2007092102002,
#  2007121410004,
#  2008012203003,
#  2008021403002,
#  2008022704011,
#  2008022904012,
#  2008022904013,
#  2008032702005,
#  2008040200033,
#  2008040200103,
#  2008040201033,
#  2008040204086,
#  2008040404048,
#  2008040704071,
#  2008040800028,
#  2008040800036,
#  2008040804104,
#  2008041004045,
#  2008041104013,
#  2008041400023,
#  2008041401006,
#  2008041500052,
#  2008041500060,
#  2008042104034,
#  2008052004044,
#  2008082104036,
#  2009013000065,
#  2009062204062,
#  2009070601030,
#  2009070601033,
#  2009070601034,
#  2009071403009,
#  2009082500010,
#  2009100610003,
#  2009111012004,
#  2010010713001,
#  2010011113001,
#  2010011213001,
#  2010011313001,
#  2010011413001,
#  2010011512001,
#  2010011512002,
#  2010040812003,
#  2010040912004,
#  2010040922001,
#  2010041612002,
#  2010051412002,
#  2010051813001,
#  2010052820002,
#  2010053106046,
#  2010060420014,
#  2010060810001,
#  2010060906001,
#  2010061706071,
#  2010070205073,
#  2010070205095,
#  2010070605045,
#  2010070605049,
#  2010070606060,
#  2010070606094,
#  2010071323001,
#  2010071323002,
#  2010071323003,
#  2010071323004,
#  2010071323005,
#  2010071323006,
#  2010071423006,
#  2010082422026,
#  2010102606030,
#  2010111006026,
#  2010111606040,
#  2010120606023,
#  2011040806110,
#  2011041408046,
#  2011041408047,
#  2011041408091,
#  2011041420011,
#  2011041820036,
#  2011042608056,
#  2011050604050,
#  2011050604061,
#  2011051212004,
#  2011051604088,
#  2011052404044,
#  2011053104018,
#  2011060804031,
#  2011071506014,
#  2011102524009,
#  2011102708060,
#  2011102708082,
#  2011121410001,
#  2012012308310,
#  2012022212004,
#  2012030208173,
#  2012032024065,
#  2012071208112,
#  2012082408040,
#  2012091208049,
#  2012100907114,
#  2012100907178,
#  2012101007011,
#  2012101105061,
#  2012102608111,
#  2012111406067,
#  2012121105093,
#  2013012108002,
#  2013012108014,
#  2013012206081,
#  2013012806125,
#  2013053008130,
#  2013061108035,
#  2013061108130,
#  2013061808193,
#  2013070308028,
#  2013070308043,
#  2013072208048,
#  2013072208051,
#  2013072208052,
#  2013073008139,
#  2013081206032}

# %% [markdown]
# ### TODO:
# Stille sammen data slik at vi har en all_data og en post_1900 med alle tekstfilene.
# Denne skal legges ut

# %% [markdown]
# ## Remove the dont-need from xml files

# %%
from pathlib import Path

p = Path("reocr_batch_2/digibok/")
i = 0
for x in p.iterdir():
    code = x.name.split("digibok_")[1]
    i += 1
    #print(code)
print(i)
