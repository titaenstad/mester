# %%
from collections import Counter

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# #### The first part of the form has 3 questions for each pair of stanzas.
# #### The second part of the form has 2 question for each stanza

# %% [markdown]
# # Collect annotations for pairwise comparisons

# %%
def get_pairwise_annotation_df(form_csv_path, source_tsv_path):
    df = pd.read_csv(form_csv_path)
    df = df.T
    
    source_df = pd.read_csv(source_tsv_path, sep="\t")
    source_df["order_in_pair"] = [1,2]*(len(source_df)//2)
    written_by_human = source_df.loc[source_df["type"]=="orig"].order_in_pair
    
    choose_human_prompt = "Hvilket vers er skrevet av et menneske?"
    rhymes_v1 = "Er vers 1 skrevet på rim?"
    rhymes_v2 = "Er vers 2 skrevet på rim?"

    rated_human = []
    rhyme_rating = []    

    for i, gold in enumerate(written_by_human):
        human_s = choose_human_prompt
        v1_s = rhymes_v1
        v2_s = rhymes_v2
        if i:
            human_s += f".{i}"
            v1_s += f".{i}"
            v2_s += f".{i}"

        orig_rated_human = df.loc[human_s]
        orig_rated_human = [int(e.split()[1])==gold for e in orig_rated_human]

        rhyme_v1 = list(df.loc[v1_s].apply(int))
        rhyme_rating.append(rhyme_v1)

        rhyme_v2 = list(df.loc[v2_s].apply(int))
        rhyme_rating.append(rhyme_v2)


        i = i*2
        if source_df.loc[i].type == "orig":
            rated_human.append(orig_rated_human)
            rated_human.append([not(e) for e in orig_rated_human])
        else:
            rated_human.append([not(e) for e in orig_rated_human])
            rated_human.append(orig_rated_human)


    source_df["rated_human"] = rated_human
    source_df["rhyme_rating"] = rhyme_rating
    return source_df

# %% [markdown]
# # Collect annotations for standalone verses

# %%
def get_standalone_annotation_df(form_csv_path, source_tsv_path):
    df = pd.read_csv(form_csv_path)
    df = df.T
    
    source_df = pd.read_csv(source_tsv_path, sep="\t")
    rhymes_q = "Er verset skrevet på rim?"
    human_q = "Er verset skrevet av et menneske?"

    rated_human = []
    rhyme_rating = []    

    for i in range(len(source_df)):
        human_s = human_q
        rhymes_s = rhymes_q
        if i:
            human_s += f".{i}"
            rhymes_s += f".{i}"

        rated_human.append([e=="Ja" for e in df.loc[human_s]])
        rhyme_rating.append(list(df.loc[rhymes_s].apply(int))) 

    source_df["rated_human"] = rated_human
    source_df["rhyme_rating"] = rhyme_rating

    return source_df

# %% [markdown]
# # Summary

# %%
def get_avg_rhyme_rating(df):
    return round(np.mean([n for e in df["rhyme_rating"] for n in e]), 2)

def get_rated_human_percentage(df, not_human=False):
    rated = [e for l in df["rated_human"] for e in l]
    if not_human:
        return round(np.mean([not(e) for e in rated])*100, 2)
    return round(np.mean(rated)*100, 2)

# %% [markdown]
# # Look at results

# %%
side_by_side_df = pd.DataFrame({})
standalone_df = pd.DataFrame({})

for i in range(1, 5):
    df = get_pairwise_annotation_df(f"annotations/Evaluering av AI-genererte dikt og rim {i}.csv",
                                   f"side_by_side_form_{i}.tsv")
    df["form_number"] = [i]*len(df)
    side_by_side_df = pd.concat([side_by_side_df, df])
    
    df = get_standalone_annotation_df(f"annotations/Evaluering av AI-genererte dikt og rim {i}.csv",
                                     f"rest_{i}.tsv")
    df["form_number"] = [i]*len(df)
    standalone_df = pd.concat([standalone_df, df])

# %%
standalone_df
# Out:
#     Unnamed: 0  type  scheme  \
# 0            5  line    ABCB
# 1            3  orig     AAB
# 2            4  orig    AABB
# 3            0  orig  ABCCAB
# 4           15  base       -
# ..         ...   ...     ...
# 15           9  line  ABABCC
# 16          19  base       -
# 17          18  base       -
# 18           7  line  ABABCC
# 19           8  line  ABABCC
#
#                                                stanza  \
# 0    med yndig majestet han går \n som gjorde sinn...
# 1   hva er det for et mektig lys\ndet farer som et...
# 2   skurken saulus løfter armen\natter dette stikk...
# 3   frysende skinner det store og sanne\nvarme har...
# 4    og til han far elsket sønn så fordum lystig v...
# ..                                                ...
# 15   skjønt hver av dem er kraftig som en hest \n ...
# 16   hvor vred ble det kryp i sne \n som bølger i ...
# 17   ta dem dog av meg selv \n over denne dag jeg ...
# 18   og enda ser a ut som a var bare skinn og bein...
# 19   folkets hån ham gjennomstinger \n sangen fore...
#
#                                          rated_human           rhyme_rating  \
# 0     [False, True, True, False, False, False, True]  [3, 3, 3, 3, 3, 2, 3]
# 1        [True, True, False, True, True, True, True]  [2, 3, 3, 2, 2, 2, 2]
# 2      [True, True, False, False, True, True, False]  [3, 3, 3, 3, 3, 3, 3]
# 3      [True, False, False, False, True, True, True]  [2, 3, 3, 3, 3, 2, 2]
# 4   [True, False, False, False, False, False, False]  [3, 3, 3, 2, 2, 1, 2]
# ..                                               ...                    ...
# 15          [False, True, False, False, False, True]     [2, 2, 2, 2, 2, 2]
# 16           [True, False, False, True, True, False]     [1, 1, 1, 1, 3, 1]
# 17        [False, False, False, False, False, False]     [0, 0, 0, 0, 0, 0]
# 18            [False, True, False, True, True, True]     [3, 3, 3, 3, 3, 2]
# 19          [False, True, False, True, False, False]     [2, 2, 1, 2, 2, 1]
#
#     form_number
# 0             1
# 1             1
# 2             1
# 3             1
# 4             1
# ..          ...
# 15            4
# 16            4
# 17            4
# 18            4
# 19            4
#
# [80 rows x 7 columns]

# %%
side_by_side_df
# Out:
#     Unnamed: 0    type  scheme  \
# 0           20  stanza    ABAB
# 1            0    orig  AABCCB
# 2            1    orig    ABAB
# 3           18    line    ABAB
# 4           16    line    ABAB
# ..         ...     ...     ...
# 25          27    base       -
# 26          13    orig    ABAB
# 27          28    base       -
# 28          14    orig    AABB
# 29          22  stanza  AABCBC
#
#                                                stanza  pair_number  \
# 0    her hørte dalen her så det seg svang \n runde...            0
# 1   sjo-i sjo-i hyss\nsang jeg om et kyss\nnei det...            0
# 2   du den høyeste blandt høye\ndu den viseste bla...            1
# 3    inn i fjellets flammesky \n en lovsangs brus ...            1
# 4    landets fiender og dro \n la min unge søsters...            2
# ..                                                ...          ...
# 25   jeg er død som en byrde i mørket lyser \n og ...           12
# 26  for henne selv ble livet nu\nen natt hvor inge...           13
# 27   ti falt ei het og vill \n av byens siste natt...           13
# 28  å nå forstår jeg det var ham\njeg drømte om de...           14
# 29   se sitt forgylte embedsskrud \n går han som f...           14
#
#     order_in_pair                                       rated_human  \
# 0               1  [False, False, True, False, False, False, False]
# 1               2       [True, True, False, True, True, True, True]
# 2               1      [True, True, False, False, True, True, True]
# 3               2   [False, False, True, True, False, False, False]
# 4               1   [False, True, True, False, False, False, False]
# ..            ...                                               ...
# 25              2          [True, False, False, False, True, False]
# 26              1              [True, True, True, True, True, True]
# 27              2        [False, False, False, False, False, False]
# 28              1              [True, True, True, True, True, True]
# 29              2        [False, False, False, False, False, False]
#
#              rhyme_rating  form_number
# 0   [3, 3, 2, 3, 3, 1, 3]            1
# 1   [3, 3, 3, 3, 3, 3, 3]            1
# 2   [3, 3, 3, 3, 3, 3, 3]            1
# 3   [3, 3, 3, 3, 3, 0, 3]            1
# 4   [3, 3, 3, 3, 3, 1, 3]            1
# ..                    ...          ...
# 25     [0, 0, 0, 0, 0, 0]            4
# 26     [3, 3, 3, 3, 3, 3]            4
# 27     [0, 0, 0, 0, 0, 0]            4
# 28     [3, 3, 3, 3, 3, 3]            4
# 29     [3, 2, 2, 3, 3, 3]            4
#
# [120 rows x 9 columns]

# %%
base = side_by_side_df.loc[side_by_side_df["type"]=="base"]
line = side_by_side_df.loc[side_by_side_df["type"]=="line"]
stanza = side_by_side_df.loc[side_by_side_df["type"]=="stanza"] 
orig = side_by_side_df.loc[side_by_side_df["type"]=="orig"] 

print(f"""
PAIRWISE ratings results:
    Original stanzas:
        Average rhyme rating                   : {get_avg_rhyme_rating(orig)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(orig)}
    
    Baseline generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(base)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(base)}
    
    Line-level generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(line)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(line)}
        
    Stanza-level generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(stanza)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(stanza)}
""")
# Out:
# PAIRWISE ratings results:
#     Original stanzas:
#         Average rhyme rating                   : 2.61
#         % of times rated 'written by a human'  : 85.19
#
#     Baseline generation:
#         Average rhyme rating                   : 0.61
#         % of times rated 'written by a human'  : 19.26
#
#     Line-level generation:
#         Average rhyme rating                   : 2.33
#         % of times rated 'written by a human'  : 17.78
#
#     Stanza-level generation:
#         Average rhyme rating                   : 2.02
#         % of times rated 'written by a human'  : 7.41

# %%
base = standalone_df.loc[standalone_df["type"]=="base"]
line = standalone_df.loc[standalone_df["type"]=="line"]
stanza = standalone_df.loc[standalone_df["type"]=="stanza"] 
orig = standalone_df.loc[standalone_df["type"]=="orig"] 

print(f"""
STANDALONE ratings results:
    Original stanzas:
        Average rhyme rating                   : {get_avg_rhyme_rating(orig)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(orig)}
    
    Baseline generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(base)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(base)}
    
    Line-level generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(line)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(line)}
        
    Stanza-level generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(stanza)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(stanza)}
""")
# Out:
# STANDALONE ratings results:
#     Original stanzas:
#         Average rhyme rating                   : 2.68
#         % of times rated 'written by a human'  : 82.96
#
#     Baseline generation:
#         Average rhyme rating                   : 0.91
#         % of times rated 'written by a human'  : 25.19
#
#     Line-level generation:
#         Average rhyme rating                   : 2.2
#         % of times rated 'written by a human'  : 48.89
#
#     Stanza-level generation:
#         Average rhyme rating                   : 1.79
#         % of times rated 'written by a human'  : 11.11

# %%
total_df = pd.concat([standalone_df, side_by_side_df])

base = total_df.loc[total_df["type"]=="base"]
line = total_df.loc[total_df["type"]=="line"]
stanza = total_df.loc[total_df["type"]=="stanza"] 
orig = total_df.loc[total_df["type"]=="orig"] 

print(f"""
COMBINED ratings results:
    Original stanzas:
        Average rhyme rating                   : {get_avg_rhyme_rating(orig)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(orig)}
    
    Baseline generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(base)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(base)}
    
    Line-level generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(line)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(line)}
        
    Stanza-level generation:
        Average rhyme rating                   : {get_avg_rhyme_rating(stanza)}
        % of times rated 'written by a human'  : {get_rated_human_percentage(stanza)}
""")
# Out:
# COMBINED ratings results:
#     Original stanzas:
#         Average rhyme rating                   : 2.63
#         % of times rated 'written by a human'  : 84.63
#
#     Baseline generation:
#         Average rhyme rating                   : 0.76
#         % of times rated 'written by a human'  : 22.22
#
#     Line-level generation:
#         Average rhyme rating                   : 2.27
#         % of times rated 'written by a human'  : 33.33
#
#     Stanza-level generation:
#         Average rhyme rating                   : 1.91
#         % of times rated 'written by a human'  : 9.26

# %% [markdown]
# # Find most controversial stanzas

# %%
def rhyme_controversial_stanzas(df, threshold=3):
    
    def above_threshold(ratings):
        ma = max(ratings)
        mi = min(ratings)
        return ma-mi
    
    df = df.copy()   
    df["rhyme_diff"] = df.rhyme_rating.apply(above_threshold)
    
    return df.loc[df["rhyme_diff"]>=threshold]

def human_controversial(df, threshold=3):
    
    def count_true_ratings(ratings):
        return sum(ratings)
    
    def count_false_ratings(ratings):
        c_true = count_true_ratings(ratings)
        c_false = len(ratings)-c_true
        return c_false
    
    df = df.copy()
    df["count_human"] = df.rated_human.apply(count_true_ratings)
    df["count_not_human"] = df.rated_human.apply(count_false_ratings)
    return df.loc[(df["count_human"] >= threshold) & (df["count_not_human"] >= threshold)]

# %%
rh_con = rhyme_controversial_stanzas(total_df)
                                    
print(len(rh_con))

for e in rh_con.itertuples():
    print(e.rhyme_rating)
    print(e.type)
    print(e.stanza)
    print("--\n")
# Out:
# 19
# [3, 2, 0, 2, 2, 1, 2]
# stanza
#  hvor bårer med skum over utsteinen slår
#  og kjølens siste bakker i det kildested
#  det første hender med høstens redsler død
#  hin yngste apall strør blikke hevet goder tå flyver ned
# --
#
# [3, 2, 3, 2, 2, 0, 3]
# orig
# da lyner et lys ned i dypet
# en gnistrende sprøyt av ild
# det glitrer av blånende bølger
# er havet likevel til
# --
#
# [2, 1, 3, 1, 1, 0, 1]
# base
#  så stolt som sus av ført over vannet
#  bak litt av hundre om fabrikk
#  steg opp av deres dyp var plass
#  som vrak på femti favne
#
#
# --
#
# [2, 1, 3, 2, 2, 0, 2]
# line
#  der sisler stekepanner fylt med flesk og småmakrell
#  der sitter på fluberget tusner av fugl
#  menn og kvinner tatt i ed
#  der er rom hans lengsels mål og med
# --
#
# [3, 2, 1, 1, 0, 0, 2]
# line
#  alene mot tuseners raseri
#  de onde omringer mitt leie
#  og klokker med gullplateklang
#  alt er nå blitt fryd og lyst
#  vekker landets storhet noen gjenklang i hans bryst
#  tro som en sang
# --
#
# [3, 2, 2, 0, 2, 1, 3]
# orig
# til oppbrudd blir allting gjort istand
# mens skumringen faller på
# skjønt veien er stengt av det brusende hav
# så skal de bent fremad gå
# --
#
# [3, 1, 0, 1, 0, 1, 2]
# stanza
#  til han fikk sove en officer
#  minnes av en hjelm en tross officer
#  og mulden det var koldt lik en som var bak en såmann smertenes her
# --
#
# [3, 3, 3, 3, 3, 0, 3]
# line
#  inn i fjellets flammesky
#  en lovsangs brus som storm mot sky
#  fra sinnet på ny og på ny
#  fra sinnet på ny og på ny
# --
#
# [2, 3, 3, 2, 2, 1, 0]
# orig
# tillykke med dåden dere frelste imperiet
# mac donald og thomas og henderson
# og jobben var hård dere fortjener en ferie
# men først må dere kysse hr. baldwins hånd
# --
#
# [2, 2, 3, 2, 2, 0, 0]
# line
#  dødens bytte aldri blir
#  og budet våk og bed
#  som ormen dypt i muld
#  men ble lys for lys og fred
# --
#
# [2, 3, 2, 2, 2, 0, 2]
# base
#  paulus av dem andre dog han stand
#  dagens minner i brann
#  og de ser mot evighetens flod
#  og tente dagen over støvets veie
#
#
# --
#
# [2, 3, 3, 2, 2, 0, 2]
# stanza
#  og thomas og jakker
#  hvis budskap bed
#  for velfylt liv
#  tankens mæler var lang søkt fred
# --
#
# [2, 3, 0, 2, 0, 0, 0]
# base
#  vi vet det ham dog må sprenges
#  skipet han kjenner seg kjemper
#  hver dag etter år
#  går mengden på sin tid
#  over seirens dag til gry
#
#
# --
#
# [1, 3, 1, 0, 0, 0, 0]
# base
#  og tross den tross dødninghaven
#  over vennens liv er bange
#  hver gang han synger se ham
#  den er seirens dag til gry
#
#
# --
#
# [3, 2, 1, 1, 0, 1, 1]
# stanza
#  og av det dype vell
#  i det av det dype vell
#  og godt sa kar han
#  de første var ivare
#  med berguhyre
#  lyktenes brune i holmer slør land
# --
#
# [2, 3, 2, 2, 2, 0, 3]
# line
#  det ruller nokså ille og han setter sjøgangsben
#  det regner igjen
#  til deg så i hvis sanger-vår
#  med yndig majestet han går
#  ja selv sin egen salighet
#  og bøkene hos karpus som du vet
# --
#
# [0, 0, 0, 0, 0, 0, 3]
# base
#  skal vi bringe oss i dette bilde
#  og slekter som kjenner vår ætt
#  all nød og strid til dåd
#
#
# --
#
# [3, 3, 3, 3, 0, 2, 3]
# stanza
#  den hedningeby
#  ved heltens tordensky
#  lyster hill pelen gry
# --
#
# [0, 0, 0, 0, 0, 1, 3]
# base
#  da stod de på sterke vakt
#  rundt rundt og går rundt de to
#  to de sterke talløse hender
#  i nattens skjul fra muren ned
#
#
# --

# %%
h_con = human_controversial(total_df)

print(len(h_con))

for e in h_con.itertuples():
    print(e.rated_human)
    print("actual type:", e.type)
    print("--")
    print(e.stanza)
    print("--\n")
# Out:
# 25
# [False, True, True, False, False, False, True]
# actual type: line
# --
#  med yndig majestet han går
#  som gjorde sinnet blått av romantikk
#  vansiret av laster sykdom og sår
#  plutselig stod stauper igjen for mitt blikk
# --
#
# [True, True, False, False, True, True, False]
# actual type: orig
# --
# skurken saulus løfter armen
# atter dette stikk i barmen
# denne angst de syner røde
# taus han stirrer på den døde
# --
#
# [True, False, False, False, True, True, True]
# actual type: orig
# --
# frysende skinner det store og sanne
# varme har titt klekket øgler av nid
# du dødning deroppe sumpen er lunken
# hat er på jorden himlen er sunken
# så merk da med offerets islys vår panne
# rid rytter rid
# --
#
# [False, False, True, True, False, False, True]
# actual type: base
# --
#  på abel-meholas marker
#  i harpen i favn
#  og spiller
#  i skjebnens skjulte ro
#  hvorfor vil jeg deg til gavn
#  o når du er det tvilen er din tilflukt
#  i hvert hjerte ligger der
#
#
# --
#
# [True, False, False, False, True, False, True]
# actual type: stanza
# --
#  nuets underveis
#  se det er det jovisst
#  der ligger så stille mot vest hvor sol går ned
#  som klippene og sluttet kvist
# --
#
# [False, True, False, False, True, True, False]
# actual type: line
# --
#  ennu en dag uten den
#  tross venners advarsler bønner og klage
#  hvor engang hellig offerild
#  som du nå ser det glitre og tindre
# --
#
# [True, False, True, True, False, False, False]
# actual type: line
# --
#  alene mot tuseners raseri
#  de onde omringer mitt leie
#  og klokker med gullplateklang
#  alt er nå blitt fryd og lyst
#  vekker landets storhet noen gjenklang i hans bryst
#  tro som en sang
# --
#
# [True, False, True, False, True, False, True]
# actual type: orig
# --
# at de er spinkle så man skjelner hvert et ben
# det er det ingen av dem selv som merker
# for nye safter suser i hver gren
# og selv i by gjør våren underverker
# --
#
# [True, False, True, False, True, False, True]
# actual type: orig
# --
# til oppbrudd blir allting gjort istand
# mens skumringen faller på
# skjønt veien er stengt av det brusende hav
# så skal de bent fremad gå
# --
#
# [True, False, False, True, False, True, True]
# actual type: line
# --
#  ved dvergers spill og gledesgny
#  om den klare høysommerdag
#  som om det er av en dag
#  tusende seil bær den rikdom og ry
# --
#
# [False, True, False, True, True, True, False]
# actual type: orig
# --
# og man har i disse egne
# fra den tid et munnhell hatt
# som i korthet kan betegne
# gudmund storebingens kraft
# --
#
# [True, True, False, False, False, True, False]
# actual type: base
# --
#  så må de ha vise
#  kan trenge seg inn
#  nå er den å farvel farvel
#  å farvel farvel
#  du som fulgte i somre atten
#
#
# --
#
# [True, True, True, False, False, True, False]
# actual type: base
# --
#  ensomhet er du
#  hva skal israels gud
#  kong saul kneler ned
#  over de høye fjelle
#  du vet hva du skal og bøte
#  kun dens frihet gav
#  og at svenske sverd kan bite
#  litt om gangen av
#
# --
#
# [True, True, False, False, False, False, True]
# actual type: base
# --
#  så lærer det reist seg i flokk fra vår fjord
#  og flykter i stimer til finnmark i nord
#  det står de himmelske duft mot himlens buer
#  som makter krig trygg hvor sjøene faller
#  å våkne til hav og ro går ut
#  mens solen i natten fra skyenes rull
#  har pusset mot havet sitt himmelske gull
#  som en skinnende lysestake
#
#
# --
#
# [False, True, False, True, False, True, False]
# actual type: line
# --
#  forgjeves ei bud ble ham sendt
#  av arisk kraft til hundrede procent
#  hvem vet jeg her og ser hva er hendt
# --
#
# [True, True, False, True, False, False, True]
# actual type: line
# --
#  og siden fler som perler i en kjede
#  antiokia forstår
#  guds løftes land hans fot ei får betrede
#  de hjerter her var skapt av sorg og glede
#  og voktet gjeter kveg og får
# --
#
# [True, False, False, True, True, False]
# actual type: base
# --
#  hvor vred ble det kryp i sne
#  som bølger i klipper og fjord
#  mens bølgen og mørke blir toner
#  med tenner av gull i munn
#  pesetas dollar og franc og pund
#
#
# --
#
# [False, True, True, True, False, False, False]
# actual type: base
# --
#  paulus av dem andre dog han stand
#  dagens minner i brann
#  og de ser mot evighetens flod
#  og tente dagen over støvets veie
#
#
# --
#
# [True, False, False, False, True, True, True]
# actual type: orig
# --
# omsider er han oppe men en storm som den han møter
# ikveld har kalsen aldri møtt på noe hav han for
# da hadde det vært bedre med arrest og brisk og bøter
# der flyr det alt imot ham et par jernbeslåtte skor
# --
#
# [False, False, True, False, True, True, False]
# actual type: orig
# --
# det følte hver som kom
# fra reis igjen og så seg om
# det følte hver som gikk
# i siste avskjedsblikk
# --
#
# [True, True, False, True, False, False, True]
# actual type: line
# --
#  sjelevingens hvilegren
#  har båret det ord og det ble igjen
#  frem stormer egyptens armé
#  et dryssende stjernegry
#  fra sinnet på ny og på ny
#  hans veier ble lys for lys og fred
# --
#
# [True, False, False, False, False, True, True]
# actual type: base
# --
#  der sisler stekepanner fylt med flesk og småmakrell
#  og veggene gir gjenlyd av de sultne ungers sprell
#  ja nesten at vi flokk vi stirrede mot
#  og skjær går frem som en skygge
#  hvor ingen havets ås
#  fikk den seg somren til
#
#
# --
#
# [False, True, True, True, True, False, False]
# actual type: orig
# --
# barnabas med takk og glede
# rekker paulus broderhånd
# knytter gjerne gamle bånd
# føyer dertil dog en bønn
# la min unge søstersønn
# lenkes til vår broderkjede
# --
#
# [True, False, False, True, False, True, True]
# actual type: base
# --
#  men se han kommer med venner
#  på klippens bryst da lød
#  evangeliets herlige bud
#
#
# --
#
# [False, True, True, False, True, False, False]
# actual type: orig
# --
# å våke over fedrelandets lover
# å sørge for at ingenting forlises
# er smukt betryggende for folkehellet
# men det er skjønnere med ånd å våge
# å slå med moses tryllestav på fjellet
# skjønt nytten ei kan fattes og bevises
# --

# %% [markdown]
# # Find original stanzas rated 'not human'

# %%
orig = total_df.loc[total_df["type"]=="orig"].copy()

def avg_rating(ratings):
    s = sum(ratings)
    return s/len(ratings)

orig["avg_human_rating"] = orig.rated_human.apply(avg_rating)
hu = orig.loc[orig["avg_human_rating"]<=0.5]
for e in hu.itertuples():
    print(e.rated_human)
    print(e.scheme)
    print(e.stanza)
    print("--\n")
# Out:
# [False, False, False, False, True, True, False]
# ABAB
# tillykke med dåden dere frelste imperiet
# mac donald og thomas og henderson
# og jobben var hård dere fortjener en ferie
# men først må dere kysse hr. baldwins hånd
# --
#
# [False, False, True, False, True, True, False]
# AABB
# det følte hver som kom
# fra reis igjen og så seg om
# det følte hver som gikk
# i siste avskjedsblikk
# --
#
# [False, True, True, False, True, False, False]
# ABCDCB
# å våke over fedrelandets lover
# å sørge for at ingenting forlises
# er smukt betryggende for folkehellet
# men det er skjønnere med ånd å våge
# å slå med moses tryllestav på fjellet
# skjønt nytten ei kan fattes og bevises
# --

# %%
hu
# Out:
#     Unnamed: 0  type  scheme  \
# 7            3  orig    ABAB
# 14           7  orig    AABB
# 17           8  orig  ABCDCB
#
#                                                stanza  \
# 7   tillykke med dåden dere frelste imperiet\nmac ...
# 14  det følte hver som kom\nfra reis igjen og så s...
# 17  å våke over fedrelandets lover\nå sørge for at...
#
#                                         rated_human           rhyme_rating  \
# 7   [False, False, False, False, True, True, False]  [2, 3, 3, 2, 2, 1, 0]
# 14   [False, False, True, False, True, True, False]  [3, 3, 3, 3, 3, 3, 3]
# 17   [False, True, True, False, True, False, False]  [2, 3, 2, 2, 2, 2, 2]
#
#     form_number  pair_number  order_in_pair  avg_human_rating
# 7             1          3.0            2.0          0.285714
# 14            2          7.0            1.0          0.428571
# 17            3          8.0            2.0          0.428571

# %%
for f, p in zip(hu.form_number, hu.pair_number):
    s = side_by_side_df.loc[(side_by_side_df.form_number == f) & (side_by_side_df.pair_number == p)]
    for e in s.itertuples():
        print(e.rhyme_rating)
        print(e.type)
        print(e.rated_human)
        print(e.stanza)
        print("")
    print("___________________--___________________")
# Out:
# [2, 3, 3, 2, 2, 1, 1]
# line
# [True, True, True, True, False, False, True]
#  han er jo
#  hva var det en guds fiolin
#  templet du har skjendet med vold og blod
#  især i det siste de trenger seg inn
#
# [2, 3, 3, 2, 2, 1, 0]
# orig
# [False, False, False, False, True, True, False]
# tillykke med dåden dere frelste imperiet
# mac donald og thomas og henderson
# og jobben var hård dere fortjener en ferie
# men først må dere kysse hr. baldwins hånd
#
# ___________________--___________________
# [3, 3, 3, 3, 3, 3, 3]
# orig
# [False, False, True, False, True, True, False]
# det følte hver som kom
# fra reis igjen og så seg om
# det følte hver som gikk
# i siste avskjedsblikk
#
# [3, 3, 2, 1, 1, 1, 3]
# line
# [True, True, False, True, False, False, True]
#  sjelevingens hvilegren
#  har båret det ord og det ble igjen
#  frem stormer egyptens armé
#  et dryssende stjernegry
#  fra sinnet på ny og på ny
#  hans veier ble lys for lys og fred
#
# ___________________--___________________
# [0, 1, 0, 0, 0, 0, 1]
# base
# [True, False, False, True, False, True, True]
#  men se han kommer med venner
#  på klippens bryst da lød
#  evangeliets herlige bud
#
#
#
# [2, 3, 2, 2, 2, 2, 2]
# orig
# [False, True, True, False, True, False, False]
# å våke over fedrelandets lover
# å sørge for at ingenting forlises
# er smukt betryggende for folkehellet
# men det er skjønnere med ånd å våge
# å slå med moses tryllestav på fjellet
# skjønt nytten ei kan fattes og bevises
#
# ___________________--___________________

# %% [markdown]
# ## Plot rhyme ratings

# %%
def get_rhyme_ratings_counts(type_):
    ratings = list(standalone_df.loc[standalone_df["type"]==type_].rhyme_rating) + list(side_by_side_df.loc[side_by_side_df["type"]==type_].rhyme_rating)
    flat_ratings = [r for rates in ratings for r in rates]
    return Counter(flat_ratings)

c_base = get_rhyme_ratings_counts("base")
c_line = get_rhyme_ratings_counts("line")
c_stanza = get_rhyme_ratings_counts("stanza")
c_orig =  get_rhyme_ratings_counts("orig")

# %%
base = sorted(list(c_base.items()), key=lambda x: x[0])
line = sorted(list(c_line.items()), key=lambda x: x[0])
stanza = sorted(list(c_stanza.items()), key=lambda x: x[0])
orig = sorted(list(c_orig.items()), key=lambda x: x[0])

line = [(_, c/sum(c_line.values())*100) for _, c in line]
base = [(_, c/sum(c_base.values())*100) for _, c in base]
stanza = [(_, c/sum(c_stanza.values())*100) for _, c in stanza]
orig = [(_, c/sum(c_orig.values())*100) for _, c in orig]

# %%
labels, base_counts = zip(*base)
_, line_counts = zip(*line)
_, stanza_counts = zip(*stanza)
_, orig_counts = zip(*orig)

# %%
len(labels)
# Out:
# 4

# %%
br4
# Out:
# [0.44999999999999996,
#  1.4499999999999997,
#  2.4499999999999997,
#  3.4499999999999997]

# %%
fig, ax = plt.subplots(figsize=(10,5))

barWidth = 0.15

# Set position of bar on X axis
br1 = np.arange(len(labels))
br2 = [x + barWidth for x in br1]
br3 = [x + barWidth for x in br2]
br4 = [x + barWidth for x in br3]

# Make the plot
plt.bar(br1, base_counts, color ='pink', width = barWidth,
        edgecolor ='grey', label ='Base')
plt.bar(br2, stanza_counts, color ='lightblue', width = barWidth,
        edgecolor ='grey', label ='Stanza')
plt.bar(br3, line_counts, color ='b', width = barWidth,
        edgecolor ='grey', label ='Line')
plt.bar(br4, orig_counts, color ='purple', width = barWidth,
        edgecolor ='grey', label ='Orig')

plt.xlabel('Rhyme rating', fontsize = 15)
plt.ylabel('% of stanzas rated', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(labels))], labels)
 
plt.legend()
plt.show()

# %%
for e in total_df.loc[total_df.type == "stanza"].itertuples():
    print(e.rhyme_rating)
    print(e.stanza)
    print(e.form_number)
    print("")
# Out:
# [3, 2, 0, 2, 2, 1, 2]
#  hvor bårer med skum over utsteinen slår
#  og kjølens siste bakker i det kildested
#  det første hender med høstens redsler død
#  hin yngste apall strør blikke hevet goder tå flyver ned
# 1
#
# [2, 2, 3, 2, 2, 1, 2]
#  vel fiolin
#  jeg satt med i varme hud
#  men stod under vold og fred
#  og maktet skjold hadde prisen gud
# 1
#
# [2, 2, 2, 2, 2, 1, 2]
#  opp jeg bygge grensen bered
#  frossen fred
#  og lang er av prøvesten
#  bak arne ring gikk på høyens atten
# 1
#
# [2, 2, 2, 2, 2, 0, 2]
#  nuets underveis
#  se det er det jovisst
#  der ligger så stille mot vest hvor sol går ned
#  som klippene og sluttet kvist
# 1
#
# [2, 2, 1, 2, 2, 0, 2]
#  og følge i ro av savn ildstråleflor
#  hvor jeg spør deg han skjønnere skal storm
#  o gud og lenge lyse søstersønn
#  spredt jord og slappe slappe stæders trollmann krigerby vande vandringsmann beklemt lyster utsikt lønn
# 1
#
# [1, 0, 0, 0, 0, 0, 1]
#  det mørkner det legems klare hjerne
#  den sløyer og slynger seg om stolt og om mast
#  langs berget de modig seg for korsets kyst
#  og trosse trollmenn ytterst evne
# 2
#
# [3, 3, 2, 2, 3, 3, 3]
#  med ett og sank med en aftenvind
#  i vår brudekrans
#  og tiden var falt mellom vin og glans
#  jeg led den sølvsardin
# 2
#
# [3, 3, 3, 3, 3, 3, 2]
#  for jeg lærte meg selv i denne iblant
#  er kommet er det dype sjelesår
#  om lys av sol i sol og vår
#  og tåker bærer og odins sanne forsvant
# 2
#
# [3, 2, 1, 2, 2, 1, 2]
#  barnet som hedenske embedsmenn
#  derfor fulgte med dens menn
#  det var i det brune blikk i hand
#  så jeg fra meg her og nå er det stiv
#  side kamerat sæd holder liv
#  fra jakob lenges ånd
# 2
#
# [2, 2, 1, 2, 1, 0, 2]
#  av en brottsjø som gikk bak
#  for solens skinn av splid
#  selv til naturens livets tid
#  vesen hjelpe så et modig kamp
# 2
#
# [2, 3, 3, 3, 3, 3, 3]
#  for hele havets tull
#  og i altet tryllerull
#  da ble opprørske grodde muld
# 3
#
# [3, 1, 0, 1, 0, 1, 2]
#  til han fikk sove en officer
#  minnes av en hjelm en tross officer
#  og mulden det var koldt lik en som var bak en såmann smertenes her
# 3
#
# [1, 2, 2, 1, 2, 2, 2]
#  hvem er der jeg her stenger 's
#  jeg kom der la nå i det hele skal sage
#  stryke fossegrimens dans
#  så ville jeg i at reise en krans
#  av bårene lille rase lille solskinn hadde lysestake
# 3
#
# [2, 3, 3, 2, 2, 2, 2]
#  fjellene i storfangst går og fuglesang
#  hvis morgenglans er klokkeklang
#  lukk mitt nordlys jøde kastes begynte stamsund flod nærmer sang
# 3
#
# [2, 3, 2, 2, 2, 1, 2]
#  en smed
#  mildt der aldri får en flod
#  liten først dog tiden kunde de få bered
#  så kan han som kampens angst våk og bed
#  og blende lever neppe tankens vredes maktet evighetsro
# 3
#
# [1, 2, 2, 2, 2, 2]
#  disse det atter nøye
#  svarte jorden helt kan
#  all ditt mektige øye
#  et brus ingen speider ut over land
#  trellen i bygde parat
#  flettes a bleke bleke natt
# 4
#
# [2, 1, 1, 3, 2, 1]
#  der kanskje du hold ut i tidevann
#  jeg vil fløt i dem bo her i en sovekupé
#  dem nå er gått over sjøen i land
#  den stille fred
#  det bølgende hedersmann
#  lyktenes brune i holmer slør land
# 4
#
# [3, 2, 3, 3, 3, 2]
#  paulus ser han broderhånd
#  mesteren han vil i sitt morgengry
#  så vant vi så vant jeg min lenge i hånd
#  norge er i vår gate hvor en by
#  vi rustet her oss her hvor blomstring og skrammer
#  sopper blander hvormed bølgekammer
# 4
#
# [1, 0, 0, 0, 1, 0]
#  nå har du våren i blomst ved dag
#  det jevnet vår stol på hvert et tog
#  var slik en dom i syrerslaget
#  over alt der finnes så ny man mer storedragen
#  under blomster på fjorden uten lysestake
#  begeistringen lakker bedrifter fostret siden
# 4
#
# [2, 0, 1, 1, 2, 1]
#  det regnet hadde tenkt da han taler
#  om bergets topp til havet endelig steg
#  det lyner fra lien og palmer
#  når natten kryper mengden på sin vei
#  der ligger splittet frem den svømmer i de hernord
#  i soldis morgenrøde trettes hvelvet jord
# 4
#
# [3, 3, 2, 3, 3, 1, 3]
#  her hørte dalen her så det seg svang
#  rundet det grønnes rikt på sved
#  og i folkerang
#  barnet dybwad var langsomt lang søkt fred
# 1
#
# [2, 3, 3, 3, 3, 2, 3]
#  jeg kjenner dem og slang
#  der står ensom og tung og kry
#  bekymringer sang
#  lyster hill pelen gry
# 1
#
# [2, 3, 3, 2, 2, 0, 2]
#  og thomas og jakker
#  hvis budskap bed
#  for velfylt liv
#  tankens mæler var lang søkt fred
# 1
#
# [2, 3, 3, 3, 3, 2, 3]
#  var ødegård
#  tegnet stjernen og meiet som grøden
#  og plutselig som vår
#  klarere sommerens glimter fornekter døden
# 1
#
# [2, 2, 2, 2, 2, 1, 3]
#  jaget som fredløse søkte jeg avsted
#  den fart så blidt og bred
#  og storm og merk mitt liv stred
#  da tegner kysset 1
# 1
#
# [3, 2, 3, 3, 3, 2, 3]
#  vi somren vel bøde
#  og deres døde
#  bud skal forstå
#  visselig rundet tørre råd
# 2
#
# [2, 1, 2, 0, 1, 2, 2]
#  det frem til de grønne brammer
#  i støvets vinter jeg kommer
#  hvem er din hund eller denne verden ene
#  og her nei alt gløder alt hernede om kveldene
# 2
#
# [3, 2, 1, 1, 0, 1, 1]
#  og av det dype vell
#  i det av det dype vell
#  og godt sa kar han
#  de første var ivare
#  med berguhyre
#  lyktenes brune i holmer slør land
# 2
#
# [3, 2, 2, 2, 1, 1, 1]
#  der er blitt til timen kommet jeg ter
#  og mor så ble stanset der
#  da kan se den ad gaten troll og rød
#  mens kokkemadamene strever
#  det er som et med frodig goder verset her lever
#  her bølgeslag gyldne rank død
# 2
#
# [1, 0, 0, 0, 0, 0, 0]
#  russlands sære kogleri
#  jeg kom mine mål til å eie
#  og det er en gyllen dag så bred
#  han føler tåker og av deres kunster
#  for norges liv
#  norske norske norske norske norske hunger grønnes varslet mumler urørt urørt favntak betenk bitterhet slemt karpus grisjka løvspring bakved 1942
# 2
#
# [2, 2, 2, 1, 2, 1, 3]
#  bueganger
#  blånende bølger
#  tempelkor
#  denne jord
#  jeg husker för
#  i soldis morgenrøde trettes hvelvet jord
# 3
#
# [2, 2, 2, 1, 2, 2, 3]
#  og hva det er fylt av liv og gammen
#  de røde drømmer under hammen
#  i dagene som fikk jeg fredløs i fart
#  sover her hvor nr. 13 er landet vårt
#  den grodde hvelv til stav og stat
#  vekker brødrene fordømt
# 3
#
# [3, 3, 3, 3, 0, 2, 3]
#  den hedningeby
#  ved heltens tordensky
#  lyster hill pelen gry
# 3
#
# [2, 3, 3, 3, 3, 1, 3]
#  har din kulde rød
#  nød
#  engang var full av bann
#  bedre fuglen oss i land
#  fra løgn vårt vane-gjengeri
#  år og synge fri
# 3
#
# [2, 3, 2, 2, 2, 2, 3]
#  så er jeg rede hvis du må
#  graver velter nå
#  er dagen lang hist i ditt amen
#  din fjord når solen
#  bak gondvanaland
#  lyktenes brune i holmer slør land
# 3
#
# [2, 1, 1, 2, 3, 1]
#  suste over skyer av bølger sprang
#  og dets glans er månen hvit og rundet
#  jeg vandret jeg mellom slang
#  i folkerang
#  vik fra landet
# 4
#
# [1, 2, 2, 1, 3, 3]
#  dog mens natten er full av fred
#  dette stumme de sterke gror
#  den store hav som en blomst i bre
#  her er det fram av guds fred i hvilken fred
#  sneen hvilket er sen visshet ord
# 4
#
# [2, 2, 1, 2, 2, 2]
#  dype dyp min vei er krystall
#  hvem skal til verdens skam og fall
#  se da vilde smykke
#  og løven temtes til en puddelhund
#  for kirke og gjentok det grønnes rikt og ikke
#  og skjermet veksler buldrer hever frossen blåst bunn
# 4
#
# [2, 3, 1, 1, 2, 2]
#  i norges skinnende gnist
#  rede når dets enkle enfoldige trøst
#  det demrer av tåket luft og sand
#  i fredens slags blomster når man er på vann
#  hvor vadestedets stener i fjord og land
#  mens sjøene evigt slør land
# 4
#
# [3, 2, 2, 3, 3, 3]
#  se sitt forgylte embedsskrud
#  går han som forut bud
#  og langs havet i kjøkken og i kammers og i kott
#  liten her hist stakkars kristiansand
#  så ror i godt
#  mens sjøene evigt slør land
# 4

# %%
def check_rated(df, pr=False):
    less_three = 0
    less_two = 0
    less_one = 0

    for e in df.itertuples():
        r = e.rhyme_rating
        c = Counter(r)
        majority_rating = c.most_common()[0][0]
        if majority_rating < 3:
            less_three += 1
            if majority_rating < 2:
                less_two += 1
                if majority_rating < 1:
                    less_one += 1
                if pr:
                    print(r)
                    print(e.stanza)
                    print("")

    return less_three, less_two, less_one




base = total_df.loc[total_df["type"]=="base"].copy()
line = total_df.loc[total_df["type"]=="line"].copy()
stanza = total_df.loc[total_df["type"]=="stanza"].copy()
orig = total_df.loc[total_df["type"]=="orig"].copy()

check_rated(base), check_rated(stanza), check_rated(line, pr=True),  check_rated(orig, pr=True)
# Out:
# [1, 1, 0, 0, 0, 0, 0]
#  ennu en dag uten den
#  tross venners advarsler bønner og klage
#  hvor engang hellig offerild
#  som du nå ser det glitre og tindre
#
# [3, 1, 1, 1, 2, 1]
# skrevet det står
# ei mennesket lever
# av brød alene
# men fra guds munn
# går ut den føde
# som atter i sjelen
# lar livet gløde
# ((38, 34, 27), (29, 9, 3), (17, 1, 1), (17, 1, 0))

# %% [markdown]
# # Rhyme and rated human related???
# ## Baseline model

# %%
rated_human = [int(e) for r in base.rated_human for e in r]
rhyme_ratings = [e for r in base.rhyme_rating for e in r]


h_r = list(zip(rated_human, rhyme_ratings))

c = Counter(h_r)
l = sorted(c.items(), key= lambda x: x[0])


neg_counts = [e[1] for e in l[:4]]
pos_counts = [e[1] for e in l[4:]]

tot_counts = [a+b for a,b in zip(pos_counts, neg_counts)]

pos_counts_norm = [(a/b)*100 for a,b in zip(pos_counts, tot_counts)]
neg_counts_norm = [(a/b)*100 for a,b in zip(neg_counts, tot_counts)]

fig, ax = plt.subplots(figsize=(10,5))

barWidth = 0.15

br1 = np.arange(4)
br2 = [x + barWidth for x in br1]

# Make the plot
plt.bar(br1, pos_counts_norm, color ='pink', width = barWidth,
        edgecolor ='grey', label ='Rated human')
plt.bar(br2, neg_counts_norm, color ='lightblue', width = barWidth,
        edgecolor ='grey', label ='Rated not human')

plt.xlabel('Rhyme rating', fontsize = 15)
plt.ylabel('% of ratings per rhyme score', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(labels))], labels)
plt.title("Baseline model", size=20)

plt.legend()
plt.show()

# %% [markdown]
# ## Stanza based model

# %%
rated_human = [int(e) for r in stanza.rated_human for e in r]
rhyme_ratings = [e for r in stanza.rhyme_rating for e in r]

h_r = list(zip(rated_human, rhyme_ratings))

c = Counter(h_r)
l = sorted(c.items(), key= lambda x: x[0])


neg_counts = [e[1] for e in l[:4]]
pos_counts = [e[1] for e in l[4:]]
pos_counts, neg_counts

tot_counts = [a+b for a,b in zip(pos_counts, neg_counts)]

pos_counts_norm = [(a/b)*100 for a,b in zip(pos_counts, tot_counts)]
neg_counts_norm = [(a/b)*100 for a,b in zip(neg_counts, tot_counts)]

# %%
fig, ax = plt.subplots(figsize=(10,5))

barWidth = 0.15

br1 = np.arange(4)
br2 = [x + barWidth for x in br1]

# Make the plot
plt.bar(br1, pos_counts_norm, color ='pink', width = barWidth,
        edgecolor ='grey', label ='Rated human')
plt.bar(br2, neg_counts_norm, color ='lightblue', width = barWidth,
        edgecolor ='grey', label ='Rated not human')

plt.xlabel('Rhyme rating', fontsize = 15)
plt.ylabel('% of ratings per rhyme score', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(labels))], labels)
plt.title("Stanza-based model", size=20)

plt.legend()
plt.show()

# %% [markdown]
# ## Line-based model

# %%
rated_human = [int(e) for r in line.rated_human for e in r]
rhyme_ratings = [e for r in line.rhyme_rating for e in r]

h_r = list(zip(rated_human, rhyme_ratings))

c = Counter(h_r)
l = sorted(c.items(), key= lambda x: x[0])


neg_counts = [e[1] for e in l[:4]]
pos_counts = [e[1] for e in l[4:]]
pos_counts, neg_counts

tot_counts = [a+b for a,b in zip(pos_counts, neg_counts)]

pos_counts_norm = [(a/b)*100 for a,b in zip(pos_counts, tot_counts)]
neg_counts_norm = [(a/b)*100 for a,b in zip(neg_counts, tot_counts)]

# %%
fig, ax = plt.subplots(figsize=(10,5))

barWidth = 0.15

br1 = np.arange(4)
br2 = [x + barWidth for x in br1]

# Make the plot
plt.bar(br1, pos_counts_norm, color ='pink', width = barWidth,
        edgecolor ='grey', label ='Rated human')
plt.bar(br2, neg_counts_norm, color ='lightblue', width = barWidth,
        edgecolor ='grey', label ='Rated not human')

plt.xlabel('Rhyme rating', fontsize = 15)
plt.ylabel('% of ratings per rhyme score', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(labels))], labels)
plt.title("Line-based model", size=20)

plt.legend()
plt.show()

# %% [markdown]
# ## Original human stanzozozo

# %%
rated_human = [int(e) for r in orig.rated_human for e in r]
rhyme_ratings = [e for r in orig.rhyme_rating for e in r]

h_r = list(zip(rated_human, rhyme_ratings))

c = Counter(h_r)
l = sorted(c.items(), key= lambda x: x[0])


neg_counts = [e[1] for e in l[:4]]
pos_counts = [e[1] for e in l[4:]]
pos_counts, neg_counts

tot_counts = [a+b for a,b in zip(pos_counts, neg_counts)]

pos_counts_norm = [(a/b)*100 for a,b in zip(pos_counts, tot_counts)]
neg_counts_norm = [(a/b)*100 for a,b in zip(neg_counts, tot_counts)]

# %%
fig, ax = plt.subplots(figsize=(10,5))

barWidth = 0.15

br1 = np.arange(4)
br2 = [x + barWidth for x in br1]

# Make the plot
plt.bar(br1, pos_counts_norm, color ='pink', width = barWidth,
        edgecolor ='grey', label ='Rated human')
plt.bar(br2, neg_counts_norm, color ='lightblue', width = barWidth,
        edgecolor ='grey', label ='Rated not human')

plt.xlabel('Rhyme rating', fontsize = 15)
plt.ylabel('% of ratings per rhyme score', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(labels))], labels)
plt.title("Original stanzas", size=20)

plt.legend()
plt.show()
