# %%
import pandas as pd

# %% [markdown]
# #### The first part of the form has 3 questions for each pair of stanzas.
# #### The second part of the form has 2 question for each stanza

# %% [markdown]
# # Collect annotations for pairwise comparisons

# %%
def get_pairwise_annotation_df(form_csv_path, source_tsv_path):
    df = pd.read_csv(form_csv_path)
    df = df.T
    
    source_df = pd.read_csv(source_tsv_path, sep="\t")
    source_df["order_in_pair"] = [1,2]*(len(source_df)//2)
    written_by_human = source_df.loc[source_df["type"]=="orig"].order_in_pair
    
    choose_human_prompt = "Hvilket vers er skrevet av et menneske?"
    rhymes_v1 = "Er vers 1 skrevet på rim?"
    rhymes_v2 = "Er vers 2 skrevet på rim?"

    rated_human = []
    rhyme_rating = []    

    for i, gold in enumerate(written_by_human):
        human_s = choose_human_prompt
        v1_s = rhymes_v1
        v2_s = rhymes_v2
        if i:
            human_s += f".{i}"
            v1_s += f".{i}"
            v2_s += f".{i}"

        orig_rated_human = df.loc[human_s]
        orig_rated_human = [int(e.split()[1])==gold for e in orig_rated_human]

        rhyme_v1 = list(df.loc[v1_s].apply(int))
        rhyme_rating.append(rhyme_v1)

        rhyme_v2 = list(df.loc[v2_s].apply(int))
        rhyme_rating.append(rhyme_v2)


        i = i*2
        if source_df.loc[i].type == "orig":
            rated_human.append(orig_rated_human)
            rated_human.append([not(e) for e in orig_rated_human])
        else:
            rated_human.append([not(e) for e in orig_rated_human])
            rated_human.append(orig_rated_human)


    source_df["rated_human"] = rated_human
    source_df["rhyme_rating"] = rhyme_rating
    return source_df

# %%
get_pairwise_annotation_df("Evaluering av AI-genererte dikt og rim 1.csv", "side_by_side_form_1.tsv")
# Out:
#     Unnamed: 0    type   scheme  \
# 0           20  stanza     ABAB
# 1            0    orig   AABCCB
# 2            1    orig     ABAB
# 3           18    line     ABAB
# 4           16    line     ABAB
# 5            2    orig   ABCBDD
# 6           15    line     ABAB
# 7            3    orig     ABAB
# 8           19    line     ABCB
# 9            4    orig     ABAB
# 10          21  stanza     ABAB
# 11           5    orig     ABCB
# 12          26    base        -
# 13           6    orig     ABAB
# 14           7    orig  ABCBBDD
# 15          17    line     ABAB
# 16          25    base        -
# 17           8    orig     ABAB
# 18           9    orig    ABABC
# 19          24  stanza     ABCB
# 20          29    base        -
# 21          10    orig     ABAB
# 22          23  stanza     ABAB
# 23          11    orig   ABCCAB
# 24          12    orig     AABB
# 25          27    base        -
# 26          28    base        -
# 27          13    orig      AAA
# 28          22  stanza     ABAB
# 29          14    orig     ABCB
#
#                                                stanza  pair_number  \
# 0    her hørte dalen her så det seg svang \n runde...            0
# 1   sjo-i sjo-i hyss\nsang jeg om et kyss\nnei det...            0
# 2   du den høyeste blandt høye\ndu den viseste bla...            1
# 3    inn i fjellets flammesky \n en lovsangs brus ...            1
# 4    landets fiender og dro \n la min unge søsters...            2
# 5   da som ville dyr\nde fråder freser\nstimler sa...            2
# 6    han er jo \n hva var det en guds fiolin \n te...            3
# 7   tillykke med dåden dere frelste imperiet\nmac ...            3
# 8    dødens bytte aldri blir \n og budet våk og be...            4
# 9   vel møtt i bølger hvor vi flyr\nog hav er du f...            4
# 10   jeg kjenner dem og slang \n der står ensom og...            5
# 11  her blinker ingen stjerner gjennom natten\nsom...            5
# 12   med kongen bud med il \n og så han på sterke ...            6
# 13  han truer jo den milde fred\nsom hviler over a...            6
# 14  for alt som er igjen av ham er dette askebeger...            7
# 15   svever omkring mannen ved det skrikende ror \...            7
# 16   paulus av dem andre dog han stand \n dagens m...            8
# 17  omsider er han oppe men en storm som den han m...            8
# 18  hvo kan den liflighet beskrive\nsom sjelen i s...            9
# 19   og thomas og jakker \n hvis budskap bed \n fo...            9
# 20   vi vet det ham dog må sprenges \n skipet han ...           10
# 21  det være en gud hvis arm\nmaktet å hele hver b...           10
# 22   var ødegård \n tegnet stjernen og meiet som g...           11
# 23  evig det store skal skapes i smerte\nalt skal ...           11
# 24  mens lyset glitrer over hav\ngår silden i sin ...           12
# 25   og tross den tross dødninghaven \n over venne...           12
# 26   karmels rygg han lyder \n vit dog det høye rå...           13
# 27  mørsere gjødde og spydde det stank av karbol o...           13
# 28   jaget som fredløse søkte jeg avsted \n den fa...           14
# 29  i kjellerens klamme kvelende luft\ngår døperen...           14
#
#     order_in_pair                                 rated_human  \
# 0               1   [False, False, True, False, False, False]
# 1               2       [True, True, False, True, True, True]
# 2               1      [True, True, False, False, True, True]
# 3               2    [False, False, True, True, False, False]
# 4               1    [False, True, True, False, False, False]
# 5               2      [True, False, False, True, True, True]
# 6               1      [True, True, True, True, False, False]
# 7               2    [False, False, False, False, True, True]
# 8               1  [False, False, False, False, False, False]
# 9               2        [True, True, True, True, True, True]
# 10              1   [False, False, True, False, False, False]
# 11              2       [True, True, False, True, True, True]
# 12              1   [False, False, True, False, False, False]
# 13              2       [True, True, False, True, True, True]
# 14              1       [False, True, True, True, True, True]
# 15              2   [True, False, False, False, False, False]
# 16              1     [False, True, True, True, False, False]
# 17              2     [True, False, False, False, True, True]
# 18              1        [True, True, True, True, True, True]
# 19              2  [False, False, False, False, False, False]
# 20              1   [False, False, False, True, False, False]
# 21              2       [True, True, True, False, True, True]
# 22              1    [True, False, False, False, False, True]
# 23              2      [False, True, True, True, True, False]
# 24              1       [False, True, True, True, True, True]
# 25              2   [True, False, False, False, False, False]
# 26              1   [False, False, False, True, False, False]
# 27              2       [True, True, True, False, True, True]
# 28              1   [False, False, True, False, False, False]
# 29              2       [True, True, False, True, True, True]
#
#           rhyme_rating
# 0   [3, 3, 2, 3, 3, 1]
# 1   [3, 3, 3, 3, 3, 3]
# 2   [3, 3, 3, 3, 3, 3]
# 3   [3, 3, 3, 3, 3, 0]
# 4   [3, 3, 3, 3, 3, 1]
# 5   [2, 3, 3, 2, 2, 3]
# 6   [2, 3, 3, 2, 2, 1]
# 7   [2, 3, 3, 2, 2, 1]
# 8   [2, 2, 3, 2, 2, 0]
# 9   [2, 3, 3, 3, 3, 2]
# 10  [2, 3, 3, 3, 3, 2]
# 11  [2, 2, 3, 2, 2, 1]
# 12  [1, 2, 0, 0, 0, 0]
# 13  [3, 3, 3, 3, 3, 2]
# 14  [3, 3, 2, 2, 2, 2]
# 15  [3, 3, 3, 3, 3, 1]
# 16  [2, 3, 2, 2, 2, 0]
# 17  [2, 3, 2, 3, 2, 3]
# 18  [2, 3, 3, 3, 2, 2]
# 19  [2, 3, 3, 2, 2, 0]
# 20  [2, 3, 0, 2, 0, 0]
# 21  [2, 3, 3, 3, 3, 2]
# 22  [2, 3, 3, 3, 3, 2]
# 23  [2, 3, 2, 3, 2, 1]
# 24  [2, 3, 3, 3, 3, 1]
# 25  [1, 3, 1, 0, 0, 0]
# 26  [1, 1, 1, 0, 2, 0]
# 27  [2, 3, 1, 3, 3, 1]
# 28  [2, 2, 2, 2, 2, 1]
# 29  [1, 2, 3, 2, 2, 1]

# %% [markdown]
# # Collect annotations for standalone verses

# %%
def get_standalone_annotation_df(form_csv_path, source_tsv_path):
    df = pd.read_csv(form_csv_path)
    df = df.T
    
    source_df = pd.read_csv(source_tsv_path, sep="\t")
    rhymes_q = "Er verset skrevet på rim?"
    human_q = "Er verset skrevet av et menneske?"

    rated_human = []
    rhyme_rating = []    

    for i in range(len(source_df)):
        human_s = human_q
        rhymes_s = rhymes_q
        if i:
            human_s += f".{i}"
            rhymes_s += f".{i}"

        rated_human.append([e=="Ja" for e in df.loc[human_s]])
        rhyme_rating.append(list(df.loc[rhymes_s].apply(int))) 

    source_df["rated_human"] = rated_human
    source_df["rhyme_rating"] = rhyme_rating

    return source_df

# %%
source_p = "rest_1.tsv"
form_p = "Evaluering av AI-genererte dikt og rim 1.csv"

get_standalone_annotation_df(form_p, source_p)
# Out:
#     Unnamed: 0    type  scheme  \
# 0            5    line    ABCB
# 1            3    orig     AAB
# 2            4    orig    AABB
# 3            0    orig  ABCCAB
# 4           15    base       -
# 5           11  stanza    ABCB
# 6            2    orig    ABAB
# 7           12  stanza    ABCB
# 8           13  stanza    AABB
# 9            1    orig    ABCB
# 10          16    base       -
# 11          17    base       -
# 12          10  stanza    ABCB
# 13          14  stanza    AABB
# 14           6    line    ABCB
# 15           9    line    AABB
# 16          19    base       -
# 17          18    base       -
# 18           7    line    ABCB
# 19           8    line    AABB
#
#                                                stanza  \
# 0    med yndig majestet han går \n som gjorde sinn...
# 1   hva er det for et mektig lys\ndet farer som et...
# 2   skurken saulus løfter armen\natter dette stikk...
# 3   frysende skinner det store og sanne\nvarme har...
# 4    og til han far elsket sønn så fordum lystig v...
# 5    hvor bårer med skum over utsteinen slår \n og...
# 6   og bestefar fuglen i buret\nsom drømte om skog...
# 7    vel fiolin \n jeg satt med i varme hud \n men...
# 8    opp jeg bygge grensen bered \n frossen fred \...
# 9   da lyner et lys ned i dypet\nen gnistrende spr...
# 10   på abel-meholas marker \n i harpen i favn \n ...
# 11   er endelig i loddrett sprekk \n allting er so...
# 12   nuets underveis \n se det er det jovisst \n d...
# 13   og følge i ro av savn ildstråleflor \n hvor j...
# 14   og vever hele strandskogen inn i et spinn \n ...
# 15   om langvarig slit i slavekår \n med yndig maj...
# 16   så stolt som sus av ført over vannet \n bak l...
# 17   da er det morgen \n riktig riktig morgen \n s...
# 18   ennu en dag uten den \n tross venners advarsl...
# 19   der sisler stekepanner fylt med flesk og småm...
#
#                                    rated_human        rhyme_rating
# 0     [False, True, True, False, False, False]  [3, 3, 3, 3, 3, 2]
# 1        [True, True, False, True, True, True]  [2, 3, 3, 2, 2, 2]
# 2       [True, True, False, False, True, True]  [3, 3, 3, 3, 3, 3]
# 3      [True, False, False, False, True, True]  [2, 3, 3, 3, 3, 2]
# 4    [True, False, False, False, False, False]  [3, 3, 3, 2, 2, 1]
# 5    [True, False, False, False, False, False]  [3, 2, 0, 2, 2, 1]
# 6         [True, True, True, True, True, True]  [3, 3, 3, 3, 2, 2]
# 7   [False, False, False, False, False, False]  [2, 2, 3, 2, 2, 1]
# 8   [False, False, False, False, False, False]  [2, 2, 2, 2, 2, 1]
# 9         [True, True, True, True, True, True]  [3, 2, 3, 2, 2, 0]
# 10    [False, False, True, True, False, False]  [1, 1, 2, 2, 2, 0]
# 11   [True, False, False, False, False, False]  [1, 1, 0, 0, 0, 0]
# 12    [True, False, False, False, True, False]  [2, 2, 2, 2, 2, 0]
# 13   [False, True, False, False, False, False]  [2, 2, 1, 2, 2, 0]
# 14       [False, True, True, True, True, True]  [3, 3, 3, 3, 3, 2]
# 15      [False, True, True, True, False, True]  [2, 3, 3, 3, 3, 2]
# 16  [False, False, False, False, False, False]  [2, 1, 3, 1, 1, 0]
# 17   [True, False, False, False, False, False]  [2, 1, 0, 0, 2, 0]
# 18     [False, True, False, False, True, True]  [1, 1, 0, 0, 0, 0]
# 19      [True, True, True, True, False, False]  [2, 1, 3, 2, 2, 0]
