# %% [markdown]
# source: https://github.com/minoguep/rhyme_detection and https://paulminogue.com/index.php/2021/02/14/using-a-siamese-neural-network-to-create-a-simple-rhyme-detector/

# %%
import string
import json

import nltk
import numpy as np
import pandas as pd
import tensorflow as tf

from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Subtract
from tensorflow.keras.callbacks import ModelCheckpoint, TerminateOnNaN, CSVLogger, EarlyStopping

tqdm.pandas()

MAX_LEN = 64
SEED = 420
# sets random, np.random and tf.random seed
tf.keras.utils.set_random_seed(
    SEED
)
# Out:
# 2022-04-12 00:45:53.010317: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-12 00:45:53.010353: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %% [markdown]
# ### Step 1: Create dataset
# We want equally many positive and negative samples of rhyme pairs

# %%
rhyme_pairs = pd.read_csv("manual_repair_plus_good_buckets_positive_pairs.tsv", sep="\t",)
wiki_rhyme_pairs = pd.read_csv("wiktionary_rhyme_pairs.tsv", sep="\t")

rhyme_pairs
# Out:
#           word_a        word_b  rhyme
# 0        kvinner        finner      1
# 1            vil          vill      1
# 2      tordensky  solskinnsfly      1
# 3         strand        Cannes      1
# 4         Kviste         niste      1
# ...          ...           ...    ...
# 38162        lot           rot      1
# 38163        sot      sjelerot      1
# 38164      svang    underklang      1
# 38165   tilsidst    kvinnelist      1
# 38166       sagt     underlagt      1
#
# [38167 rows x 3 columns]

# %%
wiki_rhyme_pairs["rhyme"] = [1]*len(wiki_rhyme_pairs)
wiki_rhyme_pairs
# Out:
#            word_a       word_b  rhyme
# 0         rutebil       ørepil      1
# 1           mobil   servicebil      1
# 2      jugendstil      varebil      1
# 3           onani       lureri      1
# 4          bifili      selleri      1
# ...           ...          ...    ...
# 80358    kvartmil      konebil      1
# 80359   møllehjul  balansehjul      1
# 80360         sti       infami      1
# 80361       kjemi      levkemi      1
# 80362    fanekort  kontantkort      1
#
# [80363 rows x 3 columns]

# %%
rhymes = pd.concat((rhyme_pairs, wiki_rhyme_pairs))
rhymes
# Out:
#           word_a        word_b  rhyme
# 0        kvinner        finner      1
# 1            vil          vill      1
# 2      tordensky  solskinnsfly      1
# 3         strand        Cannes      1
# 4         Kviste         niste      1
# ...          ...           ...    ...
# 80358   kvartmil       konebil      1
# 80359  møllehjul   balansehjul      1
# 80360        sti        infami      1
# 80361      kjemi       levkemi      1
# 80362   fanekort   kontantkort      1
#
# [118530 rows x 3 columns]

# %%
non_rhymes = pd.read_csv("wiktionary_negative_rhyme_pairs.tsv", sep="\t")
non_rhymes["rhyme"] = [0]*len(non_rhymes)
non_rhymes
# Out:
#            word_a        word_b  rhyme
# 0            idet    sennepsgul      0
# 1          kupert   paradisfugl      0
# 2       kombinert     lettekorn      0
# 3             ste       vestrøn      0
# 4          uttært          mort      0
# ...           ...           ...    ...
# 877424    cøliaki  avløpsventil      0
# 877425       tært     hermefugl      0
# 877426   bordbønn   ulykkesfugl      0
# 877427     stjert           føn      0
# 877428    kollasj       ukelønn      0
#
# [877429 rows x 3 columns]

# %%
pos = rhymes.copy()
neg = non_rhymes.sample(n=len(pos), random_state=SEED)
df = pd.concat([pos, neg])
df = df.reset_index()
df
# Out:
#          index     word_a        word_b  rhyme
# 0            0    kvinner        finner      1
# 1            1        vil          vill      1
# 2            2  tordensky  solskinnsfly      1
# 3            3     strand        Cannes      1
# 4            4     Kviste         niste      1
# ...        ...        ...           ...    ...
# 237055  288389    binderi      vassfugl      0
# 237056  689877     empati       ukekort      0
# 237057  190137   kukelurt     slagbjørn      0
# 237058  729199   jaktkort       omspill      0
# 237059  580590     kåseri        hertil      0
#
# [237060 rows x 4 columns]

# %%
all_data = pd.read_csv("tita_rhymes_poems.tsv", sep="\t")

all_text = ""
for e in all_data.stanza:
    all_text += e

# %% [markdown]
# ### Step 2: Create model
# Copy paste from Pauls notebook

# %%
def tokenize_inputs(phrase_a, phrase_b, tokenizer):
    tokenized_phrases = tokenizer.texts_to_sequences([phrase_a, phrase_b])

    # now loop through inputs and pad or reduce size if required
    tokenized_phrases_for_output = []
    for phrase in tokenized_phrases:
        if len(phrase) < MAX_LEN:
            length_to_pad = MAX_LEN - len(phrase)
            phrase_for_output = ([0] * length_to_pad) + phrase
        elif len(phrase) > MAX_LEN:
            phrase_for_output = phrase[-MAX_LEN:]
        else:
            phrase_for_output = phrase
        tokenized_phrases_for_output.append(phrase_for_output)

    return tf.constant(tokenized_phrases_for_output, dtype=tf.float64)

# %%
tokenizer = Tokenizer(char_level=True, lower=True)
tokenizer.fit_on_texts(all_text)

df['word_tokens'] = df.progress_apply(
    lambda row: tokenize_inputs(row['word_a'], row['word_b'], tokenizer), axis=1
)

tokenizer_config = tokenizer.to_json()

with open('tokenizer_config.json', 'w') as f:
    f.write(tokenizer_config)
# Out:
#   0%|          | 0/237060 [00:00<?, ?it/s]
# 2022-04-12 00:45:56.271307: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-12 00:45:56.271365: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-12 00:45:56.271386: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (tita-laptop): /proc/driver/nvidia/version does not exist
# 2022-04-12 00:45:56.271770: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def create_model():
  
    word_a_input_tokens = Input(
      shape=(MAX_LEN, 1), name='word_a_input_tokens'
      )
    word_b_input_tokens = Input(
      shape=(MAX_LEN, 1), name='word_b_input_tokens'
      )
    
    # This is the siamese portion of the model 
    common_lstm = LSTM(64, return_sequences=False, activation="relu", name="common_lstm_layer")

    word_a_lstm_output = common_lstm(word_a_input_tokens)
    word_b_lstm_output = common_lstm(word_b_input_tokens)

    #concatenate_lstm_outputs
    concat_layer = Subtract(name="concatenate_lstm_outputs")(
      [word_a_lstm_output, word_b_lstm_output]
      )
    
    # dense layers before final classification
    dense_layers = Dense(64, activation="relu", name="first_dense_layer")(concat_layer)
    dense_layers = Dropout(0.5)(dense_layers)

    dense_layers = Dense(32, activation="relu", name="second_dense_layer")(dense_layers)
    dense_layers = Dropout(0.5)(dense_layers)

    dense_layers = Dense(8, activation="relu", name="third_dense_layer")(dense_layers)
    dense_layers = Dropout(0.5)(dense_layers)

    classification_layer = Dense(1, activation="sigmoid", name="classification_layer")(dense_layers)
    
    model = Model(
      inputs=[word_a_input_tokens, word_b_input_tokens], 
      outputs = classification_layer
      )

    model.compile(
      loss="binary_crossentropy",
      metrics=["accuracy"],
      optimizer="Adam"
    )

    return model

# %%
X_train_indexes, X_test_indexes, y_train, y_test = train_test_split(
    list(df.index), list(df['rhyme']), stratify=df['rhyme'], 
    test_size=0.4, random_state=SEED
    )

X_test_indexes, X_val_indexes, y_test, y_val = train_test_split(
    X_test_indexes, y_test, stratify=y_test, 
    test_size=0.25, random_state=SEED
    )

X_train = tf.convert_to_tensor(list(df.loc[X_train_indexes]["word_tokens"]))
X_val = tf.convert_to_tensor(list(df.loc[X_val_indexes]["word_tokens"]))
X_test = tf.convert_to_tensor(list(df.loc[X_test_indexes]["word_tokens"]))

y_train = tf.convert_to_tensor(y_train)
y_val = tf.convert_to_tensor(y_val)
y_test = tf.convert_to_tensor(y_test)
# Out:
# 2022-04-12 00:46:11.584793: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 145649664 exceeds 10% of free system memory.

# %%
print(f"""
    Data set size: Full set: {len(df)}
    Train: {len(X_train), len(y_train)}
    Validation: {len(X_val), len(y_val)}
    Test: {len(X_test), len(y_test)}
""")
# Out:
#     Data set size: Full set: 237060
#     Train: (142236, 142236)
#     Validation: (23706, 23706)
#     Test: (71118, 71118)

# %%
model_name = "rhyme_model_200k_1"

# %%
# #Uncomment to train model 

# model = create_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=128,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )
# Out:
# Epoch 1/100
# 1112/1112 [==============================] - 59s 50ms/step - loss: 0.4133 - accuracy: 0.8295 - val_loss: 0.2046 - val_accuracy: 0.9351
# Epoch 2/100
# 1112/1112 [==============================] - 74s 67ms/step - loss: 0.2582 - accuracy: 0.9148 - val_loss: 0.1461 - val_accuracy: 0.9491
# Epoch 3/100
# 1112/1112 [==============================] - 72s 65ms/step - loss: 0.2127 - accuracy: 0.9270 - val_loss: 0.1180 - val_accuracy: 0.9559
# Epoch 4/100
# 1112/1112 [==============================] - 82s 74ms/step - loss: 0.1824 - accuracy: 0.9368 - val_loss: 0.0972 - val_accuracy: 0.9663
# Epoch 5/100
# 1112/1112 [==============================] - 76s 68ms/step - loss: 0.1635 - accuracy: 0.9434 - val_loss: 0.0802 - val_accuracy: 0.9713
# Epoch 6/100
# 1112/1112 [==============================] - 73s 66ms/step - loss: 0.1470 - accuracy: 0.9477 - val_loss: 0.0824 - val_accuracy: 0.9700
# Epoch 7/100
# 1112/1112 [==============================] - 76s 68ms/step - loss: 0.1358 - accuracy: 0.9524 - val_loss: 0.0675 - val_accuracy: 0.9748
# Epoch 8/100
# 1112/1112 [==============================] - 72s 65ms/step - loss: 0.1294 - accuracy: 0.9544 - val_loss: 0.0587 - val_accuracy: 0.9793
# Epoch 9/100
# 1112/1112 [==============================] - 77s 69ms/step - loss: 0.1203 - accuracy: 0.9575 - val_loss: 0.0518 - val_accuracy: 0.9827
# Epoch 10/100
# 1112/1112 [==============================] - 78s 70ms/step - loss: 0.1163 - accuracy: 0.9592 - val_loss: 0.0562 - val_accuracy: 0.9808
# Epoch 11/100
# 1112/1112 [==============================] - 73s 66ms/step - loss: 0.1108 - accuracy: 0.9605 - val_loss: 0.0488 - val_accuracy: 0.9833
# Epoch 12/100
# 1112/1112 [==============================] - 73s 66ms/step - loss: 0.1084 - accuracy: 0.9615 - val_loss: 0.0434 - val_accuracy: 0.9856
# Epoch 13/100
# 1112/1112 [==============================] - 73s 66ms/step - loss: 0.1040 - accuracy: 0.9629 - val_loss: 0.0435 - val_accuracy: 0.9857
# Epoch 14/100
# 1112/1112 [==============================] - 73s 66ms/step - loss: 0.1005 - accuracy: 0.9638 - val_loss: 0.0427 - val_accuracy: 0.9851
# Epoch 15/100
# 1112/1112 [==============================] - 59s 53ms/step - loss: 0.0976 - accuracy: 0.9657 - val_loss: 0.0337 - val_accuracy: 0.9884
# Epoch 16/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0970 - accuracy: 0.9656 - val_loss: 0.0356 - val_accuracy: 0.9872
# Epoch 17/100
# 1112/1112 [==============================] - 48s 44ms/step - loss: 0.0928 - accuracy: 0.9668 - val_loss: 0.0399 - val_accuracy: 0.9862
# Epoch 18/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0916 - accuracy: 0.9677 - val_loss: 0.0323 - val_accuracy: 0.9898
# Epoch 19/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0857 - accuracy: 0.9690 - val_loss: 0.0264 - val_accuracy: 0.9916
# Epoch 20/100
# 1112/1112 [==============================] - 48s 44ms/step - loss: 0.0848 - accuracy: 0.9700 - val_loss: 0.0411 - val_accuracy: 0.9863
# Epoch 21/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0843 - accuracy: 0.9696 - val_loss: 0.0279 - val_accuracy: 0.9912
# Epoch 22/100
# 1112/1112 [==============================] - 50s 45ms/step - loss: 0.0837 - accuracy: 0.9699 - val_loss: 0.0260 - val_accuracy: 0.9908
# Epoch 23/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0821 - accuracy: 0.9707 - val_loss: 0.0279 - val_accuracy: 0.9912
# Epoch 24/100
# 1112/1112 [==============================] - 48s 44ms/step - loss: 0.0785 - accuracy: 0.9718 - val_loss: 0.0227 - val_accuracy: 0.9937
# Epoch 25/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0792 - accuracy: 0.9716 - val_loss: 0.0229 - val_accuracy: 0.9932
# Epoch 26/100
# 1112/1112 [==============================] - 49s 44ms/step - loss: 0.0780 - accuracy: 0.9717 - val_loss: 0.0268 - val_accuracy: 0.9914
# Epoch 27/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0792 - accuracy: 0.9719 - val_loss: 0.0208 - val_accuracy: 0.9932
# Epoch 28/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0737 - accuracy: 0.9731 - val_loss: 0.0282 - val_accuracy: 0.9897
# Epoch 29/100
# 1112/1112 [==============================] - 49s 44ms/step - loss: 0.0764 - accuracy: 0.9725 - val_loss: 0.0268 - val_accuracy: 0.9923
# Epoch 30/100
# 1112/1112 [==============================] - 49s 44ms/step - loss: 0.0763 - accuracy: 0.9722 - val_loss: 0.0228 - val_accuracy: 0.9920
# Epoch 31/100
# 1112/1112 [==============================] - 49s 44ms/step - loss: 0.0717 - accuracy: 0.9737 - val_loss: 0.0207 - val_accuracy: 0.9929
# Epoch 32/100
# 1112/1112 [==============================] - 49s 44ms/step - loss: 0.0703 - accuracy: 0.9743 - val_loss: 0.0224 - val_accuracy: 0.9921
# Epoch 33/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0699 - accuracy: 0.9747 - val_loss: 0.0212 - val_accuracy: 0.9938
# Epoch 34/100
# 1112/1112 [==============================] - 49s 44ms/step - loss: 0.0683 - accuracy: 0.9755 - val_loss: 0.0235 - val_accuracy: 0.9932
# Epoch 35/100
# 1112/1112 [==============================] - 48s 44ms/step - loss: 0.0700 - accuracy: 0.9747 - val_loss: 0.0156 - val_accuracy: 0.9946
# Epoch 36/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0675 - accuracy: 0.9756 - val_loss: 0.0207 - val_accuracy: 0.9937
# Epoch 37/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0679 - accuracy: 0.9755 - val_loss: 0.0183 - val_accuracy: 0.9941
# Epoch 38/100
# 1112/1112 [==============================] - 48s 44ms/step - loss: 0.0672 - accuracy: 0.9755 - val_loss: 0.0189 - val_accuracy: 0.9943
# Epoch 39/100
# 1112/1112 [==============================] - 47s 43ms/step - loss: 0.0658 - accuracy: 0.9763 - val_loss: 0.0174 - val_accuracy: 0.9951
# Epoch 40/100
# 1112/1112 [==============================] - 47s 43ms/step - loss: 0.0661 - accuracy: 0.9755 - val_loss: 0.0265 - val_accuracy: 0.9926
# Epoch 41/100
# 1112/1112 [==============================] - 47s 42ms/step - loss: 0.0656 - accuracy: 0.9759 - val_loss: 0.0170 - val_accuracy: 0.9950
# Epoch 42/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0661 - accuracy: 0.9757 - val_loss: 0.0181 - val_accuracy: 0.9951
# Epoch 43/100
# 1112/1112 [==============================] - 49s 44ms/step - loss: 0.0665 - accuracy: 0.9758 - val_loss: 0.0181 - val_accuracy: 0.9940
# Epoch 44/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0651 - accuracy: 0.9766 - val_loss: 0.0186 - val_accuracy: 0.9943
# Epoch 45/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0629 - accuracy: 0.9770 - val_loss: 0.0154 - val_accuracy: 0.9951
# Epoch 46/100
# 1112/1112 [==============================] - 48s 43ms/step - loss: 0.0625 - accuracy: 0.9769 - val_loss: 0.0131 - val_accuracy: 0.9957
# Epoch 47/100
# 1112/1112 [==============================] - 49s 44ms/step - loss: 0.0637 - accuracy: 0.9766 - val_loss: 0.0161 - val_accuracy: 0.9947
# Epoch 48/100
# 1112/1112 [==============================] - 52s 46ms/step - loss: 0.0590 - accuracy: 0.9780 - val_loss: 0.0132 - val_accuracy: 0.9958
# Epoch 49/100
# 1112/1112 [==============================] - 51s 45ms/step - loss: 0.0642 - accuracy: 0.9768 - val_loss: 0.0151 - val_accuracy: 0.9951
# Epoch 50/100
# 1112/1112 [==============================] - 51s 46ms/step - loss: 0.0606 - accuracy: 0.9779 - val_loss: 0.0161 - val_accuracy: 0.9952
# Epoch 51/100
# 1112/1112 [==============================] - 50s 45ms/step - loss: 0.0592 - accuracy: 0.9780 - val_loss: 0.0136 - val_accuracy: 0.9957
# Epoch 52/100
# 1112/1112 [==============================] - 50s 45ms/step - loss: 0.0597 - accuracy: 0.9779 - val_loss: 0.0159 - val_accuracy: 0.9951
# Epoch 53/100
# 1112/1112 [==============================] - 50s 45ms/step - loss: 0.0636 - accuracy: 0.9770 - val_loss: 0.0165 - val_accuracy: 0.9945

# %%
# load the model
model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_test[:, 0], X_test[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99     35559
#            1       0.99      1.00      0.99     35559
#
#     accuracy                           0.99     71118
#    macro avg       0.99      0.99      0.99     71118
# weighted avg       0.99      0.99      0.99     71118

# %%
test = df.loc[X_test_indexes].copy()
test["pred"] = y_pred
test["pred"] = test["pred"].apply(lambda x: int(x))
test
# Out:
#          index       word_a         word_b  rhyme  \
# 61710    23543          bli        draperi      1
# 35508    35508         leve           veve      1
# 214462  491835     abortert       alpehorn      0
# 107319   69152         kvil    lapidarstil      1
# 193151   56406      nyptorn            jul      0
# ...        ...          ...            ...    ...
# 223739  542661  omsorgslønn    leprabasill      0
# 43065     4898  uartikulert  velorganisert      1
# 236128  728659        gjært      selvgjort      0
# 27776    27776          frø             kø      1
# 63754    25587         glid        symfoni      1
#
#                                               word_tokens  pred
# 61710   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 35508   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 214462  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 107319  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 193151  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# ...                                                   ...   ...
# 223739  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 43065   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 236128  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 27776   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 63754   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
#
# [71118 rows x 6 columns]

# %%
test[test.rhyme != test.pred]
# Out:
#          index   word_a       word_b  rhyme  \
# 30537    30537     hvil         vill      1
# 39504     1337  fromasj     pistasie      1
# 156268  436525     tort  adgangskort      0
# 143083  275590     lurt          yrt      0
# 181869   31940   baufil          hul      0
# ...        ...      ...          ...    ...
# 147123  547553     nært        usyrt      0
# 47981     9814   hertil  fiolinspill      1
# 161393  143148     hasj         fred      0
# 6172      6172    stort         land      1
# 196945  874429     tort        plirt      0
#
#                                               word_tokens  pred
# 30537   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 39504   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 156268  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 143083  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 181869  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# ...                                                   ...   ...
# 147123  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 47981   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 161393  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 6172    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 196945  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
#
# [385 rows x 6 columns]

# %%
samples = [
    ["Kan du ikke se det", "Deg skal jeg lede"], 
    ["Kaker av alle slag", "Her henger Norges flagg"], 
    ["Jeg har ikke tid", "Til dette svineri"],
    ["Hva har du sagt", "Kaken er bakt"], 
    ["Barna er lagt", "Kaken er laget"],
    ["Gjorde du det med vilje", "Kaken smaker vanilje"], 
    ["Dette vokser", "Satans underbukser"],
    ["tid", "svineri"]
]

samples2 = [[b,a] for a,b in samples]
print(samples2)

sample_tokens = [tokenize_inputs(lyrics[0], lyrics[1], tokenizer) for lyrics in samples]
sample_tokens = tf.convert_to_tensor(sample_tokens)

sample_tokens2 = [tokenize_inputs(lyrics[0], lyrics[1], tokenizer) for lyrics in samples2]
sample_tokens2 = tf.convert_to_tensor(sample_tokens2)

sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

sample_pred2 = model.predict([sample_tokens2[:, 0], sample_tokens2[:, 1]])
predictions2 = [round(pred[0], 4) for pred in sample_pred2]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print(f"{'Rhyme' if predictions2[i] > 0.5 else 'Non-rhyme'}({predictions2[i]})")
    print("---------------\n")
# Out:
# [['Deg skal jeg lede', 'Kan du ikke se det'], ['Her henger Norges flagg', 'Kaker av alle slag'], ['Til dette svineri', 'Jeg har ikke tid'], ['Kaken er bakt', 'Hva har du sagt'], ['Kaken er laget', 'Barna er lagt'], ['Kaken smaker vanilje', 'Gjorde du det med vilje'], ['Satans underbukser', 'Dette vokser'], ['svineri', 'tid']]
# Sentence 1: Kan du ikke se det
# Sentence 2: Deg skal jeg lede
# Rhyme(0.9991999864578247)
# Rhyme(1.0)
# ---------------
#
# Sentence 1: Kaker av alle slag
# Sentence 2: Her henger Norges flagg
# Rhyme(0.9934999942779541)
# Rhyme(0.5748000144958496)
# ---------------
#
# Sentence 1: Jeg har ikke tid
# Sentence 2: Til dette svineri
# Rhyme(1.0)
# Non-rhyme(0.0)
# ---------------
#
# Sentence 1: Hva har du sagt
# Sentence 2: Kaken er bakt
# Rhyme(0.9937000274658203)
# Rhyme(0.9998999834060669)
# ---------------
#
# Sentence 1: Barna er lagt
# Sentence 2: Kaken er laget
# Rhyme(1.0)
# Rhyme(0.7289999723434448)
# ---------------
#
# Sentence 1: Gjorde du det med vilje
# Sentence 2: Kaken smaker vanilje
# Rhyme(0.9998000264167786)
# Rhyme(1.0)
# ---------------
#
# Sentence 1: Dette vokser
# Sentence 2: Satans underbukser
# Rhyme(0.9994999766349792)
# Rhyme(0.9991999864578247)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Rhyme(1.0)
# Non-rhyme(0.25429999828338623)
# ---------------

# %% [markdown]
# ## Try again with mirrored examples included

# %%
def get_mirrored_df(df):
    mirror = pd.DataFrame({"word_a": df["word_b"], 
                           "word_b": df["word_a"], 
                           "rhyme": df["rhyme"], 
                           "word_tokens":[(t[1], t[0]) for t in df["word_tokens"]]})
    return pd.concat((df, mirror))

# %%
train_df = df.loc[X_train_indexes]
dev_df = df.loc[X_val_indexes]
len(train_df), len(dev_df)
# Out:
# (142236, 23706)

# %%
double_train = get_mirrored_df(train_df)
double_train
# Out:
#            index         word_a            word_b  rhyme  \
# 115133   76966.0          knort      sjøtransport      1
# 36499    36499.0          svært             verdt      1
# 183128  522520.0       tsjuvasj            kalori      0
# 77004    38837.0        monarki           biologi      1
# 53316    15149.0        alliert  overadministrert      1
# ...          ...            ...               ...    ...
# 202208       NaN        frihjul            byport      0
# 59542        NaN     prosjektil           leiebil      1
# 108621       NaN    omdiskutert           blasert      1
# 188165       NaN          kjemi             gjurt      0
# 183206       NaN  syketransport            bedyrt      0
#
#                                               word_tokens
# 115133  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 36499   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 183128  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 77004   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 53316   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                   ...
# 202208  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 59542   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 108621  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 188165  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 183206  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [284472 rows x 5 columns]

# %%
double_dev = get_mirrored_df(dev_df)
double_dev
# Out:
#            index        word_a       word_b  rhyme  \
# 84331    46164.0      døgnvill   trekkspill      1
# 46777     8610.0    trekkspill  mellomspill      1
# 231293   60728.0        sjømil    buskvekst      0
# 171305  798600.0       breport       bakeri      0
# 69491    31324.0      livsstil     racerbil      1
# ...          ...           ...          ...    ...
# 46112        NaN  rundbogestil  rokokkostil      1
# 126681       NaN           ill      kompani      0
# 213297       NaN          dyrt        gnurt      0
# 47153        NaN    veteranbil       snøbil      1
# 160690       NaN       høytysk      binderi      0
#
#                                               word_tokens
# 84331   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 46777   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 231293  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 171305  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 69491   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                   ...
# 46112   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 126681  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 213297  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 47153   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 160690  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [47412 rows x 5 columns]

# %%
X_train = tf.convert_to_tensor(list(double_train["word_tokens"]))
X_val = tf.convert_to_tensor(list(double_dev["word_tokens"]))

y_train = tf.convert_to_tensor(list(double_train["rhyme"]))
y_val = tf.convert_to_tensor(list(double_dev["rhyme"]))
# Out:
# 2022-04-12 01:36:09.100534: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 291299328 exceeds 10% of free system memory.

# %%
model_name = "rhyme_model_200k_mirror"

# %%
# # Uncomment to train model 
# model = create_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=128,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )
# Out:
# Epoch 1/100
# 2022-04-12 01:36:09.972535: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 145649664 exceeds 10% of free system memory.
# 2022-04-12 01:36:10.004550: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 145649664 exceeds 10% of free system memory.
# 2223/2223 [==============================] - 102s 45ms/step - loss: 0.4230 - accuracy: 0.8328 - val_loss: 0.2152 - val_accuracy: 0.9407
# Epoch 2/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.2628 - accuracy: 0.9089 - val_loss: 0.1370 - val_accuracy: 0.9670
# Epoch 3/100
# 2223/2223 [==============================] - 105s 47ms/step - loss: 0.2221 - accuracy: 0.9264 - val_loss: 0.1500 - val_accuracy: 0.9519
# Epoch 4/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.2026 - accuracy: 0.9351 - val_loss: 0.0965 - val_accuracy: 0.9794
# Epoch 5/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1906 - accuracy: 0.9400 - val_loss: 0.0931 - val_accuracy: 0.9811
# Epoch 6/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1838 - accuracy: 0.9431 - val_loss: 0.0897 - val_accuracy: 0.9811
# Epoch 7/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1688 - accuracy: 0.9459 - val_loss: 0.0727 - val_accuracy: 0.9834
# Epoch 8/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1582 - accuracy: 0.9482 - val_loss: 0.0702 - val_accuracy: 0.9826
# Epoch 9/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1522 - accuracy: 0.9501 - val_loss: 0.0626 - val_accuracy: 0.9846
# Epoch 10/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1506 - accuracy: 0.9508 - val_loss: 0.0642 - val_accuracy: 0.9843
# Epoch 11/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1471 - accuracy: 0.9519 - val_loss: 0.0517 - val_accuracy: 0.9890
# Epoch 12/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1448 - accuracy: 0.9527 - val_loss: 0.0561 - val_accuracy: 0.9876
# Epoch 13/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1424 - accuracy: 0.9534 - val_loss: 0.0508 - val_accuracy: 0.9885
# Epoch 14/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1406 - accuracy: 0.9539 - val_loss: 0.0467 - val_accuracy: 0.9904
# Epoch 15/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1387 - accuracy: 0.9546 - val_loss: 0.0453 - val_accuracy: 0.9900
# Epoch 16/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1373 - accuracy: 0.9557 - val_loss: 0.0411 - val_accuracy: 0.9914
# Epoch 17/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1346 - accuracy: 0.9563 - val_loss: 0.0457 - val_accuracy: 0.9885
# Epoch 18/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1338 - accuracy: 0.9562 - val_loss: 0.0395 - val_accuracy: 0.9914
# Epoch 19/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1341 - accuracy: 0.9564 - val_loss: 0.0388 - val_accuracy: 0.9907
# Epoch 20/100
# 2223/2223 [==============================] - 104s 47ms/step - loss: 0.1307 - accuracy: 0.9572 - val_loss: 0.0329 - val_accuracy: 0.9925
# Epoch 21/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1308 - accuracy: 0.9574 - val_loss: 0.0331 - val_accuracy: 0.9927
# Epoch 22/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1284 - accuracy: 0.9582 - val_loss: 0.0379 - val_accuracy: 0.9910
# Epoch 23/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1262 - accuracy: 0.9590 - val_loss: 0.0333 - val_accuracy: 0.9928
# Epoch 24/100
# 2223/2223 [==============================] - 99s 44ms/step - loss: 0.1241 - accuracy: 0.9598 - val_loss: 0.0316 - val_accuracy: 0.9931
# Epoch 25/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1138 - accuracy: 0.9595 - val_loss: 0.0239 - val_accuracy: 0.9943
# Epoch 26/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1057 - accuracy: 0.9602 - val_loss: 0.0209 - val_accuracy: 0.9948
# Epoch 27/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1067 - accuracy: 0.9598 - val_loss: 0.0206 - val_accuracy: 0.9941
# Epoch 28/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1035 - accuracy: 0.9606 - val_loss: 0.0233 - val_accuracy: 0.9945
# Epoch 29/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.1051 - accuracy: 0.9605 - val_loss: 0.0256 - val_accuracy: 0.9937
# Epoch 30/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1041 - accuracy: 0.9607 - val_loss: 0.0711 - val_accuracy: 0.9783
# Epoch 31/100
# 2223/2223 [==============================] - 99s 44ms/step - loss: 0.1040 - accuracy: 0.9603 - val_loss: 0.0241 - val_accuracy: 0.9934
# Epoch 32/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1012 - accuracy: 0.9618 - val_loss: 0.0180 - val_accuracy: 0.9950
# Epoch 33/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0999 - accuracy: 0.9621 - val_loss: 0.0191 - val_accuracy: 0.9947
# Epoch 34/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1011 - accuracy: 0.9616 - val_loss: 0.0160 - val_accuracy: 0.9962
# Epoch 35/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.1001 - accuracy: 0.9620 - val_loss: 0.0150 - val_accuracy: 0.9958
# Epoch 36/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.0996 - accuracy: 0.9616 - val_loss: 0.0182 - val_accuracy: 0.9954
# Epoch 37/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0999 - accuracy: 0.9619 - val_loss: 0.0151 - val_accuracy: 0.9963
# Epoch 38/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0996 - accuracy: 0.9618 - val_loss: 0.0180 - val_accuracy: 0.9953
# Epoch 39/100
# 2223/2223 [==============================] - 101s 45ms/step - loss: 0.0973 - accuracy: 0.9627 - val_loss: 0.0150 - val_accuracy: 0.9964
# Epoch 40/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.0980 - accuracy: 0.9630 - val_loss: 0.0155 - val_accuracy: 0.9960
# Epoch 41/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.0971 - accuracy: 0.9629 - val_loss: 0.0160 - val_accuracy: 0.9960
# Epoch 42/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0979 - accuracy: 0.9627 - val_loss: 0.0141 - val_accuracy: 0.9967
# Epoch 43/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0963 - accuracy: 0.9630 - val_loss: 0.0190 - val_accuracy: 0.9949
# Epoch 44/100
# 2223/2223 [==============================] - 99s 44ms/step - loss: 0.0971 - accuracy: 0.9628 - val_loss: 0.0133 - val_accuracy: 0.9965
# Epoch 45/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0943 - accuracy: 0.9641 - val_loss: 0.0122 - val_accuracy: 0.9971
# Epoch 46/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0955 - accuracy: 0.9634 - val_loss: 0.0136 - val_accuracy: 0.9966
# Epoch 47/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.0964 - accuracy: 0.9632 - val_loss: 0.0186 - val_accuracy: 0.9950
# Epoch 48/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0944 - accuracy: 0.9639 - val_loss: 0.0198 - val_accuracy: 0.9945
# Epoch 49/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.0950 - accuracy: 0.9635 - val_loss: 0.0158 - val_accuracy: 0.9960
# Epoch 50/100
# 2223/2223 [==============================] - 101s 46ms/step - loss: 0.0942 - accuracy: 0.9641 - val_loss: 0.0124 - val_accuracy: 0.9969
# Epoch 51/100
# 2223/2223 [==============================] - 101s 45ms/step - loss: 0.0931 - accuracy: 0.9646 - val_loss: 0.0171 - val_accuracy: 0.9956
# Epoch 52/100
# 2223/2223 [==============================] - 101s 45ms/step - loss: 0.0949 - accuracy: 0.9636 - val_loss: 0.0130 - val_accuracy: 0.9968
# Epoch 53/100
# 2223/2223 [==============================] - 100s 45ms/step - loss: 0.0931 - accuracy: 0.9642 - val_loss: 0.0233 - val_accuracy: 0.9954
# Epoch 54/100
# 2223/2223 [==============================] - 101s 45ms/step - loss: 0.0921 - accuracy: 0.9646 - val_loss: 0.0123 - val_accuracy: 0.9969
# Epoch 55/100
# 2223/2223 [==============================] - 101s 45ms/step - loss: 0.0950 - accuracy: 0.9636 - val_loss: 0.0180 - val_accuracy: 0.9948
# Epoch 56/100
# 2223/2223 [==============================] - 99s 44ms/step - loss: 0.0941 - accuracy: 0.9641 - val_loss: 0.0142 - val_accuracy: 0.9962
# Epoch 57/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.0930 - accuracy: 0.9647 - val_loss: 0.0309 - val_accuracy: 0.9904
# Epoch 58/100
# 2223/2223 [==============================] - 99s 45ms/step - loss: 0.0938 - accuracy: 0.9639 - val_loss: 0.0122 - val_accuracy: 0.9969
# Epoch 59/100
# 2223/2223 [==============================] - 101s 45ms/step - loss: 0.0930 - accuracy: 0.9645 - val_loss: 0.0134 - val_accuracy: 0.9965

# %%
# load the model
model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_test[:, 0], X_test[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      1.00     35559
#            1       0.99      1.00      1.00     35559
#
#     accuracy                           1.00     71118
#    macro avg       1.00      1.00      1.00     71118
# weighted avg       1.00      1.00      1.00     71118

# %%
test = df.loc[X_test_indexes].copy()
test["pred"] = y_pred
test["pred"] = test["pred"].apply(lambda x: int(x))
test
test[test.rhyme != test.pred]
# Out:
#          index       word_a       word_b  rhyme  \
# 236961  413717         hasj           eg      0
# 25820    25820  fløytespill         smil      1
# 179744  233918     boretårn       havørn      0
# 39504     1337      fromasj     pistasie      1
# 156268  436525         tort  adgangskort      0
# ...        ...          ...          ...    ...
# 214853  230479     pipelort      ID-kort      0
# 39042      875         tort    sluseport      1
# 211694  764723           de      entalpi      0
# 161393  143148         hasj         fred      0
# 6172      6172        stort         land      1
#
#                                               word_tokens  pred
# 236961  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 25820   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 179744  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 39504   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 156268  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# ...                                                   ...   ...
# 214853  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 39042   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
# 211694  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 161393  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     1
# 6172    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....     0
#
# [250 rows x 6 columns]

# %%
samples = [
    ["Kan du ikke se det", "Deg skal jeg lede"], 
    ["Kaker av alle slag", "Her henger Norges flagg"], 
    ["Jeg har ikke tid", "Til dette svineri"],
    ["Hva har du sagt", "Kaken er bakt"], 
    ["Barna er lagt", "Kaken er laget"],
    ["Gjorde du det med vilje", "Kaken smaker vanilje"], 
    ["Dette vokser", "Satans underbukser"],
    ["tid", "svineri"]
]

samples2 = [[b,a] for a,b in samples]

sample_tokens = [tokenize_inputs(lyrics[0], lyrics[1], tokenizer) for lyrics in samples]
sample_tokens = tf.convert_to_tensor(sample_tokens)

sample_tokens2 = [tokenize_inputs(lyrics[0], lyrics[1], tokenizer) for lyrics in samples2]
sample_tokens2 = tf.convert_to_tensor(sample_tokens2)

sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

sample_pred2 = model.predict([sample_tokens2[:, 0], sample_tokens2[:, 1]])
predictions2 = [round(pred[0], 4) for pred in sample_pred2]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print(f"{'Rhyme' if predictions2[i] > 0.5 else 'Non-rhyme'}({predictions2[i]})")
    print("---------------\n")
# Out:
# Sentence 1: Kan du ikke se det
# Sentence 2: Deg skal jeg lede
# Rhyme(0.9957000017166138)
# Rhyme(0.9952999949455261)
# ---------------
#
# Sentence 1: Kaker av alle slag
# Sentence 2: Her henger Norges flagg
# Rhyme(0.996999979019165)
# Rhyme(0.9975000023841858)
# ---------------
#
# Sentence 1: Jeg har ikke tid
# Sentence 2: Til dette svineri
# Rhyme(0.8123999834060669)
# Rhyme(0.9900000095367432)
# ---------------
#
# Sentence 1: Hva har du sagt
# Sentence 2: Kaken er bakt
# Rhyme(0.9979000091552734)
# Rhyme(0.9975000023841858)
# ---------------
#
# Sentence 1: Barna er lagt
# Sentence 2: Kaken er laget
# Non-rhyme(0.0)
# Non-rhyme(0.0007999999797903001)
# ---------------
#
# Sentence 1: Gjorde du det med vilje
# Sentence 2: Kaken smaker vanilje
# Rhyme(0.9970999956130981)
# Rhyme(0.9970999956130981)
# ---------------
#
# Sentence 1: Dette vokser
# Sentence 2: Satans underbukser
# Rhyme(0.9970999956130981)
# Rhyme(0.9970999956130981)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Rhyme(0.9957000017166138)
# Rhyme(0.9957000017166138)
# ---------------
