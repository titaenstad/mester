# %% [markdown]
# source: https://github.com/minoguep/rhyme_detection and https://paulminogue.com/index.php/2021/02/14/using-a-siamese-neural-network-to-create-a-simple-rhyme-detector/

# %%
import string
import json

import nltk
import numpy as np
import pandas as pd
import tensorflow as tf

from tqdm.notebook import tqdm

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix

from tensorflow.keras import Model
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.layers import Input, LSTM, Dense, Dropout, Subtract, Lambda
from tensorflow.keras.callbacks import ModelCheckpoint, TerminateOnNaN, CSVLogger, EarlyStopping

tqdm.pandas()

MAX_LEN = 64
SEED = 420
# sets random, np.random and tf.random seed
tf.keras.utils.set_random_seed(
    SEED
)

# %% [markdown]
# ## Model architecture

# %%
# Pauls code
def create_model():
  
    word_a_input_tokens = Input(
      shape=(MAX_LEN, 1), name='word_a_input_tokens'
      )
    word_b_input_tokens = Input(
      shape=(MAX_LEN, 1), name='word_b_input_tokens'
      )
    
    # This is the siamese portion of the model 
    common_lstm = LSTM(64, return_sequences=False, activation="relu", name="common_lstm_layer")

    word_a_lstm_output = common_lstm(word_a_input_tokens)
    word_b_lstm_output = common_lstm(word_b_input_tokens)

    #concatenate_lstm_outputs
    concat_layer = Subtract(name="concatenate_lstm_outputs")(
      [word_a_lstm_output, word_b_lstm_output]
      )
        
    # dense layers before final classification
    dense_layers = Dense(64, activation="relu", name="first_dense_layer")(concat_layer)
    dense_layers = Dropout(0.5)(dense_layers)

    dense_layers = Dense(32, activation="relu", name="second_dense_layer")(dense_layers)
    dense_layers = Dropout(0.5)(dense_layers)

    dense_layers = Dense(8, activation="relu", name="third_dense_layer")(dense_layers)
    dense_layers = Dropout(0.5)(dense_layers)

    classification_layer = Dense(1, activation="sigmoid", name="classification_layer")(dense_layers)
    
    model = Model(
      inputs=[word_a_input_tokens, word_b_input_tokens], 
      outputs = classification_layer
      )

    model.compile(
      loss="binary_crossentropy",
      metrics=["accuracy"],
      optimizer="Adam"
    )

    return model

# %%
# My symmetric version
def create_symmetric_model():  
    word_a_input_tokens = Input(
      shape=(MAX_LEN, 1), name='word_a_input_tokens'
      )
    word_b_input_tokens = Input(
      shape=(MAX_LEN, 1), name='word_b_input_tokens'
      )
    
    # This is the siamese portion of the model 
    common_lstm = LSTM(64, return_sequences=False, activation="relu", name="common_lstm_layer")

    word_a_lstm_output = common_lstm(word_a_input_tokens)
    word_b_lstm_output = common_lstm(word_b_input_tokens)

    #concatenate_lstm_outputs
    concat_layer = Subtract(name="concatenate_lstm_outputs")(
      [word_a_lstm_output, word_b_lstm_output]
      )
    
    concat_layer = Lambda(lambda x: tf.math.abs(x))(concat_layer)
    
    # dense layers before final classification
    dense_layers = Dense(64, activation="relu", name="first_dense_layer")(concat_layer)
    dense_layers = Dropout(0.5)(dense_layers)

    dense_layers = Dense(32, activation="relu", name="second_dense_layer")(dense_layers)
    dense_layers = Dropout(0.5)(dense_layers)

    dense_layers = Dense(8, activation="relu", name="third_dense_layer")(dense_layers)
    dense_layers = Dropout(0.5)(dense_layers)

    classification_layer = Dense(1, activation="sigmoid", name="classification_layer")(dense_layers)
    
    model = Model(
      inputs=[word_a_input_tokens, word_b_input_tokens], 
      outputs = classification_layer
      )

    model.compile(
      loss="binary_crossentropy",
      metrics=["accuracy"],
      optimizer="Adam"
    )

    return model

# %% [markdown]
# # Data
# We want equally many positive and negative samples of rhyme pairs

# %%
pos = pd.read_csv("tsvs/positive_pairs.tsv", sep="\t")
full_neg = pd.read_csv("tsvs/negative_pairs.tsv", sep="\t")
neg = full_neg.sample(n=len(pos), random_state=SEED)
df = pd.concat([pos, neg])
df = df.reset_index(drop=True)
df
# Out:
#           word_a  word_b  rhyme
# 0          stall  skrall      1
# 1           ving    ting      1
# 2          orden  horden      1
# 3          taler  svaler      1
# 4      juleskikk   blikk      1
# ...          ...     ...    ...
# 14471       hatt   slott      0
# 14472        mur   stund      0
# 14473        hud    mave      0
# 14474        dør    sans      0
# 14475        inn   kvist      0
#
# [14476 rows x 3 columns]

# %% [markdown]
# ## Words to char tokens
# Copy paste from Pauls notebook

# %%
def tokenize_inputs(phrase_a, phrase_b, tokenizer):
    tokenized_phrases = tokenizer.texts_to_sequences([phrase_a, phrase_b])

    # now loop through inputs and pad or reduce size if required
    tokenized_phrases_for_output = []
    for phrase in tokenized_phrases:
        if len(phrase) < MAX_LEN:
            length_to_pad = MAX_LEN - len(phrase)
            phrase_for_output = ([0] * length_to_pad) + phrase
        elif len(phrase) > MAX_LEN:
            phrase_for_output = phrase[-MAX_LEN:]
        else:
            phrase_for_output = phrase
        tokenized_phrases_for_output.append(phrase_for_output)

    return tf.constant(tokenized_phrases_for_output, dtype=tf.float64)

# %%
# all_data = pd.read_csv("tsvs/tita_rhymes_poems.tsv", sep="\t")

# all_text = ""
# for e in all_data.stanza:
#     all_text += e
# tokenizer = Tokenizer(char_level=True, lower=True)
# tokenizer.fit_on_texts(all_text)

# tokenizer_config = tokenizer.to_json()

# with open('siamese_lstm_tokenizer_config.json', 'w') as f:
#     f.write(tokenizer_config)

# %%
with open("siamese_lstm_tokenizer_config.json") as f:
    tokenizer_config = f.read()

tokenizer = tf.keras.preprocessing.text.tokenizer_from_json(tokenizer_config)

# %%
df['word_tokens'] = df.progress_apply(
    lambda row: tokenize_inputs(row['word_a'], row['word_b'], tokenizer), axis=1
)
# Out:
#   0%|          | 0/14476 [00:00<?, ?it/s]

# %%
X_train_indexes, X_test_indexes, y_train, y_test = train_test_split(
    list(df.index), list(df['rhyme']), stratify=df['rhyme'], 
    test_size=0.4, random_state=SEED
    )

X_test_indexes, X_val_indexes, y_test, y_val = train_test_split(
    X_test_indexes, y_test, stratify=y_test, 
    test_size=0.25, random_state=SEED
    )

X_train = tf.convert_to_tensor(list(df.loc[X_train_indexes]["word_tokens"]))
X_val = tf.convert_to_tensor(list(df.loc[X_val_indexes]["word_tokens"]))
X_test = tf.convert_to_tensor(list(df.loc[X_test_indexes]["word_tokens"]))

y_train = tf.convert_to_tensor(y_train)
y_val = tf.convert_to_tensor(y_val)
y_test = tf.convert_to_tensor(y_test)

# %%
print(f"""
    Data set size: Full set: {len(df)}
    Train: {len(X_train)}
    Validation: {len(X_val)}
    Test: {len(X_test)}
""")
# Out:
#     Data set size: Full set: 14476
#     Train: 8685
#     Validation: 1448
#     Test: 4343

# %% [markdown]
# # Baseline

# %%
test_text = df.loc[X_test_indexes]
test_text
# Out:
#         word_a  word_b  rhyme  \
# 1789     hugge   vugge      1
# 6140      snar     far      1
# 9312      høre  kvider      0
# 10727  brenner    gang      0
# 13969  hernede    saft      0
# ...        ...     ...    ...
# 5965       sti   verdi      1
# 10776     nåde   grunn      0
# 4184      fans   krans      1
# 12052    sanne     rid      0
# 6398     hørte   rørte      1
#
#                                              word_tokens
# 1789   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6140   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9312   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 10727  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 13969  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                  ...
# 5965   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 10776  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 4184   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 12052  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6398   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [4343 rows x 4 columns]

# %%
def is_vowel(char):
    return char in ['e', 'a', 'i', 'o', 'u', 'å', 'ø', 'y', 'æ', 'é', 'ö', 'ä', 'á', 'à']

def last_letters(word):
    for i in range(len(word)-1, -1, -1):
        if is_vowel(word[i]):
            break
    return word[i:]

def rhymes(word_a, word_b):
    return last_letters(word_a) == last_letters(word_b)


baseline_pred = [rhymes(word_a, word_b) for word_a, word_b in zip(test_text.word_a, test_text.word_b)]

# %%
print("Test set accuracy")
print(classification_report(y_test, baseline_pred))
# Out:
# Test set accuracy
#               precision    recall  f1-score   support
#
#            0       0.88      0.93      0.90      2171
#            1       0.93      0.87      0.90      2172
#
#     accuracy                           0.90      4343
#    macro avg       0.90      0.90      0.90      4343
# weighted avg       0.90      0.90      0.90      4343

# %%
samples = [
    ["se det", "frede"], 
    ["tid", "svineri"],
    ["sagt", "sagd"],
    ["vilje", "vanilje"], 
    ["vokser", "bukser"],
    ["ha det", "badet"]
]

for a, b in samples:
    pred = rhymes(a,b)
    print("Sentence 1:", a)
    print("Sentence 2:", b)
    if pred:
        print("Rhyme\n")
    else:
        print("Not rhyme\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Not rhyme
#
# Sentence 1: tid
# Sentence 2: svineri
# Not rhyme
#
# Sentence 1: sagt
# Sentence 2: sagd
# Not rhyme
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme
#
# Sentence 1: ha det
# Sentence 2: badet
# Rhyme

# %% [markdown]
# # First model

# %%
model_name = "rhyme_model_1"

# model = create_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='val_loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=128,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )
# Out:
# Epoch 1/100
# 68/68 [==============================] - 5s 48ms/step - loss: 0.7014 - accuracy: 0.4663 - val_loss: 0.6845 - val_accuracy: 0.5000
# Epoch 2/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.6632 - accuracy: 0.5950 - val_loss: 0.6021 - val_accuracy: 0.8363
# Epoch 3/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.5846 - accuracy: 0.7769 - val_loss: 0.4907 - val_accuracy: 0.8833
# Epoch 4/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.5182 - accuracy: 0.8298 - val_loss: 0.4446 - val_accuracy: 0.8881
# Epoch 5/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.4821 - accuracy: 0.8469 - val_loss: 0.4009 - val_accuracy: 0.8985
# Epoch 6/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.4522 - accuracy: 0.8563 - val_loss: 0.3743 - val_accuracy: 0.8819
# Epoch 7/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.4316 - accuracy: 0.8479 - val_loss: 0.3370 - val_accuracy: 0.8909
# Epoch 8/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.4019 - accuracy: 0.8576 - val_loss: 0.3074 - val_accuracy: 0.9006
# Epoch 9/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3784 - accuracy: 0.8668 - val_loss: 0.2877 - val_accuracy: 0.9054
# Epoch 10/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.3599 - accuracy: 0.8659 - val_loss: 0.2720 - val_accuracy: 0.9075
# Epoch 11/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3619 - accuracy: 0.8642 - val_loss: 0.2613 - val_accuracy: 0.9068
# Epoch 12/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3482 - accuracy: 0.8695 - val_loss: 0.2533 - val_accuracy: 0.9075
# Epoch 13/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3445 - accuracy: 0.8700 - val_loss: 0.2502 - val_accuracy: 0.9123
# Epoch 14/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.3382 - accuracy: 0.8690 - val_loss: 0.2374 - val_accuracy: 0.9109
# Epoch 15/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.3325 - accuracy: 0.8694 - val_loss: 0.2313 - val_accuracy: 0.9130
# Epoch 16/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.3242 - accuracy: 0.8789 - val_loss: 0.2338 - val_accuracy: 0.9185
# Epoch 17/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3170 - accuracy: 0.8812 - val_loss: 0.2288 - val_accuracy: 0.9109
# Epoch 18/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.3201 - accuracy: 0.8822 - val_loss: 0.2183 - val_accuracy: 0.9185
# Epoch 19/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.3140 - accuracy: 0.8843 - val_loss: 0.2196 - val_accuracy: 0.9185
# Epoch 20/100
# 68/68 [==============================] - 3s 40ms/step - loss: 0.3100 - accuracy: 0.8824 - val_loss: 0.2159 - val_accuracy: 0.9164
# Epoch 21/100
# 68/68 [==============================] - 3s 40ms/step - loss: 0.2987 - accuracy: 0.8887 - val_loss: 0.2145 - val_accuracy: 0.9206
# Epoch 22/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2990 - accuracy: 0.8872 - val_loss: 0.1973 - val_accuracy: 0.9227
# Epoch 23/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.2935 - accuracy: 0.8895 - val_loss: 0.1979 - val_accuracy: 0.9247
# Epoch 24/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.3045 - accuracy: 0.8885 - val_loss: 0.2010 - val_accuracy: 0.9233
# Epoch 25/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2893 - accuracy: 0.8938 - val_loss: 0.1974 - val_accuracy: 0.9233
# Epoch 26/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2803 - accuracy: 0.8968 - val_loss: 0.1965 - val_accuracy: 0.9268
# Epoch 27/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2828 - accuracy: 0.8960 - val_loss: 0.1860 - val_accuracy: 0.9316
# Epoch 28/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2835 - accuracy: 0.8933 - val_loss: 0.2003 - val_accuracy: 0.9275
# Epoch 29/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2862 - accuracy: 0.8989 - val_loss: 0.1891 - val_accuracy: 0.9302
# Epoch 30/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2841 - accuracy: 0.8955 - val_loss: 0.1881 - val_accuracy: 0.9344
# Epoch 31/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2758 - accuracy: 0.9022 - val_loss: 0.1843 - val_accuracy: 0.9344
# Epoch 32/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2723 - accuracy: 0.8959 - val_loss: 0.1894 - val_accuracy: 0.9316
# Epoch 33/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2779 - accuracy: 0.9014 - val_loss: 0.1840 - val_accuracy: 0.9392
# Epoch 34/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.2722 - accuracy: 0.9003 - val_loss: 0.1897 - val_accuracy: 0.9302
# Epoch 35/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2647 - accuracy: 0.9018 - val_loss: 0.1982 - val_accuracy: 0.9344
# Epoch 36/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.2651 - accuracy: 0.9028 - val_loss: 0.1919 - val_accuracy: 0.9406
# Epoch 37/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2688 - accuracy: 0.9036 - val_loss: 0.1771 - val_accuracy: 0.9358
# Epoch 38/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2715 - accuracy: 0.9031 - val_loss: 0.1804 - val_accuracy: 0.9372
# Epoch 39/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2654 - accuracy: 0.9056 - val_loss: 0.1826 - val_accuracy: 0.9399
# Epoch 40/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.2607 - accuracy: 0.9089 - val_loss: 0.1775 - val_accuracy: 0.9372
# Epoch 41/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2677 - accuracy: 0.9064 - val_loss: 0.1802 - val_accuracy: 0.9413
# Epoch 42/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.2577 - accuracy: 0.9065 - val_loss: 0.1819 - val_accuracy: 0.9372

# %%
model_name = "rhyme_model_1"

# load the model
model = load_model(f"models/{model_name}.hdf5")
y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print("Val set accuracy")
print(classification_report(y_val, y_pred))

# y_pred = model.predict([X_test[:, 0], X_test[:, 1]])
# y_pred = y_pred > 0.5
# print(classification_report(y_test, y_pred))
# Out:
# Val set accuracy
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94       724
#            1       0.96      0.92      0.94       724
#
#     accuracy                           0.94      1448
#    macro avg       0.94      0.94      0.94      1448
# weighted avg       0.94      0.94      0.94      1448

# %%
def get_mirrored_df(df):
    df = df.copy()
    mirror = pd.DataFrame({"word_a": df["word_b"], 
                           "word_b": df["word_a"], 
                           "rhyme": df["rhyme"], 
                           "word_tokens":[(t[1], t[0]) for t in df["word_tokens"]]})
    return mirror

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
val.loc[val["pred1"] != val["rhyme"]]
# Out:
#              word_a  word_b  rhyme  \
# 6537          havet    gave      1
# 6898           bred      se      1
# 14059          ende      vé      0
# 8529           sale    tale      0
# 10339          øyet      er      0
# ...             ...     ...    ...
# 13429          dikt    raft      0
# 460    rikmannslott    fått      1
# 1010     uskyldsren      en      1
# 6395            mer    fler      1
# 13766            en  landet      0
#
#                                              word_tokens  pred1
# 6537   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 6898   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 14059  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 8529   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 10339  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# ...                                                  ...    ...
# 13429  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 460    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 1010   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 6395   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 13766  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
#
# [91 rows x 5 columns]

# %%
mirror_val = get_mirrored_df(val)
mirror_val
# Out:
#              word_a     word_b  rhyme  \
# 3594          hytte   beskytte      1
# 2736           halm       malm      1
# 14351        ganger      visen      0
# 5492          forbi         li      1
# 9140           borg        ene      0
# ...             ...        ...    ...
# 13766        landet         en      0
# 9926         morgen       hjul      0
# 1196   ferdselsårer      kårer      1
# 6586          finne  noensinne      1
# 13290          frem        røk      0
#
#                                              word_tokens
# 3594   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 2736   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 14351  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 5492   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9140   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                  ...
# 13766  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9926   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 1196   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6586   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [1448 rows x 4 columns]

# %%
mirror_X_val = tf.convert_to_tensor(list(mirror_val["word_tokens"]))

mirror_y_pred = model.predict([mirror_X_val[:, 0], mirror_X_val[:, 1]])
mirror_y_pred = mirror_y_pred > 0.5
print(classification_report(y_val, mirror_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.97      0.94       724
#            1       0.97      0.90      0.93       724
#
#     accuracy                           0.94      1448
#    macro avg       0.94      0.94      0.94      1448
# weighted avg       0.94      0.94      0.94      1448

# %%
val["pred2"] = mirror_y_pred
diff = val.loc[val["pred1"] != val["pred2"]]
print(len(diff))
diff
# Out:
# 36
#               word_a         word_b  rhyme  \
# 2068              's     santkehans      1
# 4491           skred            ned      1
# 7007             inn  avgrundsskinn      1
# 12892    presteskrud             ei      0
# 6934       garantier           vier      1
# 304            lever        strever      1
# 3178            gård            sår      1
# 1322              ve            tre      1
# 1509             sti          forbi      1
# 13497         kveget         banket      0
# 5617   solskinnsvind            inn      1
# 5444        likefrem           hjem      1
# 5997              er           især      1
# 13150        griller         glider      0
# 2885             øen          snøen      1
# 5667              ny          aveny      1
# 2637              ve             Se      1
# 4533         veteran   Ku-Klux-Klan      1
# 3633            stat         dravat      1
# 5301              er            lær      1
# 5504            hård            vår      1
# 1255           stand      tyribrann      1
# 4360           kjent          vendt      1
# 2839              vi            tid      1
# 3554            slår           gård      1
# 6917            korn       nypetorn      1
# 7161            strå            ljå      1
# 6487            bort           vårt      1
# 1269          svenne         elende      1
# 3961       bibelsted            ned      1
# 10459             én           sved      0
# 460     rikmannslott           fått      1
# 10318          kåret           bære      0
# 6069            slut             ut      1
# 2223             inn    pålandsvind      1
# 13290            røk           frem      0
#
#                                              word_tokens  pred1  pred2
# 2068   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 4491   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 7007   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 12892  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 6934   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 304    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 3178   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 1322   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 1509   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 13497  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 5617   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 5444   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 5997   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 13150  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 2885   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 5667   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 2637   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 4533   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 3633   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 5301   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 5504   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 1255   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 4360   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 2839   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 3554   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 6917   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 7161   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 6487   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 1269   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 3961   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 10459  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 460    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 10318  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 6069   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 2223   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True

# %%
samples = [
    ["se det", "frede"], 
    ["tid", "svineri"],
    ["sagt", "sagd"],
    ["vilje", "vanilje"], 
    ["vokser", "bukser"],
    ["ha det", "badet"]
]

samples2 = [[b,a] for a,b in samples]

sample_tokens = [tokenize_inputs(lyrics[0], lyrics[1], tokenizer) for lyrics in samples]
sample_tokens = tf.convert_to_tensor(sample_tokens)

sample_tokens2 = [tokenize_inputs(lyrics[0], lyrics[1], tokenizer) for lyrics in samples2]
sample_tokens2 = tf.convert_to_tensor(sample_tokens2)

sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

sample_pred2 = model.predict([sample_tokens2[:, 0], sample_tokens2[:, 1]])
predictions2 = [round(pred[0], 4) for pred in sample_pred2]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print(f"{'Rhyme' if predictions2[i] > 0.5 else 'Non-rhyme'}({predictions2[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Non-rhyme(0.3463999927043915)
# Non-rhyme(0.29510000348091125)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Non-rhyme(0.3490000069141388)
# Non-rhyme(0.30869999527931213)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Non-rhyme(0.27160000801086426)
# Non-rhyme(0.30329999327659607)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(0.9952999949455261)
# Rhyme(0.9952999949455261)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(0.9911999702453613)
# Rhyme(0.9477999806404114)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Non-rhyme(0.26499998569488525)
# Non-rhyme(0.257999986410141)
# ---------------

# %% [markdown]
# # Try again with different 2:3 positive to negative ratio
# Expand train set.
# The set is already 50/50 positive and negative.
# We want to make it 40/60 --> increase negative examples by half of what we already have

# %%
new_neg_train = len(X_train) // 4

new_neg_train
# Out:
# 2171

# %%
# use same seed, and extract all the pairs already used + the ones we need 
negative2 = full_neg.sample(n=len(pos) + new_neg_train, random_state=SEED)

# %%
unused_neg = negative2[len(pos):]
unused_neg
# Out:
#               word_a    word_b  rhyme
# 9448             hår   blundet      0
# 15651        brenner     skatt      0
# 16533            siv    stille      0
# 16219  verdensdommen    kronet      0
# 13700           jord      sans      0
# ...              ...       ...    ...
# 3741             stå      gang      0
# 20029           vekt    dørken      0
# 11242           sner     huset      0
# 9095           klang     rørte      0
# 6784               i  stjerner      0
#
# [2171 rows x 3 columns]

# %%
# use same tokenizer as above
unused_neg['word_tokens'] = unused_neg.progress_apply(
    lambda row: tokenize_inputs(row['word_a'], row['word_b'], tokenizer), axis=1
)
unused_neg
# Out:
#   0%|          | 0/2171 [00:00<?, ?it/s]
# /tmp/ipykernel_5420/3559433584.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unused_neg['word_tokens'] = unused_neg.progress_apply(
#               word_a    word_b  rhyme  \
# 9448             hår   blundet      0
# 15651        brenner     skatt      0
# 16533            siv    stille      0
# 16219  verdensdommen    kronet      0
# 13700           jord      sans      0
# ...              ...       ...    ...
# 3741             stå      gang      0
# 20029           vekt    dørken      0
# 11242           sner     huset      0
# 9095           klang     rørte      0
# 6784               i  stjerner      0
#
#                                              word_tokens
# 9448   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 15651  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 16533  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 16219  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 13700  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                  ...
# 3741   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 20029  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 11242  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9095   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6784   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [2171 rows x 4 columns]

# %%
X_new = list(unused_neg["word_tokens"])
y_new = list(unused_neg["rhyme"])

# %%
X_train_new = tf.convert_to_tensor(list(df.loc[X_train_indexes]["word_tokens"]) +  X_new)
y_train_new = tf.convert_to_tensor(list(y_train) + y_new)


X_train_new.shape, y_train_new.shape
# Out:
# (TensorShape([10856, 2, 64]), TensorShape([10856]))

# %%
model_name = "rhyme_model_23_ratio"

# # Uncomment to train
# model = create_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='val_loss', patience=5)

# history = model.fit(
#     [X_train_new[:, 0], X_train_new[:, 1]],
#     y_train_new,
#     batch_size=128,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )
# Out:
# Epoch 1/100
# 85/85 [==============================] - 6s 46ms/step - loss: 0.6150 - accuracy: 0.5878 - val_loss: 0.5513 - val_accuracy: 0.5000
# Epoch 2/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.5128 - accuracy: 0.7775 - val_loss: 0.5001 - val_accuracy: 0.8805
# Epoch 3/100
# 85/85 [==============================] - 4s 45ms/step - loss: 0.4768 - accuracy: 0.8666 - val_loss: 0.4719 - val_accuracy: 0.8978
# Epoch 4/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.4469 - accuracy: 0.8798 - val_loss: 0.4587 - val_accuracy: 0.8916
# Epoch 5/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.4293 - accuracy: 0.8835 - val_loss: 0.4301 - val_accuracy: 0.9026
# Epoch 6/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4184 - accuracy: 0.8803 - val_loss: 0.4139 - val_accuracy: 0.9019
# Epoch 7/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4014 - accuracy: 0.8834 - val_loss: 0.4024 - val_accuracy: 0.9123
# Epoch 8/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3897 - accuracy: 0.8852 - val_loss: 0.3900 - val_accuracy: 0.9054
# Epoch 9/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3813 - accuracy: 0.8861 - val_loss: 0.3753 - val_accuracy: 0.9040
# Epoch 10/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3649 - accuracy: 0.8893 - val_loss: 0.3600 - val_accuracy: 0.9047
# Epoch 11/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.3592 - accuracy: 0.8901 - val_loss: 0.3612 - val_accuracy: 0.9123
# Epoch 12/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3511 - accuracy: 0.8908 - val_loss: 0.3487 - val_accuracy: 0.9116
# Epoch 13/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3416 - accuracy: 0.8909 - val_loss: 0.3268 - val_accuracy: 0.9109
# Epoch 14/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3349 - accuracy: 0.8952 - val_loss: 0.3245 - val_accuracy: 0.9068
# Epoch 15/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3292 - accuracy: 0.8984 - val_loss: 0.3045 - val_accuracy: 0.9192
# Epoch 16/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3212 - accuracy: 0.9020 - val_loss: 0.3013 - val_accuracy: 0.9254
# Epoch 17/100
# 85/85 [==============================] - 4s 45ms/step - loss: 0.3118 - accuracy: 0.9002 - val_loss: 0.2920 - val_accuracy: 0.9213
# Epoch 18/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.3132 - accuracy: 0.9020 - val_loss: 0.2871 - val_accuracy: 0.9164
# Epoch 19/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3106 - accuracy: 0.9015 - val_loss: 0.2786 - val_accuracy: 0.9289
# Epoch 20/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2960 - accuracy: 0.9100 - val_loss: 0.2775 - val_accuracy: 0.9254
# Epoch 21/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2952 - accuracy: 0.9080 - val_loss: 0.2688 - val_accuracy: 0.9323
# Epoch 22/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2903 - accuracy: 0.9094 - val_loss: 0.2647 - val_accuracy: 0.9289
# Epoch 23/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2787 - accuracy: 0.9109 - val_loss: 0.2561 - val_accuracy: 0.9372
# Epoch 24/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2711 - accuracy: 0.9165 - val_loss: 0.2542 - val_accuracy: 0.9365
# Epoch 25/100
# 85/85 [==============================] - 4s 46ms/step - loss: 0.2722 - accuracy: 0.9108 - val_loss: 0.2590 - val_accuracy: 0.9344
# Epoch 26/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2742 - accuracy: 0.9115 - val_loss: 0.2373 - val_accuracy: 0.9378
# Epoch 27/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2650 - accuracy: 0.9101 - val_loss: 0.2283 - val_accuracy: 0.9413
# Epoch 28/100
# 85/85 [==============================] - 4s 47ms/step - loss: 0.2599 - accuracy: 0.9159 - val_loss: 0.2194 - val_accuracy: 0.9309
# Epoch 29/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2511 - accuracy: 0.9172 - val_loss: 0.2122 - val_accuracy: 0.9406
# Epoch 30/100
# 85/85 [==============================] - 5s 56ms/step - loss: 0.2469 - accuracy: 0.9195 - val_loss: 0.2377 - val_accuracy: 0.9323
# Epoch 31/100
# 85/85 [==============================] - 4s 47ms/step - loss: 0.2524 - accuracy: 0.9174 - val_loss: 0.2200 - val_accuracy: 0.9385
# Epoch 32/100
# 85/85 [==============================] - 4s 49ms/step - loss: 0.2429 - accuracy: 0.9213 - val_loss: 0.2062 - val_accuracy: 0.9413
# Epoch 33/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2439 - accuracy: 0.9207 - val_loss: 0.2037 - val_accuracy: 0.9385
# Epoch 34/100
# 85/85 [==============================] - 4s 48ms/step - loss: 0.2414 - accuracy: 0.9219 - val_loss: 0.2078 - val_accuracy: 0.9372
# Epoch 35/100
# 85/85 [==============================] - 4s 41ms/step - loss: 0.2386 - accuracy: 0.9218 - val_loss: 0.2121 - val_accuracy: 0.9358
# Epoch 36/100
# 85/85 [==============================] - 4s 41ms/step - loss: 0.2247 - accuracy: 0.9275 - val_loss: 0.2020 - val_accuracy: 0.9392
# Epoch 37/100
# 85/85 [==============================] - 3s 41ms/step - loss: 0.2298 - accuracy: 0.9244 - val_loss: 0.1945 - val_accuracy: 0.9392
# Epoch 38/100
# 85/85 [==============================] - 4s 41ms/step - loss: 0.2321 - accuracy: 0.9253 - val_loss: 0.2004 - val_accuracy: 0.9413
# Epoch 39/100
# 85/85 [==============================] - 3s 41ms/step - loss: 0.2200 - accuracy: 0.9273 - val_loss: 0.2052 - val_accuracy: 0.9406
# Epoch 40/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2191 - accuracy: 0.9305 - val_loss: 0.2027 - val_accuracy: 0.9337
# Epoch 41/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2243 - accuracy: 0.9281 - val_loss: 0.2053 - val_accuracy: 0.9351
# Epoch 42/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2341 - accuracy: 0.9231 - val_loss: 0.1975 - val_accuracy: 0.9454

# %%
model_name = "rhyme_model_23_ratio"

# load the model
model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.96      0.95       724
#            1       0.96      0.93      0.94       724
#
#     accuracy                           0.95      1448
#    macro avg       0.95      0.95      0.95      1448
# weighted avg       0.95      0.95      0.95      1448

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
val.loc[val["pred1"] != val["rhyme"]]
# Out:
#        word_a    word_b  rhyme  \
# 14351   visen    ganger      0
# 6537    havet      gave      1
# 10849  gløder  skjelver      0
# 14059    ende        vé      0
# 13792    land    skritt      0
# ...       ...       ...    ...
# 13283  besvær   slipper      0
# 9777    seder     døden      0
# 6395      mer      fler      1
# 13766      en    landet      0
# 13290     røk      frem      0
#
#                                              word_tokens  pred1
# 14351  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 6537   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 10849  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 14059  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 13792  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# ...                                                  ...    ...
# 13283  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 9777   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 6395   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 13766  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
#
# [89 rows x 5 columns]

# %%
mirror_val = get_mirrored_df(val)
mirror_X_val = tf.convert_to_tensor(list(mirror_val["word_tokens"]))

mirror_y_pred = model.predict([mirror_X_val[:, 0], mirror_X_val[:, 1]])
mirror_y_pred = mirror_y_pred > 0.5
print(classification_report(y_val, mirror_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.92      0.93       724
#            1       0.92      0.95      0.93       724
#
#     accuracy                           0.93      1448
#    macro avg       0.93      0.93      0.93      1448
# weighted avg       0.93      0.93      0.93      1448

# %%
val["pred2"] = mirror_y_pred
diff = val.loc[val["pred1"] != val["pred2"]]
print(len(diff))
diff
# Out:
# 40
#            word_a       word_b  rhyme  \
# 10849      gløder     skjelver      0
# 8478       Graven       lukket      0
# 10012         nær       svenne      0
# 7978         garn         rest      0
# 2791          min          inn      1
# 2068           's   santkehans      1
# 6160         godt  huldreslått      1
# 11256       plagg         frem      0
# 1646         munn  morgenstund      1
# 7991           se     kveldene      0
# 12975      næring          tid      0
# 7833       skjule        svake      0
# 8774        ruger       fanger      0
# 1322           ve          tre      1
# 9685        plagg          fem      0
# 1265          ihu          gru      1
# 9390          jeg          vil      0
# 6363    helligdom           om      1
# 2584    Jerusalem         hjem      1
# 9533          lek          dog      0
# 11844       visen      slanger      0
# 8104         barm     åndedrag      0
# 9375       grunne           er      0
# 932        litani        forbi      1
# 2582        igjen         penn      1
# 3963         sted          sæd      1
# 13078      kjenne           se      0
# 3930        kveld        skjel      1
# 1256           om         flom      1
# 3495       farvel         vell      1
# 11738      skrekk           så      0
# 8683       sanden      peneste      0
# 4360        kjent        vendt      1
# 13659  allegorien          mén      0
# 6487         bort         vårt      1
# 2308         tent    forbannet      1
# 10602       kåret        vente      0
# 12005   fortæring          tid      0
# 10459          én         sved      0
# 3125          inn          sin      1
#
#                                              word_tokens  pred1  pred2
# 10849  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 8478   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 10012  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 7978   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 2791   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 2068   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 6160   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 11256  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 1646   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 7991   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 12975  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 7833   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 8774   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 1322   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 9685   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 1265   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 9390   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 6363   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 2584   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 9533   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 11844  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 8104   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 9375   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 932    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 2582   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 3963   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 13078  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 3930   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 1256   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 3495   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 11738  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 8683   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 4360   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 13659  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 6487   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 2308   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 10602  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 12005  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 10459  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 3125   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False

# %%
samples2 = [[b,a] for a,b in samples]

sample_tokens = [tokenize_inputs(lyrics[0], lyrics[1], tokenizer) for lyrics in samples]
sample_tokens = tf.convert_to_tensor(sample_tokens)

sample_tokens2 = [tokenize_inputs(lyrics[0], lyrics[1], tokenizer) for lyrics in samples2]
sample_tokens2 = tf.convert_to_tensor(sample_tokens2)

sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

sample_pred2 = model.predict([sample_tokens2[:, 0], sample_tokens2[:, 1]])
predictions2 = [round(pred[0], 4) for pred in sample_pred2]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print(f"{'Rhyme' if predictions2[i] > 0.5 else 'Non-rhyme'}({predictions2[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Non-rhyme(0.4487000107765198)
# Rhyme(0.7192999720573425)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Rhyme(0.7950000166893005)
# Non-rhyme(0.46619999408721924)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Rhyme(0.7366999983787537)
# Rhyme(0.5515999794006348)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(0.8246999979019165)
# Rhyme(0.8246999979019165)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(0.8246999979019165)
# Rhyme(0.8246999979019165)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Non-rhyme(0.15049999952316284)
# Non-rhyme(0.35659998655319214)
# ---------------

# %% [markdown]
# # Use symmetric model

# %%
model_name = "rhyme_model_1_symmetric"

# # Uncomment to train model 

# model = create_symmetric_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5", monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='val_loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=128,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )
# Out:
# Epoch 1/100
# 68/68 [==============================] - 5s 48ms/step - loss: 0.6868 - accuracy: 0.5064 - val_loss: 0.6213 - val_accuracy: 0.8094
# Epoch 2/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.6091 - accuracy: 0.7058 - val_loss: 0.5159 - val_accuracy: 0.8743
# Epoch 3/100
# 68/68 [==============================] - 3s 41ms/step - loss: 0.5543 - accuracy: 0.7699 - val_loss: 0.4251 - val_accuracy: 0.8902
# Epoch 4/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.4820 - accuracy: 0.8150 - val_loss: 0.3450 - val_accuracy: 0.9006
# Epoch 5/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.4187 - accuracy: 0.8347 - val_loss: 0.2761 - val_accuracy: 0.9075
# Epoch 6/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.3692 - accuracy: 0.8474 - val_loss: 0.2362 - val_accuracy: 0.9095
# Epoch 7/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3428 - accuracy: 0.8614 - val_loss: 0.2270 - val_accuracy: 0.9130
# Epoch 8/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.3072 - accuracy: 0.8815 - val_loss: 0.2148 - val_accuracy: 0.9171
# Epoch 9/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2838 - accuracy: 0.8903 - val_loss: 0.2073 - val_accuracy: 0.9220
# Epoch 10/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.2709 - accuracy: 0.8928 - val_loss: 0.2073 - val_accuracy: 0.9192
# Epoch 11/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2697 - accuracy: 0.8908 - val_loss: 0.2055 - val_accuracy: 0.9233
# Epoch 12/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2594 - accuracy: 0.8997 - val_loss: 0.2066 - val_accuracy: 0.9220
# Epoch 13/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2663 - accuracy: 0.8944 - val_loss: 0.1972 - val_accuracy: 0.9240
# Epoch 14/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2492 - accuracy: 0.8969 - val_loss: 0.1903 - val_accuracy: 0.9296
# Epoch 15/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2484 - accuracy: 0.9055 - val_loss: 0.1798 - val_accuracy: 0.9309
# Epoch 16/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2390 - accuracy: 0.9050 - val_loss: 0.1798 - val_accuracy: 0.9344
# Epoch 17/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.2292 - accuracy: 0.9044 - val_loss: 0.1803 - val_accuracy: 0.9378
# Epoch 18/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.2275 - accuracy: 0.9135 - val_loss: 0.1878 - val_accuracy: 0.9372
# Epoch 19/100
# 68/68 [==============================] - 3s 42ms/step - loss: 0.2233 - accuracy: 0.9117 - val_loss: 0.1820 - val_accuracy: 0.9385
# Epoch 20/100
# 68/68 [==============================] - 3s 44ms/step - loss: 0.2253 - accuracy: 0.9156 - val_loss: 0.1685 - val_accuracy: 0.9454
# Epoch 21/100
# 68/68 [==============================] - 3s 49ms/step - loss: 0.2185 - accuracy: 0.9173 - val_loss: 0.1830 - val_accuracy: 0.9392
# Epoch 22/100
# 68/68 [==============================] - 3s 48ms/step - loss: 0.2126 - accuracy: 0.9157 - val_loss: 0.1734 - val_accuracy: 0.9406
# Epoch 23/100
# 68/68 [==============================] - 3s 50ms/step - loss: 0.2183 - accuracy: 0.9119 - val_loss: 0.1796 - val_accuracy: 0.9420
# Epoch 24/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.2158 - accuracy: 0.9147 - val_loss: 0.1806 - val_accuracy: 0.9413
# Epoch 25/100
# 68/68 [==============================] - 4s 54ms/step - loss: 0.2069 - accuracy: 0.9195 - val_loss: 0.1630 - val_accuracy: 0.9406
# Epoch 26/100
# 68/68 [==============================] - 3s 49ms/step - loss: 0.2004 - accuracy: 0.9239 - val_loss: 0.1707 - val_accuracy: 0.9434
# Epoch 27/100
# 68/68 [==============================] - 3s 49ms/step - loss: 0.1972 - accuracy: 0.9234 - val_loss: 0.1845 - val_accuracy: 0.9344
# Epoch 28/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.1974 - accuracy: 0.9254 - val_loss: 0.1903 - val_accuracy: 0.9358
# Epoch 29/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.2030 - accuracy: 0.9247 - val_loss: 0.1653 - val_accuracy: 0.9482
# Epoch 30/100
# 68/68 [==============================] - 3s 43ms/step - loss: 0.1896 - accuracy: 0.9301 - val_loss: 0.1620 - val_accuracy: 0.9503
# Epoch 31/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.1864 - accuracy: 0.9263 - val_loss: 0.1749 - val_accuracy: 0.9406
# Epoch 32/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.1889 - accuracy: 0.9235 - val_loss: 0.1724 - val_accuracy: 0.9420
# Epoch 33/100
# 68/68 [==============================] - 3s 45ms/step - loss: 0.1842 - accuracy: 0.9285 - val_loss: 0.1730 - val_accuracy: 0.9399
# Epoch 34/100
# 68/68 [==============================] - 3s 46ms/step - loss: 0.1834 - accuracy: 0.9270 - val_loss: 0.1715 - val_accuracy: 0.9441
# Epoch 35/100
# 68/68 [==============================] - 3s 47ms/step - loss: 0.1882 - accuracy: 0.9318 - val_loss: 0.1724 - val_accuracy: 0.9441

# %%
# load the model

model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.93      0.94       724
#            1       0.94      0.95      0.94       724
#
#     accuracy                           0.94      1448
#    macro avg       0.94      0.94      0.94      1448
# weighted avg       0.94      0.94      0.94      1448

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
mirror_val = get_mirrored_df(val)
mirror_X_val = tf.convert_to_tensor(list(mirror_val["word_tokens"]))

mirror_y_pred = model.predict([mirror_X_val[:, 0], mirror_X_val[:, 1]])
mirror_y_pred = mirror_y_pred > 0.5
val["pred2"] = mirror_y_pred


val.loc[val["pred1"] != val["pred2"]]
# Out:
# Empty DataFrame
# Columns: [word_a, word_b, rhyme, word_tokens, pred1, pred2]
# Index: []

# %%
sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

sample_pred2 = model.predict([sample_tokens2[:, 0], sample_tokens2[:, 1]])
predictions2 = [round(pred[0], 4) for pred in sample_pred2]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print(f"{'Rhyme' if predictions2[i] > 0.5 else 'Non-rhyme'}({predictions2[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Rhyme(0.7488999962806702)
# Rhyme(0.7488999962806702)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Rhyme(0.6347000002861023)
# Rhyme(0.6347000002861023)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Non-rhyme(0.093299999833107)
# Non-rhyme(0.093299999833107)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(0.9995999932289124)
# Rhyme(0.9995999932289124)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(0.9987999796867371)
# Rhyme(0.9987999796867371)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Non-rhyme(0.1657000035047531)
# Non-rhyme(0.1657000035047531)
# ---------------

# %% [markdown]
# ## 2:3 ratio symmetric

# %%
model_name = "rhyme_model_23_ratio_symmetric"

# #Uncomment to train model 
# model = create_symmetric_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='val_loss', patience=5)

# history = model.fit(
#     [X_train_new[:, 0], X_train_new[:, 1]],
#     y_train_new,
#     batch_size=128,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )
# Out:
# Epoch 1/100
# 85/85 [==============================] - 6s 50ms/step - loss: 0.6139 - accuracy: 0.5878 - val_loss: 0.5514 - val_accuracy: 0.5000
# Epoch 2/100
# 85/85 [==============================] - 4s 46ms/step - loss: 0.5283 - accuracy: 0.7901 - val_loss: 0.4992 - val_accuracy: 0.8778
# Epoch 3/100
# 85/85 [==============================] - 4s 47ms/step - loss: 0.4722 - accuracy: 0.8702 - val_loss: 0.4576 - val_accuracy: 0.8999
# Epoch 4/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.4293 - accuracy: 0.8770 - val_loss: 0.4145 - val_accuracy: 0.8999
# Epoch 5/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3881 - accuracy: 0.8843 - val_loss: 0.3364 - val_accuracy: 0.9040
# Epoch 6/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.3570 - accuracy: 0.8911 - val_loss: 0.2844 - val_accuracy: 0.9047
# Epoch 7/100
# 85/85 [==============================] - 4s 45ms/step - loss: 0.3122 - accuracy: 0.8987 - val_loss: 0.2504 - val_accuracy: 0.9116
# Epoch 8/100
# 85/85 [==============================] - 4s 45ms/step - loss: 0.2988 - accuracy: 0.9028 - val_loss: 0.2241 - val_accuracy: 0.9199
# Epoch 9/100
# 85/85 [==============================] - 4s 45ms/step - loss: 0.2885 - accuracy: 0.9095 - val_loss: 0.2356 - val_accuracy: 0.9075
# Epoch 10/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2749 - accuracy: 0.9134 - val_loss: 0.2132 - val_accuracy: 0.9157
# Epoch 11/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2719 - accuracy: 0.9122 - val_loss: 0.2215 - val_accuracy: 0.9171
# Epoch 12/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2603 - accuracy: 0.9179 - val_loss: 0.2047 - val_accuracy: 0.9199
# Epoch 13/100
# 85/85 [==============================] - 4s 46ms/step - loss: 0.2585 - accuracy: 0.9179 - val_loss: 0.1972 - val_accuracy: 0.9233
# Epoch 14/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.2505 - accuracy: 0.9221 - val_loss: 0.1944 - val_accuracy: 0.9233
# Epoch 15/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2472 - accuracy: 0.9248 - val_loss: 0.1874 - val_accuracy: 0.9302
# Epoch 16/100
# 85/85 [==============================] - 4s 46ms/step - loss: 0.2381 - accuracy: 0.9262 - val_loss: 0.1877 - val_accuracy: 0.9330
# Epoch 17/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2345 - accuracy: 0.9272 - val_loss: 0.1982 - val_accuracy: 0.9296
# Epoch 18/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2317 - accuracy: 0.9325 - val_loss: 0.1800 - val_accuracy: 0.9316
# Epoch 19/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2292 - accuracy: 0.9325 - val_loss: 0.1807 - val_accuracy: 0.9337
# Epoch 20/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.2217 - accuracy: 0.9340 - val_loss: 0.1724 - val_accuracy: 0.9434
# Epoch 21/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2249 - accuracy: 0.9328 - val_loss: 0.2128 - val_accuracy: 0.9296
# Epoch 22/100
# 85/85 [==============================] - 4s 46ms/step - loss: 0.2211 - accuracy: 0.9367 - val_loss: 0.1697 - val_accuracy: 0.9448
# Epoch 23/100
# 85/85 [==============================] - 4s 45ms/step - loss: 0.2109 - accuracy: 0.9370 - val_loss: 0.1787 - val_accuracy: 0.9448
# Epoch 24/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.2085 - accuracy: 0.9396 - val_loss: 0.1677 - val_accuracy: 0.9468
# Epoch 25/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1960 - accuracy: 0.9445 - val_loss: 0.1793 - val_accuracy: 0.9454
# Epoch 26/100
# 85/85 [==============================] - 4s 46ms/step - loss: 0.1995 - accuracy: 0.9390 - val_loss: 0.1693 - val_accuracy: 0.9441
# Epoch 27/100
# 85/85 [==============================] - 4s 46ms/step - loss: 0.2088 - accuracy: 0.9387 - val_loss: 0.2220 - val_accuracy: 0.9282
# Epoch 28/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1984 - accuracy: 0.9387 - val_loss: 0.1590 - val_accuracy: 0.9503
# Epoch 29/100
# 85/85 [==============================] - 4s 44ms/step - loss: 0.1932 - accuracy: 0.9400 - val_loss: 0.1619 - val_accuracy: 0.9489
# Epoch 30/100
# 85/85 [==============================] - 4s 46ms/step - loss: 0.1905 - accuracy: 0.9426 - val_loss: 0.1851 - val_accuracy: 0.9468
# Epoch 31/100
# 85/85 [==============================] - 4s 47ms/step - loss: 0.2033 - accuracy: 0.9395 - val_loss: 0.1631 - val_accuracy: 0.9537
# Epoch 32/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1940 - accuracy: 0.9445 - val_loss: 0.1575 - val_accuracy: 0.9503
# Epoch 33/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1818 - accuracy: 0.9457 - val_loss: 0.1617 - val_accuracy: 0.9510
# Epoch 34/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1814 - accuracy: 0.9447 - val_loss: 0.1716 - val_accuracy: 0.9454
# Epoch 35/100
# 85/85 [==============================] - 4s 42ms/step - loss: 0.1825 - accuracy: 0.9445 - val_loss: 0.1753 - val_accuracy: 0.9448
# Epoch 36/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1825 - accuracy: 0.9447 - val_loss: 0.1735 - val_accuracy: 0.9454
# Epoch 37/100
# 85/85 [==============================] - 4s 43ms/step - loss: 0.1819 - accuracy: 0.9453 - val_loss: 0.1775 - val_accuracy: 0.9510

# %%
# load the model
model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.96      0.95       724
#            1       0.96      0.94      0.95       724
#
#     accuracy                           0.95      1448
#    macro avg       0.95      0.95      0.95      1448
# weighted avg       0.95      0.95      0.95      1448

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
mirror_val = get_mirrored_df(val)
mirror_X_val = tf.convert_to_tensor(list(mirror_val["word_tokens"]))

mirror_y_pred = model.predict([mirror_X_val[:, 0], mirror_X_val[:, 1]])
mirror_y_pred = mirror_y_pred > 0.5
val["pred2"] = mirror_y_pred


val.loc[val["pred1"] != val["pred2"]]
# Out:
# Empty DataFrame
# Columns: [word_a, word_b, rhyme, word_tokens, pred1, pred2]
# Index: []

# %%
sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Non-rhyme(0.018200000748038292)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Non-rhyme(0.10849999636411667)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Non-rhyme(0.35670000314712524)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(0.9998000264167786)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(1.0)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Non-rhyme(0.0)
# ---------------

# %% [markdown]
# # Use dense rhyme pair dataset

# %%
rhyme_pairs = pd.read_csv("tsvs/manual_repair_plus_good_buckets_pairs.tsv", sep="\t")
neg_pairs = pd.read_csv("tsvs/negative_pairs.tsv", sep="\t")

pos_pairs = rhyme_pairs.sample(n=len(neg_pairs), random_state=SEED)
pos_pairs = pos_pairs.reset_index(drop=True)
dense_df = pd.concat((pos_pairs, neg_pairs))
dense_df = dense_df.reset_index(drop=True)
dense_df
# Out:
#             word_a          word_b  rhyme
# 0            brand        Kinamann      1
# 1      flammespill            hvil      1
# 2           tømmer  strålestrømmer      1
# 3            grunn        elvebunn      1
# 4            svøpe           støpe      1
# ...            ...             ...    ...
# 44889        frekk          kupler      0
# 44890         ness            snor      0
# 44891         seil          gynget      0
# 44892      LOFOTEN            Røst      0
# 44893          hus          skoger      0
#
# [44894 rows x 3 columns]

# %% [markdown]
# ## Remove the pairs that are in test set

# %%
test = df.loc[X_test_indexes].copy()
test
# Out:
#         word_a  word_b  rhyme  \
# 1789     hugge   vugge      1
# 6140      snar     far      1
# 9312      høre  kvider      0
# 10727  brenner    gang      0
# 13969  hernede    saft      0
# ...        ...     ...    ...
# 5965       sti   verdi      1
# 10776     nåde   grunn      0
# 4184      fans   krans      1
# 12052    sanne     rid      0
# 6398     hørte   rørte      1
#
#                                              word_tokens
# 1789   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6140   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9312   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 10727  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 13969  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                  ...
# 5965   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 10776  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 4184   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 12052  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6398   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [4343 rows x 4 columns]

# %%
test_pairs = set(zip(test.word_a, test.word_b))
dense_pairs = set(zip(dense_df.word_a, dense_df.word_b))
overlapping_pairs = test_pairs.intersection(dense_pairs)
len(overlapping_pairs), len(test_pairs)
# Out:
# (2798, 4343)

# %%
drop_is = [dense_df[(dense_df.word_a == a)&(dense_df.word_b == b)].index.to_list()[0] for a,b in overlapping_pairs]

# %%
dense_df = dense_df.drop(drop_is)

# %% [markdown]
# ## Train etc

# %%
dense_df['word_tokens'] = dense_df.progress_apply(
    lambda row: tokenize_inputs(row['word_a'], row['word_b'], tokenizer), axis=1
)
# Out:
#   0%|          | 0/42096 [00:00<?, ?it/s]

# %%
X_train = tf.convert_to_tensor(list(dense_df["word_tokens"]))
y_train = tf.convert_to_tensor(list(dense_df['rhyme']))

# %%
X_train.shape, y_train.shape
# Out:
# (TensorShape([42096, 2, 64]), TensorShape([42096]))

# %%
model_name = "rhyme_model_40k"

# # Uncomment to train model 

# model = create_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=256,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )

# %%
# load the model
model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97       724
#            1       0.97      0.97      0.97       724
#
#     accuracy                           0.97      1448
#    macro avg       0.97      0.97      0.97      1448
# weighted avg       0.97      0.97      0.97      1448

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
diff = val.loc[val["pred1"] != val["rhyme"]]
print(len(diff))
diff
# Out:
# 43
#             word_a      word_b  rhyme  \
# 6537         havet        gave      1
# 8529          sale        tale      0
# 10339         øyet          er      0
# 6803         ahner       faner      1
# 7996          sang    sildring      0
# 6624            nu        sous      1
# 8397      Evighøye        leie      0
# 1584          tent     procent      1
# 4422         bever        fred      1
# 13613           li        seil      0
# 12179       venner    befester      0
# 6558           det        bade      1
# 10040         blod        gulv      0
# 12892  presteskrud          ei      0
# 10401         Blix     omkring      0
# 1322            ve         tre      1
# 5524          kyst        sist      1
# 13497       kveget      banket      0
# 12189      strikke       ramme      0
# 996      høvelspån        på'n      1
# 4668           går      plogen      1
# 6936        gikten         den      1
# 5545        fugler     skjuler      1
# 11836         jord       klart      0
# 11266      tilende  strålefjed      0
# 2191          vred       lever      1
# 12922          sky          se      0
# 2197          land        veie      1
# 9668          salt        natt      0
# 729            FAR      landet      1
# 9205        mylder      fyller      0
# 12030          tid       fjell      0
# 2302   solskinsdag       minne      1
# 6653            sa          av      1
# 9016            se    minarett      0
# 12714        sverd          se      0
# 4867         fødes       rører      1
# 13659   allegorien         mén      0
# 2138          støt   aftenglød      1
# 6487          bort        vårt      1
# 2308          tent   forbannet      1
# 7818        hender      verden      0
# 6395           mer        fler      1
#
#                                              word_tokens  pred1
# 6537   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 8529   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 10339  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 6803   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 7996   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 6624   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 8397   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 1584   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 4422   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 13613  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 12179  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 6558   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 10040  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 12892  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 10401  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 1322   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 5524   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 13497  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 12189  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 996    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 4668   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 6936   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 5545   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 11836  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 11266  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 2191   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 12922  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 2197   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 9668   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 729    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 9205   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 12030  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 2302   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 6653   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 9016   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 12714  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 4867   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 13659  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 2138   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 6487   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 2308   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 7818   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 6395   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False

# %%
mirror_val = get_mirrored_df(val)
mirror_val
# Out:
#              word_a     word_b  rhyme  \
# 3594          hytte   beskytte      1
# 2736           halm       malm      1
# 14351        ganger      visen      0
# 5492          forbi         li      1
# 9140           borg        ene      0
# ...             ...        ...    ...
# 13766        landet         en      0
# 9926         morgen       hjul      0
# 1196   ferdselsårer      kårer      1
# 6586          finne  noensinne      1
# 13290          frem        røk      0
#
#                                              word_tokens
# 3594   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 2736   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 14351  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 5492   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9140   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                  ...
# 13766  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9926   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 1196   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6586   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [1448 rows x 4 columns]

# %%
mirror_X_val = tf.convert_to_tensor(list(mirror_val["word_tokens"]))

mirror_y_pred = model.predict([mirror_X_val[:, 0], mirror_X_val[:, 1]])
mirror_y_pred = mirror_y_pred > 0.5
print(classification_report(y_val, mirror_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.95      0.96       724
#            1       0.95      0.96      0.96       724
#
#     accuracy                           0.96      1448
#    macro avg       0.96      0.96      0.96      1448
# weighted avg       0.96      0.96      0.96      1448

# %%
val["pred2"] = mirror_y_pred
diff = val.loc[val["pred1"] != val["pred2"]]
print(len(diff))
diff
# Out:
# 34
#               word_a      word_b  rhyme  \
# 8320         kompani        blod      0
# 10339           øyet          er      0
# 6803           ahner       faner      1
# 8397        Evighøye        leie      0
# 1584            tent     procent      1
# 8939          engang          li      0
# 10322          bragt       flukt      0
# 8200             nær         ren      0
# 8357             øye        skje      0
# 2154         stammen        amen      1
# 13094         skader       tiden      0
# 3801           ilder    pupiller      1
# 13015         flamme      dukkes      0
# 5294           klore       foret      1
# 6244             vel        selv      1
# 10243  rullestenslyd          bø      0
# 13150        griller      glider      0
# 11266        tilende  strålefjed      0
# 632              grå         ago      1
# 12922            sky          se      0
# 12400          skikk         ulv      0
# 13542      overskyet         nær      0
# 12030            tid       fjell      0
# 9016              se    minarett      0
# 12593      sceneriet         øde      0
# 11056            men         øye      0
# 6569         skatter      bratte      1
# 8892            satt        lagt      0
# 12813        mildnes        høre      0
# 13659     allegorien         mén      0
# 7657           krans         ånd      0
# 13429           dikt        raft      0
# 10459             én        sved      0
# 10318          kåret        bære      0
#
#                                              word_tokens  pred1  pred2
# 8320   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 10339  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 6803   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 8397   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 1584   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 8939   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 10322  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 8200   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 8357   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 2154   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 13094  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 3801   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 13015  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 5294   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 6244   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 10243  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 13150  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 11266  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 632    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 12922  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 12400  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 13542  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 12030  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 9016   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 12593  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 11056  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 6569   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 8892   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 12813  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 13659  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 7657   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 13429  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 10459  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 10318  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True

# %%
sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

sample_pred2 = model.predict([sample_tokens2[:, 0], sample_tokens2[:, 1]])
predictions2 = [round(pred[0], 4) for pred in sample_pred2]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print(f"{'Rhyme' if predictions2[i] > 0.5 else 'Non-rhyme'}({predictions2[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Rhyme(0.6312999725341797)
# Non-rhyme(0.40459999442100525)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Rhyme(0.8783000111579895)
# Rhyme(0.7177000045776367)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Non-rhyme(0.0)
# Non-rhyme(0.0)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(0.9843000173568726)
# Rhyme(0.9854000210762024)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(0.9803000092506409)
# Rhyme(0.9803000092506409)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Non-rhyme(0.0)
# Non-rhyme(0.0)
# ---------------

# %% [markdown]
# ## Symmetric 40k

# %%
model_name = "rhyme_model_40k_symmetric"

# #Uncomment to train model 
# model = create_symmetric_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=256,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )

# %%
# load the model
model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.97      0.98      0.97       724
#            1       0.98      0.97      0.97       724
#
#     accuracy                           0.97      1448
#    macro avg       0.97      0.97      0.97      1448
# weighted avg       0.97      0.97      0.97      1448

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
diff = val.loc[val["pred1"] != val["rhyme"]]
print(len(diff))
# Out:
# 38

# %%
sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Rhyme(0.9480000138282776)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Non-rhyme(0.2621999979019165)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Non-rhyme(0.11819999665021896)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(1.0)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(1.0)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Non-rhyme(0.0)
# ---------------

# %% [markdown]
# # Use dense and wiktionary dataset

# %%
rhyme_pairs = pd.read_csv("tsvs/merged_buckets_pairs.tsv", sep="\t")
non_rhymes = pd.read_csv("tsvs/wiktionary_negative_rhyme_pairs.tsv", sep="\t")
non_rhymes["rhyme"] = [0]*len(non_rhymes)


pos = rhyme_pairs.sample(n=23000, random_state=SEED)
neg = non_rhymes.sample(n=23000, random_state=SEED)
dw_df = pd.concat([pos, neg])
dw_df = dw_df.reset_index(drop=True)
dw_df
# Out:
#             word_a        word_b  rhyme
# 0             smil      kodisill      1
# 1        hybridbil    renkespill      1
# 2            vigil          till      1
# 3           hittil      racerbil      1
# 4          husvill  ambulansebil      1
# ...            ...           ...    ...
# 45995  prillarhorn      måsefugl      0
# 45996        vigil       sjalusi      0
# 45997         bort      postkort      0
# 45998    munnspill     uplassert      0
# 45999        vrælt       borttil      0
#
# [46000 rows x 3 columns]

# %%
dw_pairs = set(zip(dw_df.word_a, dw_df.word_b))
overlapping_pairs = test_pairs.intersection(dw_pairs)
len(overlapping_pairs), len(test_pairs)
# Out:
# (163, 4343)

# %%
drop_is = [dw_df[(dw_df.word_a == a)&(dw_df.word_b == b)].index.to_list()[0] for a,b in overlapping_pairs]
len(drop_is)
# Out:
# 163

# %%
dw_df = dw_df.drop(drop_is)

# %%
dw_df['word_tokens'] = dw_df.progress_apply(
    lambda row: tokenize_inputs(row['word_a'], row['word_b'], tokenizer), axis=1
)
# Out:
#   0%|          | 0/45837 [00:00<?, ?it/s]

# %%
dw_df
# Out:
#             word_a        word_b  rhyme  \
# 0             smil      kodisill      1
# 1        hybridbil    renkespill      1
# 2            vigil          till      1
# 3           hittil      racerbil      1
# 4          husvill  ambulansebil      1
# ...            ...           ...    ...
# 45995  prillarhorn      måsefugl      0
# 45996        vigil       sjalusi      0
# 45997         bort      postkort      0
# 45998    munnspill     uplassert      0
# 45999        vrælt       borttil      0
#
#                                              word_tokens
# 0      ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 1      ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 2      ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 3      ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 4      ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                  ...
# 45995  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 45996  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 45997  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 45998  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 45999  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [45837 rows x 4 columns]

# %%
# X_train, X_test_dw, y_train, y_test_dw = train_test_split(
#     list(dw_df["word_tokens"]), list(dw_df['rhyme']), stratify=list(dw_df['rhyme']), 
#     test_size=len(y_test), random_state=SEED
#     )

X_train_indexes, X_test_dw_indexes, y_train, y_test_dw = train_test_split(
    list(dw_df.index), list(dw_df['rhyme']), stratify=list(dw_df['rhyme']), 
    test_size=len(y_test), random_state=SEED
    )

X_train = tf.convert_to_tensor(list(dw_df.loc[X_train_indexes]["word_tokens"]))
y_train = tf.convert_to_tensor(y_train)

X_test_dw = tf.convert_to_tensor(list(dw_df.loc[X_test_dw_indexes]["word_tokens"]))
y_test_dw = tf.convert_to_tensor(y_test_dw)

# %%
X_test_dw.shape, y_test_dw.shape
# Out:
# (TensorShape([4343, 2, 64]), TensorShape([4343]))

# %%
X_train.shape, y_train.shape
# Out:
# (TensorShape([41494, 2, 64]), TensorShape([41494]))

# %%
model_name = "rhyme_model_dw_40k"

# # Uncomment to train model 
# model = create_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='val_loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=256,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )

# %%
# load the model
model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87       724
#            1       0.86      0.89      0.88       724
#
#     accuracy                           0.88      1448
#    macro avg       0.88      0.88      0.88      1448
# weighted avg       0.88      0.88      0.88      1448

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
diff = val.loc[val["pred1"] != val["rhyme"]]
print(len(diff))
diff
# Out:
# 180
#             word_a       word_b  rhyme  \
# 6537         havet         gave      1
# 4288   totenslæger        beger      1
# 6898          bred           se      1
# 5490         brann         sand      1
# 10247          rot       berget      0
# ...            ...          ...    ...
# 13283       besvær      slipper      0
# 9777         seder        døden      0
# 6395           mer         fler      1
# 2223           inn  pålandsvind      1
# 13290          røk         frem      0
#
#                                              word_tokens  pred1
# 6537   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 4288   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 6898   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 5490   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 10247  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# ...                                                  ...    ...
# 13283  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 9777   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 6395   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 2223   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
#
# [180 rows x 5 columns]

# %%
mirror_val = get_mirrored_df(val)
mirror_val
# Out:
#              word_a     word_b  rhyme  \
# 3594          hytte   beskytte      1
# 2736           halm       malm      1
# 14351        ganger      visen      0
# 5492          forbi         li      1
# 9140           borg        ene      0
# ...             ...        ...    ...
# 13766        landet         en      0
# 9926         morgen       hjul      0
# 1196   ferdselsårer      kårer      1
# 6586          finne  noensinne      1
# 13290          frem        røk      0
#
#                                              word_tokens
# 3594   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 2736   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 14351  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 5492   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9140   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                  ...
# 13766  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9926   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 1196   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6586   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [1448 rows x 4 columns]

# %%
mirror_X_val = tf.convert_to_tensor(list(mirror_val["word_tokens"]))

mirror_y_pred = model.predict([mirror_X_val[:, 0], mirror_X_val[:, 1]])
mirror_y_pred = mirror_y_pred > 0.5
print(classification_report(y_val, mirror_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.50      0.66       724
#            1       0.66      0.98      0.79       724
#
#     accuracy                           0.74      1448
#    macro avg       0.81      0.74      0.72      1448
# weighted avg       0.81      0.74      0.72      1448

# %%
val["pred2"] = mirror_y_pred
diff = val.loc[val["pred1"] != val["pred2"]]
print(len(diff))
diff
# Out:
# 310
#        word_a     word_b  rhyme  \
# 9140      ene       borg      0
# 8385    krans  bedrifter      0
# 11640  strime       borg      0
# 11356  slippe        død      0
# 10849  gløder   skjelver      0
# ...       ...        ...    ...
# 7444      ned    berører      0
# 13200    hånd      komme      0
# 9642     svak    stenges      0
# 13766      en     landet      0
# 13290     røk       frem      0
#
#                                              word_tokens  pred1  pred2
# 9140   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 8385   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 11640  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 11356  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 10849  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# ...                                                  ...    ...    ...
# 7444   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 13200  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 9642   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 13766  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
#
# [310 rows x 6 columns]

# %%
sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

sample_pred2 = model.predict([sample_tokens2[:, 0], sample_tokens2[:, 1]])
predictions2 = [round(pred[0], 4) for pred in sample_pred2]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print(f"{'Rhyme' if predictions2[i] > 0.5 else 'Non-rhyme'}({predictions2[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Rhyme(0.9837999939918518)
# Rhyme(0.9652000069618225)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Rhyme(0.6118999719619751)
# Rhyme(0.9620000123977661)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Rhyme(0.6176000237464905)
# Non-rhyme(0.0)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(0.9997000098228455)
# Rhyme(0.9997000098228455)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(0.9997000098228455)
# Rhyme(0.9993000030517578)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Rhyme(0.7821999788284302)
# Rhyme(0.9057000279426575)
# ---------------

# %% [markdown]
# ## Symmetric dense and wiktionary dataset

# %%
model_name = "rhyme_model_dw_40k_symmetric"

# # Uncomment to train model 
# model = create_symmetric_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='val_loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=256,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )

# %%
# load the model
# model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.86      0.87       724
#            1       0.86      0.89      0.88       724
#
#     accuracy                           0.88      1448
#    macro avg       0.88      0.88      0.88      1448
# weighted avg       0.88      0.88      0.88      1448

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
val.loc[val["pred1"] != val["rhyme"]]
# Out:
#             word_a       word_b  rhyme  \
# 6537         havet         gave      1
# 10245   brudehuset       gjeste      0
# 4288   totenslæger        beger      1
# 14059         ende           vé      0
# 5490         brann         sand      1
# ...            ...          ...    ...
# 9777         seder        døden      0
# 2223           inn  pålandsvind      1
# 13200         hånd        komme      0
# 13766           en       landet      0
# 13290          røk         frem      0
#
#                                              word_tokens  pred1
# 6537   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 10245  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 4288   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 14059  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 5490   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# ...                                                  ...    ...
# 9777   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 2223   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 13200  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 13766  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
#
# [179 rows x 5 columns]

# %%
sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Rhyme(0.5407999753952026)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Non-rhyme(0.2770000100135803)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Non-rhyme(0.46869999170303345)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(0.9997000098228455)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(0.9987999796867371)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Rhyme(0.995199978351593)
# ---------------

# %% [markdown]
# # Use wiktionary pairs as test

# %%
rhymes = pd.read_csv("tsvs/wiktionary_rhyme_pairs.tsv", sep="\t")
rhymes["rhyme"] = [1]*len(rhymes)
non_rhymes = pd.read_csv("tsvs/wiktionary_negative_rhyme_pairs.tsv", sep="\t")
non_rhymes["rhyme"] = [0]*len(non_rhymes)
len(rhymes), len(non_rhymes)
# Out:
# (80363, 849993)

# %%
pos = rhymes.copy()
neg = non_rhymes.sample(n=len(pos), random_state=SEED)
w_df = pd.concat([pos, neg])
w_df = w_df.reset_index(drop=True)
w_df
# Out:
#              word_a       word_b  rhyme
# 0              amfi       deponi      1
# 1       sofistikert  uartikulert      1
# 2            alkymi      modneri      1
# 3             habil     anglofil      1
# 4         spekulert     motivert      1
# ...             ...          ...    ...
# 160721      avgjort    oljebrønn      0
# 160722        tamil   visittkort      0
# 160723         girt    klartekst      0
# 160724           de  ulykkesfugl      0
# 160725  vagabondasj           ni      0
#
# [160726 rows x 3 columns]

# %%
w_pairs = set(zip(w_df.word_a, w_df.word_b))
overlapping_pairs = test_pairs.intersection(w_pairs)
len(overlapping_pairs), len(test_pairs)
# Out:
# (17, 4343)

# %%
drop_is = [w_df[(w_df.word_a == a) & (w_df.word_b == b)].index.to_list()[0] for a,b in overlapping_pairs]
len(drop_is)
# Out:
# 17

# %%
w_df = w_df.drop(drop_is)

# %%
w_df['word_tokens'] = w_df.progress_apply(
    lambda row: tokenize_inputs(row['word_a'], row['word_b'], tokenizer), axis=1
)
# Out:
#   0%|          | 0/160709 [00:00<?, ?it/s]

# %%
w_df
# Out:
#              word_a       word_b  rhyme  \
# 0              amfi       deponi      1
# 1       sofistikert  uartikulert      1
# 2            alkymi      modneri      1
# 3             habil     anglofil      1
# 4         spekulert     motivert      1
# ...             ...          ...    ...
# 160721      avgjort    oljebrønn      0
# 160722        tamil   visittkort      0
# 160723         girt    klartekst      0
# 160724           de  ulykkesfugl      0
# 160725  vagabondasj           ni      0
#
#                                               word_tokens
# 0       ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 1       ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 2       ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 3       ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 4       ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                   ...
# 160721  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 160722  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 160723  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 160724  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 160725  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [160709 rows x 4 columns]

# %%
X_train = tf.convert_to_tensor(list(w_df["word_tokens"]))
y_train = tf.convert_to_tensor(list(w_df['rhyme']))

# %%
X_train.shape, y_train.shape
# Out:
# (TensorShape([160709, 2, 64]), TensorShape([160709]))

# %%
model_name = "rhyme_model_wiktionary"

# # Uncomment to train model 
# model = create_model()

# model_checkpoint = ModelCheckpoint(f"models/{model_name}.hdf5",monitor="val_loss")
# terminate_on_nan = TerminateOnNaN()
# csv_logger = CSVLogger(f'logs/training_{model_name}.log')
# early_stop = EarlyStopping(monitor='loss', patience=5)

# history = model.fit(
#     [X_train[:, 0], X_train[:, 1]],
#     y_train,
#     batch_size=256,
#     epochs=100,
#     callbacks=[model_checkpoint, terminate_on_nan, csv_logger, early_stop],
#     validation_data=([X_val[:, 0], X_val[:, 1]], y_val)
# )

# %%
# load the model
model = load_model(f"models/{model_name}.hdf5")

y_pred = model.predict([X_val[:, 0], X_val[:, 1]])
y_pred = y_pred > 0.5
print(classification_report(y_val, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.86      0.78       724
#            1       0.83      0.66      0.73       724
#
#     accuracy                           0.76      1448
#    macro avg       0.77      0.76      0.76      1448
# weighted avg       0.77      0.76      0.76      1448

# %%
val = df.loc[X_val_indexes].copy()
val["pred1"] = y_pred
diff = val.loc[val["pred1"] != val["rhyme"]]
print(len(diff))
diff
# Out:
# 346
#             word_a        word_b  rhyme  \
# 3594      beskytte         hytte      1
# 6537         havet          gave      1
# 5456           lav          grav      1
# 351            rar           kar      1
# 4288   totenslæger         beger      1
# ...            ...           ...    ...
# 1070     Oskoreien         vegen      1
# 2223           inn   pålandsvind      1
# 1196         kårer  ferdselsårer      1
# 6586     noensinne         finne      1
# 13290          røk          frem      0
#
#                                              word_tokens  pred1
# 3594   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 6537   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 5456   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 351    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 4288   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# ...                                                  ...    ...
# 1070   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 2223   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 1196   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 6586   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True
#
# [346 rows x 5 columns]

# %%
mirror_val = get_mirrored_df(val)
mirror_val
# Out:
#              word_a     word_b  rhyme  \
# 3594          hytte   beskytte      1
# 2736           halm       malm      1
# 14351        ganger      visen      0
# 5492          forbi         li      1
# 9140           borg        ene      0
# ...             ...        ...    ...
# 13766        landet         en      0
# 9926         morgen       hjul      0
# 1196   ferdselsårer      kårer      1
# 6586          finne  noensinne      1
# 13290          frem        røk      0
#
#                                              word_tokens
# 3594   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 2736   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 14351  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 5492   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9140   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                  ...
# 13766  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 9926   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 1196   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 6586   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [1448 rows x 4 columns]

# %%
mirror_X_val = tf.convert_to_tensor(list(mirror_val["word_tokens"]))

mirror_y_pred = model.predict([mirror_X_val[:, 0], mirror_X_val[:, 1]])
mirror_y_pred = mirror_y_pred > 0.5
print(classification_report(y_val, mirror_y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.72      0.87      0.79       724
#            1       0.84      0.66      0.74       724
#
#     accuracy                           0.76      1448
#    macro avg       0.78      0.76      0.76      1448
# weighted avg       0.78      0.76      0.76      1448

# %%
val["pred2"] = mirror_y_pred
diff = val.loc[val["pred1"] != val["pred2"]]
print(len(diff))
diff
# Out:
# 376
#             word_a    word_b  rhyme  \
# 3594      beskytte     hytte      1
# 11356       slippe       død      0
# 5456           lav      grav      1
# 351            rar       kar      1
# 4288   totenslæger     beger      1
# ...            ...       ...    ...
# 5177          blod  sjelebod      1
# 8367      kanhende    kommer      0
# 6835        troner     æoner      1
# 6586     noensinne     finne      1
# 13290          røk      frem      0
#
#                                              word_tokens  pred1  pred2
# 3594   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 11356  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 5456   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 351    ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 4288   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# ...                                                  ...    ...    ...
# 5177   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 8367   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 6835   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
# 6586   ((tf.Tensor(0.0, shape=(), dtype=float64), tf....  False   True
# 13290  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....   True  False
#
# [376 rows x 6 columns]

# %%
sample_pred = model.predict([sample_tokens[:, 0], sample_tokens[:, 1]])
predictions = [round(pred[0], 4) for pred in sample_pred]

sample_pred2 = model.predict([sample_tokens2[:, 0], sample_tokens2[:, 1]])
predictions2 = [round(pred[0], 4) for pred in sample_pred2]

for i in range(len(samples)):
    print(f"Sentence 1: {samples[i][0]}")
    print(f"Sentence 2: {samples[i][1]}")
    print(f"{'Rhyme' if predictions[i] > 0.5 else 'Non-rhyme'}({predictions[i]})")
    print(f"{'Rhyme' if predictions2[i] > 0.5 else 'Non-rhyme'}({predictions2[i]})")
    print("---------------\n")
# Out:
# Sentence 1: se det
# Sentence 2: frede
# Rhyme(1.0)
# Rhyme(0.982699990272522)
# ---------------
#
# Sentence 1: tid
# Sentence 2: svineri
# Rhyme(0.9998000264167786)
# Non-rhyme(0.05270000174641609)
# ---------------
#
# Sentence 1: sagt
# Sentence 2: sagd
# Rhyme(1.0)
# Non-rhyme(0.0)
# ---------------
#
# Sentence 1: vilje
# Sentence 2: vanilje
# Rhyme(1.0)
# Rhyme(0.9991000294685364)
# ---------------
#
# Sentence 1: vokser
# Sentence 2: bukser
# Rhyme(1.0)
# Rhyme(1.0)
# ---------------
#
# Sentence 1: ha det
# Sentence 2: badet
# Non-rhyme(9.999999747378752e-05)
# Non-rhyme(9.999999747378752e-05)
# ---------------

# %% [markdown]
# # Test set best model
