# %%
from collections import Counter, defaultdict
import itertools
import string
import pickle

import matplotlib.pyplot as plt
import networkx as nx
import nltk
import pandas as pd

# %%
df = pd.read_csv("tsvs/positive_pairs.tsv", sep="\t")
df
# Out:
#              word_a   word_b  rhyme
# 0             stall   skrall      1
# 1              ving     ting      1
# 2             orden   horden      1
# 3             taler   svaler      1
# 4         juleskikk    blikk      1
# ...             ...      ...    ...
# 7233         spratt     datt      1
# 7234          brøde     døde      1
# 7235  gjennomgløder    føder      1
# 7236            løs      røs      1
# 7237       sjenerer  manerer      1
#
# [7238 rows x 3 columns]

# %%
pairs = set(zip(*(df.word_a, df.word_b)))
len(pairs)
# Out:
# 7238

# %%
vocab = set(df.word_a)
vocab.update(set(df.word_b))
len(vocab)
# Out:
# 6290

# %%
s = "\t".join(vocab)
with open("tsvs/annotation_pairs_vocab.tsv", "w+") as f:
    f.write(s)

# %% [markdown]
# ## Get buckets from graph
# ### Connect rhymes via overlapping rhyme pairs
# If A and B rhyme, and B and C rhyme, A and C should also rhyme.
# Go through each rhyme pair and create rhyming buckets.

# %%
# G = nx.Graph()

# edges = pairs.copy()
# vertices = list(vocab)

# G.add_nodes_from(vertices)
# G.add_edges_from(edges)

# nx.write_edgelist(G, "graphs/rhyme_graph.edgelist")
# buckets = list(nx.connected_components(G))

# with open('pickles/rhyme_graph_buckets.pickle','wb') as f:
#     pickle.dump(buckets, f)

G = nx.read_edgelist("graphs/rhyme_graph.edgelist")
with open('pickles/rhyme_graph_buckets.pickle','rb') as f:
    buckets = pickle.load(f)

# %%
len(list(G.edges))
# Out:
# 7238

# %%
len(buckets), len(pairs)
# Out:
# (1259, 7238)

# %% [markdown]
# ## Check buckets

# %%
not_twos = [bucket for bucket in buckets if len(bucket)>2]
twos = [bucket for bucket in buckets if len(bucket)==2]

print(f"""
There are {len(buckets)} connected components in the graph.
Of these, {len(twos)} are simply isolated rhyme pairs,
meaning {len(buckets) - len(twos)} of the components have more than 2 vertices.
The average number of vertices in the >2 components is {sum(len(bucket) for bucket in not_twos)/len(not_twos)}.
""")
# Out:
# There are 1259 connected components in the graph.
# Of these, 727 are simply isolated rhyme pairs,
# meaning 532 of the components have more than 2 vertices.
# The average number of vertices in the >2 components is 9.090225563909774.

# %%
not_twos.sort(key=len, reverse=True)
for i, bucket in enumerate(not_twos):
    print(len(bucket), "\t" , i)
    print(bucket)
# Out:
# 227 	 0
# {'besværet', 'port', 'ror', 'skapermann', 'Eginafjord', 'hedersmann', 'sjungekor', 'forsann', 'legerot', 'Co.', 'duer', 'ødeland', 'nord', 'truer', 'an', 'fremmedland', 'Tor', 'beherskero', 'fot', 'strand', 'svære', 'kan', 'stort', 'to', 'jord', 'tort', 'motor', 'Bentsebro', 'eie', 'akkord', 'fiskermann', 'skor', 'Nord', 'Sand', 'hvordan', 'flor', 'hårdt', 'kuer', 'forlot', 'tann', 'takke', 'skjæret', 'naglebor', 'næret', 'jo', 'bort', 'overbord', 'leie', 'luer', 'åndehære', 'kristenblod', 'bestemor', 'besnære', 'opveie', 'kongestor', 'stjerneland', 'snor', 'Staats-affære', 'skuer', 'forstand', 'mod', 'vårt', 'hjerteluer', 'perlerand', 'beror', 'kort', 'fro', 'go', 'bære', 'spann', 'Cannes', 'munke-tro', 'hedningjord', 'Ho', 'hor', 'Totakvann', 'overflod', 'blod', 'spor', 'bor', 'hvor', 'rognekjæret', 'bebor', 'mot', 'land', 'ord', 'mor', 'Sillejord', 'slavestand', 'mord', 'lære', 'gro', 'fedreland', 'kirkekor', 'redningsmann', 'fjære', 'han', 'Johan', 'gror', 'glo', 'kjære', 'sko', 'grand', 'marøyesand', 'solstrålebrann', 'blomsterflor', 'været', 'ifjor', 'ro', 'brand', 'bot', 'gjerde', 'imot', 'fugleværet', 'norskhetslære', 'lot', 'Ford', 'tempelkor', 'bero', 'frelser-mann', 'bord', 'tyrann', 'tuer', 'bror', 'fjelebod', 'regnbu-bro', 'evighetsro', 'motormann', 'flo', 'ørkenland', 'stod', 'rot', 'birkerot', 'strålebro', 'forstod', 'fiskevann', 'tror', 'sand', 'kor', 'helsebot', 'hære', 'eiermann', 'bro', 'mo', 'adelsblod', 'fortæret', 'lo', 'alterbord', 'god', 'tinderand', 'dro', 'rand', 'ære', 'brann', 'fuglekor', 'vinterland', 'gjære', 'Wergeland', 'for', 'gjerdet', 'kommando-ord', 'druer', 'dernord', 'ombord', 'ere', 'varselsord', 'bølgehære', 'vandringsmann', 'gruer', 'likedan', 'avgrunnsbro', 'dyresteeie', 'veie', 'ferde', 'kildevann', 'bann', 'sfære', 'svor', 'klipperand', 'fort', 'illgjerningsmann', 'tro', 'slo', 'mann', 'Gondvanaland', 'sjelebod', 'sno', 'gjort', 'flod', 'stor', 'buer', 'sort', 'tyribrann', 'no', 'himmelbro', 'stand', 'Helgeland', 'glor', 'för', 'ørkensand', 'arvegods', 'Gondwanaland', 'tæret', 'himmelluer', 'klo', 'perleport', 'sot', 'ildstråleflor', 'gravgårds-tuer', 'være', 'skjære', 'slåpetornstrand', 'iland', 'fjord', 'hernord', 'Kariskjæret', 'bod', 'beskuer', 'stråleflor', 'gudelære', 'sjelerot', 'Kristiansand', 'vann', 'pleie', 'bo', 'Kinamann', 'tidevann'}
# 189 	 1
# {'vinterhi', 'svær', 'kjerr', 'ni', 'løvehale', 'hvit', 'bi', 'her', 'røde', 'grøde', 'morgenrøde', 'flere', 'knusleri', 'stri', 'vane-gjengeri', 'forbi', 'verdi', 'løvsalstrær', 'energi', 'enhver', 'kveder', 'Wergelands-rid', 'tverr', 'sær', 'flid', 'vær', 'si', 'brutale', 'bale', 'hjertenskjær', 'oppstandelsesskjær', 'forbløde', 'svermeri', 'blid', 'vis-à-vis', 'spreder', 'gli', 'dale', 'li', 'hver', 'begjær', 'gi', 'befri', 'glid', 'ospetrær', 'dit', 'raseri', 'aftenskjær', 'hit', 'klær', 'idealet', 'dere', 'helligbrøde', 'bøte', 'vandaler', 'kjempehær', 'fosforskjær', 'marmorhvit', 'imøde', 'nattetid', 'dvale', 'rosenskjær', 'nid', 'besvær', 'strid', 'harmoni', 'husvale', 'aftenrøde', 'himmelsaler', 'solgangsvær', 'forstøte', 'dyreføde', 'taler', 'tyranni', 'fremtidssti', 'opprørsleder', 'de', 'skjær', 'mere', 'der', 'prale', 'bli', 'dødningklær', 'pokaler', 'melodi', 'kogleri', 'bøde', 'gale', 'ti', 'reder', 'hi', 'Madrid', 'nær', 'tale', 'lillaskjær', 'sommersti', 'symfoni', 'hær', 'tid', 'er', 'befaler', 'kjøpmannsferd', 'kirkesti', 'gleder', 'føde', 'gevær', 'trær', 'sale', 'selv-ironi', 'galer', 'Lie', 'morgenskjær', 'især', 'irisskjær', 'bergeli', 'blomstertrær', 'Kariskjær', 'daler', 'bløde', 'tver', 'slit', 'gjøde', 'fril', 'maler', 'lit', 'austenvær', 'bølgeaktig', 'steder', 'fri', 'dåreføde', 'rid', 'betreder', 'sympati', 'tildøde', 'parti', 'fundere', 'tidlig', 'saler', 'fiske-vær', 'treder', 'rær', 'forræder', 'praler', 'eder', 'breder', 'vi', 'øde', 'freder', 'sti', 'leder', 'bær', 'svaler', 'bit', 'kjær', 'lær', 'trønder-heder', 'i', 'deri', 'geni', 'spær', 'jøde', 'forleder', 'sveder', 'nattelosji', 'ski', 'folkeleikskjeder', 'beder', 'portaler', 'streder', 'flammeskjær', 'brøde', 'trylleri', 'arbeidsbi', 'svale', 'møte', 'feriere', 'kvaler', 'gløde', 'fjær', 'døde', 'forhale', 'befale', 'seder', 'id', 'litani', 'kjeder', 'Enhver', 'splid', 'heder'}
# 148 	 2
# {'bestandighet', 'hente', 'galgetre', 'fjed', 'sovekupé', 'strever', 'silhouett', 'arbeidsfred', 'ed', 'broderrett', 'never', 'kafé', 'juletre', 'gret', 'fortred', 'idé', 'ætt', 'husbondsvett', 'skred', 'offersted', 'sne', 'beverte', 'opstandelse', 'profet', 'klokkeslett', 'armé', 'elvebredd', 'sæd', 'barmhjertighet', 'samvittighet', 'virkelighet', 'spredt', 'mett', 'Sovjet', 'bre', 'vet', 'fred', 'trett', 'tett', 'avsted', 'skje', 'tre', 'regimente', 'evighet', 'villighet', 'skjendte', 'svever', 'kledt', 'led', 'med', 'brett', 'gled', 'Nudetre', 've', 'vé', 'strålefjed', 'vever', 'kristenhet', 'snever', 'herned', 'kjever', 'sed', 'Nasaret', 'slett', 'lever', 'salighet', 'brente', 'minarett', 'slet', 'vett', 'kjærlighet', 'moské', 'bever', 'bered', 'nærte', 'varieté', 'lærte', 'smerte', 'vred', 'tretaburett', 'regnebrett', 'let', 'spett', 'sted', 'eierett', 'ubønnhørlighet', 'hemlighet', 'beredt', 'grett', 'bred', 'sverte', 'kre', 'kildested', 'frelsesarmé', 'hever', 'Se', 'hett', 'stred', 'arnested', 'kjerte', 'arbeidsnever', 'fett', 'et', 'hvileplett', 'kafe', 'hvilested', 'sett', 'ved', 'krever', 'bibelsted', 'spente', 'derved', 'ensomhet', 'tente', 'herved', 'bade', 'sved', 'rettferdighet', 'geled', 'smed', 'det', 'rett', 'lett', 'blomsterbed', 'nett', 'vinter-sne', 'plett', 'beskjed', 'bed', 'ned', 'folkevett', 'kjente', 'jente', 'moderhjerte', 'kjed', 'se', 'le', 'sped', 'avste', 'herlighet', 'kne', 'hjerte', 'be', 'vente', 'spe', 'kjærlighed', 'ett', 'vadested'}
# 144 	 3
# {'Nordvest', 'prest', 'stå', 'står', 'vrå', 'klippekrå', 'Å', 'fest', 'dernest', 'går', 'attrå', 'blest', 'yppersteprest', 'tilhest', 'plogen', 'platå', 'hu', 'år', 'strå', 'sår', 'norden', 'vår', 'igår', 'nidingsdåd', 'gjest', 'forsmår', 'rest', 'på', 'rå', 'ihu', 'nordvest', 'formå', 'forslår', 'lyseblå', 'blå', 'forgår', 'korsfest', 'forstår', 'trå', 'plartå', 'bittesmå', 'narrefest', 'flyvebåt', 'bu', 'fedrenehu', 'gru', 'allerbest', 'forgå', 'derpå', 'slå', 'kår', 'ru', 'våt', 'så', 'dåd', 'hunger-grå', 'protest', 'manifest', 'nogen', 'også', 'spår', 'hest', 'mest', 'sjelesår', 'Korsfest', 'forstå', 'Vå', 'lest', 'du', 'flu', 'trengselskår', 'hård', 'foregiår', 'enno', 'forårsfest', 'skogen', 'Når', 'råd', 'pest', 'gule-blå', 'må', 'gråt', 'tå', 'forestår', 'formår', 'blaå', 'sydvest', 'får', 'jorden', 'sommerfest', 'skjå', 'blu', 'sous', 'grå', 'torden', 'nu', 'heltedåd', 'ennu', 'murstensgård', 'best', 'få', 'slavekår', 'ljå', 'gå', 'pinsefest', 'itu', 'istå', 'hår', 'hjertesår', 'bru', 'foreslår', 'nå', 'hyttevrå', 'sanger-vår', 'rår', 'båt', 'hjertekrå', 'tiggerkår', 'bestå', 'skrå', 'ødegård', 'aldersgrå', 'Norden', 'ago', 'å', 'slu', 'Litli-litli-lu', 'banesår', 'gledesfest', 'skår', 'skyteskår', 'mår', 'slår', 'potteskår', 'fjorden', 'muregård', 'antennetråd', 'små', 'låt', 'lå', 'vest', 'når', 'gård', 'mannedåd'}
# 92 	 4
# {'kølleslag', 'landliggedag', 'rinne', 'tinde', 'synderinne', 'venninne', 'Prag', 'sinne', 'sommerdag', 'flag', 'bølgeslag', 'pinne', 'blinde', 'nag', 'tvinne', 'kvak', 'minne', 'fuglen', 'vederlag', 'bedrag', 'hjertelag', 'bak', 'søndenvindsdrag', 'spinne', 'herinne', 'slag', 'idag', 'mak', 'dag', 'måneskinnet', 'hinne', 'vinne', 'minnet', 'blak', 'tak', 'kirketag', 'inne', 'fiskerlag', 'gudinne', 'høysommerdag', 'nederlag', 'evighetsdag', 'vingeslag', 'forsvinne', 'smertesdrag', 'binde', 'behag', 'vrak', 'brak', 'trellebinde', 'velbehag', 'kvinne', 'egen', 'ansiktsdrag', 'oktoberdag', 'trilleslag', 'ingensinne', 'Slinde', 'finne', 'svinne', 'slavinne', 'jag', 'noensinne', 'besinne', 'sag', 'bygdelag', 'strak', 'hyttetak', 'lerkeslag', 'frelsesdag', 'vinde', 'lag', 'solskinns-dag', 'binne', 'svak', 'sak', 'solskinsdag', 'flak', 'bag', 'trællekvinne', 'søndenvinde', 'kranselag', 'brag', 'drag', 'skinnet', 'åndedrag', 'hammerslag', 'derinne', 'herskerinne', 'smak', 'folkeslag', 'tordenslag'}
# 68 	 5
# {'blommer', 'sjel', 'rebell', 'sommer', 'Jesabell', 'fuglefjell', 'julekveld', 'veld', 'hæl', 'forfengelighet', 'Hel', 'østenvindskveld', 'flommer', 'gjeld', 'hotell', 'ikveld', 'skjell', 'hell', 'sæl', 'kjell', 'tommer', 'fjell', 'trommer', 'sprell', 'sommerkveld', 'stråleveld', 'strålevell', 'karusell', 'pastell', 'allikevel', 'vel', 'juvel', 'farvel', 'dommer', 'Fortell', 'toneveld', 'dvel', 'kommer', 'ihjel', 'hvelv', 'saltarell', 'grensefjell', 'bagatell', 'vesteråls-sommer', 'Hell', 'Israel', 'del', 'lell', 'vell', 'hel', 'vinterkveld', 'smell', 'skjel', 'gjel', 'fjeld', 'kveld', 'bakkehell', 'fortell', 'elv', 'perlemorsskjell', 'småmakrell', 'Desemberkveld', 'Teruel', 'kildevell', 'skjelv', 'selv', 'stell', 'trell'}
# 67 	 6
# {'atten', 'edelsten', 'pen', 'venn', 'mellom-menn', 'hen', 'natten', 'anker', 'hverdagsfenomen', 'spenn', 'sken', 'en', 'tiden', 'korstog-ren', 'sen', 'derhen', 'vandringsmenn', 'nypegren', 'gren', 'tanker', 'embedsmenn', 'vanker', 'appetitten', 'Aten', 'gikten', 'banker', 'sten', 'prøvesten', 'villvinsranker', 'ven', 'penn', 'sanker', 'knatten', 'Viken', 'kviden', 'igjen', 'ren', 'ben', 'len', 'striden', 'siden', 'men', 'én', 'uskyldsren', 'sjøgangsben', 'den', 'vår-flom-tiden', 'svenn', 'Fagerlien', 'send', 'hvilegren', 'planker', 'skatten', 'enn', 'ranker', 'suveren', 'rullesten', 'følgesvenn', 'viden', 'lend', 'undertiden', 'mén', 'rennesten', 'hven', 'menn', 'suveréen', 'skranker'}
# 62 	 7
# {'tonehav', 'glad', 'hyrdestav', 'stad', 'la', 'murstensgrav', 'skyttergrav', 'da', 'vidunderbad', 'gjenoppta', 'fra', 'bispestav', 'gav', 'ja', 'Ambarvalia', 'hav', 'kvad', 'lav', 'rav', 'bølgegrav', 'ad', 'dra', 'hurra', 'stav', 'derav', 'Middelhav', 'bra', 'hovedstad', 'ormegrav', 'Voilá', 'av', 'krav', 'kongestav', 'tinderad', 'bedra', 'blad', 'enda', 'sa', 'grav', 'gråstensgrav', 'ifra', 'strålebad', 'bad', 'bokstav', 'a', 'ta', 'nav', 'hva', 'derifra', 'ha', 'høyreblad', 'rad', 'knea', 'Nicaragua', 'massegrav', 'kjemperad', 'støttestav', 'gjerdestav', 'had', 'gla', 'trav', 'Antiokia'}
# 58 	 8
# {'sagt', 'takt', 'skytte', 'akt', 'prakt', 'makt', 'stråtak-hytte', 'beskytte', 'gådemakt', 'skjønnhetsdrakt', 'lytte', 'nordlys-prakt', 'ødelagt', 'knytte', 'guddomsmakt', 'kontrakt', 'svakt', 'trakt', 'stråtakhytte', 'bytte', 'flytte', 'forakt', 'skaper-makt', 'brakt', 'frakt', 'forsagt', 'dødningdrakt', 'overmakt', 'herskermakt', 'marmordrakt', 'nytte', 'avrustningspakt', 'jakt', 'ammevakt', 'bragt', 'radiotrakt', 'lagt', 'hytte', 'englevakt', 'rakt', 'underlagt', 'slakt', 'svanedrakt', 'belagt', 'kongemakt', 'sjakt', 'tryllemakt', 'bakt', 'ringeakt', 'strakt', 'tilbakelagt', 'menneskedrakt', 'vakt', 'prestedrakt', 'drakt', 'krigerbytte', 'forutsagt', 'pakt'}
# 49 	 9
# {'solskinnsvind', 'lind', 'søndenvind', 'grind', 'mandolin', 'marsaftenvind', 'marmortrinn', 'eventyr-sinn', 'nordenvind', 'blind', 'tind', 'min', 'avgrundsskinn', 'kjerringgrin', 'derinn', 'hvin', 'syrin', 'arbeidervin', 'hjernespinn', 'svin', 'sardin', 'inn', 'kanin', 'stinn', 'stjerneskinn', 'ditinn', 'pålandsvind', 'ørnesinn', 'vestenvind', 'sinn', 'kinn', 'violin', 'trinn', 'aftenvind', 'fin', 'vind', 'sin', 'spinn', 'fiolin', 'finn', 'skinn', 'hermelin', 'måneskinn', 'lampeskinn', 'drømmespinn', 'sølvsardin', 'vin', 'lin', 'din'}
# 45 	 10
# {'seierssang', 'sprang', 'alfesang', 'blomstervang', 'jubelklang', 'forårssang', 'klang', 'klokkeklang', 'vang', 'igang', 'bladehang', 'fuglesang', 'lang', 'tang', 'bølgegang', 'betvang', 'kjempe-sang', 'ingengang', 'strengeklang', 'sirenesang', 'hang', 'trang', 'tonetrang', 'avskjedssang', 'Rolland', 'folkerang', 'kjøkkengang', 'gullplateklang', 'rang', 'solnedgang', 'Nang', 'opprørstrang', 'fang', 'jubelsang', 'svang', 'slang', 'vingefang', 'milelang', 'engang', 'tvang', 'stang', 'sang', 'gang', 'merkestang', 'underklang'}
# 45 	 11
# {'sanger-vei', 'alfarveg', 'frydeskrik', 'kontrafei', 'kirke-vei', 'skrek', 'flik', 'kirkeveg', 'næringsvei', 'vek', 'jeg', 'deg', 'nei', 'veg', 'Pompei', 'skrik', 'vuggemei', 'tryllesvik', 'ek', 'svek', 'ei', 'langelek', 'prek', 'rik', 'meg', 'snei', 'vei', 'seg', 'jordbærhei', 'lek', 'kvinneskrik', 'vik', 'slik', 'Nei', 'grei', 'blek', 'fugleskrik', 'korpeskrik', 'lik', 'svik', 'lei', 'snik', 'steg', 'aftenvei', 'hei'}
# 45 	 12
# {'frist', 'alvorsdyst', 'sist', 'Krist', 'trist', 'tilsist', 'tvist', 'lyst', 'hist', 'visst', 'klagerøst', 'kvinnelist', 'pøst', 'Jovisst', 'gnist', 'sosialist', 'røst', 'elskovslist', 'svanebryst', 'høst', 'kyst', 'belyst', 'tilsidst', 'ametyst', 'bryst', 'list', 'moder-bryst', 'harsellist', 'pist', 'forvisst', 'trøst', 'brøst', 'Røst', 'diekryst', 'urtidsdyst', 'kvist', 'brist', 'jettedyst', 'dyst', 'forløst', 'sagakyst', 'bjørkekvist', 'øst', 'tyst', 'kommunist'}
# 39 	 13
# {'Ham', 'stender', 'ham', 'regnvannsrenner', 'ender', 'frender', 'blender', 'lam', 'slam', 'fornam', 'svenner', 'strender', 'sender', 'forbrenner', 'selverkjenner', 'hundeglam', 'stram', 'fram', 'dyreham', 'dram', 'spenner', 'lender', 'hverdagslam', 'hender', 'kam', 'venner', 'kjenner', 'brenner', 'dam', 'bram', 'program', 'skam', 'bekjenner', 'tenner', 'omspenner', 'vender', 'tam', 'menneskehender', 'rovdyrtenner'}
# 38 	 14
# {'lød', 'brød', 'nød', 'lårer', 'dø', 'blomsterskjød', 'brøt', 'himmelbrød', 'glød', 'frø', 'stø', 'mø', 'sjø', 'bø', 'Bø', 'Brød', 'kø', 'skjød', 'dårer', 'ø', 'sårer', 'død', 'kårer', 'årer', 'mjød', 'stød', 'moderskjød', 'rød', 'kjød', 'forbrød', 'bød', 'skjøt', 'ferdselsårer', 'faderskjød', 'tårer', 'bårer', 'bløt', 'gårder'}
# 38 	 15
# {'forlatt', 'skratt', 'natt', 'stat', 'ratt', 'parat', 'fat', 'flat', 'smatt', 'besatt', 'godnatt', 'mat', 'kamerat', 'soldat', 'fatt', 'bratt', 'hatt', 'sommernatt', 'fingerhatt', 'lat', 'vinter-natt', 'glatt', 'tatt', 'matt', 'att', 'kratt', 'prat', 'skatt', 'stillehavspassat', 'dravat', 'blomsterskatt', 'verdensstat', 'satt', 'hat', 'fortidsstat', 'Natt', 'betatt', 'at'}
# 37 	 16
# {'dertil', 'mil', 'il', 'fløytespill', 'offerild', 'strengespill', 'bølgespill', 'ørkenild', 'renkespill', 'sommermild', 'bil', 'pistil', 'klokkespill', 'solgangsild', 'smil', 'fil', 'vill', 'till', 'sild', 'apespill', 'ild', 'flammespill', 'harpespill', 'smertens-tid', 'til', 'april', 'fargespill', 'pil', 'narrespill', 'hvil', 'tvil', 'mild', 'vil', 'arbeidshvil', 'spill', 'morraspill', 'kil'}
# 34 	 17
# {'funn', 'bunn', 'sunn', 'hund', 'pund', 'offerlund', 'tanke-grunn', 'odelsgrunn', 'ørkenbunn', 'solmorgenstund', 'sekund', 'blund', 'elvebunn', 'hun', 'flammemunn', 'fund', 'munn', 'morgenstund', 'barnemunn', 'kun', 'englemunn', 'barne-munn', 'stund', 'grunn', 'rund', 'midnattsstund', 'sund', 'hjertegrunn', 'klippegrunn', 'Staupersund', 'puddelhund', 'blomstergrunn', 'menneskemunn', 'lund'}
# 31 	 18
# {'smått', 'gudeslott', 'drott', 'huldreslått', 'betrådt', 'forstått', 'vått', 'gått', 'brått', 'himmelblått', 'fått', 'mørkekott', 'godt', 'rått', 'grått', 'mørkegrått', 'stått', 'blott', 'yacht', 'spott', 'blått', 'brott', 'kott', 'slott', 'skafott', 'fyrsteslott', 'stjerneblått', 'drømmeslott', 'rikmannslott', 'slått', 'flott'}
# 29 	 19
# {'tsar', 'far', 'snar', 'var', 'flokker', 'klokker', 'bar', 'par', 'kar', 'knar', 'svar', 'rar', 'januar', 'underbar', 'åpenbar', 'tar', 'lokker', 'manovar', 'terneflokker', 'tråkker', 'spar', 'skulderblar', 'fotefar', 'skar', 'har', 'stokker', 'klar', 'glar', 'oksepar'}
# 29 	 20
# {'morgen-gry', 'flammesky', 'solskinnsfly', 'ly', 'stjernegry', 'tordensky', 'våbengny', 'morgen-sky', 'kry', 'by', 'sky', 'gny', 'ny', 'vintersky', 'våpengny', 'vikingery', 'verdensby', 'morgensky', 'spy', 'gry', 'gledesgny', 'fly', 'aveny', 'ry', 'krigerby', 'hedningeby', 'fødeby', 'morgengry', 'bly'}
# 29 	 21
# {'vannet', 'procent', 'strandet', 'landet', 'forbannet', 'annet', 'sandet', 'forbrent', 'sendt', 'spannet', 'blandet', 'FAR', 'tent', 'moment', 'endt', 'kjent', 'ubekjent', 'spent', 'instrument', 'Sorrent', 'betendt', 'endevendt', 'brent', 'prent', 'vendt', 'dødssakrament', 'fryktbespent', 'skrent', 'hendt'}
# 28 	 22
# {'Bugge-Hans', "'s", 'sankthans', 'blomsterkrans', 'herskerkrans', 'bølgedans', 'solskinnsglans', 'farvesans', 'dømmesans', 'Sanktehans', 'fargesans', 'seierskrans', 'måneglans', 'sans', 'krans', 'brudekrans', 'glans', 'santkehans', 'stråleglans', 'stans', 'tornekrans', 'guddomsglans', 'fans', 'hans', 'vanns', 'tindekrans', 'Hans', 'dans'}
# 28 	 23
# {'vunder', 'innunder', 'lykkestunder', 'munne', 'sekunder', 'vunde', 'blunder', 'grunne', 'blunner', 'lunde', 'ingenlunde', 'blomstermunne', 'oppunder', 'hunde', 'sunne', 'kunne', 'runde', 'munner', 'blunde', 'vidunder', 'sunde', 'grunner', 'kunde', 'grunder', 'lunder', 'spunne', 'stunder', 'under'}
# 27 	 24
# {'rider', 'dis', 'kvider', 'juletider', 'paradis', 'omsider', 'pris', 'tider', 'vrider', 'strider', 'forlis', 'vis', 'glider', 'gnis', 'is', 'kassevis', 'svider', 'bris', 'Moskvais', 'furuflis', 'lider', 'gis', 'individer', 'skrider', 'ris', 'sider', 'Paradis'}
# 25 	 25
# {'midt', 'titt', 'tidt', 'stridt', 'mitt', 'kreditt', 'slitt', 'sitt', 'tritt', 'mareritt', 'Moabit', 'vidt', 'såvidt', 'hvitt', 'milevidt', 'profitt', 'granitt', 'fritt', 'ritt', 'blidt', 'lidt', 'litt', 'skritt', 'Krit', 'ditt'}
# 24 	 26
# {'spisesal', 'Kal', 'bacchanal', 'slavemoral', 'opal', 'dal', 'sval', 'portal', 'gal', 'kanal', 'slottsportal', 'pral', 'ritual', 'katedral', 'pastoral', 'skral', 'ideal', 'kval', 'sal', 'Cheval', 'sjal', 'Baal', 'signal', 'smal'}
# 24 	 27
# {'musikk', 'romantikk', 'trikk', 'butikk', 'gøyeblikk', 'avskjedsblikk', 'juleskikk', 'fabrikk', 'klikk', 'drikk', 'blikk', 'hornmusikk', 'nikk', 'forgikk', 'republikk', 'prikk', 'gikk', 'skikk', 'stikk', 'politikk', 'leskedrikk', 'fikk', 'mystikk', 'trafikk'}
# 24 	 28
# {'binder', 'kvinner', 'synderinner', 'hinder', 'slavinner', 'prestinner', 'vinner', 'tinder', 'gudinner', 'danserinner', 'rinner', 'romerinner', 'forsvinner', 'pinner', 'svinner', 'minner', 'finner', 'renner', 'kinner', 'blinder', 'spinner', 'skinner', 'barneminner', 'jettekvinner'}
# 23 	 29
# {'svare', 'sokneskare', 'forklare', 'skare', 'spare', 'venneskare', 'kristenskare', 'krigerskare', 'tiggerskare', 'vare', 'barneskare', 'bevare', 'broderskare', 'klare', 'fanfare', 'bare', 'ivare', 'snare', 'fare', 'kare', 'mare', 'åpenbare', 'smertensmare'}
# 23 	 30
# {'rede', 'hede', 'frede', 'askestedet', 'sprede', 'lede', 'brede', 'berede', 'bede', 'glede', 'betrede', 'trede', 'hernede', 'dernede', 'kjede', 'tilstede', 'Dernede', 'klede', 'broderkjede', 'fremtrede', 'kvede', 'vrede', 'nede'}
# 23 	 31
# {'gategutt', 'klut', 'forskutt', 'slut', 'gutt', 'bølgesprut', 'stut', 'minutt', 'fut', 'sprut', 'brutt', 'lut', 'lutt', 'Knut', 'stutt', 'slutt', 'ut', 'sut', 'sønderskutt', 'krutt', 'skutt', 'tilslutt', 'nut'}
# 23 	 32
# {'blond', 'høvdingånd', 'evighetsbånd', 'fiskerånd', 'prutningsmonn', 'klædebon', 'hosebånd', 'skulderband', 'ledebånd', 'liljebånd', 'Washington', 'helvedånd', 'mon', 'fonn', 'broderhånd', 'helligånd', 'bånd', 'Henderson', 'ordensbånd', 'hand', 'ånd', 'hånd', 'sånn'}
# 22 	 33
# {'omkull', 'fangehull', 'underfull', 'tankefull', 'tryllerull', 'kummerfull', 'smilehull', 'ull', 'rull', 'Bull', 'vemodsfull', 'gull', 'lunefull', 'fortrøstningsfull', 'Hull', 'tull', 'kjempe-kull', 'muld', 'månegull', 'kull', 'hull', 'full'}
# 21 	 34
# {'barneøye', 'nøye', 'øyet', 'himmelhøye', 'møye.', 'pløye', 'fortøye', 'bøyet', 'øye', 'døyet', 'møye', 'døye', 'pløyet', 'drøye', 'Høye', 'høye', 'bøye', 'fornøye', 'Evighøye', 'hundeskinns-trøye', 'fornøyet'}
# 21 	 35
# {'ende', 'avvende', 'kjenne', 'overende', 'vende', 'tilende', 'frende', 'svenne', 'tvende', 'skjende', 'hende', 'sende', 'kanhende', 'fullende', 'henne', 'blende', 'tenne', 'brenne', 'derhenne', 'elende', 'tilkjenne'}
# 21 	 36
# {'legedom', 'stråleflom', 'ensom', 'rundtenom', 'bom', 'fattigdom', 'Rom', 'rom', 'Sunium', 'krum', 'lom', 'tom', 'flom', 'dom', 'kom', 'om', 'helligdom', 'skum', 'from', 'dum', 'som'}
# 21 	 37
# {'begavet', 'have', 'lavet', 'begravet', 'kavet', 'stave', 'avet', 'grave', 'gravet', 'havet', 'slave', 'lave', 'trave', 'verdenshave', 'stavet', 'kave', 'gave', 'kravet', 'mave', 'gudegave', 'brave'}
# 20 	 38
# {'tamme', 'flammen', 'hammen', 'bjørkestammen', 'flamme', 'sammen', 'ramme', 'stammen', 'skammen', 'klamme', 'alterflammen', 'amen', 'adelsstamme', 'stamme', 'lamme', 'Amen', 'skamme', 'gammen', 'samme', 'rammen'}
# 20 	 39
# {'rosenglør', 'kjør', 'direktør', 'tørr', 'Hør', 'glør', 'bør', 'honnør', 'slør', 'humør', 'spør', 'rør', 'sør', 'gjør', 'før', 'klør', 'dør', 'hør', 'tør', 'brudeslør'}
# 19 	 40
# {'tryllebundet', 'forsvunnen', 'spunnet', 'runden', 'stundet', 'runnet', 'funnet', 'svunnet', 'begrunnet', 'bunnen', 'bundet', 'vunnet', 'forsvunnet', 'sjelegrunnen', 'lunden', 'munnen', 'rundet', 'blundet', 'grunnen'}
# 19 	 41
# {'skatte', 'bratte', 'skratte', 'matte', 'barne-latter', 'skatter', 'debatter', 'forlatte', 'datter', 'rabatter', 'latter', 'atter', 'hatter', 'erstatte', 'katter', 'satte', 'fatte', 'fatter', 'forfatter'}
# 19 	 42
# {'fetter', 'gjetter', 'amuletter', 'besetter', 'skvetter', 'fletter', 'spretter', 'stjernenetter', 'sletter', 'setter', 'utsletter', 'jetter', 'metter', 'letter', 'retter', 'fortetter', 'hetter', 'tretter', 'netter'}
# 18 	 43
# {'skall', 'tall', 'skal', 'bjelkehall', 'trall', 'hall', 'kall', 'hal', 'metall', 'tempelhall', 'bergkrystall', 'bølgefall', 'tordenskrall', 'fall', 'krystall', 'stall', 'manne-fall', 'skrall'}
# 18 	 44
# {'brant', 'sant', 'pant', 'gigant', 'grant', 'vant', 'bandt', 'diamant', 'forsvant', 'iblant', 'svant', 'rant', 'hjerter', 'fant', 'tant', 'iblandt', 'kant', 'spant'}
# 18 	 45
# {'dolk', 'scene', 'tjene', 'rense', 'svolk', 'formene', 'mene', 'alene', 'rene', 'ense', 'folk', 'tolk', 'forene', 'Ene', 'ene', 'bolk', 'smalgangsfolk', 'stene'}
# 18 	 46
# {'skille', 'silde', 'kilde', 'bilde', 'lille', 'ille', 'spille', 'forsilde', 'bildet', 'trille', 'bryllupsgilde', 'snille', 'milde', 'grille', 'formilde', 'ville', 'stille', 'vilde'}
# 17 	 47
# {'leire', 'ter', 'officer', 'protester', 'ner', 'trer', 'fler', 'kvarter', 'beleire', 'ler', 'ser', 'skjer', 'mer', 'sner', 'seire', 'ber', 'karakter'}
# 17 	 48
# {'em', 'Jerusalem', 'strålebrem', 'gjem', 'ungdoms-hjem', 'hvem', 'brem', 'fem', 'hvilehjem', 'likefrem', 'frem', 'lem', 'hjem', 'rem', 'menneskehjem', 'klem', 'dem'}
# 17 	 49
# {'seierslønn', 'brønn', 'smertensstønn', 'smerte-stønn', 'lønn', 'historiedønn', 'grønn', 'skjønn', 'smertestønn', 'sønn', 'bønn', 'drønn', 'Ølversønn', 'søstersønn', 'tjønn', 'stønn', 'Menneskesønn'}
# 17 	 50
# {'rammer', 'strammer', 'drammer', 'furustammer', 'prammer', 'lammer', 'fosforkammer', 'dammer', 'hammer', 'stammer', 'kammer', 'flammer', 'skrammer', 'bølgekammer', 'seildugshammer', 'jammer', 'brammer'}
# 16 	 51
# {'påskemorgenrøden', 'evighetsrøden', 'grøden', 'nøden', 'døden', 'forøden', 'morgenrøden', 'brøden', 'seiersgløden', 'hungersnøden', 'aftenrøden', 'fornøden', 'gløden', 'morgen-røden', 'føden', 'solmorgenrøden'}
# 16 	 52
# {'ørnebrus', 'dukkehus', 'hus', 'lus', 'brus', 'vingesus', 'elvesus', 'krus', 'rus', 'forrådshus', 'tankesus', 'grus', 'sus', 'bølgebrus', 'mus', 'drømmehus'}
# 16 	 53
# {'fordrevet', 'bevet', 'skrevet', 'strevet', 'gjennombevet', 'henrevet', 'sønderrevet', 'blevet', 'revet', 'drevet', 'vevet', 'levet', 'svevet', 'krevet', 'kingelvevet', 'hevet'}
# 16 	 54
# {'mager', 'dager', 'tager', 'behager', 'kulelager', 'fager', 'klager', 'nager', 'drager', 'bedrager', 'oldingplager', 'plager', 'jager', 'rager', 'forjager', 'avskjedsklager'}
# 15 	 55
# {'omringer', 'bringer', 'svinger', 'stinger', 'verdensbetvinger', 'klinger', 'englevinger', 'betvinger', 'tvinger', 'vinger', 'lansesvinger', 'finger', 'springer', 'ringer', 'gjennomstinger'}
# 15 	 56
# {'stopp', 'hopp', 'dvergfurutopp', 'askeladd-tropp', 'edderkopp', 'topp', 'kopp', 'granetopp', 'bjørketopp', 'furutopp', 'kropp', 'knopp', 'mastetopp', 'opp', 'stropp'}
# 15 	 57
# {'Hardanger', 'folke-sanger', 'fanger', 'stanger', 'anger', 'sanger', 'falanger', 'pranger', 'uhellsvanger', 'slanger', 'bueganger', 'vanger', 'tanger', 'ganger', 'søyleganger'}
# 15 	 58
# {'pakkbodliv', 'viv', 'stiv', 'Bliv', 'siv', 'kiv', 'kunster', 'lokomotiv', 'dunster', 'driv', 'kniv', 'tidsfordriv', 'liv', 'bliv', 'fuglekiv'}
# 15 	 59
# {'vorden', 'skåren', 'hjorden', 'orden', 'morgen', 'uorden', 'Borgen', 'båren', 'gudeborgen', 'våren', 'sorgen', 'horden', 'utkåren', 'søndagsmorgen', 'gården'}
# 15 	 60
# {'brud', 'ud', 'gud', 'hud', 'englebud', 'Gud', 'kongeskrud', 'skrud', 'narreskrud', 'nådebud', 'seiersbud', 'bud', 'embedsskrud', 'presteskrud', 'likferdsskrud'}
# 15 	 61
# {'æressol', 'bol', 'Kongestol', 'sol', 'pol', 'stol', 'symbol', 'metropol', 'Hol', 'kaprifol', 'frivol', 'sagastol', 'purpurkjol', 'kongestol', 'herskerstol'}
# 14 	 62
# {'fryse', 'trykke', 'stykke', 'alders-smykke', 'seiers-smykke', 'tykke', 'gyse', 'Niirenbergerstykke', 'lykke', 'perle-smykke', 'lyse', 'smykke', 'henrykke', 'kyse'}
# 14 	 63
# {'dvele', 'knele', 'hæler', 'mæle', 'bestjele', 'besjele', 'stjele', 'hedningesjele', 'dele', 'deler', 'fjæle', 'sjele', 'melet', 'hele'}
# 14 	 64
# {'tillike', 'slike', 'fliker', 'vike', 'fremstige', 'riket', 'pike', 'vike.', 'kongerike', 'himmelriker', 'svike', 'minnerike', 'rike', 'like'}
# 14 	 65
# {'nemme', 'temme', 'hjemme', 'stemme', 'gjemme', 'fornemme', 'glemme', 'gremme', 'guddomsstemme', 'klemme', 'tordenstemme', 'demme', 'fremme', 'skremme'}
# 14 	 66
# {'føre', 'helstøvle-føre', 'høre', 'tape', 'berøre', 'skape', 'kjøre', 'øret', 'snøre', 'øre', 'røre', 'gjøre', 'døre', 'sløret'}
# 14 	 67
# {'nage', 'plage', 'sage', 'mage', 'hage', 'lage', 'forårsdage', 'syrerslaget', 'behage', 'dage', 'jage', 'drage', 'klage', 'bedrage'}
# 14 	 68
# {'gremmer', 'glemmer', 'beskjemmer', 'klemmer', 'skremmer', 'remmer', 'menneskestemmer', 'lemmer', 'stemmer', 'fremmer', 'gjemmer', 'fornemmer', 'demmer', 'hemmer'}
# 14 	 69
# {'elde', 'felle', 'velde', 'fortelle', 'fjelle', 'trelle', 'bjelle', 'tjelde', 'skjønnhets-velde', 'enevelde', 'melde', 'gjelde', 'jettevelde', 'nelde'}
# 14 	 70
# {'flyr', 'skyr', 'fyr', 'myr', 'betyr', 'eventyr', 'knyr', 'kyr', 'bestyr', 'gryr', 'menneskedyr', 'utferdseventyr', 'dyr', 'offerdyr'}
# 13 	 71
# {'pass', 'blomsterflass', 'palass', 'plass', 'Mads', 'glass', 'kvass', 'parnass', 'vindusglass', 'gass', 'taremadrass', 'gudspalass', 'morass'}
# 13 	 72
# {'oppstanden', 'ødelanden', 'hinannen', 'hannen', 'brannen', 'sanden', 'selvannen', 'randen', 'stranden', 'himmelranden', 'mannen', 'pannen', 'annen'}
# 13 	 73
# {'klinge', 'gjennomstinge', 'bringe', 'opsvinge', 'tvinge', 'vinge', 'jettebringe', 'betvinge', 'springe', 'oppsvinge', 'ringe', 'svinge', 'tinge'}
# 13 	 74
# {'hører', 'ødes', 'rører', 'berører', 'snører', 'dører', 'kulører', 'ører', 'dødes', 'fødes', 'fører', 'gjødes', 'slører'}
# 13 	 75
# {'snarer', 'kristenskarer', 'drikkevarer', 'svarer', 'skarer', 'forsvarer', 'sparer', 'farer', 'bevarer', 'åpenbarer', 'erfarer', 'folkeskarer', 'fanfarer'}
# 13 	 76
# {'kviste', 'miste', 'friste', 'siste', 'visste', 'liste', 'triste', 'riste', 'dødningkiste', 'Kviste', 'niste', 'kiste', 'briste'}
# 13 	 77
# {'kart', 'svart', 'bart', 'snart', 'besvart', 'art', 'rart', 'standart', 'bevart', 'fart', 'klart', 'åpenbart', 'hardt'}
# 13 	 78
# {'våg', 'slog', 'jog', 'skrog', 'dog', 'og', 'plog', 'skog', 'Danebrog', 'tog', 'sprog', 'dommersprog', 'drog'}
# 13 	 79
# {'ingenting', 'ring', 'sving', 'palmesving', 'klippering', 'ving', 'omkring', 'kring', 'spring', 'Ting', 'måkeving', 'engleving', 'ting'}
# 13 	 80
# {'stande', 'vanne', 'barnesanne', 'panne', 'blande', 'branne', 'sanne', 'forbanne', 'barne-sanne', 'sande', 'vande', 'strande', 'lande'}
# 13 	 81
# {'kampestein', 'grein', 'smergelslipestein', 'egn', 'fødeegn', 'tilregn', 'pileregn', 'regn', 'bein', 'klippeegn', 'rein', 'tegn', 'hegn'}
# 13 	 82
# {'overvelder', 'feller', 'heller', 'forteller', 'gjelder', 'ektefeller', 'bryllupsfeller', 'farveller', 'hjeller', 'bjeller', 'teller', 'treller', 'kvelder'}
# 12 	 83
# {'forstøtt', 'født', 'dødt', 'nøtt', 'hestekjøtt', 'søtt', 'rødt', 'blødt', 'bløtt', 'støtt', 'møtt', 'ødt'}
# 12 	 84
# {'dagen', 'skarlagen', 'klagen', 'betagen', 'Redselsslagen', 'plagen', 'slagen', 'pinsedagen', 'kragen', 'dragen', 'hagen', 'Storedragen'}
# 12 	 85
# {'talt', 'valgt', 'gjaldt', 'Vestersalt', 'overalt', 'gestalt', 'salt', 'smalt', 'kaldt', 'kalt', 'alt', 'falt'}
# 12 	 86
# {'merk', 'skaperverk', 'frelserverk', 'verk', 'kvinne-verk', 'befrierverk', 'plankeverk', 'sterk', 'redningsverk', 'renholdsverk', 'berserk', 'riddingsverk'}
# 12 	 87
# {'fantasier', 'stier', 'parodier', 'draperier', 'vier', 'ironier', 'befrier', 'melodier', 'lier', 'garantier', 'tier', 'bier'}
# 11 	 88
# {'drøy', 'høy', 'øy', 'fløy', 'regnbueøy', 'tøy', 'ridetøy', 'Gaukværøy', 'ridetøy-', 'møy', 'støy'}
# 11 	 89
# {'soldater', 'pater', 'gater', 'prater', 'kamerater', 'forlater', 'flater', 'plater', 'marmorflater', 'hater', 'attentater'}
# 11 	 90
# {'skride', 'tilside', 'side', 'lide', 'tide', 'pyramide', 'efemeride', 'stride', 'kvide', 'vide', 'blide'}
# 11 	 91
# {'jekt', 'vekt', 'centnervekt', 'dekt', 'varetekt', 'slaveslekt', 'trelleslekt', 'projekt', 'frekt', 'sommerblekt', 'slekt'}
# 11 	 92
# {'strålekast', 'øyekast', 'fast', 'brast', 'kast', 'skjendtselslast', 'hast', 'krasst', 'mast', 'kvast', 'rast'}
# 11 	 93
# {'spredte', 'tilrette', 'slette', 'gjette', 'tvette', 'sette', 'trette', 'dette', 'rette', 'hette', 'lette'}
# 11 	 94
# {'henger', 'strenger', 'flenger', 'trenger', 'enger', 'sprenger', 'gatedrenger', 'penger', 'stenger', 'slenger', 'lenger'}
# 11 	 95
# {'legioner', 'anemoner', 'toner', 'kongetroner', 'granittregioner', 'forsoner', 'kroner', 'æoner', 'fortoner', 'troner', 'millioner'}
# 11 	 96
# {'forlener', 'fortjener', 'stener', 'ener', 'mener', 'blomstergrener', 'grener', 'hyener', 'forener', 'tjener', 'sener'}
# 11 	 97
# {'gjemt', 'bestemt', 'beklemt', 'glemt', 'stemt', 'slemt', 'forglemt', 'klemt', 'skjemt', 'forstemt', 'klokkeklemt'}
# 11 	 98
# {'gatesprekk', 'dekk', 'flekk', 'sprekk', 'skrekk', 'eventyrhekk', 'vekk', 'trekk', 'frekk', 'strekk', 'sekk'}
# 10 	 99
# {'gledesstrøm', 'blåtøyssøm', 'øm', 'drøm', 'framtidsdrøm', 'tonestrøm', 'strøm', 'søm', 'nordlys-strøm', 'svøm'}
# 10 	 100
# {'fold', 'vold', 'hedenold', 'gold', 'koll', 'protokoll', 'avindsskjold', 'kold', 'skjold', 'kobberskjold'}
# 10 	 101
# {'true', 'kue', 'bue', 'grue', 'stue', 'due', 'skue', 'kampestenstue', 'tue', 'lue'}
# 10 	 102
# {'fange', 'bange', 'slange', 'mange', 'stange', 'gange', 'trange', 'søylegange', 'lange', 'sange'}
# 10 	 103
# {'gjerne', 'stjerne', 'hjerne', 'kaserne', 'tærne', 'fjerne', 'verne', 'kjerne', 'trærne', 'fødsels-stjerne'}
# 10 	 104
# {'morderstål', 'skål', 'skrål', 'tål', 'mål', 'gledesbål', 'nål', 'bål', 'stål', 'dvergemål'}
# 10 	 105
# {'danser', 'skanser', 'stanser', 'kranser', 'panser', 'sanser', 'stimulanser', 'dissonanser', 'lanser', 'bekranser'}
# 10 	 106
# {'miner', 'triner', 'ruiner', 'rabbiner', 'hviner', 'piner', 'latiner', 'disipliner', 'terminer', 'maskiner'}
# 10 	 107
# {'etsteds', 'ness', 'press', 'tess', 'tilkness', 'gress', 'kness', 'kongress', 'gjess', 'dress'}
# 10 	 108
# {'dregg', 'skjegg', 'bjelkevegg', 'måkeegg', 'egg', 'klippevegg', 'vegg', 'legg', 'hegg', 'klegg'}
# 10 	 109
# {'kaserner', 'kverner', 'lanterner', 'verner', 'stjerner', 'kjerner', 'fjerner', 'tærner', 'strandblomststjerner', 'hjerner'}
# 10 	 110
# {'bordet', 'orde', 'roret', 'ordet', 'frokostbordet', 'spore', 'gjorde', 'store', 'snore', 'evighetsordet'}
# 10 	 111
# {'luren', 'guttenaturen', 'turen', 'sturen', 'klippemuren', 'figuren', 'naturen', 'muren', 'kuren', 'uren'}
# 10 	 112
# {'pisk', 'fisk', 'sirkuspisk', 'harnisk', 'bisk', 'disk', 'grisk', 'frisk', 'brisk', 'hvisk'}
# 10 	 113
# {'taget', 'laget', 'jaget', 'bedaget', 'forjaget', 'plaget', 'daget', 'slaget', 'bedraget', 'ridderslaget'}
# 10 	 114
# {'seier', 'heier', 'Dreier', 'feier', 'veier', 'bølgeleier', 'neier', 'eier', 'kongeveier', 'meier'}
# 10 	 115
# {'smukt', 'fukt', 'tukt', 'brukt', 'lukt', 'frukt', 'produkt', 'slukt', 'flukt', 'bukt'}
# 10 	 116
# {'fester', 'korsfester', 'befester', 'gjester', 'prester', 'Mester', 'mester', 'rester', 'forpester', 'kjøkemester'}
# 10 	 117
# {'gnaver', 'staver', 'architraver', 'haver', 'skaver', 'graver', 'raver', 'bokstaver', 'gaver', 'slaver'}
# 10 	 118
# {'sol-stråle-foss', 'koloss', 'kloss', 'oss', 'tiltross', 'tross', 'foss', 'stenkoloss', 'slåss', 'loss'}
# 10 	 119
# {'bilder', 'stiller', 'triller', 'kilder', 'griller', 'filler', 'skiller', 'sviller', 'hilder', 'spiller'}
# 10 	 120
# {'skåret', 'låret', 'dåret', 'håret', 'utkåret', 'såret', 'året', 'hundreåret', 'kåret', 'båret'}
# 10 	 121
# {'kultur', 'natur', 'tur', 'ur', 'gallions-figur', 'mur', 'snur', 'skur', 'bur', 'lur'}
# 9 	 122
# {'hevne', 'kirkestevne', 'stevne', 'revne', 'levne', 'nevne', 'frihets-stevne', 'evne', 'jevne'}
# 9 	 123
# {'tilbake', 'lake', 'stake', 'svake', 'hake', 'smake', 'rake', 'lysestake', 'vrake'}
# 9 	 124
# {'dekker', 'klipperekker', 'strekker', 'rekker', 'sekker', 'trekker', 'forskrekker', 'snekker', 'brekker'}
# 9 	 125
# {'ahner', 'baner', 'vaner', 'faner', 'planer', 'aner', 'graner', 'partisaner', 'maner'}
# 9 	 126
# {'saft', 'lavt', 'skaft', 'bileskaft', 'underkraft', 'draft', 'kraft', 'haft', 'raft'}
# 9 	 127
# {'larm', 'karm', 'arm', 'gatelarm', 'alarm', 'folkelarm', 'harm', 'varm', 'barm'}
# 9 	 128
# {'favn', 'kjærlighets-favn', 'gavn', 'savn', 'ravn', 'havn', 'navn', 'kongenavn', 'stavn'}
# 8 	 129
# {'lyne', 'Januarsynet', 'solnedgangsbrynet', 'hav-brynet', 'trynet', 'himmel-brynet', 'synet', 'brynet'}
# 8 	 130
# {'bedøvet', 'øvet', 'bedrøvet', 'røvet', 'sløvet', 'løvet', 'prøvet', 'støvet'}
# 8 	 131
# {'storbyvrimlen', 'sjelevrimlen', 'folkevrimlen', 'vrimlen', 'kremmervrimlen', 'himlen', 'menneskevrimlen', 'menneskestimlen'}
# 8 	 132
# {'indre', 'lindrer', 'lindre', 'tindre', 'tindrer', 'forhindre', 'mindre', 'hindre'}
# 8 	 133
# {'skyller', 'tryller', 'fyller', 'gyller', 'mylder', 'forgyller', 'hyller', 'bylder'}
# 8 	 134
# {'flokk', 'nok', 'gudeflokk', 'klippeblokk', 'dvergeflokk', 'fiende-flokk', 'fnokk', 'lokk'}
# 8 	 135
# {'gåde', 'tråde', 'sådde', 'råde', 'måde', 'nåde', 'Nåde', 'våde'}
# 8 	 136
# {'bygge', 'skygge', 'betrygge', 'hygge', 'himmelbrygge', 'trygge', 'brygge', 'rygge'}
# 8 	 137
# {'jeger', 'teger', 'neger', 'tryllebeger', 'beger', 'kveger', 'totenslæger', 'askebeger'}
# 8 	 138
# {'klingen', 'Storebingen', 'vingen', 'bringen', 'tingen', 'ringen', 'ingen', 'øyelågsvingen'}
# 8 	 139
# {'lønner', 'forskjønner', 'rønner', 'bønner', 'drønner', 'sønner', 'stønner', 'tønner'}
# 8 	 140
# {'Thule', 'klippehule', 'hule', 'bule', 'fugle', 'skjule', 'gule', 'ugle'}
# 8 	 141
# {'piker', 'beriker', 'drømmeriker', 'sviker', 'skriker', 'riker', 'diker', 'viker'}
# 8 	 142
# {'prenter', 'skrenter', 'kontinenter', 'henter', 'renter', 'jenter', 'venter', 'instrumenter'}
# 8 	 143
# {'ærer', 'bærer', 'tærer', 'skjærer', 'lærer', 'begjærer', 'sfærer', 'fjærer'}
# 8 	 144
# {'ovenover', 'over', 'utover', 'sover', 'lover', 'vover', 'hestehover', 'derover'}
# 8 	 145
# {'ikke', 'slikke', 'prikke', 'kvikke', 'strikke', 'drikke', 'blikke', 'skikke'}
# 8 	 146
# {'avgrunnsbruset', 'huse', 'gruset', 'kruset', 'bruse', 'suse', 'knuse', 'huset'}
# 8 	 147
# {'herd', 'ferd', 'menskeverd', 'oldinge-verd', 'sverd', 'romerferd', 'verd', 'menneskeferd'}
# 7 	 148
# {'rullestenslyd', 'lyd', 'pryd', 'jubellyd', 'fryd', 'spyd', 'syd'}
# 7 	 149
# {'kallet', 'alle', 'skalle', 'kalle', 'falle', 'hodeskalle', 'fossefallet'}
# 7 	 150
# {'delt', 'elt', 'Belt', 'helt', 'meldt', 'felt', 'telt'}
# 7 	 151
# {'lukter', 'bukter', 'fukter', 'frukter', 'produkter', 'tukter', 'slukter'}
# 7 	 152
# {'driver', 'iver', 'river', 'skiver', 'forbliver', 'perspektiver', 'motiver'}
# 7 	 153
# {'aften-hvile', 'pile', 'mile', 'smile', 'ile', 'hvile', 'tvile'}
# 7 	 154
# {'parykker', 'trykker', 'istykker', 'stykker', 'krykker', 'nykker', 'småstadsnykker'}
# 7 	 155
# {'tyre', 'fyre', 'ferjemannshyre', 'Dyre', 'styre', 'myre', 'berguhyre'}
# 7 	 156
# {'neste', 'heste', 'hester', 'feste', 'beste', 'gjeste', 'fleste'}
# 7 	 157
# {'tunger', 'runger', 'ravneunger', 'hunger', 'lunger', 'fugle-unger', 'unger'}
# 7 	 158
# {'begynt', 'mynt', 'forkynt', 'tynt', 'skillemynt', 'pynt', 'Gynt'}
# 7 	 159
# {'stenges', 'slenges', 'sprenges', 'flenges', 'henges', 'vrenges', 'lenges'}
# 7 	 160
# {'Harmen', 'varmen', 'våpenlarmen', 'barmen', 'larmen', 'armen', 'varmen-'}
# 7 	 161
# {'trakter', 'makter', 'forakter', 'fakter', 'sjakter', 'jakter', 'betrakter'}
# 7 	 162
# {'senker', 'renker', 'tenker', 'lenker', 'skjenker', 'plankebenker', 'krenker'}
# 7 	 163
# {'utrolig', 'fortrolig', 'urolig', 'kongebolig', 'rolig', 'bolig', 'trolig'}
# 7 	 164
# {'preget', 'Beveget', 'meget', 'kveget', 'eget', 'leget', 'beveget'}
# 7 	 165
# {'tomme', 'fromme', 'komme', 'flomme', 'domme', 'tromme', 'omme'}
# 7 	 166
# {'tømte', 'strømte', 'berømte', 'fordømte', 'rømte', 'dømte', 'drømte'}
# 7 	 167
# {'13', 'skvetten', 'ætten', 'pletten', 'Hermonjetten', 'sletten', 'søvnig-gretten'}
# 7 	 168
# {'rømme', 'ømme', 'kongedømme', 'drømme', 'strømme', 'dømme', 'tømme'}
# 7 	 169
# {'trenge', 'lærepenge', 'lenge', 'strenge', 'fortrenge', 'sprenge', 'forvrenge'}
# 7 	 170
# {'ansvarsflate', 'gate', 'klassehatet', 'late', 'prate', 'flate', 'sekretariatet'}
# 7 	 171
# {'herberge', 'besverge', 'berget', 'berge', 'Perge', 'verge', 'bjerge'}
# 7 	 172
# {'yder', 'lyder', 'fryder', 'syder', 'byder', 'dyder', 'fortryder'}
# 7 	 173
# {'savner', 'favner', 'gavner', 'ravner', 'havner', 'navner', 'avner'}
# 7 	 174
# {'iler', 'hviler', 'tilsmiler', 'piler', 'tviler', 'biler', 'smiler'}
# 7 	 175
# {'forynger', 'slynger', 'blomsterklynger', 'tynger', 'gynger', 'synger', 'klynger'}
# 7 	 176
# {'banke', 'redningsplanke', 'turneringsskranke', 'ranke', 'tanke', 'blanke', 'vanke'}
# 7 	 177
# {'distrikt', 'plikt', 'rikt', 'kvikt', 'slikt', 'sikt', 'dikt'}
# 7 	 178
# {'kirkedalen', 'halen', 'salen', 'pralen', 'dalen', 'dvalen', 'lundesalen'}
# 7 	 179
# {'krystaller', 'raller', 'faller', 'kongehaller', 'haller', 'vasaller', 'kaller'}
# 7 	 180
# {'spøk', 'røk', 'strøk', 'gjøk', 'forsøk', 'føk', 'besøk'}
# 7 	 181
# {'smul', 'jul', 'hul', 'hjul', 'skjul', 'ul', 'fugl'}
# 6 	 182
# {'dreng', 'streng', 'elveseng', 'heng', 'eng', 'sammenheng'}
# 6 	 183
# {'faret', 'sparet', 'svaret', 'åpenbaret', 'besvaret', 'forklaret'}
# 6 	 184
# {'kongetrone', 'tone', 'forsone', 'trone', 'krone', 'sone'}
# 6 	 185
# {'nordvesten', 'resten', 'vesten', 'nesten', 'arresten', 'hesten'}
# 6 	 186
# {'folkehellet', 'fjellet', 'tonevellet', 'hellet', 'bakkehellet', 'fossevellet'}
# 6 	 187
# {'forhærden', 'verden', 'ferden', 'pilgrimsferden', 'dødningferden', 'forherden'}
# 6 	 188
# {'gjekket', 'paddekvekket', 'knekket', 'dekket', 'stekket', 'forskrekket'}
# 6 	 189
# {'strekke', 'sprekke', 'dekke', 'tonerekke', 'vekke', 'frekke'}
# 6 	 190
# {'gynge', 'synge', 'klynge', 'tynge', 'dynge', 'kjempeslynge'}
# 6 	 191
# {'knuser', 'bruser', 'buser', 'sluser', 'huser', 'suser'}
# 6 	 192
# {'speiler', 'peiler', 'steiler', 'negler', 'seiler', 'snegler'}
# 6 	 193
# {'bedrift', 'lueskrift', 'drift', 'skift', 'skrift', 'gift'}
# 6 	 194
# {'fullt', 'mammonkult', 'hullt', 'Storekult', 'alvorsfullt', 'pult'}
# 6 	 195
# {'verre', 'færre', 'herre', 'Vårherre', 'dessverre', 'innesperre'}
# 6 	 196
# {'svimmel', 'himmel', 'forårshimmel', 'vrimmel', 'stimmel', 'klippestrimmel'}
# 6 	 197
# {'tuft', 'tåkeluft', 'blomsterduft', 'fornuft', 'luft', 'duft'}
# 6 	 198
# {'gys', 'bys', 'frys', 'tilbys', 'lys', 'grys'}
# 6 	 199
# {'stirrer', 'dirrer', 'forvirrer', 'klirrer', 'svirrer', 'virrer'}
# 6 	 200
# {'tømmer', 'dømmer', 'strålestrømmer', 'svømmer', 'drømmer', 'strømmer'}
# 6 	 201
# {'harv', 'skarv', 'fedrearv', 'marv', 'arv', 'tarv'}
# 6 	 202
# {'vippe', 'blomsterknippe', 'klippe', 'glippe', 'knippe', 'slippe'}
# 6 	 203
# {'kjøp', 'bøsseløp', 'svøp', 'støp', 'løp', 'krøp'}
# 6 	 204
# {'tøve', 'øve', 'prøve', 'sløve', 'røve', 'løve'}
# 6 	 205
# {'skilt', 'forspilt', 'mildt', 'vilt', 'spilt', 'stilt'}
# 6 	 206
# {'rov', 'kov', 'behov', 'lov', 'Østaskog', 'grov'}
# 6 	 207
# {'egne', 'hegne', 'regne', 'allevegne', 'betegne', 'vegne'}
# 6 	 208
# {'vinden', 'kinden', 'kinnen', 'kvinnen', 'forinnen', 'herskerinnen'}
# 6 	 209
# {'hugg', 'dugg', 'lugg', 'smugg', 'glugg', 'pugg'}
# 6 	 210
# {'lade', 'skade', 'blade', 'stade', 'vårkaskade', 'glade'}
# 6 	 211
# {'glipper', 'klipper', 'tripper', 'skipper', 'kipper', 'slipper'}
# 6 	 212
# {'attakker', 'akker', 'snakker', 'bakker', 'hakker', 'flakker'}
# 6 	 213
# {'lyster', 'kryster', 'bryster', 'kyster', 'ryster', 'silkebryster'}
# 6 	 214
# {'master', 'laster', 'haster', 'raster', 'kaster', 'gaster'}
# 6 	 215
# {'meteorer', 'rokkelorer', 'morer', 'porer', 'sporer', 'matadorer'}
# 6 	 216
# {'enke', 'benker', 'skjenke', 'tenke', 'krenke', 'lenke'}
# 6 	 217
# {'stigen', 'gigen', 'higen', 'skabningsstigen', 'krigen', 'himmelstigen'}
# 6 	 218
# {'måler', 'tilmåler', 'skåler', 'tåler', 'stråler', 'nåler'}
# 6 	 219
# {'bølgerygg', 'rygg', 'brygg', 'bygg', 'trygg', 'skyskraperbygg'}
# 6 	 220
# {'flytter', 'beskytter', 'rytter', 'bytter', 'hytter', 'lytter'}
# 6 	 221
# {'tæring', 'fortæring', 'færing', 'næring', 'belæring', 'gjæring'}
# 6 	 222
# {'fordømt', 'dømt', 'drømt', 'forsømt', 'skrømt', 'ømt'}
# 5 	 223
# {'strimer', 'stimer', 'timer', 'kimer', 'steamer'}
# 5 	 224
# {'stolt', 'koldt', 'Bolt', 'holdt', 'graneholt'}
# 5 	 225
# {'formerer', 'proklamerer', 'regjerer', 'manerer', 'sjenerer'}
# 5 	 226
# {'fyrstetiger', 'viger', 'intriger', 'stiger', 'kriger'}
# 5 	 227
# {'love', 'skove-', 'sove', 'vove', 'morgenskove'}
# 5 	 228
# {'andre', 'forandre', 'kjempegirlandre', 'hverandre', 'vandre'}
# 5 	 229
# {'beven', 'sveven', 'leven', 'veven', 'neven'}
# 5 	 230
# {'krenket', 'senket', 'benket', 'lenket', 'skjenket'}
# 5 	 231
# {'bark', 'hark', 'ark', 'spark', 'mark'}
# 5 	 232
# {'stuen', 'bjelkestuen', 'skuen', 'gruen', 'luen'}
# 5 	 233
# {'lommen', 'verdensdommen', 'dommen', 'kommen', 'gommen'}
# 5 	 234
# {'spares', 'åpenbares', 'bevares', 'forsvares', 'klares'}
# 5 	 235
# {'strålespeil', 'speil', 'feil', 'seil', 'geil'}
# 5 	 236
# {'bevise', 'vise', 'ise', 'prise', 'lise'}
# 5 	 237
# {'tiet', 'sceneriet', 'befriet', 'partiet', 'viet'}
# 5 	 238
# {'skuler', 'huler', 'fugler', 'smuler', 'skjuler'}
# 5 	 239
# {'sivet', 'verdenslivet', 'givet', 'livet', 'hedninge-livet'}
# 5 	 240
# {'bøtes', 'fløtes', 'møtes', 'aften', 'omstøtes'}
# 5 	 241
# {'lenkes', 'senkes', 'benkes', 'krenkes', 'skjenkes'}
# 5 	 242
# {'hevner', 'nevner', 'revner', 'stevner', 'evner'}
# 5 	 243
# {'minister', 'kopister', 'frihetsrigorister', 'bister', 'antikrister'}
# 5 	 244
# {'Ørn', 'himmelørn', 'sognebørn', 'tørn', 'bjørn'}
# 5 	 245
# {'barnelugger', 'dugger', 'vugger', 'glugger', 'hugger'}
# 5 	 246
# {'svamp', 'damp', 'stamp', 'kamp', 'ramp'}
# 5 	 247
# {'rank', 'bank', 'blank', 'sank', 'frank'}
# 5 	 248
# {'dagligdags', 'laks', 'aks', 'straks', 'slags'}
# 5 	 249
# {'Bern', 'vern', 'fjern', 'jern', 'Komintern'}
# 5 	 250
# {'bølger', 'forfølger', 'dølger', 'fordølger', 'følger'}
# 5 	 251
# {'dyp', 'gatedyp', 'kjempepolyp', 'menneskekryp', 'kryp'}
# 5 	 252
# {'kjært', 'nært', 'verdt', 'svært', 'lært'}
# 5 	 253
# {'tigger', 'brigger', 'ligger', 'pigger', 'rigger'}
# 5 	 254
# {'live', 'beskrive', 'rive', 'forblive', 'give'}
# 5 	 255
# {'skygger', 'rygger', 'brygger', 'bygger', 'iserygger'}
# 5 	 256
# {'konflikter', 'plikter', 'dikter', 'svikter', 'sikter'}
# 5 	 257
# {'fadeser', 'bleser', 'leser', 'neser', 'eser'}
# 5 	 258
# {'Sallust', 'just', 'rust', 'åndepust', 'pust'}
# 5 	 259
# {'hode', 'klode', 'gode', 'tilgode', 'tilmode'}
# 5 	 260
# {'folder', 'boller', 'volder', 'gassbeholder', 'holder'}
# 5 	 261
# {'hives', 'gives', 'skrives', 'avlives', 'drives'}
# 5 	 262
# {'veve', 'streve', 'neve', 'leve', 'kreve'}
# 5 	 263
# {'drømmesyn', 'syn', 'blomstersyn', 'lyn', 'bryn'}
# 5 	 264
# {'solen', 'fiolen', 'kjolen', 'polen', 'skolen'}
# 5 	 265
# {'truet', 'luet', 'skuet', 'kuet', 'nuet'}
# 5 	 266
# {'faste', 'laste', 'kaste', 'filisterkaste', 'baste'}
# 4 	 267
# {'kime', 'strime', 'time', 'stime'}
# 4 	 268
# {'kongeborg', 'Ingeborg', 'sorg', 'borg'}
# 4 	 269
# {'borte', 'porte', 'skjorte', 'sorte'}
# 4 	 270
# {'henskylle', 'forgylle', 'fylle', 'hylle'}
# 4 	 271
# {"skrå'n", "lå'n", 'høvelspån', "på'n"}
# 4 	 272
# {'strålet', 'bestrålet', 'målet', 'bålet'}
# 4 	 273
# {'rase', 'ekstase', 'oase', 'grimase'}
# 4 	 274
# {'mildhet', 'kvinnemildhet', 'stillhet', 'villhet'}
# 4 	 275
# {'Franken', 'banken', 'tanken', 'planken'}
# 4 	 276
# {'skapelse', 'fortapelse', 'etterapelse', 'forgapelse'}
# 4 	 277
# {'ferdig', 'iherdig', 'rettferdig', 'verdig'}
# 4 	 278
# {'bjørk', 'dørk', 'mørk', 'ørk'}
# 4 	 279
# {'gestalter', 'pjalter', 'alter', 'psalter'}
# 4 	 280
# {'åker', 'tåker', 'våker', 'måker'}
# 4 	 281
# {'vånde', 'sonde', 'ånde', 'tilhånde'}
# 4 	 282
# {'støv', 'gatestøv', 'løv', 'døv'}
# 4 	 283
# {'byde', 'lyde', 'fryde', 'tyde'}
# 4 	 284
# {'største', 'første', 'oljetørste', 'tørste'}
# 4 	 285
# {'knopper', 'hopper', 'bølgetopper', 'topper'}
# 4 	 286
# {'fornyer', 'skyer', 'avenyer', 'byer'}
# 4 	 287
# {'pakk', 'snakk', 'takk', 'tobakk'}
# 4 	 288
# {'lyver', 'klyver', 'flyver', 'styver'}
# 4 	 289
# {'forbarme', 'varme', 'harme', 'arme'}
# 4 	 290
# {'gjetning', 'fletning', 'setning', 'retning'}
# 4 	 291
# {'stengsel', 'fengsel', 'lengsel', 'trengsel'}
# 4 	 292
# {'fakler', 'mirakler', 'stakler', 'tabernakler'}
# 4 	 293
# {'barn', 'skarn', 'garn', "kar'n"}
# 4 	 294
# {'kleggen', 'veggen', 'heggen', 'eggen'}
# 4 	 295
# {'graneheien', 'lakeien', 'bjørkeheien', 'veien'}
# 4 	 296
# {'Bergenstrakten', 'makten', 'frihets-pakten', 'takten'}
# 4 	 297
# {'fyker', 'ryker', 'nyker', 'stryker'}
# 4 	 298
# {'dvelen', 'telen', 'kamelen', 'sjelen'}
# 4 	 299
# {'fane', 'ane', 'humane', 'bane'}
# 4 	 300
# {'måtte', 'fjottet', 'slottet', 'spottet'}
# 4 	 301
# {'gyter', 'skyter', 'bryter', 'flyter'}
# 4 	 302
# {'duk', 'buk', 'bruk', 'sluk'}
# 4 	 303
# {'forresten', 'sydvesten', 'blesten', 'Lofothesten'}
# 4 	 304
# {'slagg', 'flagg', 'plagg', 'ragg'}
# 4 	 305
# {'fellen', 'kvelden', 'makrellen', 'hellen'}
# 4 	 306
# {'storm', 'orm', 'norm', 'form'}
# 4 	 307
# {'øker', 'bøker', 'søker', 'spøker'}
# 4 	 308
# {'tåken', 'Kråken', 'våken', 'månelyståken'}
# 4 	 309
# {'akse', 'flakse', 'dagligdagse', 'sakse'}
# 4 	 310
# {'aker', 'saker', 'knaker', 'draker'}
# 4 	 311
# {'regnet', 'tegnet', 'egnet', 'beregnet'}
# 4 	 312
# {'broderkjeden', 'allkjærligheten', 'herneden', 'sæden'}
# 4 	 313
# {'klemte', 'temte', 'stemte', 'glemte'}
# 4 	 314
# {'følge', 'bølge', 'dølge', 'reise-følge'}
# 4 	 315
# {'frost', 'kost', 'blåst', 'grensepost'}
# 4 	 316
# {'eneste', 'beneste', 'reneste', 'peneste'}
# 4 	 317
# {'lyser', 'gyser', 'kyser', 'fryser'}
# 4 	 318
# {'ørn', 'tjørn', 'fiskeørn', 'børn'}
# 4 	 319
# {'renser', 'C.-sentenser', 'enser', 'grenser'}
# 4 	 320
# {'løfter', 'grøfter', 'snøfter', 'kløfter'}
# 4 	 321
# {'prisen', 'visen', 'grisen', 'ekspeditrisen'}
# 4 	 322
# {'hop', 'jubelrop', 'rop', 'trellehop'}
# 4 	 323
# {'forvilles', 'forspilles', 'hildes', 'spilles'}
# 4 	 324
# {'feile', 'speilet', 'seilet', 'steile'}
# 4 	 325
# {'rankt', 'blankt', 'trangt', 'langt'}
# 4 	 326
# {'morgenblånen', 'månen', 'blånen', 'himmelblånen'}
# 4 	 327
# {'kanter', 'planter', 'amaranter', 'diamanter'}
# 4 	 328
# {'minnes', 'bindes', 'vinnes', 'finnes'}
# 4 	 329
# {'løgne', 'øyne', 'forfløyne', 'fløyne'}
# 4 	 330
# {'gjemmes', 'temmes', 'fremmes', 'glemmes'}
# 4 	 331
# {'oppgangen', 'tangen', 'forbudstvangen', 'sangen'}
# 4 	 332
# {'fartøyer', 'bøyer', 'tøyer', 'støyer'}
# 4 	 333
# {'flitter', 'bitter', 'splitter', 'gitter'}
# 4 	 334
# {'skingrer', 'klingrer', 'slingrer', 'fingrer'}
# 4 	 335
# {'dårefakter', 'forpakter', 'kontrakter', 'akter'}
# 4 	 336
# {'funnen', 'folke-bunnen', 'bunden', 'stunden'}
# 4 	 337
# {'bulder', 'hulder', 'skulder', 'verdens-bulder'}
# 4 	 338
# {'hodet', 'podet', 'sloet', 'blodet'}
# 4 	 339
# {'slukket', 'lukket', 'sukket', 'dukket'}
# 4 	 340
# {'karmer', 'varmer', 'armer', 'barmer'}
# 4 	 341
# {'rader', 'fader', 'skader', 'bader'}
# 4 	 342
# {'diskuterer', 'Galileer', 'fariseer', 'Nasareer'}
# 4 	 343
# {'lister', 'brister', 'gnister', 'frister'}
# 4 	 344
# {'tok', 'krok', 'bok', 'klok'}
# 4 	 345
# {'skulle', 'gullet', 'mulde', 'kulde'}
# 4 	 346
# {'dødninghaven', 'staven', 'Graven', 'graven'}
# 4 	 347
# {'himmeldrømmen', 'tømmen', 'drømmen', 'strømmen'}
# 4 	 348
# {'gap', 'fellesskap', 'tap', 'bombedrap'}
# 4 	 349
# {'gåte', 'gråte', 'våte', 'måte'}
# 4 	 350
# {'røres', 'sløres', 'snøres', 'høres'}
# 4 	 351
# {'øen', 'snøen', 'Hovedøen', 'sjøen'}
# 4 	 352
# {'skikker', 'sikker', 'slikker', 'leskedrikker'}
# 4 	 353
# {'gjeldte', 'helter', 'belte', 'telter'}
# 4 	 354
# {'døper', 'svøper', 'løper', 'Døper'}
# 4 	 355
# {'skyld', 'idyll', 'jule-idyll', 'byll'}
# 4 	 356
# {'adjin', 'herinn', 'bind', 'sommervind'}
# 4 	 357
# {'stedet', 'rosenbedet', 'fredet', 'kvedet'}
# 4 	 358
# {'gjærer', 'kimærer', 'pærer', 'blærer'}
# 4 	 359
# {'runge', 'tunge', 'lunge', 'unge'}
# 4 	 360
# {'flaggfregatt', 'fregatt', 'admiral-fregatt', 'Kattegat'}
# 4 	 361
# {'fine', 'mine', 'dine', 'pine'}
# 4 	 362
# {'ofte', 'skofte', 'tofte', 'hofte'}
# 4 	 363
# {'gateluften', 'luften', 'blomsterduften', 'duften'}
# 4 	 364
# {'leid', 'sei', 'Rei', 'skrei'}
# 4 	 365
# {'sukke', 'opplukke', 'slukke', 'krukke'}
# 4 	 366
# {'faren', 'varen', "spare'n", 'snaren'}
# 4 	 367
# {'ektere', 'fornektere', 'vektere', 'forfektere'}
# 4 	 368
# {'freser', 'teser', 'peser', 'hveser'}
# 3 	 369
# {'lodd', 'sådd', 'nådd'}
# 3 	 370
# {'hyss', 'kyss', 'nyss'}
# 3 	 371
# {'kunst', 'gunst', 'dunst'}
# 3 	 372
# {'buret', 'skuret', 'furet'}
# 3 	 373
# {'kås', 'lås', 'gås'}
# 3 	 374
# {'skjønt', 'grønt', 'eviggrønt'}
# 3 	 375
# {'skrifter', 'bedrifter', 'skifter'}
# 3 	 376
# {'støyt', 'sprøyt', 'fløyt'}
# 3 	 377
# {'nynn', 'dynd', 'synd'}
# 3 	 378
# {'kleber', 'feber', 'leber'}
# 3 	 379
# {'fjells', 'pels', 'gjelds'}
# 3 	 380
# {'fedre', 'bedre', 'hedre'}
# 3 	 381
# {'vasker', 'masker', 'flasker'}
# 3 	 382
# {'tilfreds', 'krets', 'broderkrets'}
# 3 	 383
# {'stillet', 'seiersgildet', 'spillet'}
# 3 	 384
# {'ruger', 'duger', 'knuger'}
# 3 	 385
# {'tokter', 'vokter', 'dekokter'}
# 3 	 386
# {'kontoret', 'kirkebordet', 'koret'}
# 3 	 387
# {'jøss', 'tilsjøs', 'bøss'}
# 3 	 388
# {'stanse', 'danse', 'bekranse'}
# 3 	 389
# {'mørke', 'tørke', 'ørke'}
# 3 	 390
# {'beklages', 'plages', 'tages'}
# 3 	 391
# {'klippehanget', 'tanget', 'fanget'}
# 3 	 392
# {'snilte', 'hvilte', 'smilte'}
# 3 	 393
# {'skrev', 'drev', 'rev'}
# 3 	 394
# {'knapp', 'trapp', 'lapp'}
# 3 	 395
# {'kronet', 'tonet', 'sonet'}
# 3 	 396
# {'såre', 'tåre', 'innen-fore'}
# 3 	 397
# {'nesen', 'trapesen', 'vesen'}
# 3 	 398
# {'taket', 'braket', 'flaket'}
# 3 	 399
# {'nærmer', 'beskjermer', 'svermer'}
# 3 	 400
# {'spenning', 'kjenning', 'brenning'}
# 3 	 401
# {'skakke', 'bakke', 'nakke'}
# 3 	 402
# {'reden', 'forneden', 'Eden'}
# 3 	 403
# {'vendes', 'spennes', 'tennes'}
# 3 	 404
# {'lilje', 'tilje', 'vilje'}
# 3 	 405
# {'brystet', 'krystet', 'lystet'}
# 3 	 406
# {'Elias', 'Jeremias', 'Messias'}
# 3 	 407
# {'rålærbelte', 'velte', 'smelte'}
# 3 	 408
# {'kreves', 'leves', 'forgjeves'}
# 3 	 409
# {'åsen', 'båsen', 'Viumsåsen'}
# 3 	 410
# {'line', 'lavine', 'sine'}
# 3 	 411
# {'noe', 'goe', 'strofer'}
# 3 	 412
# {'snakken', 'bakken', 'blakken'}
# 3 	 413
# {'tollbodsrevenyer', 'ladestedsrevyer', 'mannaskyer'}
# 3 	 414
# {'oser', 'loser', 'roser'}
# 3 	 415
# {'poteter', 'kilometer', 'hemmeligheter'}
# 3 	 416
# {'sprengt', 'tenkt', 'stengt'}
# 3 	 417
# {'traff', 'blaff', 'straff'}
# 3 	 418
# {'fløyter', 'brøyter', 'sprøyter'}
# 3 	 419
# {'svirefest', 'offerprest', 'nest'}
# 3 	 420
# {'famler', 'ramler', 'samler'}
# 3 	 421
# {'kongespir', 'blir', 'gir'}
# 3 	 422
# {'kjemper', 'demper', 'lemper'}
# 3 	 423
# {'Cæsarea', 'Judea', 'Cades-Barnea'}
# 3 	 424
# {'kløvereng', 'heiagjeng', 'seng'}
# 3 	 425
# {'tispen', 'gispen', 'bispen'}
# 3 	 426
# {'kårne', 'bårne', 'tårne'}
# 3 	 427
# {'fengsler', 'stengsler', 'hengsler'}
# 3 	 428
# {'skodde', 'nådde', 'odde'}
# 3 	 429
# {'forskrekkes', 'gjekkes', 'vekkes'}
# 3 	 430
# {'taper', 'gaper', 'skaper'}
# 3 	 431
# {'trafikken', 'skikken', 'trikken'}
# 3 	 432
# {'skyggen', 'styggen', 'hesteryggen'}
# 3 	 433
# {'magneten', 'tidstrompeten', 'profeten'}
# 3 	 434
# {'nekter', 'forfekter', 'vekter'}
# 3 	 435
# {'hete', 'væte', 'Lethe'}
# 3 	 436
# {'forstening', 'mening', 'forening'}
# 3 	 437
# {'skummet', 'rommet', 'bølgeskummet'}
# 3 	 438
# {'merke', 'lerke', 'sterke'}
# 3 	 439
# {'Shanghai', 'hai', 'kai'}
# 3 	 440
# {'mukk', 'smukk', 'sukk'}
# 3 	 441
# {'byen', 'kullstøvskyen', 'skyen'}
# 3 	 442
# {'tåke', 'åket', 'tåket'}
# 3 	 443
# {'hyrde', 'byrde', 'myrde'}
# 3 	 444
# {'trua', 'stua', 'grua'}
# 3 	 445
# {'lyden', 'Syden', 'syden'}
# 3 	 446
# {'bryggen', 'ryggen', 'Nesoddryggen'}
# 3 	 447
# {'rummer', 'kummer', 'slummer'}
# 3 	 448
# {'slep', 'grep', 'rep'}
# 3 	 449
# {'hvisler', 'tidsler', 'risler'}
# 3 	 450
# {'brande', 'tande', 'aftenlande'}
# 3 	 451
# {'runer', 'basuner', 'luner'}
# 3 	 452
# {'tåpen', 'våpen', 'åpen'}
# 3 	 453
# {'Oskoreien', 'vegen', 'heien'}
# 3 	 454
# {'plukkes', 'slukkes', 'dukkes'}
# 3 	 455
# {'intense', 'grense', 'kredense'}
# 3 	 456
# {'dyrke', 'yrke', 'styrke'}
# 3 	 457
# {'rørte', 'hørte', 'førte'}
# 3 	 458
# {'gutter', 'kutter', 'futter'}
# 3 	 459
# {'reis', 'gneis', 'underveis'}
# 3 	 460
# {'furer', 'murer', 'lurer'}
# 3 	 461
# {'bjerker', 'evighetsverker', 'serker'}
# 3 	 462
# {'plassen', 'massen', 'Blomsterterrassen'}
# 3 	 463
# {'piggtrådkratt', 'skvatt', 'vanvidsnatt'}
# 3 	 464
# {'bite', 'sønderslite', 'vite'}
# 3 	 465
# {'maske', 'aske', 'vaske'}
# 3 	 466
# {'elver', 'skjelver', 'hvelver'}
# 3 	 467
# {'veide', 'feide', 'arbeide'}
# 3 	 468
# {'lempe', 'kjempe', 'dempe'}
# 3 	 469
# {'mistet', 'listet', 'bristet'}
# 3 	 470
# {'Ulv', 'ulv', 'gulv'}
# 3 	 471
# {'viser', 'beviser', 'priser'}
# 3 	 472
# {'Flake', 'tilbake.', 'make'}
# 3 	 473
# {'viktig', 'forsiktig', 'riktig'}
# 3 	 474
# {'fiskeboder', 'moder', 'broder'}
# 3 	 475
# {'bøyes', 'opphøyes', 'nøyes'}
# 3 	 476
# {'først', 'tørst', 'størst'}
# 3 	 477
# {'Urias', 'snurrebass', 'Rådhusplass'}
# 3 	 478
# {'tilorde', 'fjorde', 'borde'}
# 3 	 479
# {'føler', 'nøler', 'kjøler'}
# 3 	 480
# {'gaten', 'akrobaten', 'staden'}
# 3 	 481
# {'jernbetong', 'fasong', 'long'}
# 3 	 482
# {'kluter', 'tuter', 'skuter'}
# 3 	 483
# {'begynner', 'mynder', 'skynder'}
# 3 	 484
# {'brynde', 'hynde', 'ynde'}
# 3 	 485
# {'sammenfalder', 'galder', 'slyngelalder'}
# 3 	 486
# {'lodden', 'skodden', 'odden'}
# 3 	 487
# {'former', 'normer', 'stormer'}
# 3 	 488
# {'levnet', 'hevnet', 'folkestevnet'}
# 3 	 489
# {'bryte', 'flyte', 'lyte'}
# 3 	 490
# {'retrett', 'skvett', 'violett'}
# 3 	 491
# {'lekke', 'knekke', 'rekke'}
# 3 	 492
# {'horn', 'nypetorn', 'korn'}
# 3 	 493
# {'blåner', 'skåner', 'håner'}
# 3 	 494
# {'stinker', 'vinker', 'blinker'}
# 3 	 495
# {'striper', 'griper', 'piper'}
# 3 	 496
# {'påferde', 'geberde', 'lærde'}
# 3 	 497
# {'ubendig', 'nødvendig', 'behendig'}
# 3 	 498
# {'jordskjelvsrysten', 'kysten', 'dysten'}
# 3 	 499
# {'kneet', 'rognebærtreet', 'neet'}
# 3 	 500
# {'forferde', 'på-ferde', 'herde'}
# 3 	 501
# {'leden', 'traden', 'gleden'}
# 3 	 502
# {'lysorkan', 'aeroplan', 'ocean'}
# 3 	 503
# {'rynke', 'klynke', 'synke'}
# 3 	 504
# {'røs', 'løs', 'fjøs'}
# 3 	 505
# {'Algir', 'flir', 'spir'}
# 3 	 506
# {'murstensmassen', 'fattigkassen', 'søplekassen'}
# 3 	 507
# {'seir', 'reir', 'leir'}
# 3 	 508
# {'grunt', 'rundt', 'forundt'}
# 3 	 509
# {'frelsesarméen', 'sneen', 'véen'}
# 3 	 510
# {'ånden', 'hånden', 'Folgefonnen'}
# 3 	 511
# {'stoppe', 'toppe', 'oppe'}
# 3 	 512
# {'fossen', 'trossen', 'åssen'}
# 3 	 513
# {'vidder', 'ridder', 'henover'}
# 3 	 514
# {'stråle', 'tåle', 'måle'}
# 3 	 515
# {'sum', 'rum', 'stum'}
# 3 	 516
# {'laser', 'spaser', 'fraser'}
# 3 	 517
# {'Gyrisvoll', 'avindskjold', 'Koll'}
# 3 	 518
# {'fullbyrdet', 'myrdet', 'bebyrdet'}
# 3 	 519
# {'mursteinsrøys', 'tilkøys', 'tøys'}
# 3 	 520
# {'kirke', 'virke', 'birke'}
# 3 	 521
# {'hvert', 'snert', 'giftgass-ekspert'}
# 3 	 522
# {'legge', 'vegge', 'egge'}
# 3 	 523
# {'ærend', 'fjæren', 'tjæren'}
# 3 	 524
# {'malm', 'halm', 'psalm'}
# 3 	 525
# {'navnet', 'savnet', 'omfavnet'}
# 3 	 526
# {'farten', 'snegle-arten', 'Svarten'}
# 3 	 527
# {'stedse', 'stetse', 'kretse'}
# 3 	 528
# {'kjoler', 'skoler', 'symboler'}
# 3 	 529
# {'ruten', 'skuten', 'foruten'}
# 3 	 530
# {'dugget', 'vugget', 'rugget'}
# 3 	 531
# {'stige', 'skrige', 'hige'}

# %%
bad_buckets_i = [0, 1, 2, 3, 4, 5, 6, 7, 8, 11, 12, 13, 14, 19, 21, 23, 24, 36, 37, 38, 40, 41, 45, 59, 66, 74, 78]

good_buckets = [list(bucket) for i, bucket in enumerate(not_twos) if i not in bad_buckets_i]

under_10 = sum(len(bucket)>10 for bucket in not_twos)


print(f"""
All buckets of len<10 look alright. There are {under_10} buckets of size 2<10.
In addition, {len(good_buckets)} of the larger buckets looked alright.
This means that out of the {len(not_twos)} buckets of size>2, {len(good_buckets)} were good.
{len(bad_buckets_i)} are bad""")
# Out:
# All buckets of len<10 look alright. There are 99 buckets of size 2<10.
# In addition, 505 of the larger buckets looked alright.
# This means that out of the 532 buckets of size>2, 505 were good.
# 27 are bad

# %%
# Remove a bad word from buckets that shouldn't be there
i_ = 0
j_ = 0
for i, b in enumerate(good_buckets):
    if "smertens-tid" in b:
        i_ = i
    if "hjerter" in b:
        j_ = i
        
good_buckets[i_].remove("smertens-tid")
good_buckets[j_].remove("hjerter")

# %%
# with open('pickles/good_buckets.pickle','wb') as f:
#     pickle.dump(good_buckets, f)

with open('pickles/good_buckets.pickle','rb') as f:
    good_buckets = pickle.load(f)
len(good_buckets)
# Out:
# 505

# %%
tot_words = sum(len(bucket) for bucket in good_buckets)
print(f"""For the {len(good_buckets)} good buckets:
Total words: {tot_words}
% of vocab: {tot_words/len(vocab)*100}
Avg length: {tot_words/len(good_buckets)}
""")
# Out:
# For the 505 good buckets:
# Total words: 3326
# % of vocab: 52.87758346581876
# Avg length: 6.586138613861386

# %%
def get_mirrored_dupes(pairs):
    l = list(pairs)
    rem = set()

    for i,(a,b) in enumerate(l):
        if (b,a) in l[i:]:
            rem.add((b, a))
    return rem

# %%
gb_pairs = set()

for bucket in good_buckets:
    c = list(itertools.combinations(bucket, 2))
    if c:
        rem = get_mirrored_dupes(c)
        c = set(c) - rem
        gb_pairs.update(c)

# %%
len(gb_pairs)
# Out:
# 17689

# %%
twos = set([tuple(p) for p in twos])

# %%
len(twos)
# Out:
# 727

# %%
len(gb_pairs) + len(twos)
# Out:
# 18416

# %%
pairs_ = twos.copy()
pairs_.update(gb_pairs)
rem = get_mirrored_dupes(pairs_)
pairs_ -= rem
len(pairs_)
# Out:
# 18416

# %%
words_a, words_b = zip(*pairs_)
pair_df = pd.DataFrame({"word_a" : words_a , "word_b": words_b, "rhyme": [1]*len(pairs_)})
pair_df.to_csv("tsvs/good_buckets_pairs.tsv", sep="\t", index=False)
pair_df
# Out:
#                  word_a          word_b  rhyme
# 0      stillehavspassat            satt      1
# 1          stjerneblått           blott      1
# 2            manne-fall      tempelhall      1
# 3                 store           roret      1
# 4                  fare            mare      1
# ...                 ...             ...    ...
# 18411             nelde          gjelde      1
# 18412              bunn  solmorgenstund      1
# 18413         forpakter      dårefakter      1
# 18414            finner          hinder      1
# 18415            brøden   evighetsrøden      1
#
# [18416 rows x 3 columns]

# %%
orig_pairs = pairs.copy()

# %%
print(f"""
All combinations of the good buckets give us {len(gb_pairs)} rhyme pairs.
Of these, {len(gb_pairs)-(len(pairs)-len(orig_pairs))} already existed in the pairs data set.
We increased the pair set by {len(pairs)-len(orig_pairs)}.
+ twos = {len(gb_pairs) + len(twos)}
Vocab = {len(set(list(pair_df.word_a) + list(pair_df.word_b)))}
""")
# Out:
# All combinations of the good buckets give us 17689 rhyme pairs.
# Of these, 17689 already existed in the pairs data set.
# We increased the pair set by 0.
# + twos = 18416
# Vocab = 4780

# %% [markdown]
# ## HCS !!
# We want to try to cluster = separate the components/buckets on index 1 through 6
#
# from https://github.com/53RT/Highly-Connected-Subgraphs-Clustering-HCS/blob/master/hcs.py

# %%
def highly_connected(G, E):
    """Checks if the graph G is highly connected
    Highly connected means, that splitting the graph G into subgraphs needs more than 0.5*|V| edge deletions
    This definition can be found in Section 2 of the publication.
    :param G: Graph G
    :param E: Edges needed for splitting G
    :return: True if G is highly connected, otherwise False
    """

    return len(E) > len(G.nodes) / 2


def remove_edges(G, E):
    """Removes all edges E from G
    Iterates over all edges in E and removes them from G
    :param G: Graph to remove edges from
    :param E: One or multiple Edges
    :return: Graph with edges removed
    """

    for edge in E:
        G.remove_edge(*edge)
    return G


def HCS(G):
    """Basic HCS Algorithm
    cluster labels, removed edges are stored in global variables
    :param G: Input graph
    :return: Either the input Graph if it is highly connected, otherwise a Graph composed of
    Subgraphs that build clusters
    """

    E = nx.algorithms.connectivity.cuts.minimum_edge_cut(G)

    if not highly_connected(G, E):
        G = remove_edges(G, E)
        sub_graphs = [G.subgraph(c).copy() for c in nx.connected_components(G)]

        if len(sub_graphs) == 2:
            H = HCS(sub_graphs[0])
            _H = HCS(sub_graphs[1])

            G = nx.compose(H, _H)

    return G

# %%
bad_buckets = [not_twos[i] for i in bad_buckets_i]
tot_len = sum(len(b) for b in bad_buckets)

print(f"Total words bad buckets: {tot_len}")
print(f"Avg words bad buckets: {tot_len/len(bad_buckets)}")
# Out:
# Total words bad buckets: 1508
# Avg words bad buckets: 55.851851851851855

# %%
graphs = []

for gr in bad_buckets:
    edges = set()
    for w1 in gr:
        for w2 in list(G.neighbors(w1)):
            edges.add((w1, w2))
    comp = nx.Graph()
    comp.add_nodes_from(gr)
    comp.add_edges_from(edges)
    graphs.append(comp)

# %%
# Uncomment to cluster
# clusters = [HCS(comp.copy()) for comp in graphs]

# for i, cl in enumerate(clusters):
#     print(cl)
#     p = "graphs/cluster"+str(i)+".adjlist"
#     nx.write_adjlist(cl, p)

# %%
clusters = [nx.read_adjlist("graphs/cluster"+str(i)+".adjlist") for i in range(len(graphs))]

# %%
len(clusters)
# Out:
# 27

# %%
def get_buckets_and_lost_words(x):
    connected_comps = list(nx.connected_components(x))
    words = [w for comp in connected_comps for w in comp if len(comp)==1]
    buckets = [comp for comp in connected_comps if len(comp)>1]  
    return words, buckets

# %%
def get_fig(size):
    if size > 200:
        return plt.figure(figsize=(30, 50))
    if size > 100:
        return plt.figure(figsize=(30, 30))
    if size > 50:
        return plt.figure(figsize=(20, 20))
    return plt.figure(figsize=(10, 10))

# %%
more_buckets = []
lost_words = 0
not_divided = 0

for i, (graph, cluster) in enumerate(zip(graphs, clusters)):
    size = len(graph.nodes)
    words_, buckets_ = get_buckets_and_lost_words(cluster)    
    f = get_fig(size)
    nx.draw(graph, ax=f.add_subplot(111), with_labels=True)
    f.savefig(f"figs/pre_clustering_graph_{i}.png")
    plt.close(f)

    
    if len(buckets_) == 1:
        not_divided += 1
        print(f"Graph {i} was not separated.\n")
        continue
    print(f"""Graph {i} was separated into {len(buckets_)} components.
    It originally had {size} vertices.
    Now it has {size - len(words_)}.
    This means {len(words_)} words were separated into single vertex clusters.
    """)
    f = get_fig(size)
    nx.draw(nx.restricted_view(cluster, edges=[], nodes=(words_)), ax=f.add_subplot(111),  with_labels=True)
    f.savefig(f"figs/post_clustering_graph_{i}.png")
    plt.close(f)

    
    more_buckets += buckets_
    lost_words += len(words_)
# Out:
# Graph 0 was separated into 8 components.
#     It originally had 227 vertices.
#     Now it has 50.
#     This means 177 words were separated into single vertex clusters.
#
# Graph 1 was separated into 8 components.
#     It originally had 189 vertices.
#     Now it has 38.
#     This means 151 words were separated into single vertex clusters.
#
# Graph 2 was separated into 5 components.
#     It originally had 148 vertices.
#     Now it has 23.
#     This means 125 words were separated into single vertex clusters.
#
# Graph 3 was separated into 5 components.
#     It originally had 144 vertices.
#     Now it has 38.
#     This means 106 words were separated into single vertex clusters.
#
# Graph 4 was separated into 3 components.
#     It originally had 92 vertices.
#     Now it has 16.
#     This means 76 words were separated into single vertex clusters.
#
# Graph 5 was separated into 3 components.
#     It originally had 68 vertices.
#     Now it has 11.
#     This means 57 words were separated into single vertex clusters.
#
# Graph 6 was separated into 4 components.
#     It originally had 67 vertices.
#     Now it has 19.
#     This means 48 words were separated into single vertex clusters.
#
# Graph 7 was separated into 4 components.
#     It originally had 62 vertices.
#     Now it has 16.
#     This means 46 words were separated into single vertex clusters.
#
# Graph 8 was separated into 2 components.
#     It originally had 58 vertices.
#     Now it has 10.
#     This means 48 words were separated into single vertex clusters.
#
# Graph 9 was separated into 3 components.
#     It originally had 45 vertices.
#     Now it has 14.
#     This means 31 words were separated into single vertex clusters.
#
# Graph 10 was separated into 3 components.
#     It originally had 45 vertices.
#     Now it has 12.
#     This means 33 words were separated into single vertex clusters.
#
# Graph 11 was separated into 2 components.
#     It originally had 39 vertices.
#     Now it has 11.
#     This means 28 words were separated into single vertex clusters.
#
# Graph 12 was separated into 3 components.
#     It originally had 38 vertices.
#     Now it has 13.
#     This means 25 words were separated into single vertex clusters.
#
# Graph 13 was not separated.
#
# Graph 14 was separated into 2 components.
#     It originally had 29 vertices.
#     Now it has 9.
#     This means 20 words were separated into single vertex clusters.
#
# Graph 15 was separated into 3 components.
#     It originally had 28 vertices.
#     Now it has 10.
#     This means 18 words were separated into single vertex clusters.
#
# Graph 16 was separated into 2 components.
#     It originally had 27 vertices.
#     Now it has 10.
#     This means 17 words were separated into single vertex clusters.
#
# Graph 17 was not separated.
#
# Graph 18 was not separated.
#
# Graph 19 was separated into 2 components.
#     It originally had 20 vertices.
#     Now it has 8.
#     This means 12 words were separated into single vertex clusters.
#
# Graph 20 was separated into 2 components.
#     It originally had 19 vertices.
#     Now it has 8.
#     This means 11 words were separated into single vertex clusters.
#
# Graph 21 was not separated.
#
# Graph 22 was separated into 2 components.
#     It originally had 18 vertices.
#     Now it has 7.
#     This means 11 words were separated into single vertex clusters.
#
# Graph 23 was separated into 2 components.
#     It originally had 15 vertices.
#     Now it has 7.
#     This means 8 words were separated into single vertex clusters.
#
# Graph 24 was not separated.
#
# Graph 25 was not separated.
#
# Graph 26 was separated into 2 components.
#     It originally had 13 vertices.
#     Now it has 6.
#     This means 7 words were separated into single vertex clusters.

# %%
len(more_buckets), not_divided
# Out:
# (70, 6)

# %%
tot_words = sum(len(bucket) for bucket in more_buckets)
print(f"""For the {len(more_buckets)} more buckets:
Total words: {tot_words}
% of vocab: {tot_words/len(vocab)*100}
Avg length: {tot_words/len(more_buckets)}
""")
# Out:
# For the 70 more buckets:
# Total words: 336
# % of vocab: 5.34181240063593
# Avg length: 4.8

# %%
more_buckets = [list(b) for b in more_buckets]

# %%
# with open('pickles/hcs_rhyme_graph_buckets.pickle','wb') as f:
#     pickle.dump(more_buckets, f)

with open('pickles/hcs_rhyme_graph_buckets.pickle','rb') as f:
    more_buckets = pickle.load(f)

# %%
more_vocab = sum([len(bucket) for bucket in more_buckets])

print(f"""
With the buckets we got from graph clustering we got
{len(more_buckets)} new buckets
Average size: {more_vocab/len(more_buckets)}
{more_vocab} words out of {len(vocab)} total
We lost {lost_words} vertices
Of the bad buckets, {not_divided} were not divided by HCS
""")
# Out:
# With the buckets we got from graph clustering we got
# 70 new buckets
# Average size: 4.8
# 336 words out of 6290 total
# We lost 1055 vertices
# Of the bad buckets, 6 were not divided by HCS

# %% [markdown]
# ## Create rhyme pairs from more_buckets

# %%
graph_pairs = set()

for bucket in more_buckets:
    c = list(itertools.combinations(bucket, 2))
    if c:
        rem = get_mirrored_dupes(c)
        c = set(c) - rem
        graph_pairs.update(c)
len(graph_pairs)
# Out:
# 787

# %%
new_pairs = graph_pairs - orig_pairs

# %%
pairs1 = pairs_.copy()
pairs1.update(graph_pairs)
len(pairs1)
# Out:
# 19203

# %%
print(f"""
All combinations of the more_buckets give us {len(graph_pairs)} rhyme pairs.
Of these, {len(graph_pairs.intersection(orig_pairs))} already existed in the pairs data set.
We increased the pair set by {len(new_pairs)}.

However, the original pairs data set contain bad edges.
We add the {len(pairs_)} good_buckets pairs and {len(graph_pairs)} more_buckets pairs together for a new pair dataset.
The total length is {len(pairs1)}
""")
# Out:
# All combinations of the more_buckets give us 787 rhyme pairs.
# Of these, 338 already existed in the pairs data set.
# We increased the pair set by 449.
#
# However, the original pairs data set contain bad edges.
# We add the 18416 good_buckets pairs and 787 more_buckets pairs together for a new pair dataset.
# The total length is 19203

# %%
words_a, words_b = zip(*pairs1)
pair_df = pd.DataFrame({"word_a" : words_a, "word_b": words_b, "rhyme": [1]*len(pairs1)})
pair_df.to_csv("tsvs/hcs_plus_good_buckets_pairs.tsv", sep="\t", index=False)

# %%
pair_df
# Out:
#                  word_a          word_b  rhyme
# 0      stillehavspassat            satt      1
# 1          stjerneblått           blott      1
# 2                   med             ned      1
# 3            manne-fall      tempelhall      1
# 4                 store           roret      1
# ...                 ...             ...    ...
# 19198             nelde          gjelde      1
# 19199              bunn  solmorgenstund      1
# 19200         forpakter      dårefakter      1
# 19201            finner          hinder      1
# 19202            brøden   evighetsrøden      1
#
# [19203 rows x 3 columns]

# %%
v = set(list(pair_df.word_a)+list(pair_df.word_b))
len(v)
# Out:
# 5116

# %% [markdown]
# ## Manually remove bad edges

# %% [markdown]
# ord som den
# men/mén
# seg/seg
# brød dø, nød
# råd få, dåd
# morgen sorgen, våren

# %%
manual_buckets = []
all_bad_edges = []

# %%
len(graphs)
# Out:
# 27

# %%
i = 26
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()
            
for e in [("tog", "slog")]:
    g.remove_edge(*e)

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 26 was separated into 2 components.
# It originally had 13 vertices.
# Now it has 13.

# %%
i = 25
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("rører", "fødes")]

for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 25 was separated into 2 components.
# It originally had 13 vertices.
# Now it has 13.

# %%
i = 24
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("øret", "skape")]

for e in bad_edges:
    g.remove_edge(*e)
    
all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 24 was separated into 2 components.
# It originally had 14 vertices.
# Now it has 14.

# %%
i = 23
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()


for e in [("gården", "orden"), ("gården", "uorden"), ("morgen", "Borgen"), 
          ("gudeborgen", "morgen"), ("sorgen", "morgen")]:
    g.remove_edge(*e)

g.add_edge("gudeborgen", "sorgen")
g.add_edge("Borgen", "sorgen")
g.add_edge("uorden", "orden")

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 23 was separated into 3 components.
# It originally had 15 vertices.
# Now it has 15.

# %%
i = 22
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()


bad_edges = [("tolk", "tjene"), ("folk", "ene"), ("stene", "ense")]
    
for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 22 was separated into 3 components.
# It originally had 18 vertices.
# Now it has 18.

# %%
i = 21
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()


bad_edges = [("bratte", "hatter"), ("bratte", "fatter"), ("bratte", "skatter")]
    
for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 21 was separated into 2 components.
# It originally had 19 vertices.
# Now it has 19.

# %%
i = 20
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("vunnet", "grunnen")]

for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 20 was separated into 2 components.
# It originally had 19 vertices.
# Now it has 19.

# %%
i = 19
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("Amen", "ramme"), ("sammen", "tamme"), ("sammen", "ramme"), ("tamme", "Amen")]

for e in bad_edges:
    g.remove_edge(*e)
    
all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 19 was separated into 2 components.
# It originally had 20 vertices.
# Now it has 20.

# %%
i = 18
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()


bad_edges = [("gave", "havet"), ("kave", "havet")]

for e in bad_edges:
    g.remove_edge(*e)
    
all_bad_edges += bad_edges

g.add_edge("kave", "have")    

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 18 was separated into 2 components.
# It originally had 21 vertices.
# Now it has 21.

# %%
i = 17
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("bom", "dom"), ("rom", "om"), ("bom", "om")]    

for e in bad_edges + [("dom", "tom"), ("om", "tom"), ("kom", "tom"), ("rundtenom", "tom")]:
    g.remove_edge(*e)
    
all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
#f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 17 was separated into 2 components.
# It originally had 21 vertices.
# Now it has 21.

# %%
i = 16
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("pris", "lider"), ("vis", "lider")]

for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 16 was separated into 2 components.
# It originally had 27 vertices.
# Now it has 27.

# %%
i = 15
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("munner", "grunne"), ("munner", "lunde"), ("munner", "blunde")]

for e in bad_edges:
    g.remove_edge(*e)
    
all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 15 was separated into 2 components.
# It originally had 28 vertices.
# Now it has 28.

# %%
i = 14
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("forbannet", "tent"), ("forbrent", "landet"), ("FAR", "landet"), ("FAR", "annet")]
for e in bad_edges:
    g.remove_edge(*e)
    
g.add_edge("forbrent", "tent")
    
all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
 
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 14 was separated into 2 components.
# It originally had 29 vertices.
# Now it has 28.

# %%
i = 13
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("klokker", "tar"), ("lokker", "svar")] 

for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 13 was separated into 2 components.
# It originally had 29 vertices.
# Now it has 29.

# %%
i = 12
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [
    # straight up wrong
    ("skjød", "bårer"), ("skjød", "tårer"),
    
    # phonetically similar
    ("glød", "brøt"),
]

for e in bad_edges + [("brød", "dø")]:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 12 was separated into 4 components.
# It originally had 38 vertices.
# Now it has 38.

# %%
i = 11
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("ham", "sender"), ("ham", "hender")]

for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 11 was separated into 2 components.
# It originally had 39 vertices.
# Now it has 39.

# %%
i = 10
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("sist", "kyst"), ("bryst", "høst")]
for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 10 was separated into 3 components.
# It originally had 45 vertices.
# Now it has 45.

# %%
i = 9
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("steg", "lek"), ("seg", "lik")]

for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 9 was separated into 3 components.
# It originally had 45 vertices.
# Now it has 45.

# %%
i = 8
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [("hytte", "makt"), ("beskytte", "prakt")]

for e in bad_edges:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 8 was separated into 2 components.
# It originally had 58 vertices.
# Now it has 58.

# %%
i = 7
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

            # pronunciation variation
for e in [("sa", "av"), ("ifra", "blad"), ("hva", "glad"), ("glad", "ad"), ("glad", "strålebad"), ("glad", "bad"), 
("glad", "vidunderbad"), ("glad", "stad"), ("glad", "rad")]:
    g.remove_edge(*e)

g.add_edge("hva", "glad")
g.add_edge("ifra", "hva")
g.add_edge("vidunderbad", "rad")
    
words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 7 was separated into 3 components.
# It originally had 62 vertices.
# Now it has 62.

# %%
i = 6
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [
    # straight up wrong
    ("ranker", "venn"), ("tanker", "ben"), ("én", "anker"), ("tanker", "menn"),
]
                       #phonetical variation
for e in bad_edges + [("en", "lend"), ("men", "menn"), ("den", "men"),
                      # rhyme spanning several words
                   ("natten", "den"), ("tiden", "den"), ("appetitten", "den"), ("gikten", "den")]:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 6 was separated into 5 components.
# It originally had 67 vertices.
# Now it has 65.

# %%
i = 5
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [
    # wrong
    ("forfengelighet", "selv"), ("del", "trommer"), ("sjel", "dommer"),
    
    #phonetically similar
    ("selv", "elv"), ("selv", "hvelv"), ("selv", "skjelv"), ("sjel", "vell"), 
]

for e in bad_edges: 
    g.remove_edge(*e)

g.add_edge("skjelv", "elv")

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 5 was separated into 4 components.
# It originally had 68 vertices.
# Now it has 67.

# %%
i = 4
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [
    # straight up wrong
    ("solskinsdag", "minne"), ("fuglen", "idag"), ("egen", "rinne"),
    
    # phonetically similart
    ("tak", "nag"), ("hyttetak", "dag")
]

for e in bad_edges:
    g.remove_edge(*e)
    
g.add_edge("hyttetak", "smak")

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 4 was separated into 3 components.
# It originally had 92 vertices.
# Now it has 90.

# %%
i = 3
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)

# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()

bad_edges = [
    # phonetically similar
    ("gråt", "dåd"), ("gråt", "nidingsdåd"),

    # nu _nå
    ("du", "nå"), ("hu", "nå"),
    
    # straight up wrong
    ("skogen", "sår"), ("plogen", "går"), ("fjorden", "skogen"),
    ("forstå", "fest"),("best", "forstå"), ("forgå", "når"),
]
                    # phonetic variation
for e in bad_edges + [("råd", "få")]:
    g.remove_edge(*e)

all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")
    
f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 3 was separated into 8 components.
# It originally had 144 vertices.
# Now it has 144.

# %%
i = 2
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()


bad_edges = [
    # straight up wrong
    ("vred", "lever"), ("fred", "bever"), ("rett", "det"),
    
    #phonetically similar
    ("evighet", "ed"), ("vet", "ned"),
    ("ned", "kjærlighet"), ("ned", "gret"),
    ("elvebredd", "ned"), ("ensomhet", "med")
]

for e in bad_edges + [("tente", "det"), ("smerte", "det"), ("det", "bade")]:
    g.remove_edge(*e)
    
g.add_edge("gret", "profet")
g.add_edge("ensomhet", "profet")
    
all_bad_edges += bad_edges

words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 2 was separated into 6 components.
# It originally had 148 vertices.
# Now it has 146.

# %%
i = 1
g = graphs[i].copy()
size = len(g.nodes)

bad_edges = [
    # phonetically similar
    ("døde", "møte"), ("strid", "bit"), ("tid", "hit"), ("tid", "dit"), ("vi", "Wergelands-rid"), 
    
    # straight up wrong
    ("gløde", "strid"), ("daler", "tale"), ("heder", "der"), 
    ("dere", "svermeri"), ("dere", "heder"), ("dere", "kjær"), 
    ("dere", "sti"), ("dere", "opprørsleder"), ("tid", "tale"), ("forbløde", "tid")
   ]
                    # variations in pronuncitation
for e in bad_edges + [("vi", "tid")]:
    g.remove_edge(*e)

g.add_edge("opprørsleder", "streder")
g.add_edge("bit", "hit")
    
all_bad_edges += bad_edges
    
words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 1 was separated into 10 components.
# It originally had 189 vertices.
# Now it has 188.

# %%
i = 0
g = graphs[i].copy()
size = len(g.nodes)

# f = get_fig(size)
# nx.draw(g, ax=f.add_subplot(111), with_labels=True)
# plt.show()
    
bad_edges = [
    # straight up wrong
    ("ære", "takke"),("land","bære"), ("strand", "bølgehære"), 
    ("imot", "lære"),("stort", "kan"), ("land", "stort"),
    ("skuer", "fot"),("land", "veie"), ("tro", "jord"), 

     #somewhat similar pronunciation (still wrong)
     ("lot", "blod"), ("fot", "stod"), ("fot", "blod"), ("bot", "flod"), 
     ("bort", "vårt"), ("bort", "kort"), ("stod", "legerot"),
]

                        #heteronym 'been' vs 'the weather'
for e in bad_edges + [("været", "besværet"), ("været", "fortæret"), ("akkord", "bord")]:
    g.remove_edge(*e)

g.add_edge("legerot", "helsebot")
g.add_edge("bølgehære", "ære")

    
all_bad_edges += bad_edges
    
words_, buckets_ = get_buckets_and_lost_words(g)
print(f"""Graph {i} was separated into {len(buckets_)} components.
It originally had {size} vertices.
Now it has {size - len(words_)}.
""")

f = get_fig(size)
nx.draw(g, ax=f.add_subplot(111), with_labels=True)
f.savefig(f"figs/manual_repair_{i}.png")

manual_buckets += list(nx.connected_components(g))
# Out:
# Graph 0 was separated into 11 components.
# It originally had 227 vertices.
# Now it has 226.

# %%
with open('pickles/bad_edges.pickle','wb') as f:
    pickle.dump(all_bad_edges, f)

# %%
manual_buckets = [list(e) for e in manual_buckets if len(e) > 2]

# %%
tot_words = sum(len(bucket) for bucket in manual_buckets)
print(f"""For the {len(manual_buckets)} more buckets:
Total words: {tot_words}
% of vocab: {tot_words/len(vocab)*100}
Avg length: {tot_words/len(manual_buckets)}
""")
# Out:
# For the 91 more buckets:
# Total words: 1492
# % of vocab: 23.72019077901431
# Avg length: 16.395604395604394

# %%
with open('pickles/manual_repair_buckets.pickle','wb') as f:
    pickle.dump(manual_buckets, f)

# %%
m_pairs = set()

for bucket in manual_buckets:
    c = list(itertools.combinations(bucket, 2))
    if c:
        rem = get_mirrored_dupes(c)
        c = set(c) - rem
        m_pairs.update(c)
len(m_pairs)
# Out:
# 20183

# %%
m_pairs
# Out:
# {('Å', 'skrå'),
#  ('med', 'ned'),
#  ('nattelosji', 'bli'),
#  ('spredt', 'ett'),
#  ('tyribrann', 'Wergeland'),
#  ('gjenoppta', 'derifra'),
#  ('stor', 'hernord'),
#  ('fram', 'dyreham'),
#  ('nordlys-prakt', 'strakt'),
#  ('flor', 'kirkekor'),
#  ('let', 'lett'),
#  ('sne', 'herned'),
#  ('bølgegrav', 'stav'),
#  ('kjed', 'spe'),
#  ('fril', 'hi'),
#  ('naglebor', 'stråleflor'),
#  ('hedningjord', 'bestemor'),
#  ('flak', 'vrak'),
#  ('fril', 'befri'),
#  ('få', 'også'),
#  ('Sand', 'tyribrann'),
#  ('da', 'hurra'),
#  ('kjød', 'forbrød'),
#  ('Teruel', 'trell'),
#  ('lell', 'bakkehell'),
#  ('tid', 'rid'),
#  ('helstøvle-føre', 'snøre'),
#  ('pinsefest', 'dernest'),
#  ('blomstermunne', 'sunde'),
#  ('grå', 'også'),
#  ('herlighet', 'ensomhet'),
#  ('motor', 'fuglekor'),
#  ('forgår', 'kår'),
#  ('grett', 'regnebrett'),
#  ('være', 'Staats-affære'),
#  ('frydeskrik', 'fugleskrik'),
#  ('ti', 'sympati'),
#  ('være', 'besnære'),
#  ('ansiktsdrag', 'oktoberdag'),
#  ('sæl', 'fjell'),
#  ('løvsalstrær', 'oppstandelsesskjær'),
#  ('skapermann', 'illgjerningsmann'),
#  ('ago', 'hunger-grå'),
#  ('fotefar', 'oksepar'),
#  ('gådemakt', 'sjakt'),
#  ('inne', 'blinde'),
#  ('skinnet', 'vinde'),
#  ('svære', 'hære'),
#  ('istå', 'blaå'),
#  ('stråleflor', 'kommando-ord'),
#  ('kildevann', 'land'),
#  ('sjungekor', 'Tor'),
#  ('grett', 'husbondsvett'),
#  ('vinter-sne', 'armé'),
#  ('skåren', 'morgen'),
#  ('kledt', 'sett'),
#  ('geled', 'fortred'),
#  ('sæd', 'kjed'),
#  ('blunde', 'sunne'),
#  ('går', 'igår'),
#  ('avsted', 'kre'),
#  ('för', 'naglebor'),
#  ('farvel', 'Israel'),
#  ('bered', 'vadested'),
#  ('Nudetre', 'beskjed'),
#  ('gled', 'spe'),
#  ('herskermakt', 'belagt'),
#  ('sendt', 'spent'),
#  ('søndagsmorgen', 'sorgen'),
#  ('og', 'sprog'),
#  ('strålefjed', 'kjed'),
#  ('tonehav', 'nav'),
#  ('hjertesår', 'skyteskår'),
#  ('hedersmann', 'brann'),
#  ('Ambarvalia', 'bedra'),
#  ('strender', 'venner'),
#  ('nord', 'mord'),
#  ('vek', 'lek'),
#  ('solskinsdag', 'søndenvindsdrag'),
#  ('får', 'igår'),
#  ('forbrent', 'brent'),
#  ('instrument', 'skrent'),
#  ('silhouett', 'minarett'),
#  ('sammen', 'bjørkestammen'),
#  ('gevær', 'skjær'),
#  ('velbehag', 'oktoberdag'),
#  ('skapermann', 'fiskevann'),
#  ('Gondvanaland', 'fiskermann'),
#  ('la', 'Ambarvalia'),
#  ('vrå', 'aldersgrå'),
#  ('hedningjord', 'bor'),
#  ('lell', 'selv'),
#  ('ødeland', 'eiermann'),
#  ('sosialist', 'harsellist'),
#  ('veld', 'sprell'),
#  ('kassevis', 'bris'),
#  ('Israel', 'kildevell'),
#  ('bestå', 'så'),
#  ('julekveld', 'veld'),
#  ('brak', 'kvak'),
#  ('trær', 'der'),
#  ('ørkensand', 'redningsmann'),
#  ('eiermann', 'vinterland'),
#  ('knusleri', 'si'),
#  ('takt', 'forakt'),
#  ('arbeidsbi', 'symfoni'),
#  ('blomsterbed', 'bed'),
#  ('sovekupé', 'idé'),
#  ('julekveld', 'kildevell'),
#  ('forslår', 'spår'),
#  ('lyseblå', 'strå'),
#  ('brent', 'fryktbespent'),
#  ('lavet', 'havet'),
#  ('kjell', 'sommerkveld'),
#  ('galgetre', 'Nudetre'),
#  ('slå', 'blaå'),
#  ('ljå', 'stå'),
#  ('åpenbar', 'klar'),
#  ('bakkehell', 'småmakrell'),
#  ('fremmedland', 'tann'),
#  ('skje', 'sved'),
#  ('procent', 'brent'),
#  ('høysommerdag', 'åndedrag'),
#  ('spar', 'fotefar'),
#  ('Krist', 'tilsist'),
#  ('rik', 'tryllesvik'),
#  ('korstog-ren', 'len'),
#  ('Tor', 'blomsterflor'),
#  ('ingensinne', 'slavinne'),
#  ('rettferdighet', 'ubønnhørlighet'),
#  ('saltarell', 'lell'),
#  ('sinne', 'tvinne'),
#  ('idé', 'sed'),
#  ('naglebor', 'tempelkor'),
#  ('rabatter', 'forfatter'),
#  ('moment', 'Sorrent'),
#  ('ætt', 'minarett'),
#  ('Ho', 'mo'),
#  ('sten', 'suveréen'),
#  ('blinde', 'hinne'),
#  ('bittesmå', 'Å'),
#  ('sti', 'ti'),
#  ('bred', 'fred'),
#  ('arbeidsfred', 'kre'),
#  ('bergeli', 'parti'),
#  ('bann', 'sand'),
#  ('tider', 'svider'),
#  ('sken', 'hven'),
#  ('slavestand', 'Gondwanaland'),
#  ('venninne', 'Slinde'),
#  ('svermeri', 'raseri'),
#  ('bakkehell', 'selv'),
#  ('strålebro', 'gro'),
#  ('veld', 'Desemberkveld'),
#  ('stred', 'bibelsted'),
#  ('evighetsdag', 'lerkeslag'),
#  ('hedersmann', 'sand'),
#  ('gjeld', 'saltarell'),
#  ('Bø', 'dø'),
#  ('dåreføde', 'tildøde'),
#  ('høyreblad', 'Nicaragua'),
#  ('fuglefjell', 'skjell'),
#  ('no', 'gro'),
#  ('skaper-makt', 'brakt'),
#  ('tyrann', 'strand'),
#  ('narrefest', 'protest'),
#  ('Sand', 'tidevann'),
#  ('står', 'tiggerkår'),
#  ('ubekjent', 'vendt'),
#  ('landliggedag', 'idag'),
#  ('akt', 'prakt'),
#  ('trøst', 'klagerøst'),
#  ('står', 'skår'),
#  ('svakt', 'brakt'),
#  ('kveld', 'fortell'),
#  ('føre', 'høre'),
#  ('istå', 'antennetråd'),
#  ('vær', 'austenvær'),
#  ('lær', 'begjær'),
#  ('fjelebod', 'bod'),
#  ('bero', 'jo'),
#  ('sno', 'bo'),
#  ('omsider', 'sider'),
#  ('rosenskjær', 'spær'),
#  ('likedan', 'fiskermann'),
#  ('stram', 'hverdagslam'),
#  ('kontrakt', 'kongemakt'),
#  ('lær', 'hver'),
#  ('par', 'åpenbar'),
#  ('fiskerlag', 'vingeslag'),
#  ('spær', 'flammeskjær'),
#  ('ben', 'suveréen'),
#  ('forstå', 'formå'),
#  ('kirketag', 'sommerdag'),
#  ('jag', 'lerkeslag'),
#  ('få', 'trå'),
#  ('kjed', 'bre'),
#  ('knar', 'spar'),
#  ('skjell', 'stråleveld'),
#  ('spær', 'ospetrær'),
#  ('bølgeslag', 'oktoberdag'),
#  ('frelsesarmé', 'beskjed'),
#  ('beredt', 'folkevett'),
#  ('trær', 'rosenskjær'),
#  ('gror', 'snor'),
#  ('herinne', 'Slinde'),
#  ('motormann', 'iland'),
#  ('stå', 'hyttevrå'),
#  ('strender', 'tenner'),
#  ('stand', 'brand'),
#  ('jord', 'blomsterflor'),
#  ('Ho', 'forstod'),
#  ('alterbord', 'blomsterflor'),
#  ('beherskero', 'mo'),
#  ('prakt', 'brakt'),
#  ('avrustningspakt', 'ringeakt'),
#  ('ødelagt', 'kongemakt'),
#  ('det', 'gled'),
#  ('svermeri', 'fri'),
#  ('kjerr', 'ospetrær'),
#  ('dolk', 'smalgangsfolk'),
#  ('kristenblod', 'mod'),
#  ('harmoni', 'verdi'),
#  ('varselsord', 'bror'),
#  ('venner', 'rovdyrtenner'),
#  ('lett', 'Nasaret'),
#  ('forsmår', 'når'),
#  ('ned', 'arnested'),
#  ('deri', 'fremtidssti'),
#  ('sjelebod', 'to'),
#  ('solskinns-dag', 'evighetsdag'),
#  ('kjøpmannsferd', 'irisskjær'),
#  ('bi', 'svermeri'),
#  ('vel', 'fortell'),
#  ('her', 'lær'),
#  ('kafé', 'med'),
#  ('bølgeslag', 'vederlag'),
#  ('stråleveld', 'vinterkveld'),
#  ('ni', 'bergeli'),
#  ('kjed', 'vred'),
#  ('tiggerkår', 'når'),
#  ('strid', 'Wergelands-rid'),
#  ('kildevann', 'vann'),
#  ('lær', 'hjertenskjær'),
#  ('øde', 'døde'),
#  ('bot', 'lot'),
#  ('sosialist', 'pist'),
#  ('spor', 'gror'),
#  ('ti', 'raseri'),
#  ('tror', 'för'),
#  ('gren', 'én'),
#  ('moment', 'prent'),
#  ('våt', 'gråt'),
#  ('slå', 'antennetråd'),
#  ('kristenhet', 'profet'),
#  ('Johan', 'grand'),
#  ('gled', 'bre'),
#  ('Totakvann', 'Helgeland'),
#  ('vingeslag', 'hammerslag'),
#  ('lest', 'allerbest'),
#  ('fri', 'parti'),
#  ('skar', 'har'),
#  ('lær', 'tverr'),
#  ('mann', 'land'),
#  ('sno', 'ro'),
#  ('gløde', 'bløde'),
#  ('bror', 'mord'),
#  ('arnested', 'sved'),
#  ('Eginafjord', 'mord'),
#  ('bergeli', 'fri'),
#  ('hyrdestav', 'derav'),
#  ('glor', 'beror'),
#  ('ødeland', 'land'),
#  ('furuflis', 'is'),
#  ('mor', 'kirkekor'),
#  ('forslår', 'står'),
#  ('dyreham', 'kam'),
#  ('vadested', 'sved'),
#  ('austenvær', 'aftenskjær'),
#  ('kre', 'frelsesarmé'),
#  ('evighetsdag', 'nag'),
#  ('plartå', 'platå'),
#  ('høysommerdag', 'brag'),
#  ('endevendt', 'vendt'),
#  ('der', 'dødningklær'),
#  ('mår', 'når'),
#  ('vuggemei', 'hei'),
#  ('beherskero', 'forstod'),
#  ('alfarveg', 'jeg'),
#  ('tann', 'perlerand'),
#  ('pokaler', 'vandaler'),
#  ('svor', 'beror'),
#  ('underlagt', 'forutsagt'),
#  ('vrå', 'må'),
#  ('drag', 'frelsesdag'),
#  ('gudinne', 'ingensinne'),
#  ('jag', 'frelsesdag'),
#  ('geni', 'si'),
#  ('gleder', 'trønder-heder'),
#  ('ørkensand', 'marøyesand'),
#  ('de', 'fril'),
#  ('fjed', 'frelsesarmé'),
#  ('lavet', 'gravet'),
#  ('planker', 'banker'),
#  ('ferde', 'gudelære'),
#  ('snar', 'fotefar'),
#  ('spinne', 'vinde'),
#  ('forsann', 'Gondwanaland'),
#  ('beskjed', 'derved'),
#  ('la', 'a'),
#  ('binne', 'inne'),
#  ('ti', 'fri'),
#  ('tente', 'skjendte'),
#  ('år', 'slår'),
#  ('Cannes', 'an'),
#  ('hård', 'forestår'),
#  ('tilsist', 'pist'),
#  ('bølgehære', 'gudelære'),
#  ('ørkensand', 'forstand'),
#  ('imøde', 'dåreføde'),
#  ('blender', 'hender'),
#  ('murstensgrav', 'derav'),
#  ('enhver', 'sær'),
#  ('åpenbar', 'skar'),
#  ('kjempehær', 'klær'),
#  ('flor', 'bestemor'),
#  ('fra', 'bedra'),
#  ('kre', 'arnested'),
#  ('vrak', 'brak'),
#  ('sken', 'ben'),
#  ('snei', 'jordbærhei'),
#  ('landliggedag', 'søndenvindsdrag'),
#  ('øde', 'dyreføde'),
#  ('pokaler', 'galer'),
#  ('lav', 'trav'),
#  ('hjertekrå', 'skrå'),
#  ('folkeleikskjeder', 'forræder'),
#  ('ja', 'hurra'),
#  ('smed', 'frelsesarmé'),
#  ('bero', 'overflod'),
#  ('bror', 'kongestor'),
#  ('to', 'mod'),
#  ('undertiden', 'vår-flom-tiden'),
#  ('stod', 'glo'),
#  ('pakt', 'guddomsmakt'),
#  ('fuglefjell', 'Israel'),
#  ('vandaler', 'saler'),
#  ('geled', 'sted'),
#  ('tyrann', 'iland'),
#  ('hvor', 'ildstråleflor'),
#  ('veld', 'kildevell'),
#  ('ed', 'ned'),
#  ('toneveld', 'perlemorsskjell'),
#  ('debatter', 'forfatter'),
#  ('fjed', 'arnested'),
#  ('kafé', 'kjed'),
#  ('munne', 'kunne'),
#  ('skjell', 'kveld'),
#  ('ikveld', 'fjeld'),
#  ('kafé', 'kafe'),
#  ('gjeld', 'Fortell'),
#  ('Krist', 'kvist'),
#  ('rakt', 'kongemakt'),
#  ('himmelbro', 'glo'),
#  ('der', 'vær'),
#  ('guddomsmakt', 'kongemakt'),
#  ('varselsord', 'for'),
#  ('Totakvann', 'ørkenland'),
#  ('prest', 'gjest'),
#  ('rett', 'sett'),
#  ('frelsesarmé', 'ved'),
#  ('bale', 'befale'),
#  ('sand', 'Wergeland'),
#  ('plett', 'tretaburett'),
#  ('begjær', 'rær'),
#  ('kjempehær', 'sær'),
#  ('fremmedland', 'vinterland'),
#  ('smed', 'arnested'),
#  ('sprell', 'Desemberkveld'),
#  ('hyttevrå', 'skjå'),
#  ('englevakt', 'sjakt'),
#  ('nordlys-prakt', 'underlagt'),
#  ('vinterhi', 'vi'),
#  ('igår', 'når'),
#  ('gleder', 'treder'),
#  ('sken', 'suveren'),
#  ('hotell', 'sæl'),
#  ('forsvinne', 'trellebinde'),
#  ('fjelebod', 'mod'),
#  ('beskytte', 'stråtakhytte'),
#  ('et', 'spredt'),
#  ('ørkenland', 'redningsmann'),
#  ('frender', 'menneskehender'),
#  ('ombord', 'Tor'),
#  ('fortell', 'Teruel'),
#  ('solskinsdag', 'evighetsdag'),
#  ('nær', 'Enhver'),
#  ('ror', 'glor'),
#  ('land', 'iland'),
#  ('tak', 'smak'),
#  ('vinter-sne', 'beskjed'),
#  ('stråleflom', 'helligdom'),
#  ('kor', 'dernord'),
#  ('mord', 'ifjor'),
#  ('sæd', 'stred'),
#  ('forårsfest', 'gjest'),
#  ('se', 'kjærlighed'),
#  ('med', 'herved'),
#  ('knea', 'Nicaragua'),
#  ('forgå', 'formå'),
#  ('himmelsaler', 'taler'),
#  ('gjeld', 'strålevell'),
#  ('inne', 'spinne'),
#  ('tvinne', 'hinne'),
#  ('geled', 'spe'),
#  ('sjelerot', 'mot'),
#  ('sæl', 'vell'),
#  ('sag', 'lerkeslag'),
#  ('bord', 'hedningjord'),
#  ('strever', 'hever'),
#  ('munke-tro', 'gro'),
#  ('strålefjed', 'stred'),
#  ('spær', 'fjær'),
#  ('sed', 'sved'),
#  ('ljå', 'hyttevrå'),
#  ('bære', 'skjære'),
#  ('julekveld', 'hell'),
#  ('slett', 'spredt'),
#  ('gå', 'slå'),
#  ('ei', 'snei'),
#  ('för', 'overbord'),
#  ('bod', 'mod'),
#  ('jente', 'brente'),
#  ('fro', 'stod'),
#  ('moder-bryst', 'kyst'),
#  ('stråleveld', 'Israel'),
#  ('skyttergrav', 'krav'),
#  ('endevendt', 'fryktbespent'),
#  ('lest', 'protest'),
#  ('rabatter', 'fatter'),
#  ('strand', 'perlerand'),
#  ('snei', 'grei'),
#  ('Nudetre', 'bibelsted'),
#  ('mjød', 'død'),
#  ('glor', 'dernord'),
#  ('sommerfest', 'best'),
#  ('redningsmann', 'tinderand'),
#  ('be', 'varieté'),
#  ('moderskjød', 'glød'),
#  ('trilleslag', 'hyttetak'),
#  ('Eginafjord', 'fuglekor'),
#  ('rebell', 'trell'),
#  ('forstå', 'klippekrå'),
#  ('synderinne', 'binde'),
#  ('inne', 'tvinne'),
#  ('skred', 'strålefjed'),
#  ('trær', 'irisskjær'),
#  ('sa', 'gla'),
#  ('portaler', 'daler'),
#  ('bag', 'dag'),
#  ('evighetsro', 'sno'),
#  ('ødeland', 'vann'),
#  ('fjelebod', 'mo'),
#  ('marmordrakt', 'tryllemakt'),
#  ('gnist', 'harsellist'),
#  ('herlighet', 'hemlighet'),
#  ('Nord', 'bebor'),
#  ('grav', 'trav'),
#  ('vidunder', 'under'),
#  ('nordvest', 'protest'),
#  ('gruer', 'tuer'),
#  ('svor', 'dernord'),
#  ('skaper-makt', 'slakt'),
#  ('med', 'skred'),
#  ('Gondwanaland', 'tidevann'),
#  ('symfoni', 'tidlig'),
#  ('stød', 'skjød'),
#  ('kildested', 'le'),
#  ('stundet', 'spunnet'),
#  ('vrå', 'attrå'),
#  ('besnære', 'norskhetslære'),
#  ('lerkeslag', 'lag'),
#  ('der', 'tver'),
#  ('står', 'gård'),
#  ('bru', 'ihu'),
#  ('alvorsdyst', 'bryst'),
#  ('edelsten', 'én'),
#  ('forstå', 'istå'),
#  ('silhouett', 'ætt'),
#  ('fremtidssti', 'bli'),
#  ('bi', 'stri'),
#  ('overmakt', 'lagt'),
#  ('svakt', 'dødningdrakt'),
#  ('bor', 'mord'),
#  ('synderinne', 'ingensinne'),
#  ('kre', 'fred'),
#  ('avgrunnsbro', 'no'),
#  ('klo', 'jo'),
#  ('skatte', 'matte'),
#  ('belyst', 'ametyst'),
#  ('toneveld', 'lell'),
#  ('juletre', 'se'),
#  ('bann', 'Gondwanaland'),
#  ('brød', 'skjød'),
#  ('radiotrakt', 'ringeakt'),
#  ('led', 'se'),
#  ('lytte', 'nytte'),
#  ('husbondsvett', 'folkevett'),
#  ('sovekupé', 'ned'),
#  ('tyranni', 'bølgeaktig'),
#  ('mord', 'glor'),
#  ('skapermann', 'likedan'),
#  ('platå', 'små'),
#  ('melodi', 'li'),
#  ('an', 'grand'),
#  ('nå', 'blaå'),
#  ('hedersmann', 'Gondwanaland'),
#  ('Lie', 'trylleri'),
#  ('nid', 'splid'),
#  ('ror', 'spor'),
#  ('været', 'Kariskjæret'),
#  ('avgrunnsbro', 'blod'),
#  ('sist', 'forvisst'),
#  ('kafe', 'be'),
#  ('offersted', 'le'),
#  ('forslår', 'hjertesår'),
#  ('gå', 'små'),
#  ('fosforskjær', 'spær'),
#  ('fjed', 'fred'),
#  ('prakt', 'slakt'),
#  ('legedom', 'som'),
#  ('tinde', 'derinne'),
#  ('tvist', 'elskovslist'),
#  ('formår', 'gård'),
#  ('foregiår', 'sanger-vår'),
#  ('ormegrav', 'kongestav'),
#  ('stor', 'stråleflor'),
#  ('ødegård', 'spår'),
#  ('fjelebod', 'forstod'),
#  ('skår', 'potteskår'),
#  ('bestandighet', 'barmhjertighet'),
#  ('trengselskår', 'forstår'),
#  ('rullesten', 'suveréen'),
#  ('skapermann', 'vandringsmann'),
#  ('hjerte', 'nærte'),
#  ('kølleslag', 'åndedrag'),
#  ('strand', 'iland'),
#  ('deg', 'hei'),
#  ('plartå', 'hunger-grå'),
#  ('avste', 'varieté'),
#  ('hav', 'bokstav'),
#  ('bøde', 'bløde'),
#  ('brent', 'dødssakrament'),
#  ('edelsten', 'sen'),
#  ('smed', 'fred'),
#  ('nå', 'bestå'),
#  ('skytte', 'nytte'),
#  ('bølgegrav', 'støttestav'),
#  ('ned', 'avste'),
#  ('ned', 'moské'),
#  ('husvale', 'idealet'),
#  ('enn', 'derhen'),
#  ('sær', 'rær'),
#  ('forbi', 'bli'),
#  ('det', 'vadested'),
#  ('minnet', 'binne'),
#  ('slo', 'mod'),
#  ('melodi', 'arbeidsbi'),
#  ('sprell', 'kildevell'),
#  ('pokaler', 'befaler'),
#  ('hvilested', 'derved'),
#  ('åndehære', 'Staats-affære'),
#  ('åndehære', 'besnære'),
#  ('trengselskår', 'sår'),
#  ('marmordrakt', 'rakt'),
#  ('frelsesarmé', 'bibelsted'),
#  ('moderhjerte', 'lærte'),
#  ('akt', 'ammevakt'),
#  ('Sillejord', 'mord'),
#  ('kan', 'Kinamann'),
#  ('hører', 'kulører'),
#  ('tilhest', 'sydvest'),
#  ('deri', 'sympati'),
#  ('Co.', 'kristenblod'),
#  ('illgjerningsmann', 'Wergeland'),
#  ('der', 'nær'),
#  ('tinderand', 'Wergeland'),
#  ('sjel', 'gjel'),
#  ('Hell', 'vell'),
#  ('tann', 'stjerneland'),
#  ('austenvær', 'lillaskjær'),
#  ('sommer', 'tommer'),
#  ('sommerkveld', 'saltarell'),
#  ('blomsterbed', 'ved'),
#  ('geled', 'bre'),
#  ('slå', 'på'),
#  ('kravet', 'havet'),
#  ('gnist', 'pist'),
#  ('hva', 'Nicaragua'),
#  ('landet', 'forbannet'),
#  ('begavet', 'kravet'),
#  ('opstandelse', 'varieté'),
#  ('stø', 'mø'),
#  ('landliggedag', 'høysommerdag'),
#  ('bli', 'gi'),
#  ('brand', 'Kinamann'),
#  ('rosenskjær', 'blomstertrær'),
#  ('lære', 'gudelære'),
#  ('rot', 'sot'),
#  ('frelser-mann', 'kan'),
#  ('harsellist', 'kvist'),
#  ('må', 'slå'),
#  ('derpå', 'strå'),
#  ('kafé', 'bed'),
#  ('tyribrann', 'grand'),
#  ('kjente', 'skjendte'),
#  ('sommerkveld', 'karusell'),
#  ('kassevis', 'is'),
#  ('sti', 'kogleri'),
#  ('Jesabell', 'vel'),
#  ('slo', 'mo'),
#  ('skaper-makt', 'menneskedrakt'),
#  ('trøst', 'øst'),
#  ('slag', 'dag'),
#  ('gådemakt', 'ringeakt'),
#  ('geled', 'vred'),
#  ('forgå', 'lå'),
#  ('kjøpmannsferd', 'morgenskjær'),
#  ('fiskerlag', 'bedrag'),
#  ('kre', 'avste'),
#  ('kre', 'moské'),
#  ('bord', 'kirkekor'),
#  ('løvsalstrær', 'dødningklær'),
#  ('barmhjertighet', 'profet'),
#  ('treder', 'heder'),
#  ('de', 'energi'),
#  ('an', 'Sand'),
#  ('rosenskjær', 'rær'),
#  ('Kariskjæret', 'gjerdet'),
#  ('hjertesår', 'ødegård'),
#  ('datter', 'barne-latter'),
#  ('få', 'strå'),
#  ('energi', 'gi'),
#  ('fedrenehu', 'sous'),
#  ('enhver', 'Enhver'),
#  ('skinnet', 'svinne'),
#  ('fugleskrik', 'slik'),
#  ('fjed', 'avste'),
#  ('fjed', 'moské'),
#  ('vinterhi', 'bi'),
#  ('kongemakt', 'prestedrakt'),
#  ('tyranni', 'melodi'),
#  ('kjær', 'flammeskjær'),
#  ('solskinsdag', 'brag'),
#  ('bedra', 'knea'),
#  ('smertesdrag', 'lerkeslag'),
#  ('kjær', 'ospetrær'),
#  ('kirkekor', 'ildstråleflor'),
#  ('banesår', 'skår'),
#  ('bru', 'nu'),
#  ('prakt', 'menneskedrakt'),
#  ('sjelesår', 'hård'),
#  ('sjø', 'stø'),
#  ('fedreland', 'stjerneland'),
#  ('kirketag', 'dag'),
#  ('fiskermann', 'stand'),
#  ('skrå', 'så'),
#  ('våren', 'båren'),
#  ('kildevell', 'trell'),
#  ('smell', 'fortell'),
#  ('forstå', 'aldersgrå'),
#  ('ørkenland', 'brann'),
#  ('rognekjæret', 'lære'),
#  ('snar', 'svar'),
#  ('slave', 'verdenshave'),
#  ('blek', 'lek'),
#  ('platå', 'grå'),
#  ('regnbu-bro', 'to'),
#  ('bunnen', 'forsvunnen'),
#  ('smed', 'avste'),
#  ('smed', 'moské'),
#  ('slo', 'forstod'),
#  ('skjær', 'dødningklær'),
#  ('let', 'minarett'),
#  ('istå', 'platå'),
#  ('armé', 'kne'),
#  ('Sand', 'tann'),
#  ('skjær', 'hær'),
#  ('Jesabell', 'hotell'),
#  ('gå', 'grå'),
#  ('sjungekor', 'bord'),
#  ('motormann', 'fedreland'),
#  ('ikveld', 'vinterkveld'),
#  ('sjelesår', 'forestår'),
#  ('svakt', 'lagt'),
#  ('skjød', 'bød'),
#  ('veg', 'hei'),
#  ('ormegrav', 'nav'),
#  ('Cannes', 'fremmedland'),
#  ('dale', 'bale'),
#  ('fro', 'lo'),
#  ('stav', 'bokstav'),
#  ('løvsalstrær', 'vær'),
#  ('visst', 'gnist'),
#  ('sagt', 'bragt'),
#  ('karusell', 'vel'),
#  ('Se', 'ved'),
#  ('vandringsmann', 'tidevann'),
#  ('hjertesår', 'murstensgård'),
#  ('slavekår', 'hård'),
#  ('blest', 'rest'),
#  ('berøre', 'døre'),
#  ('rebell', 'pastell'),
#  ('skjell', 'sommerkveld'),
#  ('avet', 'begravet'),
#  ('skyteskår', 'forsmår'),
#  ('bergeli', 'si'),
#  ('forbi', 'nattelosji'),
#  ('kjell', 'fjell'),
#  ('forslår', 'banesår'),
#  ('Ambarvalia', 'ta'),
#  ('avsted', 'fortred'),
#  ('især', 'skjær'),
#  ('krav', 'gråstensgrav'),
#  ('flo', 'no'),
#  ('skapermann', 'kan'),
#  ('fjord', 'ifjor'),
#  ('solskinns-dag', 'ansiktsdrag'),
#  ('kjed', 'se'),
#  ('taler', 'portaler'),
#  ('nag', 'tordenslag'),
#  ('Nordvest', 'tilhest'),
#  ('korstog-ren', 'Aten'),
#  ('sunde', 'vunde'),
#  ('brett', 'vett'),
#  ('fiskermann', 'brand'),
#  ('flo', 'blod'),
#  ('besværet', 'næret'),
#  ('kunde', 'runde'),
#  ('bero', 'mod'),
#  ('du', 'nu'),
#  ('fedreland', 'stand'),
#  ('gale', 'dvale'),
#  ('trønder-heder', 'kjeder'),
#  ('Co.', 'bro'),
#  ('østenvindskveld', 'sæl'),
#  ('landliggedag', 'åndedrag'),
#  ('kongestav', 'trav'),
#  ('tinde', 'besinne'),
#  ('fiskevann', 'iland'),
#  ('sagt', 'guddomsmakt'),
#  ('vinter-sne', 'bibelsted'),
#  ('skatte', 'skratte'),
#  ('sanger-vei', 'kirke-vei'),
#  ('det', 'sed'),
#  ('offersted', 'herned'),
#  ('bi', 'fril'),
#  ('tyrann', 'fiskermann'),
#  ('slavekår', 'forestår'),
#  ('sår', 'skyteskår'),
#  ('nordlys-prakt', 'herskermakt'),
#  ('med', 'vinter-sne'),
#  ('beredt', 'vett'),
#  ('nett', 'regnebrett'),
#  ('hender', 'spenner'),
#  ('hor', 'hernord'),
#  ('gløde', 'imøde'),
#  ('står', 'sanger-vår'),
#  ('forstand', 'Kinamann'),
#  ('sæl', 'perlemorsskjell'),
#  ('tvist', 'bjørkekvist'),
#  ('hotell', 'saltarell'),
#  ('istå', 'Å'),
#  ('spann', 'Helgeland'),
#  ('kravet', 'gravet'),
#  ('rakt', 'sjakt'),
#  ('sommerkveld', 'Fortell'),
#  ('deri', 'raseri'),
#  ('oppstandelsesskjær', 'ospetrær'),
#  ('hår', 'slår'),
#  ('nett', 'husbondsvett'),
#  ('tiggerkår', 'muregård'),
#  ('kjøpmannsferd', 'austenvær'),
#  ('have', 'trave'),
#  ('forgår', 'hår'),
#  ('Nudetre', 'kre'),
#  ('fril', 'gi'),
#  ('vane-gjengeri', 'vis-à-vis'),
#  ('gudinne', 'trellebinde'),
#  ('står', 'banesår'),
#  ('sendt', 'brent'),
#  ('fiskerlag', 'bag'),
#  ('med', 'opstandelse'),
#  ('gled', 'se'),
#  ('klokkeslett', 'trett'),
#  ('kor', 'mor'),
#  ('ed', 'skred'),
#  ('kan', 'fiskevann'),
#  ('hurra', 'Nicaragua'),
#  ('skapermann', 'ørkensand'),
#  ('frydeskrik', 'rik'),
#  ('rad', 'vidunderbad'),
#  ('kjent', 'skrent'),
#  ('pastell', 'vel'),
#  ('se', 'bered'),
#  ('sæd', 'ved'),
#  ('overflod', 'no'),
#  ('forløst', 'Røst'),
#  ('flak', 'kvak'),
#  ('kave', 'grave'),
#  ('binde', 'Slinde'),
#  ('stave', 'lave'),
#  ('bragt', 'tilbakelagt'),
#  ('arbeidsfred', 'fortred'),
#  ('hell', 'smell'),
#  ('kafe', 'kne'),
#  ('tamme', 'samme'),
#  ('stand', 'Kinamann'),
#  ('ferde', 'hære'),
#  ('moment', 'betendt'),
#  ('bero', 'mo'),
#  ('kjerte', 'lærte'),
#  ('kvinnelist', 'kommunist'),
#  ('fedreland', 'brand'),
#  ('eierett', 'slett'),
#  ('tjene', 'formene'),
#  ('omsider', 'lider'),
#  ('strålefjed', 'ved'),
#  ('ørkensand', 'Gondwanaland'),
#  ('forslår', 'vår'),
#  ('løvsalstrær', 'tver'),
#  ('munke-tro', 'sjelebod'),
#  ('trå', 'rå'),
#  ('overflod', 'blod'),
#  ('være', 'skjæret'),
#  ('formår', 'banesår'),
#  ('bølgehære', 'hære'),
#  ('nordlys-prakt', 'kontrakt'),
#  ('tyrann', 'fedreland'),
#  ('gledesfest', 'rest'),
#  ('varselsord', 'beror'),
#  ('sommerkveld', 'strålevell'),
#  ('ni', 'de'),
#  ('tro', 'jo'),
#  ('luer', 'duer'),
#  ('kvinnelist', 'Jovisst'),
#  ('her', 'klær'),
#  ('herskerinne', 'Slinde'),
#  ('bre', 'derved'),
#  ('hovedstad', 'vidunderbad'),
#  ('kommando-ord', 'beror'),
#  ('avgrunnsbro', 'sko'),
#  ('lær', 'besvær'),
#  ('hernord', 'snor'),
#  ('kor', 'ord'),
#  ('tsar', 'snar'),
#  ('avgrunnsbro', 'adelsblod'),
#  ('trengselskår', 'rår'),
#  ('have', 'brave'),
#  ('jakt', 'slakt'),
#  ('rår', 'forestår'),
#  ('trilleslag', 'kvak'),
#  ('Totakvann', 'tyribrann'),
#  ('endevendt', 'dødssakrament'),
#  ('hvileplett', 'vett'),
#  ('blomstertrær', 'begjær'),
#  ('dyst', 'lyst'),
#  ('klo', 'bod'),
#  ('se', 'sped'),
#  ('blomstertrær', 'hver'),
#  ('svor', 'mor'),
#  ('rik', 'fugleskrik'),
#  ('hundeglam', 'stram'),
#  ('bris', 'paradis'),
#  ('sjungekor', 'bebor'),
#  ('bedrag', 'hjertelag'),
#  ('rosenskjær', 'skjær'),
#  ('Å', 'skjå'),
#  ('gudinne', 'herinne'),
#  ('tro', 'flo'),
#  ('Cannes', 'Johan'),
#  ('beder', 'spreder'),
#  ('mord', 'kongestor'),
#  ('svever', 'lever'),
#  ('bibelsted', 'avste'),
#  ('bibelsted', 'moské'),
#  ('tom', 'bom'),
#  ('tiggerkår', 'år'),
#  ('vane-gjengeri', 'litani'),
#  ('skjær', 'tver'),
#  ('spann', 'ørkenland'),
#  ('tar', 'glar'),
#  ('skjønnhetsdrakt', 'frakt'),
#  ('fram', 'slam'),
#  ('sken', 'sten'),
#  ('fryktbespent', 'hendt'),
#  ('land', 'fedreland'),
#  ('innunder', 'stunder'),
#  ('rører', 'slører'),
#  ('grunder', 'blunder'),
#  ('kveld', 'Desemberkveld'),
#  ('må', 'grå'),
#  ('bero', 'forstod'),
#  ('fest', 'rest'),
#  ('her', 'sær'),
#  ('solskinsdag', 'ansiktsdrag'),
#  ('forestår', 'muregård'),
#  ('sti', 'tyranni'),
#  ('blomsterbed', 'fred'),
#  ('fjell', 'Fortell'),
#  ('ikveld', 'Israel'),
#  ('bed', 'kjærlighed'),
#  ('fjær', 'ospetrær'),
#  ('landliggedag', 'brag'),
#  ('gruer', 'gravgårds-tuer'),
#  ('endt', 'fryktbespent'),
#  ('kjent', 'Sorrent'),
#  ('blunde', 'grunne'),
#  ('vred', 'vadested'),
#  ('vett', 'tett'),
#  ('gå', 'å'),
#  ('för', 'blomsterflor'),
#  ('kom', 'helligdom'),
#  ('kave', 'lave'),
#  ('beskjed', 'sved'),
#  ('sæl', 'lell'),
#  ('irisskjær', 'solgangsvær'),
#  ('ve', 'herved'),
#  ('allikevel', 'bagatell'),
#  ('Se', 'bibelsted'),
#  ('skor', 'kommando-ord'),
#  ('belagt', 'strakt'),
#  ('ære', 'skjære'),
#  ('vest', 'mest'),
#  ('kafé', 'beskjed'),
#  ('nord', 'jord'),
#  ('dale', 'tale'),
#  ('skjønnhetsdrakt', 'tryllemakt'),
#  ('kafé', 'blomsterbed'),
#  ('løvsalstrær', 'nær'),
#  ('år', 'potteskår'),
#  ('vel', 'Desemberkveld'),
#  ('foreslår', 'spår'),
#  ('kildested', 'strålefjed'),
#  ('fram', 'hundeglam'),
#  ('bakt', 'prestedrakt'),
#  ('Hell', 'perlemorsskjell'),
#  ('juletre', 'varieté'),
#  ('motormann', 'grand'),
#  ('avsted', 'gled'),
#  ('skjel', 'trell'),
#  ('led', 'varieté'),
#  ('strand', 'fiskermann'),
#  ('Sand', 'vinterland'),
#  ('snar', 'kar'),
#  ('brenner', 'rovdyrtenner'),
#  ('Johan', 'rand'),
#  ('farvel', 'stell'),
#  ('istå', 'hunger-grå'),
#  ('bord', 'bestemor'),
#  ('fjeld', 'kveld'),
#  ('gli', 'symfoni'),
#  ('synderinne', 'måneskinnet'),
#  ('slave', 'gudegave'),
#  ('prest', 'forårsfest'),
#  ('evighetsdag', 'folkeslag'),
#  ('sovekupé', 'skred'),
#  ('sfære', 'skjære'),
#  ('åpenbar', 'underbar'),
#  ('fjell', 'strålevell'),
#  ('englevakt', 'ringeakt'),
#  ('hotell', 'Fortell'),
#  ('trist', 'brist'),
#  ('bris', 'gnis'),
#  ('banesår', 'gård'),
#  ('hører', 'fører'),
#  ('fosforskjær', 'rær'),
#  ('fra', 'ta'),
#  ('ingenlunde', 'munne'),
#  ('vrå', 'bittesmå'),
#  ('forgår', 'foreslår'),
#  ('skaper-makt', 'trakt'),
#  ('forstår', 'slår'),
#  ('platå', 'antennetråd'),
#  ('ihu', 'fedrenehu'),
#  ('tro', 'overflod'),
#  ('minnet', 'herskerinne'),
#  ('trave', 'brave'),
#  ('glider', 'kvider'),
#  ('jag', 'folkeslag'),
#  ('gå', 'antennetråd'),
#  ('folkeleikskjeder', 'reder'),
#  ('fremmedland', 'eiermann'),
#  ('alfarveg', 'lei'),
#  ('perlerand', 'forstand'),
#  ('husbondsvett', 'tett'),
#  ('Cannes', 'ørkenland'),
#  ('morgenskjær', 'især'),
#  ('sted', 'frelsesarmé'),
#  ('omsider', 'rider'),
#  ...}

# %%
pairs_
# Out:
# {('stillehavspassat', 'satt'),
#  ('stjerneblått', 'blott'),
#  ('manne-fall', 'tempelhall'),
#  ('store', 'roret'),
#  ('fare', 'mare'),
#  ('vin', 'sin'),
#  ('ring', 'Ting'),
#  ('tynt', 'skillemynt'),
#  ('skinn', 'grind'),
#  ('kvede', 'brede'),
#  ('vinge', 'springe'),
#  ('liljebånd', 'ånd'),
#  ('godt', 'gått'),
#  ('trykker', 'nykker'),
#  ('tåkeluft', 'duft'),
#  ('herskerstol', 'Hol'),
#  ('morgen-røden', 'grøden'),
#  ('vold', 'avindsskjold'),
#  ('kingelvevet', 'bevet'),
#  ('teller', 'kvelder'),
#  ('aftenrøden', 'hungersnøden'),
#  ('borg', 'kongeborg'),
#  ('traff', 'blaff'),
#  ('året', 'dåret'),
#  ('solgangsild', 'till'),
#  ('drømmen', 'himmeldrømmen'),
#  ('sende', 'overende'),
#  ('ditinn', 'marsaftenvind'),
#  ('dravat', 'soldat'),
#  ('politikk', 'fabrikk'),
#  ('sunn', 'stund'),
#  ('flyr', 'knyr'),
#  ('vestenvind', 'marsaftenvind'),
#  ('flammer', 'prammer'),
#  ('lytter', 'hytter'),
#  ('hedningeby', 'ly'),
#  ('kinner', 'pinner'),
#  ('profitt', 'mareritt'),
#  ('randen', 'stranden'),
#  ('bevare', 'broderskare'),
#  ('hjernespinn', 'sinn'),
#  ('hvin', 'eventyr-sinn'),
#  ('møye', 'møye.'),
#  ('vil', 'fargespill'),
#  ('lammer', 'kammer'),
#  ('kvikke', 'strikke'),
#  ('alfesang', 'milelang'),
#  ('sundt', 'glunt'),
#  ('Hans', 'stråleglans'),
#  ('Staupersund', 'barne-munn'),
#  ('fortøye', 'bøyet'),
#  ('seildugshammer', 'hammer'),
#  ('lokomotiv', 'pakkbodliv'),
#  ('frekk', 'skrekk'),
#  ('ordet', 'spore'),
#  ('flat', 'mat'),
#  ('klippegrunn', 'tanke-grunn'),
#  ('Evighøye', 'bøye'),
#  ('bacchanal', 'kanal'),
#  ('skader', 'rader'),
#  ('gategutt', 'slutt'),
#  ('fødeegn', 'rein'),
#  ('rygge', 'hygge'),
#  ('apespill', 'sommermild'),
#  ('myr', 'skyr'),
#  ('stillehavspassat', 'stat'),
#  ('svinge', 'ringe'),
#  ('baste', 'faste'),
#  ('prenter', 'renter'),
#  ('menneskehjem', 'strålebrem'),
#  ('ler', 'ber'),
#  ('løs', 'røs'),
#  ('henne', 'ende'),
#  ('prester', 'fester'),
#  ('vrimlen', 'storbyvrimlen'),
#  ('admiral-fregatt', 'fregatt'),
#  ('finn', 'trinn'),
#  ('stjernegry', 'tordensky'),
#  ('vind', 'pålandsvind'),
#  ('ratt', 'fatt'),
#  ('tilkjenne', 'tenne'),
#  ('sner', 'skjer'),
#  ('stakler', 'mirakler'),
#  ('fnokk', 'dvergeflokk'),
#  ('stille', 'milde'),
#  ('skritt', 'sitt'),
#  ('seilet', 'feile'),
#  ('søndenvind', 'syrin'),
#  ('fang', 'blomstervang'),
#  ('fullende', 'derhenne'),
#  ('vare', 'svare'),
#  ('blomstergrener', 'grener'),
#  ('rang', 'alfesang'),
#  ('hinder', 'vinner'),
#  ('lukt', 'bukt'),
#  ('danser', 'panser'),
#  ('arm', 'barm'),
#  ('din', 'kinn'),
#  ('dette', 'slette'),
#  ('glør', 'dør'),
#  ('klokkeklang', 'gang'),
#  ('slang', 'jubelsang'),
#  ('løyhet', 'høyhet'),
#  ('Bliv', 'bliv'),
#  ('silde', 'bryllupsgilde'),
#  ('kold', 'hedenold'),
#  ('merkestang', 'trang'),
#  ('kongehaller', 'raller'),
#  ('minister', 'frihetsrigorister'),
#  ('tiltross', 'tross'),
#  ('ofte', 'hofte'),
#  ('drømte', 'fordømte'),
#  ('gjemme', 'stemme'),
#  ('strandblomststjerner', 'lanterner'),
#  ('bestemt', 'klokkeklemt'),
#  ('fargesans', 'glans'),
#  ('jager', 'oldingplager'),
#  ('gåte', 'våte'),
#  ('alfesang', 'strengeklang'),
#  ('finnes', 'bindes'),
#  ('lenket', 'benket'),
#  ('embedsskrud', 'seiersbud'),
#  ('fuglekiv', 'kniv'),
#  ('båret', 'låret'),
#  ('kall', 'manne-fall'),
#  ('ørkenild', 'fil'),
#  ('dal', 'pastoral'),
#  ('menneskedyr', 'dyr'),
#  ('istykker', 'trykker'),
#  ('bringer', 'tvinger'),
#  ('knyr', 'menneskedyr'),
#  ('varmen-', 'barmen'),
#  ('profeten', 'tidstrompeten'),
#  ('spy', 'ny'),
#  ('fliker', 'slike'),
#  ('meldt', 'telt'),
#  ('slang', 'kjøkkengang'),
#  ('midt', 'mitt'),
#  ('høvdingånd', 'ånd'),
#  ('bølgekammer', 'kammer'),
#  ('våbengny', 'vikingery'),
#  ('offerdyr', 'dyr'),
#  ('redningsverk', 'verk'),
#  ('argumenter', 'pergamenter'),
#  ('tvende', 'blende'),
#  ('Storedragen', 'dragen'),
#  ('kilder', 'skiller'),
#  ('bark', 'hark'),
#  ('matt', 'kratt'),
#  ('dregg', 'klegg'),
#  ('rase', 'grimase'),
#  ('øye', 'øyet'),
#  ('gudeslott', 'skafott'),
#  ('drønn', 'brønn'),
#  ('drevet', 'sønderrevet'),
#  ('dertil', 'morraspill'),
#  ('strandblomststjerner', 'tærner'),
#  ('måneskinn', 'skinn'),
#  ('pral', 'pastoral'),
#  ('verdensstat', 'godnatt'),
#  ('sølvsardin', 'kinn'),
#  ('tål', 'stål'),
#  ('himlen', 'storbyvrimlen'),
#  ('stille', 'ville'),
#  ('springer', 'finger'),
#  ('vill', 'spill'),
#  ('derinn', 'sølvsardin'),
#  ('klinger', 'finger'),
#  ('egnet', 'beregnet'),
#  ('gal', 'smal'),
#  ('folkelarm', 'larm'),
#  ('falt', 'talt'),
#  ('renkespill', 'til'),
#  ('drømmespinn', 'mandolin'),
#  ('hopp', 'granetopp'),
#  ('skrupler', 'kupler'),
#  ('fortøye', 'pløye'),
#  ('smil', 'ørkenild'),
#  ('folkeskarer', 'åpenbarer'),
#  ('slåss', 'tross'),
#  ('minutt', 'krutt'),
#  ('bier', 'stier'),
#  ('spott', 'fått'),
#  ('stropp', 'dvergfurutopp'),
#  ('forjaget', 'slaget'),
#  ('honning', 'dronning'),
#  ('kness', 'ness'),
#  ('ivare', 'broderskare'),
#  ('sprekk', 'strekk'),
#  ('alfesang', 'hang'),
#  ('dreng', 'heng'),
#  ('mystikk', 'leskedrikk'),
#  ('sal', 'signal'),
#  ('Sanktehans', 'Hans'),
#  ('øyet', 'døye'),
#  ('pryd', 'fryd'),
#  ('stutt', 'fut'),
#  ('Bull', 'kummerfull'),
#  ('tjelde', 'nelde'),
#  ('kue', 'stue'),
#  ('klem', 'ungdoms-hjem'),
#  ('fortjener', 'grener'),
#  ('levne', 'evne'),
#  ('faner', 'ahner'),
#  ('hosebånd', 'fonn'),
#  ('strengespill', 'sild'),
#  ('at', 'blomsterskatt'),
#  ('fjerner', 'kaserner'),
#  ('birke', 'virke'),
#  ('prikk', 'stikk'),
#  ('pike', 'minnerike'),
#  ('øm', 'blåtøyssøm'),
#  ('folkeskarer', 'erfarer'),
#  ('ruiner', 'latiner'),
#  ('rune', 'lune'),
#  ('apespill', 'pistil'),
#  ('stanse', 'bekranse'),
#  ('klage', 'behage'),
#  ('ritual', 'slottsportal'),
#  ('skjende', 'derhenne'),
#  ('aftenvind', 'arbeidervin'),
#  ('mil', 'spill'),
#  ('by', 'vikingery'),
#  ('odelsgrunn', 'pund'),
#  ('milevidt', 'titt'),
#  ('eier', 'feier'),
#  ('våken', 'tåken'),
#  ('salmen', 'halmen'),
#  ('verdensbetvinger', 'omringer'),
#  ('sund', 'fund'),
#  ('måneskinn', 'ørnesinn'),
#  ('vekt', 'centnervekt'),
#  ('granitt', 'fritt'),
#  ('seierssang', 'Rolland'),
#  ('fingerhatt', 'skratt'),
#  ('fossefallet', 'skalle'),
#  ('buser', 'huser'),
#  ('fortoner', 'millioner'),
#  ('freset', 'fjeset'),
#  ('mager', 'avskjedsklager'),
#  ('godt', 'yacht'),
#  ('stillhet', 'villhet'),
#  ('fyller', 'skyller'),
#  ('engang', 'sirenesang'),
#  ('fjorder', 'borer'),
#  ('jernbetong', 'fasong'),
#  ('flyr', 'bestyr'),
#  ('sommermild', 'klokkespill'),
#  ('seierssang', 'tang'),
#  ('skvetter', 'metter'),
#  ('kontur', 'klippemur'),
#  ('sus', 'ørnebrus'),
#  ('bacchanal', 'portal'),
#  ('fødeegn', 'hegn'),
#  ('kvarter', 'ber'),
#  ('klippestrimmel', 'vrimmel'),
#  ('Natt', 'godnatt'),
#  ('hvem', 'klem'),
#  ('pol', 'symbol'),
#  ('skapen', 'tapen'),
#  ('blomsterklynger', 'gynger'),
#  ('fang', 'bølgegang'),
#  ('betrygge', 'brygge'),
#  ('palmesving', 'spring'),
#  ('vang', 'bølgegang'),
#  ('navn', 'kongenavn'),
#  ('herskerstol', 'pol'),
#  ('Rolland', 'fang'),
#  ('sivet', 'verdenslivet'),
#  ('til', 'till'),
#  ('flammespill', 'fil'),
#  ('ryker', 'stryker'),
#  ('regnbueøy', 'fløy'),
#  ('sprenger', 'trenger'),
#  ('tømte', 'drømte'),
#  ('tromme', 'tomme'),
#  ('ditinn', 'trinn'),
#  ('standart', 'hardt'),
#  ("'s", 'solskinnsglans'),
#  ('nelde', 'elde'),
#  ('kry', 'tordensky'),
#  ('netter', 'besetter'),
#  ('Hans', 'santkehans'),
#  ('fem', 'strålebrem'),
#  ('flukt', 'lukt'),
#  ('lut', 'krutt'),
#  ('innesperre', 'herre'),
#  ('vold', 'fold'),
#  ('svang', 'rang'),
#  ('aner', 'maner'),
#  ('fly', 'morgengry'),
#  ('vindusglass', 'plass'),
#  ('fin', 'arbeidervin'),
#  ('avgrundsskinn', 'eventyr-sinn'),
#  ('kveger', 'totenslæger'),
#  ('idyll', 'jule-idyll'),
#  ('vill', 'mil'),
#  ('spør', 'sør'),
#  ('skarlagen', 'dragen'),
#  ('hviner', 'miner'),
#  ('jubelklang', 'sang'),
#  ('blund', 'hun'),
#  ('vang', 'folkerang'),
#  ('fangehull', 'muld'),
#  ('fryd', 'jubellyd'),
#  ('jeger', 'neger'),
#  ('jubelklang', 'blomstervang'),
#  ('blått', 'drømmeslott'),
#  ('tur', 'natur'),
#  ('sukke', 'opplukke'),
#  ('offerild', 'flammespill'),
#  ('underfull', 'full'),
#  ('skatt', 'verdensstat'),
#  ('mener', 'stener'),
#  ('Rolland', 'stang'),
#  ('natt', 'skatt'),
#  ('hjernespinn', 'finn'),
#  ('bunn', 'hjertegrunn'),
#  ('kanin', 'inn'),
#  ('il', 'april'),
#  ('vekk', 'strekk'),
#  ('kun', 'puddelhund'),
#  ('Henderson', 'hosebånd'),
#  ('gate', 'flate'),
#  ('lindrer', 'indre'),
#  ('ledebånd', 'helligånd'),
#  ('rigger', 'ligger'),
#  ('tyde', 'lyde'),
#  ('tegn', 'grein'),
#  ('hetter', 'fletter'),
#  ('hodet', 'sloet'),
#  ('hat', 'smatt'),
#  ('taket', 'flaket'),
#  ('tilkness', 'press'),
#  ('fugler', 'smuler'),
#  ('hvem', 'hjem'),
#  ('Franken', 'tanken'),
#  ('betatt', 'smatt'),
#  ('skatt', 'fatt'),
#  ('bølgesprut', 'fut'),
#  ('munning', 'runding'),
#  ('bodde', 'grodde'),
#  ('milevidt', 'kreditt'),
#  ('stjernegry', 'gny'),
#  ('kongeskrud', 'gud'),
#  ('fornøyet', 'nøye'),
#  ('mager', 'bedrager'),
#  ('måneskinn', 'sin'),
#  ('spant', 'tant'),
#  ('hjerner', 'kjerner'),
#  ('sekund', 'barne-munn'),
#  ('liten', 'viten'),
#  ('spare', 'forklare'),
#  ('stjerner', 'strandblomststjerner'),
#  ('tvende', 'derhenne'),
#  ('mager', 'jager'),
#  ('fuglekiv', 'bliv'),
#  ('hardt', 'snart'),
#  ('store', 'orde'),
#  ('stjernenetter', 'letter'),
#  ('mener', 'forener'),
#  ('driv', 'viv'),
#  ('karakter', 'ber'),
#  ('englevinger', 'finger'),
#  ('Hergisheim', 'eim'),
#  ('rive', 'give'),
#  ('fletter', 'letter'),
#  ('slavemoral', 'Baal'),
#  ('sjele', 'deler'),
#  ('grått', 'slått'),
#  ('aftenrøden', 'morgenrøden'),
#  ('opp', 'askeladd-tropp'),
#  ('lind', 'sølvsardin'),
#  ('sviller', 'griller'),
#  ('morgenstund', 'hjertegrunn'),
#  ('prat', 'fatt'),
#  ('tispen', 'gispen'),
#  ('gutt', 'brutt'),
#  ('forskutt', 'tilslutt'),
#  ('bestyr', 'fyr'),
#  ('jammer', 'flammer'),
#  ('offerild', 'fargespill'),
#  ('hvil', 'fil'),
#  ('Natt', 'fat'),
#  ('krus', 'lus'),
#  ('tonetrang', 'underklang'),
#  ('minner', 'kvinner'),
#  ('tretter', 'metter'),
#  ('sanden', 'oppstanden'),
#  ('anemoner', 'kroner'),
#  ('mitt', 'slitt'),
#  ('lamper', 'damper'),
#  ('stinn', 'solskinnsvind'),
#  ('betrådt', 'fyrsteslott'),
#  ('tiggerskare', 'smertensmare'),
#  ('myr', 'flyr'),
#  ('bandt', 'rant'),
#  ('helligånd', 'evighetsbånd'),
#  ('stekket', 'paddekvekket'),
#  ('binder', 'minner'),
#  ('glitret', 'sitret'),
#  ('trynet', 'brynet'),
#  ('smil', 'ild'),
#  ('frister', 'brister'),
#  ('slott', 'huldreslått'),
#  ('Ølversønn', 'Menneskesønn'),
#  ('ødt', 'søtt'),
#  ('muld', 'smilehull'),
#  ('kapiteler', 'blomstersjeler'),
#  ('krystall', 'bølgefall'),
#  ('gjorde', 'evighetsordet'),
#  ('offerlund', 'englemunn'),
#  ('amuletter', 'setter'),
#  ('Hans', 'stans'),
#  ('moder', 'broder'),
#  ('snekker', 'trekker'),
#  ('sving', 'ting'),
#  ('ratt', 'soldat'),
#  ('fuglekiv', 'stiv'),
#  ('kjempepolyp', 'kryp'),
#  ('rull', 'månegull'),
#  ('meier', 'veier'),
#  ('pund', 'blomstergrunn'),
#  ('kratt', 'bratt'),
#  ('sin', 'grind'),
#  ('klemt', 'slemt'),
#  ('gøyeblikk', 'drikk'),
#  ('kniv', 'stiv'),
#  ('søndenvind', 'sølvsardin'),
#  ('ørkenild', 'klokkespill'),
#  ('stut', 'Knut'),
#  ('smatt', 'godnatt'),
#  ('skinner', 'vinner'),
#  ('smått', 'forstått'),
#  ('knopp', 'furutopp'),
#  ('nemme', 'stemme'),
#  ('plater', 'attentater'),
#  ('gry', 'vintersky'),
#  ('revet', 'bevet'),
#  ('bier', 'lier'),
#  ('mester', 'fester'),
#  ('tanke-grunn', 'elvebunn'),
#  ('klokkeklang', 'tang'),
#  ('helvedånd', 'helligånd'),
#  ('renkespill', 'sild'),
#  ('lage', 'forårsdage'),
#  ('seierssang', 'trang'),
#  ('trøndersk-hedemarkisk', 'uinnskrenkt-monarkisk'),
#  ('kreves', 'leves'),
#  ('tatt', 'smatt'),
#  ('kiv', 'pakkbodliv'),
#  ('Storekult', 'fullt'),
#  ('flokk', 'nok'),
#  ('dømmesans', 'måneglans'),
#  ('sokneskare', 'mare'),
#  ('klang', 'sirenesang'),
#  ('omringer', 'finger'),
#  ('kleber', 'feber'),
#  ('binder', 'pinner'),
#  ('nært', 'kjært'),
#  ('jekt', 'centnervekt'),
#  ('rart', 'snart'),
#  ('sånn', 'blond'),
#  ('lang', 'engang'),
#  ('stillehavspassat', 'att'),
#  ('il', 'mild'),
#  ('fly', 'kry'),
#  ('funn', 'blomstergrunn'),
#  ('dertil', 'spill'),
#  ('kongeveier', 'veier'),
#  ('kring', 'ving'),
#  ('pike', 'vike'),
#  ('flukt', 'bukt'),
#  ('tørr', 'før'),
#  ('lokk', 'dvergeflokk'),
#  ('gjeste', 'feste'),
#  ('fortjener', 'stener'),
#  ('brenne', 'kanhende'),
#  ('mistet', 'listet'),
#  ('stanger', 'søyleganger'),
#  ('besvart', 'hardt'),
#  ('barneøye', 'bøyet'),
#  ('rang', 'klokkeklang'),
#  ('vene', 'pene'),
#  ('fosforkammer', 'lammer'),
#  ('trang', 'sirenesang'),
#  ('underfull', 'gull'),
#  ('brem', 'hvilehjem'),
#  ('silde', 'lille'),
#  ('fem', 'gjem'),
#  ('adelsbrev', 'strev'),
#  ('hal', 'bølgefall'),
#  ('fortelle', 'trelle'),
#  ('liljebånd', 'hand'),
#  ('plage', 'behage'),
#  ('tokter', 'dekokter'),
#  ('skrammer', 'prammer'),
#  ('gjører', 'forfører'),
#  ('hat', 'parat'),
#  ('himmelranden', 'selvannen'),
#  ('bringer', 'springer'),
#  ('oppsvinge', 'bringe'),
#  ('verre', 'herre'),
#  ('Knut', 'skutt'),
#  ('Hull', 'ull'),
#  ('folkestevnet', 'levnet'),
#  ('lang', 'betvang'),
#  ('svøpe', 'støpe'),
#  ('henrevet', 'svevet'),
#  ('avgrundsskinn', 'lampeskinn'),
#  ('trede', 'kjede'),
#  ('renholdsverk', 'frelserverk'),
#  ('hodeskalle', 'alle'),
#  ('violin', 'eventyr-sinn'),
#  ('skratt', 'mat'),
#  ('brott', 'betrådt'),
#  ('svin', 'måneskinn'),
#  ('riket', 'slike'),
#  ('gatesprekk', 'strekk'),
#  ('dem', 'klem'),
#  ('Ølversønn', 'tjønn'),
#  ('kun', 'ørkenbunn'),
#  ('lin', 'syrin'),
#  ('kry', 'gny'),
#  ('forneden', 'Eden'),
#  ('farer', 'sparer'),
#  ('stanger', 'folke-sanger'),
#  ('pakk', 'snakk'),
#  ('gater', 'hater'),
#  ('kjempe-sang', 'jubelsang'),
#  ('renner', 'synderinner'),
#  ('krans', 'bølgedans'),
#  ('stunden', 'folke-bunnen'),
#  ('iblandt', 'pant'),
#  ('gul', 'rickshawhjul'),
#  ('sol', 'Hol'),
#  ('stans', 'blomsterkrans'),
#  ('fremstige', 'slike'),
#  ('kongetroner', 'troner'),
#  ('tærner', 'kjerner'),
#  ('seire', 'beleire'),
#  ('røvet', 'bedrøvet'),
#  ('trellehop', 'rop'),
#  ('ry', 'stjernegry'),
#  ('seierssang', 'forårssang'),
#  ('sang', 'engang'),
#  ('kun', 'blund'),
#  ('verne', 'tærne'),
#  ('bøyes', 'nøyes'),
#  ('verdensstat', 'at'),
#  ('min', 'pålandsvind'),
#  ('alvorsfullt', 'fullt'),
#  ('flammespill', 'klokkespill'),
#  ('Bull', 'omkull'),
#  ('solskinnsvind', 'grind'),
#  ('jubelsang', 'kjøkkengang'),
#  ('blande', 'forbanne'),
#  ('kjempe-sang', 'kjøkkengang'),
#  ('svirefest', 'offerprest'),
#  ('sprekk', 'trekk'),
#  ('færre', 'verre'),
#  ('bladehang', 'tang'),
#  ('utrolig', 'urolig'),
#  ('edderkopp', 'mastetopp'),
#  ('demper', 'kjemper'),
#  ('sitt', 'vidt'),
#  ('brott', 'rått'),
#  ('bind', 'sommervind'),
#  ('spy', 'ry'),
#  ('renholdsverk', 'plankeverk'),
#  ('navner', 'havner'),
#  ('fans', 'sans'),
#  ('fordrevet', 'krevet'),
#  ('finn', 'svin'),
#  ('forfekter', 'nekter'),
#  ('forlatt', 'dravat'),
#  ('øvet', 'prøvet'),
#  ('ætten', 'sletten'),
#  ('pynt', 'forkynt'),
#  ('gøyeblikk', 'prikk'),
#  ('stiller', 'triller'),
#  ('forlatt', 'kamerat'),
#  ('kast', 'kvast'),
#  ('betvang', 'Rolland'),
#  ('sang', 'betvang'),
#  ('dem', 'hvem'),
#  ('forteller', 'bjeller'),
#  ('Cheval', 'bacchanal'),
#  ('viktig', 'forsiktig'),
#  ('myr', 'knyr'),
#  ('tind', 'nordenvind'),
#  ('høvdingånd', 'hand'),
#  ('klirrer', 'dirrer'),
#  ('dem', 'hjem'),
#  ('parnass', 'pass'),
#  ('besetter', 'fletter'),
#  ('befrierverk', 'merk'),
#  ('derhenne', 'svenne'),
#  ('dertil', 'mil'),
#  ('slange', 'sange'),
#  ('betvang', 'tang'),
#  ('godt', 'slott'),
#  ('forstått', 'yacht'),
#  ('stut', 'krutt'),
#  ('fiskerånd', 'mon'),
#  ('trekk', 'skrekk'),
#  ('tilsmiler', 'smiler'),
#  ('likefrem', 'frem'),
#  ('formilde', 'snille'),
#  ('fly', 'ly'),
#  ('farveller', 'kvelder'),
#  ('spy', 'by'),
#  ('Gynt', 'mynt'),
#  ('instrumenter', 'prenter'),
#  ('flakker', 'attakker'),
#  ('kaste', 'filisterkaste'),
#  ('bule', 'klippehule'),
#  ('apespill', 'ørkenild'),
#  ('derinn', 'trinn'),
#  ('vintersky', 'gny'),
#  ('revet', 'kingelvevet'),
#  ('klædebon', 'sånn'),
#  ('april', 'smil'),
#  ('opp', 'mastetopp'),
#  ('åpenbares', 'spares'),
#  ('flat', 'fat'),
#  ('fløytespill', 'mild'),
#  ('grein', 'rein'),
#  ('kjempepolyp', 'dyp'),
#  ('hasp', 'asp'),
#  ('redningsverk', 'frelserverk'),
#  ('brott', 'stjerneblått'),
#  ('sløve', 'prøve'),
#  ('rått', 'rikmannslott'),
#  ('fukter', 'bukter'),
#  ('duften', 'blomsterduften'),
#  ('vrede', 'glede'),
#  ('velde', 'felle'),
#  ('mast', 'strålekast'),
#  ('vemodsfull', 'kjempe-kull'),
#  ('kjerne', 'kaserne'),
#  ('nikk', 'blikk'),
#  ('Bugge-Hans', 'farvesans'),
#  ('slut', 'forskutt'),
#  ('perle-smykke', 'smykke'),
#  ('lidt', 'vidt'),
#  ('rekker', 'snekker'),
#  ('spore', 'roret'),
#  ('Natt', 'at'),
#  ('gigant', 'sant'),
#  ('byder', 'dyder'),
#  ('eng', 'heng'),
#  ('igang', 'Rolland'),
#  ('blide', 'side'),
#  ('nordvesten', 'arresten'),
#  ('gruset', 'knuse'),
#  ('påferde', 'lærde'),
#  ('musikk', 'gikk'),
#  ('kinn', 'solskinnsvind'),
#  ('tromme', 'komme'),
#  ('dine', 'pine'),
#  ('berguhyre', 'Dyre'),
#  ('frukt', 'smukt'),
#  ('gullplateklang', 'ingengang'),
#  ('kamerater', 'pater'),
#  ('slang', 'Nang'),
#  ('oss', 'loss'),
#  ('frisk', 'fisk'),
#  ('skatt', 'soldat'),
#  ('strenger', 'sprenger'),
#  ('partisaner', 'planer'),
#  ('inn', 'kjerringgrin'),
#  ('teller', 'bryllupsfeller'),
#  ('merkestang', 'avskjedssang'),
#  ('hvil', 'klokkespill'),
#  ('sommerblekt', 'dekt'),
#  ('tonestrøm', 'svøm'),
#  ('tanke', 'redningsplanke'),
#  ('tankefull', 'tull'),
#  ('gry', 'bly'),
#  ('blikke', 'slikke'),
#  ('igang', 'tang'),
#  ('Rolland', 'fuglesang'),
#  ('bål', 'dvergemål'),
#  ('dage', 'plage'),
#  ('krenket', 'benket'),
#  ('oljesveis', 'mahognibeis'),
#  ('berguhyre', 'fyre'),
#  ('stat', 'fatt'),
#  ('brygg', 'bølgerygg'),
#  ('gjennomstinge', 'tvinge'),
#  ('forpester', 'rester'),
#  ('politikk', 'juleskikk'),
#  ('blund', 'rund'),
#  ('glatt', 'soldat'),
#  ('lakker', 'kirkebakker'),
#  ('prat', 'soldat'),
#  ('knopp', 'topp'),
#  ('hør', 'honnør'),
#  ('hede', 'kjede'),
#  ('lat', 'bratt'),
#  ('historiedønn', 'Ølversønn'),
#  ('ler', 'leire'),
#  ('flott', 'himmelblått'),
#  ('vekk', 'trekk'),
#  ('Hør', 'klør'),
#  ('spilt', 'vilt'),
#  ('henrykke', 'trykke'),
#  ('gjemmer', 'lemmer'),
#  ('byer', 'fornyer'),
#  ('Ørn', 'sognebørn'),
#  ('spant', 'vant'),
#  ('kalle', 'kallet'),
#  ('tvang', 'slang'),
#  ('ly', 'verdensby'),
#  ('klare', 'bare'),
#  ('stillehavspassat', 'glatt'),
#  ('fiskerånd', 'evighetsbånd'),
#  ('tonetrang', 'folkerang'),
#  ('svinger', 'lansesvinger'),
#  ('vare', 'venneskare'),
#  ('dans', 'herskerkrans'),
#  ('prikke', 'slikke'),
#  ('neger', 'beger'),
#  ('at', 'betatt'),
#  ('Ølversønn', 'smerte-stønn'),
#  ('brisk', 'grisk'),
#  ('tanke', 'ranke'),
#  ('kanin', 'blind'),
#  ('svang', 'alfesang'),
#  ('dans', 'sans'),
#  ('humør', 'rosenglør'),
#  ('trafikk', 'avskjedsblikk'),
#  ('sprang', 'klang'),
#  ('prammer', 'lammer'),
#  ('Bugge-Hans', 'tornekrans'),
#  ('kanin', 'hermelin'),
#  ('barneskare', 'skare'),
#  ('broderhånd', 'ordensbånd'),
#  ('sletter', 'spretter'),
#  ('solmorgenstund', 'fund'),
#  ('dager', 'nager'),
#  ('vått', 'kott'),
#  ('blinke', 'minke'),
#  ('baner', 'ahner'),
#  ('klokkeklang', 'forårssang'),
#  ('plankeverk', 'frelserverk'),
#  ('lavt', 'draft'),
#  ('drager', 'forjager'),
#  ('lind', 'fiolin'),
#  ('sener', 'grener'),
#  ('klyver', 'lyver'),
#  ('syrerslaget', 'behage'),
#  ('krykker', 'nykker'),
#  ('drammer', 'rammer'),
#  ('enevelde', 'trelle'),
#  ('ditinn', 'svin'),
#  ('stønner', 'drønner'),
#  ('lokomotiv', 'siv'),
#  ('jevne', 'stevne'),
#  ('vanvidsnatt', 'skvatt'),
#  ('hevne', 'evne'),
#  ('purpurkjol', 'symbol'),
#  ('hatt', 'forlatt'),
#  ('blund', 'elvebunn'),
#  ('flakse', 'akse'),
#  ('tør', 'slør'),
#  ('Høye', 'bøyet'),
#  ('din', 'violin'),
#  ('barneskare', 'klare'),
#  ('Bugge-Hans', 'brudekrans'),
#  ('vintersky', 'ny'),
#  ('stått', 'godt'),
#  ('kjøkemester', 'forpester'),
#  ('kuldegyset', 'lyset'),
#  ('stjerneblått', 'kott'),
#  ('hvin', 'måneskinn'),
#  ('vind', 'eventyr-sinn'),
#  ('fjerne', 'hjerne'),
#  ('spisesal', 'Baal'),
#  ('iler', 'tviler'),
#  ('vingefang', 'bladehang'),
#  ('solgangsild', 'narrespill'),
#  ('bedrager', 'avskjedsklager'),
#  ('gremme', 'stemme'),
#  ('Hans', 'dømmesans'),
#  ('ring', 'spring'),
#  ('rytter', 'flytter'),
#  ('bisp-synoden', 'moden'),
#  ('gjaldt', 'kalt'),
#  ('jage', 'forårsdage'),
#  ('myr', 'bestyr'),
#  ('fordølger', 'følger'),
#  ('hang', 'vang'),
#  ('marmortrinn', 'sinn'),
#  ('svike', 'minnerike'),
#  ('solmorgenstund', 'hjertegrunn'),
#  ('forsilde', 'bryllupsgilde'),
#  ('fløytespill', 'il'),
#  ('stanger', 'slanger'),
#  ('parat', 'dravat'),
#  ('pærer', 'kimærer'),
#  ('forskutt', 'slutt'),
#  ('drevet', 'strevet'),
#  ('parat', 'kamerat'),
#  ('grein', 'hegn'),
#  ('intriger', 'stiger'),
#  ('seire', 'trer'),
#  ('jager', 'nager'),
#  ('bunn', 'flammemunn'),
#  ('nært', 'lært'),
#  ('betvang', 'trang'),
#  ('brudeslør', 'sør'),
#  ('ravn', 'gavn'),
#  ('telt', 'delt'),
#  ('kongress', 'tess'),
#  ('blidt', 'Krit'),
#  ('Hull', 'fortrøstningsfull'),
#  ('grisk', 'pisk'),
#  ('daget', 'ridderslaget'),
#  ('tøy', 'drøy'),
#  ('søndenvind', 'fiolin'),
#  ('slavinner', 'minner'),
#  ('foreskrev', 'billedvev'),
#  ('stammer', 'hammer'),
#  ('svinge', 'betvinge'),
#  ('ridetøy-', 'regnbueøy'),
#  ('ritt', 'vidt'),
#  ('raller', 'faller'),
#  ('briste', 'Kviste'),
#  ('mage', 'sage'),
#  ('velde', 'skjønnhets-velde'),
#  ('stridt', 'sitt'),
#  ('utkåret', 'skåret'),
#  ('metropol', 'frivol'),
#  ('falanger', 'ganger'),
#  ('kart', 'snart'),
#  ('bunn', 'Staupersund'),
#  ('myre', 'styre'),
#  ('drønner', 'rønner'),
#  ('hester', 'gjeste'),
#  ('harpespill', 'hvil'),
#  ('stans', 'glans'),
#  ('aveny', 'bly'),
#  ('lang', 'blomstervang'),
#  ('trua', 'stua'),
#  ('blomsterkrans', 'solskinnsglans'),
#  ('kaprifol', 'æressol'),
#  ('nemme', 'demme'),
#  ('Staupersund', 'blomstergrunn'),
#  ('sagastol', 'pol'),
#  ('klage', 'plage'),
#  ('støp', 'svøp'),
#  ('eneste', 'reneste'),
#  ('sinn', 'arbeidervin'),
#  ('ørnesinn', 'lin'),
#  ('tanke', 'blanke'),
#  ('sund', 'sunn'),
#  ('opp', 'dvergfurutopp'),
#  ('ringe', 'betvinge'),
#  ('klokkeklang', 'kjøkkengang'),
#  ('drømmesyn', 'syn'),
#  ('haft', 'raft'),
#  ('kviste', 'dødningkiste'),
#  ('pike', 'tillike'),
#  ('seierskrans', 'krans'),
#  ('humane', 'ane'),
#  ('engang', 'solnedgang'),
#  ('lampeskinn', 'inn'),
#  ('lin', 'sølvsardin'),
#  ('bandt', 'svant'),
#  ('henne', 'fullende'),
#  ('bjørk', 'dørk'),
#  ('smil', 'sild'),
#  ('byll', 'idyll'),
#  ('skjønn', 'sønn'),
#  ('kvarter', 'leire'),
#  ('åpenbarer', 'erfarer'),
#  ('gassbeholder', 'volder'),
#  ('fortidsstat', 'mat'),
#  ('sognebørn', 'bjørn'),
#  ('regnbueøy', 'tøy'),
#  ('leber', 'feber'),
#  ('kilen', 'hvilen'),
#  ('klem', 'strålebrem'),
#  ('tilside', 'vide'),
#  ('revne', 'evne'),
#  ('ørkenbunn', 'stund'),
#  ('bladehang', 'forårssang'),
#  ('stuen', 'luen'),
#  ('sonet', 'kronet'),
#  ('projekt', 'centnervekt'),
#  ('jubelklang', 'seierssang'),
#  ('igang', 'trang'),
#  ('bunn', 'sunn'),
#  ('Høye', 'pløye'),
#  ('forvrenge', 'lenge'),
#  ('renker', 'senker'),
#  ('tiggerskare', 'fanfare'),
#  ('gress', 'ness'),
#  ('hagen', 'dagen'),
#  ('våres', 'imorges'),
#  ('solskinnsfly', 'morgensky'),
#  ('neste', 'heste'),
#  ('stykke', 'fryse'),
#  ('skulderband', 'helvedånd'),
#  ('betrede', 'berede'),
#  ('såret', 'håret'),
#  ('fangehull', 'full'),
#  ('dekk', 'gatesprekk'),
#  ('hatt', 'satt'),
#  ('brenne', 'derhenne'),
#  ('bedrager', 'jager'),
#  ('kilder', 'griller'),
#  ('vang', 'milelang'),
#  ('kilde', 'vilde'),
#  ('kiste', 'dødningkiste'),
#  ('prestinner', 'barneminner'),
#  ('pral', 'sval'),
#  ('hampen', 'dampen'),
#  ('sønderskutt', 'bølgesprut'),
#  ('fart', 'klart'),
#  ('give', 'forblive'),
#  ('kratt', 'dravat'),
#  ('bestjele', 'hæler'),
#  ('gjeldte', 'helter'),
#  ("'s", 'stråleglans'),
#  ('sang', 'blomstervang'),
#  ('vold', 'hedenold'),
#  ('inn', 'eventyr-sinn'),
#  ('penger', 'flenger'),
#  ('kun', 'sekund'),
#  ('kvede', 'betrede'),
#  ('stue', 'grue'),
#  ('ødelanden', 'annen'),
#  ('beklemt', 'stemt'),
#  ('kirkedalen', 'pralen'),
#  ('hugger', 'dugger'),
#  ('vinket', 'blinket'),
#  ('betvang', 'forårssang'),
#  ('renkespill', 'vill'),
#  ('jettekvinner', 'svinner'),
#  ('romantikk', 'fikk'),
#  ('æoner', 'millioner'),
#  ('maskiner', 'piner'),
#  ('sprang', 'sirenesang'),
#  ('slekt', 'frekt'),
#  ('marsaftenvind', 'syrin'),
#  ('kunster', 'lokomotiv'),
#  ('vippe', 'slippe'),
#  ('skremme', 'gjemme'),
#  ('fanfare', 'bevare'),
#  ('stemmer', 'klemmer'),
#  ('menneskemunn', 'elvebunn'),
#  ('ryker', 'fyker'),
#  ('stang', 'blomstervang'),
#  ('solgangsild', 'pil'),
#  ('født', 'rødt'),
#  ('hedningeby', 'vikingery'),
#  ('havn', 'stavn'),
#  ('gjemme', 'tordenstemme'),
#  ('suse', 'kruset'),
#  ('lind', 'derinn'),
#  ('politikk', 'hornmusikk'),
#  ('seierskrans', 'farvesans'),
#  ('henrevet', 'sønderrevet'),
#  ('vinger', 'stinger'),
#  ('slang', 'engang'),
#  ('solgangsild', 'tvil'),
#  ('press', 'etsteds'),
#  ('hodebry', 'fiskerby'),
#  ('frelserverk', 'skaperverk'),
#  ('retter', 'gjetter'),
#  ('hvin', 'arbeidervin'),
#  ('bjelkehall', 'tempelhall'),
#  ('rabbiner', 'piner'),
#  ('suse', 'huset'),
#  ('synderinner', 'kvinner'),
#  ('vang', 'strengeklang'),
#  ('sommernatt', 'dravat'),
#  ('sprekk', 'vekk'),
#  ('spinn', 'inn'),
#  ('rund', 'solmorgenstund'),
#  ('lov', 'grov'),
#  ('vemodsfull', 'kummerfull'),
#  ('sommernetter', 'silhuetter'),
#  ('ur', 'kultur'),
#  ('trofer', 'beber'),
#  ('solskinnsfly', 'tordensky'),
#  ('kaldt', 'falt'),
#  ('magneten', 'profeten'),
#  ('karakter', 'leire'),
#  ('stjerneblått', 'huldreslått'),
#  ('Cheval', 'dal'),
#  ('verdensby', 'vikingery'),
#  ('høvdingånd', 'hånd'),
#  ('palass', 'parnass'),
#  ('dømmer', 'strømmer'),
#  ('rank', 'sank'),
#  ('kratt', 'vinter-natt'),
#  ...}

# %%
pairs2 = pairs_.copy()
pairs2.update(m_pairs)
len(pairs2)
# Out:
# 38599

# %%
new_pairs = m_pairs - orig_pairs

# %%
v = [w for b in manual_buckets for w in b]
print(f"""
With the buckets we got from manual graph clustering we got {len(manual_buckets)} new buckets
Average size: {len(v)/len(manual_buckets)}
{len(v)} words out of {len(vocab)} total
We lost {tot_len-len(v)} vertices

All combinations of the buckets give us {len(m_pairs)} rhyme pairs.
Of these, {len(orig_pairs.intersection(m_pairs))} already existed in the pairs data set.
We increased the pair set by {len(new_pairs)}.

However, the original pairs data set contain bad edges.
We add the {len(pairs_)} good_buckets pairs and {len(m_pairs)} manual_buckets pairs together for a new pair dataset.
The total length is {len(pairs2)}
""")
# Out:
# With the buckets we got from manual graph clustering we got 91 new buckets
# Average size: 16.395604395604394
# 1492 words out of 6290 total
# We lost 16 vertices
#
# All combinations of the buckets give us 20183 rhyme pairs.
# Of these, 1226 already existed in the pairs data set.
# We increased the pair set by 18957.
#
# However, the original pairs data set contain bad edges.
# We add the 18416 good_buckets pairs and 20183 manual_buckets pairs together for a new pair dataset.
# The total length is 38599

# %%
words_a, words_b = zip(*pairs2)
pair_df = pd.DataFrame({"word_a" : words_a, "word_b": words_b, "rhyme": [1]*len(pairs2)})
pair_df.to_csv("tsvs/manual_repair_plus_good_buckets_pairs.tsv", sep="\t", index=False)

# %%
pair_df
# Out:
#                  word_a         word_b  rhyme
# 0                     Å           skrå      1
# 1      stillehavspassat           satt      1
# 2          stjerneblått          blott      1
# 3                   med            ned      1
# 4            nattelosji            bli      1
# ...                 ...            ...    ...
# 38594         forpakter     dårefakter      1
# 38595            finner         hinder      1
# 38596            brøden  evighetsrøden      1
# 38597              hist          kvist      1
# 38598         narrefest      allerbest      1
#
# [38599 rows x 3 columns]

# %%
v = set(list(pair_df.word_a)+list(pair_df.word_b))
len(v)
# Out:
# 6272

# %%
len(all_bad_edges)
# Out:
# 106
