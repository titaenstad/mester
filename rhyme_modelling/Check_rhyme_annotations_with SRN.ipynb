# %%
[1,2,3,4,5,6,7,][:5]
# Out:
# [1, 2, 3, 4, 5]

# %%
import string

import nltk
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import tokenizer_from_json



MAX_LEN = 64
SEED = 420
# sets random, np.random and tf.random seed
tf.keras.utils.set_random_seed(
    SEED
)

# %%
rhyme_model_name = "rhyme_model_23"
tokenizer_path = 'tokenizer_config.json'

with open(tokenizer_path) as f:
    tokenizer_config = f.read()

tokenizer = tokenizer_from_json(tokenizer_config)

rhyme_model = model = load_model(f"models/{rhyme_model_name}.hdf5")

# %%
def tokenize_input(phrase, tokenizer):
    tokenized_phrase = tokenizer.texts_to_sequences([phrase])[0]

    if len(tokenized_phrase) < MAX_LEN:
        length_to_pad = MAX_LEN - len(tokenized_phrase)
        phrase_for_output = ([0] * length_to_pad) + tokenized_phrase
    elif len(tokenized_phrase) > MAX_LEN:
        phrase_for_output = tokenized_phrase[-MAX_LEN:]
    else:
        phrase_for_output = tokenized_phrase
    return tf.constant(phrase_for_output, dtype=tf.float64)

# %%
df = pd.read_csv("tita_rhymes_poems.tsv", sep="\t")

punctuation = string.punctuation + "«»—"

def remove_punctuation(stanza):
    lines = stanza.split("\n")
    clean_lines = [" ".join([t for t in nltk.tokenize.word_tokenize(line, language='norwegian', preserve_line=True) if t not in punctuation]) for line in lines]
    return clean_lines

df["clean_lines"] = df["stanza"].apply(remove_punctuation)

df["tokenized"] = [tf.convert_to_tensor([tokenize_input(line, tokenizer) for line in clean_lines]) for clean_lines in df["clean_lines"]]

df
# Out:
#      rhyme scheme                                             stanza  \
# 0         AABCCBI  Gud, la oss i din kunnskap fremmes,\nså det vi...
# 1         TAABCCB  ANNEN SANG\nFra Landego seiles mot Skrova i no...
# 2          AABCCB  Og er det en høstkveld når mørket står på\nså ...
# 3          AABCCB  Snart ligger og kaien der dyngvåt av regn,\nog...
# 4          AABCCB  Og rett bort i øst ligger Svinøya gård\nhvor B...
# ...           ...                                                ...
# 5153         AABB  Lukket! Lukket! Øde veier! Gledens vinger brut...
# 5154         AABB  Og nå stod han her som fremmed i et fremmed la...
# 5155         AABB  Opp av havets blanke bølger, som en vårfrisk m...
# 5156         AABB  Til Europa! Tanken slår ham plutselig som lyn,...
# 5157         AABB  Ei han nøler med å følge veiens nye spor.\nI d...
#
#                             filename  stanza number (in file)  \
# 0      2009013000065_1_annotated.txt                        0
# 1     2007011001018_11_annotated.txt                        0
# 2     2007011001018_11_annotated.txt                        1
# 3     2007011001018_11_annotated.txt                        2
# 4     2007011001018_11_annotated.txt                        3
# ...                              ...                      ...
# 5153  2011041408091_18_annotated.txt                        5
# 5154  2011041408091_18_annotated.txt                        6
# 5155  2011041408091_18_annotated.txt                        7
# 5156  2011041408091_18_annotated.txt                        8
# 5157  2011041408091_18_annotated.txt                        9
#
#                                             clean_lines  \
# 0     [Gud la oss i din kunnskap fremmes, så det vi ...
# 1     [ANNEN SANG, Fra Landego seiles mot Skrova i n...
# 2     [Og er det en høstkveld når mørket står på, så...
# 3     [Snart ligger og kaien der dyngvåt av regn, og...
# 4     [Og rett bort i øst ligger Svinøya gård, hvor ...
# ...                                                 ...
# 5153  [Lukket Lukket Øde veier Gledens vinger brutt,...
# 5154  [Og nå stod han her som fremmed i et fremmed l...
# 5155  [Opp av havets blanke bølger som en vårfrisk m...
# 5156  [Til Europa Tanken slår ham plutselig som lyn,...
# 5157  [Ei han nøler med å følge veiens nye spor, I d...
#
#                                               tokenized
# 0     ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 1     ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 2     ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 3     ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 4     ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# ...                                                 ...
# 5153  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 5154  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 5155  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 5156  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
# 5157  ((tf.Tensor(0.0, shape=(), dtype=float64), tf....
#
# [5158 rows x 6 columns]

# %%
letters = "---"+string.ascii_uppercase.replace("T", "").replace("I","").replace("N","")


def clean_scheme(scheme):
    def scheme_to_numeric(scheme):
        scheme = scheme.replace("T", "0")
        scheme = scheme.replace("I", "1")
        scheme = scheme.replace("N", "2")
        unique_chars = (set(scheme) - {"0", "1", "2"})
        unique_chars = sorted(list(unique_chars), key=lambda x: scheme.index(x))
        scheme = "-".join(scheme)    
        for i, c in enumerate(unique_chars, start=3):
            scheme = scheme.replace(c, str(i))
        return scheme

    def numeric_to_scheme(scheme):
        unique_chars = sorted(list(set(scheme.split("-")) - {"0", "1", "2"}), key=int)
        for i, c in enumerate(unique_chars, start=3):
            scheme = scheme.replace(c, letters[i])
        scheme = scheme.replace("-", "")
        scheme = scheme.replace("0", "T")
        scheme = scheme.replace("1", "I")
        scheme = scheme.replace("2", "N")
        return scheme

    scheme = scheme_to_numeric(scheme)
    scheme = numeric_to_scheme(scheme)
    return scheme

def annotate(model, prev_code, stanza, tokenz):
    code = ["X"]*len(stanza)
    
    for i, line in enumerate(stanza):
        if prev_code[i] in ("I", "T", "N"):
            code[i] = prev_code[i]
            continue
        if  code[i] != "X":
            continue
        letter = letters[i+3]
        code[i] = letter
        
        for j in range(i+1, len(stanza)):
            if prev_code[j] in ("I", "T", "N") or code[j] != "X":
                continue
            
            t1 = tf.reshape(tokenz[i],(1, 64))
            t2 = tf.reshape(tokenz[j], (1, 64))
            rh = model.predict([t1, t2])
            #print(f"Line 1:\n{line}\nLine 2:\n{stanza[j]}\nRhyme:{rh}\n")
            if rh[0][0] > 0.5:
                code[j] = letter
    
    return clean_scheme("".join(code))

# %%
annotations = []
for e in df.itertuples():
    annotations.append(annotate(model, e._1, e.clean_lines, e.tokenized))

# %%
i = 0
for a1, a2, stanza in zip(df["rhyme scheme"], annotations, df["stanza"]):
    if a1 != a2:
        i += 1
        if len(a1) <= 4:
            print(a1)
            print(a2)
            print(stanza)
            print("")
i, len(df)
# Out:
# ABAB
# ABCB
# Den første rettergang var mer enn nok.
# Sin rases ektefødte sønn er han!
# Han er en utsøkt fører for den flokk
# hvis skjulte verk er rov og mord og brann.
#
# ABCB
# ABCD
# Og når du kommer, ta min kappe med;
# ti kald er cellens luft og hårdt mitt leie.
# Og bøkene hos Karpus, som du vet,
# av jordisk gods det er mitt hele eie.
#
# ABCA
# ABAA
# Han sover.
# Et leie er redt til to,
# men ingen kommer.
# Det er ikke hestehover
#
# ABAB
# ABAC
# På dem med flit at bygge,
# i dem med kunst at bo
# som fugl der ligger trygge
# i bølgedalens ro
#
# ABAB
# ABAC
# Fra høydene faller en lysning vakt
# på den kulsorte klippevegg.
# Der ligger en hummer og fråder svakt
# med sin klo i likets skjegg...
#
# ABAB
# AAAB
# En grav er bedre enn alle slotter,
# der har vi hjemme så små vi er.
# Guds helgner bodde i hull og grotter,
# i graven er vi ham alle nær.
#
# ABAB
# ABAC
# Så kald på døden når du vil hvile,
# han kommer lett som en aftenvind.
# Og før det rasler i gravens pile
# er du til stjernernes fred gått inn!
#
# AABB
# AABC
# «Gå, Obadja!l Bring mitt bud
# til din herre.  Ved min Gud
# sverger jeg: Så skal det skje,
# jeg idag skal Achab. se,
#
# AABB
# ABCC
# Dog  du mente det så vel,
# derfor sletter Gud din gjeld.
# Var enn llivet fullt av brist,
# ærlig var din vilje visst;
#
# ABBA
# ABBC
# Der la han sitt hode over sitt kne
# og bad om regn.  Nå skulle det komme.
# Nå skulle straffens tid være omme.
# Men himlen var klar; ingen sky å se.
#
# ABAB
# ABAC
# Jesus, styr du mine tanker,
# Jesus, la meg leve så
# at hvor jeg i verden vanker,
# et Guds barn jeg være må!
#
# ABCB
# ABAB
# Byrden han løfter fra trett manns rygg,
# trellen for åket befrier.
# Salig enhver som tålsom og tro
# etter Guds frelse bier.
#
# AABC
# AABB
# Vannet er dypt og bunnen glatt;
# Herre, får han først i armen fatt,
# drukner det ikke, men lever,
# til du det nåde-rik hærver.
#
# AABB
# ABCC
# Tenker som så: Hvor en det er,
# han og du er det alltid nær;
# Jesus, dets lille broder,
# følger det hjem til moder.
#
# AABB
# ABCC
# kulde, hete,
# hagl og væte,
# alt er meg til næring,
# og jeg er min egen båt og færing.
#
# ABBA
# ABBC
# Se for liv i sceneriet:
# Vårens blomstring, høstens øde,
# livets terningkast blandt døde,
# jordens ætt til jorden viet.
#
# ABCB
# ABAB
# Den store fange sitter
# med hånden under kinn;
# så mange tanker krysser
# igjennom sjel og sinn.
#
# ABCB
# ABAB
# Vel er hans lenker løsnet,
# han slipper hugg og slag,
# uhindret kan han tjene
# sin mester dag for dag.
#
# ABCB
# ABCD
# Og dagene blir uker
# og ukene blir år.
# Og årene de lange
# strør sne i fangens hår.
#
# ABCB
# AABC
# For ham er Kristus livet,
# og døden kun hans venn.
# For deres skyld dog gjerne
# han elsker livet enn.
#
# ABCB
# ABAB
# Hva jordens er skal visne
# som høstens løv i jord;
# men etter livets vintre
# et evig forår gror.
#
# ABCB
# ABAB
# Han bygger livets under
# i skjul av støvets kår;
# når støvets skranker faller,
# hans verk fullkomment står.
#
# ABCB
# ABAC
# Jeg takker dere for gaven,
# den lettet mine kår;
# mest dog for hjertelaget
# som gjennom gaven slår.
#
# ABCB
# AABC
# Vi sender brødres hilsen,
# vår fryd, vår strid er én.
# Vårt hjertes skjulte streben
# er livets prøvesten.
#
# ABCB
# ABAC
# Så føler Kristi tjener
# til alle folk sin gjeld.
# Så bær han på sitt hjerte
# de manges ve og vel.
#
# ABCB
# ABAB
# Og enn ham er beskåret
# en rik og virksom dag.
# På kjente trakter frydes
# han enn i brødres lag.
#
# ABCA
# ABCD
# Ingen båter vil se dem, og de skys uten ord
# av de hvitkledte skipe med losene som våger.
# Kun hundene besøker dem, og skarnlystne måker
# svever omkring mannen ved det skrikende ror.
#
# AABB
# AABA
# Men da hin susen i meg selv tog av,
# fornam jeg mot meg evighetens hav.
# Og mine øyenlåg falt langsomt i,
# jeg var for liv, jeg var for lede fri.
#
# ABAB
# ABAC
# Der er satt seil på snekken
# og nå går faren ned
# tilsidst med seildugssekken,
# og alle følger med.
#
# ABAB
# AAAA
# Og faren selv tar roret
# og skjøtet på sin lend,
# mens gråten kvæler ordet
# hos dem som står igjen.
#
# ABCB
# ABAC
# Et kall så stort, en gjerning så rik
# på menneske aldri var lagt;
# men Gud var hans kraft — fra moders liv
# han stod med Guds ånd i pakt.
#
# ABCD
# ABCB
# Hans gjerning var gjortt Da den Høyeste kom,
# sin plass han så gjerne vek;
# ei var han Messias, men kun hans venn,
# som sank, når den større steg.
#
# ABCB
# ABCD
# Han må ha visshet. De trofaste to,
# som har lettet ham fengslets ve,
# han sender avsted  de skal bringe ham bud
# om alt de kan høre og se.
#
# ABCB
# ABBB
# Spedalske var rene, og halte sprang,
# og døvstumme priste Gud;
# de blinde så, og for fattige lød
# evangeliets herlige bud.
#
# ABCB
# ABCA
# Dog underligst var, av alt vi så
# i den store, bevegede stund,
# en enkes sønn, der av døde var vakt
# ved et ord fra Mesterens munn.»
#
# ABCB
# ABCC
# Da demret Guds lys for Døperens syn,
# han åndet, lettet og fri.
# Messias! Messias! det tonet og sang
# som en liflig og lys melodi.
#
# ABCB
# ABCD
# «Han bad oss si hva vi hørte og så,
# annet han nevnte ei
# kun det la han' til: og salig er den,
# som ikke forarges på meg.»
#
# ABCB
# ABAB
# Da bøyde han under Guds veiers vekt
# sin sterke, grublende ånd
# «Jeg æret ham før i frihet og kraft,
# nå skjer det ved fengsel og bånd.»
#
# ABCB
# AABA
# På myk divan — mens vellyst og vin!
# har sløret hans sinn og sans
# Herodes seg strekker, mens lystent han ser
# de halvnøkne lemmer i dans.
#
# ABCB
# ABCD
# «Begjær, hva du vil, mitt skjønne barn,
# du skal få det, jeg sverger derpå;
# ja ber du om selve det halve land,
# så lar jeg det gladelig gå.»
#
# ABCB
# ABBB
# Med moren til side Salome går:
# «Å,; mor, gi meg nå et råd
# Herodias skjelver av djevelsk fryd,
# nå er det tid til dåd.
#
# ABCB
# ABAC
# Hun hater hin Døper. «Han var en torn
# på min ellers så sorgløse vei.
# Nå skal han bøte. Min datters dans
# har dømt mellom ham og meg.»
#
# ABCB
# ABCD
# Herodes vakler. Han blekner av angst,
# og hans lystige hoffmenn med.
# Men angsten må skjules — befalingen skjer;
# ei brytes en konges ed.
#
# ABCB
# ABAB
# I kjellerens klamme, kvelende luft
# går Døperen ensom sin gang;
# fra oven lyder et dempet brus
# av paukers og trommers klang.
#
# ABCB
# ABCC
# Da vender han ennu for siste gang
# en tanke, vemodig og øm,
# til ham som han gav sitt hele liv
# og livets deiligste drøm.
#
# ABCB
# ABCD
# Så rekker han villig sitt hode frem
# under bønn til den fjerne venn.
# Det faller — og bæres på gyllent fat
# til moder og datter hen.
#
# ABAB
# ABCB
# Og der nordvest, hvor himlens blå
# av frost er nesten hvitt,
# der ser jeg vintrens skygge gå
# tilfjells med lange skritt!
#
# ABAB
# ABAC
# En nyperose er fullt utsprungen
# og eggeskallene er blitt bleke,
# en voksen hviting for litt for ungen
# som nyss forslukte seg på en reke!
#
# ABAB
# ABAC
# Den korte sommer er snart et sagn
# og fugleskarnet et fagert minne
# på disse klipper hvor jeg tar agn
# til drømmefisket som snart er inne.. .
#
# ABCB
# ABCD
# Slekt føder slekt,
# stigende evne den når;
# art føder art
# i millioner av år.
#
# ABAB
# ABAC
# Jeg satt og ventet og tenkte titt:
# når dagen lider, han veien vover.
# Og lyset sluktes og brente litt,
# og dagen kom og gikk over.
#
# ABAB
# AABC
# Det sner, det sner, det sner.
# Kun sne og atter sne,
# ingen jord, ingen trær mer,
# sne, sne, sne...
#
# AABB
# AABC
# Således satt jeg og drømte,
# mens døden langsomt tømte
# en himmel av frossen fred
# over verdens branntomtt ned.
#
# ABBA
# ABBC
# Hun gjemte huen i tyve år,
# måtte ikke slite den ud!
# Jeg bærer den vel engang som brud,
# når jeg for alteret går.
#
# ABBA
# ABBC
# Hun gjemte huen i tredve år,
# måtte ikke skjemme den ud!
# Så bærer jeg den så glad som brud,
# når jeg for Vor Herre står.
#
# ABBA
# ABBC
# Hun gjemte huen i fireti år,
# hugsede ennå på sin mor.
# Vesle min hue, for visst jeg tror,
# vi aldri for alteret står.
#
# ABBA
# ABBC
# Hun ganger for kisten at ta den,
# hjertet var så stort derved;
# hun leter frem til dens gamle sted,
# da var der ikke tråden igjen.
#
# AABB
# ABCC
# Og Guds herolder suste fjernt og nær,
# og ordnet disse gjenoppstandnes hær.
# Så gikk de fremover mens hjertet bevet:
# var navnet blitt i livets bøker skrevet?
#
# AABB
# ABCC
# Det drønnet på den store aveny
# titusen menn, titusen menn på ny.
# Slutt pål skrek baktroppen idet den kom
# kan hende er han gått, og graven tom!
#
# AABB
# AABA
# Da grep de sine redskap. Fliser føk
# fra mausoleet, jorden stod i røk.
# I feberlengsel grov de helten frem.
# Den ukjente soldaten ventet dem.
#
# ABCC
# AABC
# Først dødsstillhet, den stumme vantros gru.
# Så galehuset, et avsindig nå,
# de hylte, breket, hulket: protester
# Da steg han opp, og intet nyttet mer.
#
# AABB
# AAAA
# Man snakker om oppstandelse! I skrekk
# og hat og harm drog æresvakten vekk.
# Men midt blandt marmorgravens brutte sten som
# var veltet bort, stod den oppstandne, ensom.
#
# ABAB
# ABCB
# Thi for meg må det visselig være beredt
# fra evighet dette sted.
# Jeg tror ikke menneskeøye har sett
# make til lys og fred.
#
# ABAB
# ABAC
# De kurrende dauer i skogens kant
# besegler stedets ro,
# og det samme gjør det tanggrodde spant
# dernede i fjæren jo.
#
# ABAB
# AABA
# Av vannet stikker der opp en sten,
# en måke har satt seg på den.
# Eoner er gått når den skifter ben
# og lukker øyet igjen.
#
# ABA
# ABC
# Og så vil vi gå en dag eller to
# og se oss mett på alt,
# til all vår uro er falt til ro
#
# ABAB
# ABAC
# Og Elias selv: Her gikk han ense
# for å finne lys ved bekken Krit;
# å så godt han minnes disse stene,
# skogens prakt og klippenes granitt.
#
# ABAB
# ABCB
# Praktfullt reder dagens drott sitt leie,
# smykker rommet til den store fest;
# rikt den ødsler hva den har i eie
# for å hedre evighetens gjest.
#
# ABAB
# ABAC
# Og som solens stolte, glade tjener
# fryder seg den øvrige natur;
# skjønne buer jord og himmel ener,
# lynglimt spiller over fjell og ur.
#
# ABAB
# ABAC
# «Denne bønn er stor. Men hvis ditt øye
# meg i avskjedsstunden kan få se,
# vil deg gaven skjenkes fra det høye,
# ellers ei. Jehovas vilje skje!
#
# ABAB
# ABAC
# Og for Ildprofetens ånd forsvinner
# rummets skranker, dag og tid og år.
# Han ser en gyllen dag, som herlig rinner
# over jorden, når Guds time slår :
#
# ABAB
# ABAC
# Se jeg er den forlorne sønn
# som gikk på ville veie,
# og ødte bort min arv så skjønn
# for verdens glans å eie.
#
# ABC
# AAB
# Meg smakte ikke himmelbrød,
# men verdens lokkemat var søt —
# nå får jeg annet finne.
#
# ABBA
# ABCD
# «Ja  det var så menn på tide
# at vi fant ham. Lenge nok
# måtte vi i samlet flokk
# for hans trolldomskunster lide.
#
# ABAC
# ABCB
# Ha, forbannede, det er ei
# av belønning ennu nok.
# Hatets ånder!t Kom og lær meg
# tegner seg i kvinnens trekk.
#
# ABCB
# ABCD
# Og ild eller engler, pest eller storm,
# alene hans tjenere er.
# Det må fremme hans verk, det må lyde hans bud
# og tjene dem han har kjær.
#
# ABCB
# ABBB
# Men Israels folk går sin frihets vei
# med spørsmål og undren i sinn
# det følger sin fører skritt for skritt,
# men vet hverken ut eller inn.
#
# ABCB
# ABBC
# Og nå har de vandret dag etter dag
# i ørkenens hete sand
# de sterke er trette, og kvinner og barn
# har ydet snart hva de kan.
#
# ABCB
# ABCD
# Og se! Hva er dette? Hver vei er stengt,
# hvor man ser er kun fjell og sjø.
# De er ringet som viltet i snaren inn,
# for kanskje om litt å dø.
#
# ABCD
# ABCB
# Og folket får i sin redsel rett —
# akk, frihetens dag ble kort.
# Den ble kun en flyktig, dårende drøm,
# som en sky er den drevet bort.
#
# ABCB
# ABCA
# Men Moses med staven står rolig og trygg,
# som klippen i brenningens larm,
# taus hører han folkets rasende skrik,
# i tro på Jehovas arm.
#
# ABCB
# ABAC
# Han vet ikke ennu på hvilken vis
# de frelses, kun ett han vet:
# at Israels folk skal synge Guds pris
# før neste dags sol går ned.
#
# ABCB
# ABAB
# Dra fremad! Og frykt ikke Faraos tross,
# målt er hans makt og hans tid.
# Når morgenen rinner, hans arm er brutt.
# — I natt går Jehova til strid.»
#
# ABCB
# ABBB
# Til oppbrudd blir allting gjort istand
# mens skumringen faller på.
# Skjønt veien er stengt av det brusende hav,
# så skal de bent fremad gå!
#
# ABCB
# AABA
# Og solen går ned, og natten blir sort
# angst faller i folkets sinn.
# Se, da tendes et bluss som den klare dag,
# og gyllent som solens skinn.
#
# ABCB
# ABAB
# Og Moses står sterk i Guds veldes kraft,
# den høvding for Herrens hær.
# Den mektige skikkelse står som en gud
# i ildsøylens magiske skjær.
#
# ABCB
# AABC
# Så skrider de frem, de tuseners tog,
# mens natten glider forbi,
# som båret av Herrens mektige hånd
# ad havbunnens banede sti.
#
# ABCB
# ABCA
# Men gleden blir kort — mens folket slår leir
# på Arabias høyder, da se!
# Ad hulveiens spor, hvor selv de kom,
# frem stormer Egyptens armé.
#
# AABB
# AABC
# Alt som i farver, skrift og sten er skapt,
# kan vidne evig. Må vår kunst gå tapt?
# Her er vårt liv. Slik er det godt. Vi vet:
# gold er triumfen over evighet.
#
# AABB
# AAAA
# En oldtidsdikter tegnet livets drag
# som hat og vold, og alt er ens idag.
# Intet går fremad, la oss hylde ham!
# Men evig kunst kan være evig skam.
#
# ABCC
# AABC
# Det skapte lever. Her i nuets rom
# står nuets seirende mysterium.
# Et byggverk reiste hun, spent av geni.
# Men hva er stoffet det skal leve i.
#
# AABB
# AAAA
# Selv gav hun alltid. Blod og nerver sang:
# bygg nul det finnes ingen annen gang.
# Av tankens makt og lidenskapens brenning
# steg buene tilværs i lys og spenning.
#
# AABB
# ABCC
# Et under er hunl gjennom femti år
# stod vestenværet fra en salt, ung vår.
# Sol glitret over bølgene i lek,
# og stormen mørknet til, og sjøfugl skrek.
#
# AABB
# ABCC
# Da skal hun evig høre nuet til
# i alt hun øket: storm og lys og ild.
# Vær henne verdig, venner! For vi krever
# av dere at Johanne Dybwad lever!
#
# ABCB
# ABCA
# Der ensomhet økes
# av havgufs og mørke,
# titt tanken slår innad
# fra lek og fra ørke.
#
# ABCB
# ABCD
# I omsyn av himmel,
# av hav og av sten,
# blant hundre som grubler,
# til tenker blir én.
#
# ABCB
# ABCD
# En vestlands-gutt var han
# på vel et snes år.
# nå verden ham eier;
# men gutten var vår.
#
# ABCB
# ABAB
# Korset reises. Skarpt det tegner
# seg mot himlens dype blå.
# Mangens kinn ved synet blegne
# mens han stirrer mørkt derpå.
#
# ABCC
# AABB
# Hul fra mengdens hese struper,
# som fra selve helveds gruber,
# stiger brølet, hviner, skjærer,
# opp mot ham, som korset bærer:
#
# ABCC
# AABB
# Aldri så den sådan dag,
# aldri til så mørk en sak
# før den skjenket lys og varme
# Men hva er det? Gud forbarme !
#
# AABB
# AABC
# Store Gud! Se, han er død
# Som et gråtkvalt sukk det lød
# fra den lille pinte skare.
# O du kolde smertens mare  !
#
# ABAB
# ABAC
# Så avlet hin adelsmann unger
# men jorden var karrig og hård.
# Og så kom der uker av hunger,
# og ukene vokste til år.
#
# ABAB
# ABAC
# Og glansen i øynenes blånen
# tok støvet i verkstedet med,
# og tidlig ble håret om månen
# så gråhvitt som gatenes sne.
#
# ABAB
# ABAA
# Men skulle jeg henge litt bedre,
# litt mere i sol og i le
# så sier jeg takk, mine fedre.
# Nå suser en sang i vårt tre
#
# ABAB
# ABAC
# Langs elven gikk bronsestakittet.
# Der stod jeg når sol gikk ned
# og drømte og lengtet og tittet
# og hatet min haves fred.
#
# ABAB
# ABCB
# Og høyt i den store kastanjen
# i høyde med byens spir
# der kunne jeg speide til Spanien
# og lenger, ja til Algir!
#
# ABAB
# ABAC
# Men nå — kan jeg fly over byen
# med motor og larm og gny,
# og ikke engang fra skyen
# ser jeg så langt på ny.
#
# ABAB
# ABAC
# mot klippene går gjenlyd av dit sommerhvide brus
# under ishammen lo
# de dønninger som legte med rullesten og grus
# i augustnattens ro.
#
# ABAB
# ABAC
# sneen dekker lyngen og den purpurrøde prakt
# av granittklippens kne.
# Men rolig som en tanke over oddene på vakt
# står det ensomme tre.
#
# AABB
# ABCC
# Og så satt det noen i den
# sådan opp igjennom tiden,
# Sverre prest og andre menn,
# som kan ville gå igjen.
#
# ABAB
# ABAC
# Svensken sier, vi må vite
# han oss frihet gav,
# og at svenske sverd kan bite
# litt om gangen av.
#
# AABC
# AABB
# Bliver det for galt derinne,
# skal vi vei til Torgnyt finne,
# og så gjelder det en dag
# Nordens store frihetssak.
#
# TAAA
# TABB
# FRED PA JORD
# Så ble det da jul som det gjør hvert i år,
# og julefest holdtes i hver en gård
# så langt som den hellige kristenhet når.
#
# AAA
# ABA
# I eteren bruste velsignede ord
# som dengang da hyrdene hørte et kor
# der sang det utrolige: Fred på jord!
#
# AAA
# ABA
# Politisjefen syntes det også var godt,
# og gudskjelov hadde han nylig slått
# et opprør til jord og bragt statsskuten flott.
#
# AAA
# AAB
# Rebellene satt nå bak lås og slå
# og hadde det fredfullt og ventet på
# den dødsdom de alle var viss på å få.
#
# AAA
# ABB
# Og forsvarsministeren følte seg vel
# som aldri tilforn noen julekveld.
# Hans virke for freden var kronet med hell.
#
# AAA
# ABA
# Og utenriks-statsråden var også glad
# at freden var innført så fort og bra
# I Samoa og Nicaragua.
#
# AAA
# AAB
# Hver eneste sjel i vår kristenhet
# ble løftet på bølger av kjærlighet!
# For fred er det beste  som alle vet.
#
# AABB
# AABC
# Akk, sjelen er fryktsom, kroppen svak,
# ungdommens gylne vår ligger bak,
# av årenes tall over fire gang' ti
# er rundet  det beste av livet forbi.
#
# ABCB
# ABCD
# Hvor dypt enn vunden bløder,
# hans hånd den læge kan.
# Hvor hårdt enn savnet tærer,
# han slukker dog dets brann.
#
# ABCB
# ABCD
# Og kampens hærskrik synger
# fra troens spente stål. —
# Og Paulus sterk seg strekker
# mot nye, større mål.
#
# ABCC
# AABC
# Begynner som en susen i kornet sommer-dag
# og vokser til en brusen gjennom skogenes tak,
# inntil at havet bærer med torden-røst den hen,
# da intet, intet høres uten den, uten den.
#
# AABC
# AABB
# Den er det vi vil løfte, vi mange og vi små,
# i fryktløs kamp mot alle som ei ville forstå.
# Begynte som en susen i kornet sommer-dag
# og går nå alt som brusen gjennom skogenes tak.
#
# AA
# AB
# Min verk og tyngsel var ei mer en ve;
# hva før jeg så, jeg lengtet ei at se.
#
# AABB
# ABCC
# Min sjel var stille som en øde sjø.
# Og jeg var ene, som på ytterst ø
# en fugl kan sidde midt i sus og syd
# og lytte seg fortabt i havets lyd.
#
# ABCB
# ABCD
# Med vemod Saulus griper
# sin vandringsstav på ny
# forlater tung om hjerte
# den skjønne, hårde by.
#
# ABCB
# ABCD
# Hvor skal han hen? Til Tarsus?
# "Han husker Jakobs ord.
# Hans hjemstavn i det fjerne
# blandt fjellene i nord.
#
# ABCB
# ABCD
# Jerusalem har seiret,
# og falt sitt siste ord
# med egne hender dreiet
# sin egen skjebnes ror.
#
# ABBC
# ABCD
# Skyen viker.
# Overveldet av hint syn og hine ord
# Mesteren de skjønn og stor
# ser i solens lys på fjellet.
#
# ABAB
# ABAC
# For denne gass-tank hører med i bildet
# av livet mitt de første unge år,
# den tid som jo er sangens rike kilde.
# Nå skal den falle. Klinkehamren går.
#
# AABB
# ABCD
# For selve kuppelen med gassen i
# steg høyest sommertid, når folk var fri
# og var på landet for å feriere.
# Når høsten kom, da sank den dagstøtt mere.
#
# ABAB
# ABAC
# For bak det svarte fjell med kullstøvskyen
# lå eventyrets endeløse land
# den store, brusende og fine byen,
# og gjennom den en slottsvei: Karl Johan!
#
# ABAB
# ABAC
# Ja, der lå byens vest med stille gater
# og lyse hus imellom blomstertrær,
# hvor det på portene hang gylne plater
# med navnene på dem som bodde der.
#
# ABAB
# ABAC
# Og skip, så svære som den største gården
# i gaten hjemme, dampet der avsted.
# Man tenkte ofte og især om våren:
# Å, den som bare kunde være med!
#
# AABB
# AABC
# Man nærte ville planer om å rømme
# for gråe gater avler røde drømme.
# Men alltid kom man hurtig til seg selv,
# den mørke gass-tank var et grensefjell.
#
# ABAB
# ABAC
# Og derfor holdt jeg av den. Mine drømme
# er blitt trossig sang i skyggen her.
# Nå har jeg ingen planer om å rømme,
# jeg elsker byens øst, så grå den er.
#
# ABCB
# ABCD
# Og dør også han  kamerater,
# husk dette vi har å si:
# vi taper ikke, vi seirer,
# vår tro skal kjempe oss fri.
#
# ABAB
# ABAC
# En grånet far skal atter
# gå vakt og sovne inn
# til ruffens svinske latter
# og gny av sjø og vind.
#
# ABCB
# ABCD
# Hebreerne hviler ved stranden,
# hver byrde er lesset av,
# lik sorgløse barn som leker,
# uhindret av dagens krav.
#
# ABCB
# ABCD
# En fest er hver morgen som rinner,
# og natten er sval og lind,
# den vever de slumrende tanker
# i drømmens féverden inn.
#
# ABCB
# ABAB
# Og leiren gjenlyder av klager
# fra morgen til sol går ned.
# Dens kolde ånde forjager
# selv nattens stillhet og fred.
#
# ABCB
# ABCD
# Som tusen piler den rammer
# Guds tjener i hjertets grunn.
# Men taler han folket til rette,
# han egger dets harme kun.
#
# ABCB
# ABAB
# Jeg er kun hans ringe tjener
# som lyder hans lov og bud.
# Vær viss, hans miskunn vil mette
# det folk som er valgt av Gud.
#
# ABCB
# ABCD
# Så sant dere Jehova vil tjene
# i hjertets tillit og tro,
# hans hånd skal fri dere fra farer
# og føre dere trygt til ro.
#
# ABAB
# ABCB
# Når natten innhyller den hellige stad,
# da tendes i templets haller
# de kjempebluss fire, hvis strålebad
# som en flom over staden faller.
#
# ABAB
# ABCC
# Det treffer meg stundom nå som en ve,
# når jeg ser på en blomst eller sten,
# at slik som jeg før kunne tingene se
# skal jeg aldri få gjenfinne én.
#
# ABCD
# ABCB
# Den breder seg ut og tar i favn
# de larmende hærers mylder
# som dekker bjergenes kløfter og skar
# og Jesrielsletten fyller.
#
# ABAB
# ABCB
# Og seiren vil falle de sterke lett,
# ti slukt er den hellige flamme.
# Akk, Israels folk står splittet og spredt,
# og stamme har reist seg mot stamme.
#
# ABCB
# ABAB
# Av stadige kriger, av dyrtid og savn,
# er folket blitt svakt og trett.
# Og lenge det manglet den sterke hånd
# som smelter de mange til ett.
#
# ABCB
# ABBB
# Og ingen har hjelp. Hans yppersteprest
# forgjeves sitt offer har bragt.
# Hvert tegn er en gåde, hvert lys er slukt,
# kun sterk er det ondes makt.
#
# ABCB
# AABA
# Kong Saul går ut i den mørke natt,
# hans drakt er smussig og slitt.
# To menn er med ham, de viser ham vei
# og leder hans vaklende skritt.
#
# ABCB
# ABAB
# Han svøper seg inn i sin usle drakt,
# og gir seg i deres hender.
# De lister seg frem, forsiktig og skjult,
# for tusinde vaktbluss brenner.
#
# ABCB
# ABBB
# Og alt hva du trenger til livets behov
# fra nå av vil Saul deg skjenke,
# fra nå kan du drive din gjerning i fred,
# og ingen din rett skal krenke.»
#
# ABCB
# ABCD
# Og kvinnen kneler for kongens fot
# i undren og glede stor.
# Det rynkete ansikt, det hårde blikk
# får varme ved kongens ord.
#
# ABCB
# ABCD
# «Så si hva du ønsker. Og Israels Gud
# ditt hjertes begjæring vil høre.
# Hvis sorgen formørker min konges sjel,
# hans lys skal den mildt berøre.»
#
# ABCB
# ABCD
# «Ja, kvinne, min sjel som min fot er trett,
# Min dag ble en øde ørk.
# Mitt øye er trett av våken og gråt,
# lang tykkes meg natten, og mørk.
#
# ABCB
# ABCD
# Jeg sparte i svakhet hans fiendes liv,
# jeg sparte hans menn og hans eie
# Akk, han var ung, og en konge som jeg,
# langt kom han på ærens veie.
#
# ABCB
# ABAB
# Men da fikk jeg føle Gud Herrens hevn,
# da visnet min trones prakt.
# Han slo meg til jord ved sin tjeners hånd
# og trampet i støvet min makt.
#
# ABCB
# ABCD
# Og siden, til nå, i de lange år
# har jeg vandret under hans vrede.
# Der finnes ei plett på mitt hjemlands jord
# hvor Saul kan i trygghet trede.
#
# ABCB
# ABCD
# Kanhende jeg feiler. Kanhende er Gud
# et skremsel, og intet mer —
# blandt skygger en skygge, en lyd, et ord,
# en skabning av tre og leire.
#
# ABCB
# ABCD
# Knust og tilintetgjort under Guds dom
# går Saul til sitt telt på ny.
# Det lysner i øst  for siste gang
# hans øyne ser dagen gry.
#
# ABAB
# AAAA
# Med stormen ble jeg tidlig fortrolig.
# jeg lærte å springe for dens pisk,
# jeg har aldri i mitt liv hatt annen bolig
# enn et ruff og en skittenvåt brisk.
#
# AABB
# AABC
# «Du folkets hop! Du øglers ætt,
# som under føtter lov og rett
# og Herrens bud så frekt kan trede,
# hvem frelste deg fra fremtids vrede?
#
# AABB
# ABAA
# Han kommer! Riket er nå nær!
# Opp, ruste dere! Ti enhver,
# som sannhet elsker, løgnen skyr,
# skal riket bygge!l Dagen gryr!»
#
# ABCB
# ABAB
# Da skal du komme på landet,
# om du er fattig og lav,
# og se på det grønne gresset
# over en skyttergrav.»
#
# AAA
# AAB
# å være så langt, langt borte fra revolusjonens by
# den dagen dere fester for opprøret, frihetens gry,
# da drømmen ble virkelighet, vidunderlig håndfast og ny.
#
# AAA
# ABB
# Jeg synes jeg ser dere, venner, dere smiler forundret og gla:
# er det virkelig så lenge siden, så mange år siden da!
# Det kostet en hårdnakket kamp... Men den endte da sandelig bra!
#
# AAA
# AAB
# Jeg synes jeg ser dere, venner, hvor ranke og vakre dere går
# til møtet på Krasnaja-plassen, hvor millionmassen står
# og stamper i sølen, for kaldt er det så det forslår!
#
# AAA
# ABC
# Aja, du forstår det nok, Grisjka  det er ikke mere å si.
# Jeg elsker det seirende folk. Det har kjempet seg fri.
# Det har mot, det har tross, det har tro. Og det har ikke vi.
#
# ABAB
# ABCB
# Du smilte bittert: sa om hundre år!
# Men jeg er ung og vet at jeg er pen,
# og blodet mitt går som en elv ved vår
# og: vi vil danse! skriker mine ben.
#
# ABAB
# ABCB
# Og i mitt hjerte sitter der en flokk
# av unge fugler som vil ut og fly.
# Jeg elsker deg, men hvem kan elske nok
# i evig trældom i så svart en by?
#
# AABB
# ABCC
# Og så satt det noen i den
# sådan opp igjennom tiden,
# Sverre prest og andre menn,
# som kan ville gå igjen.
#
# ABAB
# ABAC
# Svensken sier, vi må vite,
# han oss frihed gav,
# og at svenske sverd kan bite
# litt om gangen av.
#
# AABB
# AABC
# Montro, hva de vilde svare,
# Christie og de gamle kare,
# hvis de stod på Eidsvoll en,
# murende med sverd om lend.
#
# AABC
# AABB
# Blir det for galt derinne,
# skal vi vei til Torgny finne,
# og så gjaller det en dag
# Nordens store frihetssak.
#
# ABAB
# ABAC
# Hun ligger og likner en verden som sank
# blot hovedets takkede ø
# løfter seg fjernt hvor kvelden står blank
# på den svarte og stigende sjø!
#
# ABAB
# ABCB
# To hender så grå og tørre som tre
# flyder på dynens trekk;
# der er hverken kval eller lysning at se
# i de hule og utslukte trekk.
#
# ABAC
# ABAB
# Den helligdom blant stammers vrimmel,
# med dødens tomhet i sitt rom,
# var skjult av lauv for lys og himmel,
# og midt i fuglesangen stum.
#
# ABAB
# ABAA
# Det drysset lauv, og bark fikk skrammer,
# og mangen grein, den knakk med gny,
# og fra de trufne hule stammer
# det lød som sukk i skogens ly.
#
# ABAB
# ABAC
# Men ett er visst og kan ei glemmes
# du tidens barn, betenk det vel!
# En helligdom i sjelen gjemmes
# dypt inne, som bak skog og fjell.
#
# ABAC
# ABAB
# Ja, står den dunkel, arm og øde,
# forstummet mellom larm og lyst.
# den har dog sæd til himmelsk grøde,
# og malm som gjemmer på sin røst.
#
# ABAB
# ABAC
# Det sendes piler mot ditt hjerte,
# og vent med hvert av livets år
# din harmes gny, ditt skrik av smerte
# og dype sukk ved dine sår.
#
# ABAB
# ABAC
# Men la blott pilen malmen røre
# i hjertets dulgte helligdom,
# da faller også i ditt øre
# den røst som sagnet minner om.
#
# AABB
# ABCC
# Da vandret de opp i den frie ur
# og blåste en slått på horn og på lur.
# Det klang så fullt gjennom lundesalen,
# det klang så søtt gjennom kirken i dalen.
#
# ABAC
# ABAB
# Hver bergehall og hver li som var
# gav bevende klang tilbake,
# den hele dal lå tindrende klar
# i toner av lyst og klage.
#
# AABB
# ABCC
# Stilhet og drøm hvori ingenting skjer,
# blot lyset som værver, blot sprøytet som sner,
# blot havet som vandrer, blot havvindens sus,
# blot åndenes gjerning i vårdagens hus!
#
# ABCB
# ABCC
# Da synker våpnene
# maktesløs ned!
# Skaper vi menneskeverd,
# skaper vi fred.
#
# ABCB
# ABAB
# Den som med høyre arm
# bærer en byrde,
# dyr og umistelig,
# kan ikke myrde.
#
# ABBA
# ABCA
# Ti av ham den minste preges,
# han som har sin skabning kjær,
# og i ham forvisst enhver
# lever, ånder og beveges.
#
# AABB
# ABCD
# Deres diktere har rett:
# «Vi er alle dog Guds ætt.»
# Dårskap er det da å mene
# Gud er lik et verk av stene.
#
# ABAB
# ABCB
# Nå er mengdens ro forbi.
# Vilt dens hån om Paulus syder:
# Skån oss! La oss være fri
# for ditt vanvidds milde dyder.
#
# ABBA
# ABCA
# Se de går de visne rester
# av et gyllent blomsterflor:
# døgnets høvding, sterk i ord,
# og sofisten, frasens mester
#
# ABAB
# ABCB
# Nå tuktet og styrket står Abrahams ætt
# i lys av det hellige minne
# nå skal de erobre sin arv, sin rett,
# og fedrenes fotspor finne.
#
# ABAB
# ABAC
# Og angsten spredes som sott i by —
# som storm over hav den jager,
# og leiren gjenlyder fra kveld til gry
# av beske og bitre klager.
#
# ABAC
# ABAB
# Da Moses står frem som Jehovas tolk,
# forferdet Guds dom han forkynner:
# Hvor lenge skal jeg trette med dette folk,
# og tåle dets tross og synder?
#
# ABAB
# ABCB
# Hver kvinne og mann over tyve år
# den samme skjebne skal friste,
# til engang dere ser hva Gud formår,
# som jevnet deres vei til det siste.
#
# ABCB
# ABCD
# Bilder fra den gamle stue
# og langsomt hjulene går,
# forgjeves det klipper og klipper,
# ut ruller dage og år
#
# ABAB
# ABAC
# Men all hans vold er den rene lise
# for den som kjenner ham slik som jeg;
# hans slag er kjærtegn, hans larm en vise
# mens dypt han svinger min vuggemei.
#
# ABAB
# ABCB
# Hvor godt at vite at tiden renner
# og livet glider mot dødens hav,
# at sorg og lykke omsider finner
# et møtested i den stille grav.
#
# ABAB
# ABCB
# Aldri til helt å ta og eie
# alltid så nære som sagnets skatt;
# favnet et nå på lystens leie
# flyktet som hind i sommernatt!
#
# ABCB
# ABAB
# Verden, hvor er du full av gåter,
# kverner som hav i klippering,
# maler din must til lette fråder,
# knuser din kraft til ingenting!
#
# ABAB
# ABCB
# Og allting er brygger mot et fjerne vi skal nå,
# hvor lenge så reisen enn vil vare.
# Det gjelder om å vokse og vite at vi må
# la tanken om alt blivende fare.
#
# ABAB
# ABAC
# Jeg tok igjen i favnen det lysende brus
# og lot himmelrummet være mitt leie!
# Jeg var for evig hjemme i verdens store hus
# og turde ta min salighet i eie.
#
# ABAB
# ABCD
# Ja, lær meg å fange i flyktende ord
# som du i din flyktende tone
# den mektige høysang om lengselens jord
# og vår evighets ventende krone.
#
# ABAB
# ABAC
# Jeg tok din hånd og følte fra dens flate
# et varsomt strøk, det lille kjærtegn, vi
# bestandig brukte i en folksom gate
# dengang da ennå intet var forbi.
#
# AABB
# AAAA
# Intet så mørkt som din fjord, når den fyker
# havsalt forbi deg og innover stryker,
# intet så mildt som din strand, dine øer,
# ja dine øer!
#
# ABAB
# ABAC
# De hørte toner, så på alt som levet,
# de sov og våket, elsket, lo som vi,
# og satt av ensomheten gjennombevet.
# De strøk en kinn, en blomst. Det er forbi.
#
# ABAB
# ABAC
# Og hans venneer gråter, klager,
# knust og knekt av tvilens ve:
# Han er dødl Som en bedrager
# ble han hengt på skjensels tre.
#
# ABCB
# ABCD
# Og kryp som visner
# i dagens id,
# det våger seg frem
# ved nattetid.
#
# ABCB
# ABAB
# Se ham jeg fostret,
# kjød av mitt kjød,
# han søker i blindhet
# sin faders død.
#
# ABCB
# ABAB
# Kan så jeg vente
# en bedre lønn
# av min fiendes frende,
# av Gerars sønn?
#
# ABAB
# ABAC
# Og la meg i sangen vi' deg
# de hedeste av mine ord.
# Det er kjolen jeg lovet at gi deg
# når jeg engang kom ut og ble stor!
#
# ABAB
# ABAC
# Du bodde der ute på skjæret
# alene med alle de små
# tæt indunder sjøen og været,
# og kun sjelden mot landet du så.
#
# ABAB
# ABAC
# Ditt blikk var bestandig der ute
# på det høye og evige hav;
# i det som i stenstuens rute
# har kun lengslene speilet seg av.
#
# ABAB
# ABCB
# Men jeg måtte videre, for jeg visste om et tre
# på den annen side fjellet i kilen,
# hvor allting er så stille og for stormene i le
# som om her var den evige hvilen . . .
#
# AABB
# ABCC
# Livet her og hisset er mitt eie,
# alle himmelhjørner er mitt leie,
# alle hemisfærer kjenner jeg,
# hele verdenshavet er min vei.
#
# AABB
# AABC
# Husk jeg ruller over sunkne kontinenter,
# menneske, husk at nye dommedager venter!
# Jeg er bølgen, jeg har lært å tie,
# jeg har lært å ligge død og bie
#
# AABB
# ABCC
# I mitt nett jeg tar det hele med
# lar det synke i min stillhet ned,
# løfter det igjen og gir det stemme,
# til det i sin evighet er hjemme.
#
# ABAB
# ABAC
# Jeg kan skimte Sydøstgrunnens bøye
# og Bølenes lange flu,
# og er det ikke Guds øye
# som kaster sin glans på dem nu?
#
# ABAB
# ABAC
# Jeg tenkte, mens jeg gjemte bort
# mitt bytte bak en sten,
# at livets mare rider fort,
# og dog er døden sen!
#
# ABAB
# ABCB
# at se et skip om våren stå
# mot fjerne hav og havne.
# Dog var det bedre om det lå
# som vrak på femti favne.
#
# ABAC
# ABAB
# Ditt blod! — det blandes med flodens vanne,
# så bølgene ruller røde, tunge.
# Ve deg, du skjønneste blandt lande !
# Ve deg, som vraket din konge!
#
# ABCB
# ABAB
# Hans folk — hans folk har syndet,
# av lystens rus besatt;
# hans folk, av Herren kåret,
# har Herrens vei forlatt.
#
# AABB
# AABC
# kun knivens snitt i sårets indre
# kan dødens morderverk forhindre.
# Ei bønn, ei tårer den må røre
# hvis hånd skal livets sonde føre.
#
# AABB
# ABCC
# Og var det enn Jehovas ord
# den gang han hersket, bred og stor
# med uinnskrenket enevelde,
# oss kan dog ordet aldri gjelde.
#
# ABBA
# ABBC
# O Jehova! Vær meg nær!
# Klæ meg i din styrkes velde.
# Hold min hånd, at jeg kan felle
# mørkets seiersdrukne hær.
#
# TAAA
# TABC
# REVOLUSJONENS RØST
# Gi meg de rene og ranke, de faste og sterke menn,
# de som har tolmod og vilje og aldri i livet går hen
# og selger min store tanke, men kjemper til døden for den.
#
# AAA
# ABA
# Gi meg de kolde og kloke, men kjenner min virkelighet.
# Bedre enn mange som sier de tror, trenger jeg noen som vet.
# Intet er mere som skrift i sand enn løfter om kjærlighet.
#
# AABB
# ABCC
# Da lå det nakne land forbrent og øde.
# Av dødens rust stod høstens kroner røde,
# og frosten skar i jordens hudlag revner,
# mens stormen kom som herjerbud og hevner.
#
# AABB
# AAAA
# De fjerne veies trær tog til at vandre,
# men røtters net bandt skogens til hverandre.
# Da sås i øde egn ei mann, ei kvinne,
# blot skyggestøtter skred for tunge vinde.
#
# ABCA
# ABCB
# Få var de hjerter
# han fant
# ringe ham tyktes
# den seier han vant.
#
# AABB
# ABCC
# I frykt og beven og i svakhet stor
# bar Paulus frem i enfold korsets ord.
# Og tn for én gav akt i storbyvrimlen,
# og lukket opp for tonen ifra himlen.
#
# AAB
# ABC
# Den greske kløkt kun så i korsets tale
# en vev av dårskap, en bedrift for gale.
# En ånd i kjøtt og blodl En gud som dør!
#
# ABCA
# ABCD
# En hengt forbryder, en forvirret jøde
# skal over verdens ve og vel befale!
# Den hjerne må i sannhet være skjør
# som kan fordøye den slags dåreføde. —
#
# ABCB
# ABAB
# Jorden er full av Guds miskunnhet,
# ingen hans godhet kan veie,
# størst dog av alt er Herrens fred,
# hjertets det dyresteeie.
#
# ABAB
# ABAC
# Skjønn er dagen til hvile, til fred,
# dagenes dag på jorden,
# gaven til alle som syndet og led,
# vidt om i syden og norden.
#
# ABAC
# ABAB
# Da signes jordlivets ringe kår,
# det lysner i støvets egne.
# Bak verdens vinter vi øyner en vår
# hvis blomstring aldri skal blekne.
#
# AABB
# ABCC
# Må føyet Paulus under strid og mén
# til Herrens tempelbygning sten på sten.
# Som kløktig bygningsmann han gav seg tid
# og la dets grunnvoll med forstand og flid.
#
# ABAB
# ABAC
# Å, Gud er med meg! Dette ene toner
# som seierssang igjennom all hans hu.
# Det var ham mer enn hærers legioner,
# det var hans lønn for stridens angst og gru.
#
# TAAA
# TABA
# NR. 13
# De spør hvor Nr. 13 er  vår kjære gamle gård?
# Den ligger inni gaten her, hvor nummer «13» står,
# og De kan se hvor svær den er, så langt kvartalet når.
#
# AAA
# ABC
# Den største gård i gaten, men det finnes mange fler
# i andre gater her i byen, hvis De bare går og ser
# skjønt ingen er så mørk og svart som Nr. 13 mer.
#
# AAA
# AAB
# Det finnes mange fler i andre byer her på jord,
# det er milevis av gater  der hvor fattigfolket bor
# ja De finner Nr. 13 helst i byers øst og nord.
#
# AAA
# AAB
# For da han kom på gamlehjem på landet her i vår,
# så ble han syk av lengsel til sin egen muregård,
# og han rømte fra sitt fengsel, skjønt han snart er åtti år
#
# AAA
# ABB
# Han husker bare alt han så «far hundred years ago»,
# det store hav som blånet mot den store himmel blå,
# hver gyllen dag, hver månenatt  før alle døgn ble grå.
#
# AAA
# ABC
# Og det raser i de unges bitre hjerte: Våk og lær,
# at du klart og nært og koldt igjennom drømmens gylne skjær
# ser veien til et land, hvor Nr. 13 ikke er!
#
# AABB
# AABC
# Hun tok oss ved hånden og følge hun gav,
# bort derfra til kirken så stille og lav,
# hvor fedrene ydmykt har bøyet kne,
# og mildt hun sa: gjør dere som det!
#
# AABB
# ABAA
# Hun strødde sin sne over fjellbratte li,
# bød så sine gutter å stå den på ski.
# Hun knuste med stormhånd det nordhavs speil,
# bød så sine gutter å heise seil.
#
# AABB
# ABBC
# Da løsnet begeistringens rullende fonn,
# da døptes vi av hennes mektige ånd,
# da stod over fjellet et syn i glød,
# som siden oss maner inntil vår død.
#
# AABB
# AABC
# Mens de herjer skjærets sommer
# visner gress og skjøre blommer;
# lyngen falmer skittenbrun
# full av fugleskarn og dun.
#
# ABAB
# ABCB
# Mens luften er sval i dagens gry
# og duggen i solen skinner,
# han driver sin hjord fra hegnets ly,
# det frodigste gress han finner.
#
# ABAB
# ABCB
# Slik var det, men slik er det ei mer,
# hans hjerte så underlig banker.
# Tidt står han på haugen og ser og ser
# og fylles av selsomme tanker.
#
# ABAB
# ABCB
# Det selsomme kom, uten tid, uten ord
# det strømmet i hjertenes tale,
# det rislet som vårregn i rosenes flor,
# og vokste som elven i dale.
#
# ABBA
# ABCA
# Og ingen gav akt på ringhet, på rang
# sin vårdrøm de pleiet,
# sin lykke de eiet,
# og lukket den fast i fang.
#
# ABBA
# ABBC
# Han tenkte med beven på fremtidens vei
# Hvor meget den unge
# forstod av det tunge
# som ventet ham, visste han ei.
#
# ABBA
# ABBC
# Og Isais sønner, de eldste tre,
# til slagmarken følger —
# Den gamle ei dølger
# det volder hans hjerte ve.
#
# ABCB
# AAAB
# Og dog — hva ingen annen
# på jord fikk lov å se,
# for ham er åpenbaret,
# det lindrer savnets ve.
#
# ABCB
# ABAB
# Fra skyens gylne riker
# den dalte stille ned,
# et avskjedsord fra oven,
# et bud om kraft og fred.
#
# ABCB
# ABBC
# Hans råd ei støv kan fatte,
# hans veier ingen vet.
# Til sist dog alt som lever,
# må se hans herlighet.
#
# AABB
# AABC
# «Satan vik! Du ei meg feller;
# det er slektens liv det gjelder.»
# Peter, ennu kan du ei
# sanse Herrens skjulte vei.
#
# AABB
# AABC
# Den som ei sitt liv vil miste,
# livets tap må evig friste.
# Den som villig livet gir
# dødens bytte aldri blir.
#
# AABB
# AABC
# Dog ei dødens gap, det kolde,
# skyldfritt offer kan beholde.
# Frem jeg går i solgylt gry
# ut av grav til liv på ny;
#
# ABAB
# ABAC
# Der sniker en het melodi
# hitut fra en skummel kafe.
# En kvinne glir langsomt forbi.
# Et blikk og et smil. Kan jeg se?
#
# ABAB
# ABCB
# Du vesle runde og glatte sten,
# hvor kan du være slik åpenbaring,
# så tet og gylden, så fast og ren,
# en uttømt mening, en full forklaring!
#
# AABB
# ABCC
# Men ta det rolig. Det er rart med kjærlighet:
# den truer talg av trebokk, som du vet.
# Ja, selv om jeg går skoa av meg
# så får du få en boa av meg!
#
# ABAB
# ABCB
# Hans hår er lyst som gyllen høvelspån
# og luggen vilter, ingen oljesveis,
# og mørkebrunt og rødt er fjeset på'n,
# ja rent som strøket med mahognibeis!
#
# ABCB
# ABAB
# Forunderlig nå å tenke
# på en dag i ungdommens vår
# med solglitter over havet
# og søndenvind i ditt hår!
#
# ABAB
# ABAA
# Og her foran hullet i jorden
# flammer det opp igjen
# og legger sin glans over fjorden
# så jeg ingenting ser uten den.
#
# ABAB
# AABC
# For hu er ikke grei, å nei, å komma te på knea,
# hu har sin egen fine sveis å mestre Kalsen på.
# Vi kjenner a, for vi har sjæl så ofte måtti be'a
# å spara litt på dynamitten! Bare bi litt nå!»
#
# ABAB
# ABCB
# «Du lyse gud! Nei Kalsa, det er kvinnfolk som kan lyne
# det spruter gnister ta å som en smergelslipestein,
# sir konene i trappen, «ho! Der fikk 'n en i trynet!
# Og enda ser a ut som a var bare skinn og bein!
#
# ABAB
# ABAC
# Hva, satan ...? Nei så pinadø om Kalsen er non fange,
# han skal vel alltids ennå kunne hoppe overbord!
# For hvem kan si han noen gang så Anton Kalsen bange?
# Nei det er rekti, Kalsen — det var jaggu sanne ord!
#
# ABAB
# ABAC
# Han kravler opp i vinduet, slår neven inn i ruten
# så glasset raser singlende mot gårdens støpte sten
# og smiler triumferende og hopper ut fra skuten!
# Og tre etasjers fall er nokså drøyt for gamle ben.
#
# ABCB
# ABCA
# Avsindig stimer gatens barn
# som jaget av en ve
# mot gledens åpne, hvite favn:
# kafé og varieté.
#
# ABCB
# ABCD
# Og det er deilig å forgå
# for mennesker og dyr!
# Og dette er vår siste natt,
# og ingen morgen gryr.
#
# ABAB
# ABCA
# De samme bøker, de selvsamme tanker,
# som flinkt av hele slekten gjør en eneste én,
# en fortreffelig fyr som kan stå på ett ben
# og ramse hele leksen, som der slippes et anker!
#
# ABBA
# ABCA
# De samme bøker, de selv-samme tanker
# kamratene åt; men jeg tapte appetitten
# og så lenge vrakte kosten, til jeg endelig ble kvitt den
# og hoppet så glad over hjemmets skranker.
#
# AABB
# AABC
# Skjeggete karer, titt over de tredve,
# og slukne på hvert ord, satt og trellede bredved
# rejiserede kropper på sytten år,
# sorgløst-galne som spurv i vår.
#
# AABC
# ABBC
# Jeg, den yngste i laget, gikk og ventet på parti,
# inntil nytt kull kom inn, over jul Jonas Lie.
# Som bare hadde en «preliminær»-eksamen til den «norske»
# (ikke latinske) embets-eksamen.
#
# AABB
# AABC
# Ei skinn-luen skjulte hans panne, den høye,
# hans klassiske drag og hans mektige øye.
# Nå krum-bøydd av smerte, nå reist av sin kraft,
# han kastet sterke tanker, og han kastet ikke lavt.
#
# ABCD
# AABB
# Det var krefter i de karer som var med på hin lek,
# det var vilje i de krefter som den gang steg.
# Nå stod han der tilbake, forglemt i sin krok.
# Men gjerningen han gjorde, den var en høvdings dog!
#
# AABB
# AABC
# Den flokk av «barbarer» han førte av sted,
# hadde just ei til mål hist å sette seg ned.
# Den ble ikke «latiner», ei fremmed tenknings trell;
# men den ble under toget alt mere seg selv.
#
# AABC
# ABCD
# Hans «grammatikk» kom ikke! Han selv gikk derhen
# hvor tenkningens lov ikke skrives med penn.
# Hans «grammatikk» kom ikke;  men det liv den har hatt,
# behøvde ikke svertens forlengende kraft.
#
# ABAB
# ABAC
# Slik var jeg kommet: en pilgrim med hjertet i skjelvende sang,
# fjernt fra en stenby i vesten, en gate på dypene der.
# Fattig og ung var jeg kommet. Jeg lignet min ungdom engang
# med trær som forsmekter på stengrunn, min gates fortvilede trær.
#
# ABAB
# AAAB
# Eiet jeg intet? Jeg eiet min drøm og min trossige tro
# drømmen om fanen, som luer om dagen i himmelens sol,
# om natten elektrisk belyst og som aldri vil falle til ro,
# høyt over Krasnaja-Plassen — det evige opprørs symbol!
#
# ABAB
# ABCB
# Ryktet var gått.  På min østkant, i Whitechapel og Moabit,
# nedi de mørkeste kroker, i bakgårder, kjeldere, skur
# hadde vi hørt evangeliet: klangen i massenes skritt,
# dengang de russiske brødre løp storm mot den eldgamle mur!
#
# ABBA
# AAAA
# Slik var jeg kommet: med tuseners lengsel og drøm i mitt sinn
# hit for å dvele ved synet av fanen, som flammer ved natt
# høyt over Kreml, hvor engang de gull-lagte tsarørner satt,
# foldende ut sine vinger til flukt over kuppel og tind!
#
# ABCB
# ABCD
# Og vi må aldri la vår tro få farve
# av gatedypet som vi lever i.
# Et grånet hjerte bringer nederlaget —
# ved fanen over Kreml seirer vi!
#
# AABC
# ABCD
# I høstens hus, i vintrens hi,
# på forårsvei og sommersti,
# i menneskegrend, på hav og land
# Det regner igjen.
#
# ABCB
# ABCD
# Så mintes han atter feststemt,
# landet fra fjell til sjø.
# For det skal vi seile, sa han,
# for det er det kjært å dø.
#
# ABCB
# ABCD
# Hjemmefronten, vår stolthet,
# kjemper i sult og tross.
# De krever, og her er svaret:
# dere kan tro på oss.
#
# ABCB
# ABCD
# Stemmen skurret og døde
# da mannen i køyen slo av.
# Så 1lå han med harde øyne
# og smilte som om han sa:
#
# ABCB
# ABCD
# Men en ting kunne du gjerne
# betro meg: Hvordan kan det skje
# at bare vi sjøfolk er utvalgt
# til å bli herjet med?
#
# ABCB
# ABCD
# Vi hører sandelig ingen
# formane på ny og på ny
# soldaten til å marsjere
# og flygeren til å fly.
#
# ABCB
# ABCD
# Er det på plass vi skal holdes?
# Hvor vi vender oss hen
# summer med ros og refsing
# ivrige mellom-menn.
#
# ABCB
# ABCD
# Storm og tåke og blindskjær,
# med det var vi vant å stri,
# ubåter, fly og miner
# det får vi finne oss i.
#
# ABCB
# ABCA
# Hva skal vi da være stolt av?
# Når ingen lenger kan ta
# posteringer fra deres regnskap
# og gi dem til oss: hva da?
#
# ABCB
# ABCD
# Da skal vi likevel seile
# i bitre, frysende år,
# fordi vi kan ikke annet,
# fordi denne krigen er vår.
#
# ABAC
# AAAB
# ytt gjennom luften i natten farer
# et tog på skummende, svarte hester.
# I stormgang drager de ville skarer;
# de har kun skyer til fotefeste.
#
# ABAC
# ABAB
# Det holdtes et bryllup på Øvre Flake
# tre hellige juledager til ende.
# Blant terner fantes ei brudens make,
# og brudgommens ei mellom ungersvenner.
#
# AABB
# AABC
# Det stod en glans i den festlige hall
# av dekkede bord og av dyrt metall,
# det fantes en skatt som er kommet for orde,
# av kobber på vegg og av sølv på bordet.
#
# AABB
# ABCC
# Vår brud hadde atter sin krone på,
# for no skulle skålen om bordet gå.
# Og no tok kjøkemesteren ordet
# og krevde stillhet med slag i bordet.
#
# ABCB
# ABAB
# Da styrtet inn i det benkede gilde
# de vidt beryktede Seimsberserker.
# Øynene rullet mørke og ville,
# på pannene hadde de slagsmålsmerker.
#
# AABB
# ABBB
# De grep sitt offer og slepte ham hen
# til hallens dør og ut gjennom den.
# Da ble det en rasende kamp i gården,
# og gjestene fulgte i vill uorden.
#
# ABCD
# ABCB
# De styrtet ut med bluss og med branner,
# ti tett over egnen ruget mørket.
# Da så de brudgommen opp seg manne;
# no var han av vinterens luftning styrket.
#
# ABAB
# ABCB
# Ti gjennom luften i mulmet suste
# et huiende tog på fnysende hester;
# det fr over skogen mot brudehuset
# og vilde det blodige gilde gjeste.
#
# AABB
# ABCC
# Du er den friske iling i
# vårt trege vane-gjengeri.
# Du er den salte hav-strøm som
# i våre lumre fjorder kom.
#
# ABCB
# ABAB
# Så lenge du tar Sverres tak,
# så lenge du er landets fører,
# Vi vet vi seirer slag i slag;
# din kamp-lur de med redsel hører.
#
# ABCC
# AABB
# Den ånd som i Hjørunga-våg
# for tusen år brøt fremmed åk,
# som ingen konges makt fikk fellet,
# som endog trosset pave-veldet,
#
# ABAB
# ABAC
# For bjerkene her ved broen
# de var meg i unge år
# en trøst og en støtte i troen
# på alt som bar navn av vår
#
# ABCB
# ABAB
# På gjensyn, min ungdoms bjerker,
# på gjensyn, min svarte by!
# Jeg suser i bil over broen
# imorgen ved dagens gry
#
# ABCB
# ABCD
# Men vel er der villere steder
# og mørkere herlighed til.
# Se, fjellene lyser langt inne
# med panden i uvær og ild.
#
# ABCB
# ABAB
# Det lyner på havet; augustnattens sort
# er spent over bølger og skum.
# Synsranden ruller ustanselig bort
# i det uhyre, gapende rom.
#
# ABAB
# ABCB
# Aldri er ånden så mættet med fred,
# eller verden så klar for mitt syn
# som når jorden er badet i mørke og sved,
# og dypet er prydet med lyn.
#
# ABCB
# ABBC
# Her bøyet de sitt hode
# for dødens tunge ve,
# mens Peter stille hvisket:
# «Det måtte, måtte skje.»
#
# ABCB
# ABCD
# Ti selv har du intet å håpe.
# Lykken er ikke for deg.
# For fremtidens slekt skal du åpne
# en bedre og lysere vei.
#
# AABB
# AABC
# Se  Iyset formes som en due,
# et syn, som øyne knapt kan skue
# som fra de høye himles fred
# seg senker over Jesus ned.
#
# ABAB
# ABAC
# Og strendene snakker og måkene knyr
# og hver sjø kaster lyset tilbake. . .
# Og nesten usynlig i solskinnet flyr
# en trost til sin bortgjemte make!
#
# AABB
# ABCD
# Og folk forbi meg til kirke kjøre,
# snart stiger salmen for åpne døre,
# Godt mot! Du hilste på fler enn meg,
# skjønt du i skyndingen så det ei.
#
# AABB
# AAAA
# Godt mot, du vandrer på kirke-vei!
# Du bér for dine, for mine jeg;
# ti bønnen bærer et stykke frem
# på veien mellom de tvenne hjem.
#
# AABB
# ABCD
# Dere bøyer inn; jeg må vidre kjøre,
# mens salmen følger fra åpne døre.
# Godt mot! Du hilste på fler enn meg,
# skjønt du i skyndingen så det ei.
#
# AABB
# AAAB
# I det lyse land har alt og alle skjønnhets skrud.
# Og i skjønnhet svøper grekeren sin unge gud.
# Ante han måskje at Herrens kjærlighet og makt
# engang skulle skinne i hans største skapnings drakt.
#
# AABB
# AABC
# Skipet dreier skarpt om klippebjerget Sunium,
# Tra hvis topp Atenes tempel lyser hvitt som skum.
# Og for spente seil går ferden videre mot nord
# rid den yndefulle, glitrende Eginafjord.
#
# AABB
# AAAA
# Et sus av regn som sivet mot elv, mot vårgrønn eng,
# et vær av vekst og mildhet og evig sammenheng.
# Som dalen her, så slekten; ja, her kan livet si,
# der finnes noe større enn det å være fri.
#
# AABB
# AABC
# Den våte, milde vinden står om oss som et hjem,
# den kjente slekter før oss; nær bringes vi til dem.
# Som evighet, som mening vi føler livet gro,
# fordi den vinden strøk oss, og trær og fjell forstod.
#
# ABAB
# ABAC
# Fylt av vemmelse og lede,
# gudløs, håbløs, uten fred,
# synes folkeakren rede
# for den nye livets sæd.
#
# ABAB
# ABAC
# Rundt om Saulus sitter benket
# broderskaren tett og nær,
# hellig stillhet har seg senket
# over alle, hver især.
#
# ABCB
# ABCA
# En lilje gror på pannens hvelv,
# med feberdugg, fra sorgens sjø.
# Men på din kinn, der kan jeg se
# en rose dø.»
#
# ABCB
# ABCA
# Hun fant meg røtter til behag
# og honning, manna langs vår vei.
# Og i sitt sprog, så sa hun visst:
# jeg elsker deg.
#
# ABCB
# ABAB
# Der kysset hun meg blidt isøvn,
# der drømte jeg  vel hva er hendt?
# den drøm som jeg har nettopp drømt
# på iskold skrent.
#
# AABB
# ABCC
# Når rosen dør, dens blade er
# en seng for deres hjertenskjær.
# Når du er gått, min elskov sanker
# sin rosenseng av dine tanker.
#
# ABCB
# ABAB
# «Nok min gutt! Jeg ser det nå,
# den sømmer seg din gråt
# hvis jeg var skyldfri slik som du,
# min kinn var også våt.
#
# ABAB
# ABAC
# «Nok, nok min tjener! Du har rett,
# du føler dypt og smukt...
# Men jeg, hvis sinn er mere lett,
# må le ved skipets flukt»
#
# ABAB
# ABCB
# Jeg byr dem livets lyst som kom,
# foruten sorg farvel!
# Min sorg, min sorg bad ingen om!
# Det er min sorg ikveld.. .
#
# ABAB
# ABAA
# Så ensom, ensom går min vei
# alt på det hvite hav.
# Men ingen får et sukk fra meg
# som ingen holder av!
#
# AABA
# ABCD
# «Gjør det! gjør det!
# Du skal se
# dødens trussel
# tvinger ham i kne»
#
# ABAB
# ABAC
# Jehova har seirettl Hans tales makt
# flammet i ild fra sky.
# Hans alter, så lenge i skjensel lagt
# er reist av gruset på ny.
#
# ABCB
# AABA
# Her kommer dine arme små
# Fra sorg, fra sult, fra gru.
# De ble korsfestet alt som barn,
# Kom også dem ihu.
#
# AAA
# ABC
# Dy, far; det egenkjærlig er
# å være der
# når alle andre, vi, er her?
#
# AAA
# ABA
# Men dine sønner og døtre, ja vi dine barn,
# skjønte oss ikke på lykken og rotet ihop våre garn,
# så vi i stedet for lykken fanget inn bare skarn.
#
# AAA
# AAB
# da  i vår barndoms gylne og skinnende gry,
# da tankene strømmet som sol gjennom hjernens sky
# og vi i undren så oss omkring i en verden ny
#
# AAA
# AAB
# Fant vi en gressgang ved havet, så slo vi oss ned
# og levet en sommer på dette velsignede sted.
# Morgenen kom med arbeid og aftenen kom med fred.
#
# AAA
# ABA
# Årtusener gikk. Og vi trellet for herskernes ætt,
# noen med plogen, andre med spade og spett.
# Tusenvis gikk vi i krig for de herskendes ære og rett.
#
# AAA
# AAB
# Dette var straffen fordi vi fornektet vår mor,
# fordi vi tok fremmede guder og glemte deg jord,
# deilige jord under solbålets ildstråleflor!
#
# AAA
# ABA
# mørsere gjødde og spydde, det stank av karbol og blod
# og menneskekjøtt, som ble stekt på granatsplinters glo,
# ...
# hun ser et velkjendt vrak;
# hun venter ham som i kahytten sover,
# og denne venten slipper ei sitt tak.
#
# ABAB
# ABAC
# Da sover verden i den gamle stue,
# hun har bragt alt til ro.
# Se henne der mot himlens kalde bue,
# mens skjørtet flagrer i den skarpe sno!
#
# ABAB
# ABAC
# Vi som avlet unger
# for å se dem dø,
# dø i krig og hunger,
# for ære eller brød —
#
# ABAB
# ABCD
# Engang skal vi hevne.
# Ennu gir vi tål.
# Herd din unge evne,
# så den blir som stål.
#
# ABAC
# ABCB
# Men ekene stod mørke og mektige som før
# og tedde frem en avklaret bygning
# og fanget i sitt nett alle brott som fra sør
# brøt inn over vinterhavets rykning.
#
# ABAB
# ABCB
# Ja slik stod de fredet i tusene år,
# elsket og æret av alle.
# Men mennesket bytter guder og jorden skifter kår
# og Tjømøs gamle eker måtte falle.
#
# ABA
# ABC
# Uendelig fjernt er allting her,
# verden er skjult langt borte.
# På klippene sitter av skarv en hær,
#
# ABCB
# ABAA
# Jeg ser ikke liv på dekket nå,
# og ingen lyd er å høre.
# De sover dernede mot klenningen ru
# og med brenningens brus i sitt øre.
#
# AABB
# ABCD
# Forferdelse griper de trofaste tre,
# som fulgte ham lengst. Nå svikter de med.
# Hva kan det dog være? H a n vakler jo,
# som stetse var preget av kongelig ro!
#
# AABB
# ABCC
# H a n bever som svakeste, usleste orm,
# som klippefast stod i den villeste storm.
# O Gud, hva er dette? Stumme de står.
# Han likner en skygge, der bort han går.
#
# ABCD
# AABC
# For slektens brøde
# villig han er å sone og bøte;
# men veien?  Er dett e vel veien ut
# for verden fra fallets dyp til Gud?
#
# AABB
# AAAA
# «Si, vet du at døden er syndens lønn?
# Hvem krever din død? Du er jo Guds sønn?
# Spar deg for døden  et ord av din munn,
# du blir verdens herre i samme stund.
#
# AABC
# ABCD
# Hevnsyk over sitt nederlags tort
# spiller den onde sitt høyeste kort.
# — Grufulle time, som sammen hefter
# en evighet før og en evighet etter
#
# AABB
# ABCC
# O skal jeg smake den bitre ve,
# da rekk meg din hånd;  Din vilje skje
# Da åpnes himlen. Og angstens pil
# flykter for Faderens lyse smil.
#
# AABB
# ABCC
# Da sverger han hest ved avgrunnens huler,
# ved alt, hva helvete eier og skjuler:
# «Den seir skal bli dyr — til siste dag
# skal blodig jeg hevne mitt nederlag.
#
# AABB
# AAAB
# Da går et usigelig smertesdrag
# over Frelserens ansikt. Men uten nag
# han smiler imot ham: «Venn, er det deg?
# Judas, hva er ditt ærend hos meg?»
#
# ABAB
# ABAC
# Ja, ja toner toppene med farver som gull,
# og ja stemmer sølvbekken i.
# Og røttene rører seg i vårjordens muld
# og et ja gjør en pilevånd fri!
#
# ABBA
# ABBC
# Og minnene leker i ynglingens hu
# som stjernene blinker i ørkenens natt —
# kan hende han ser, om enn dunkelt og matt,
# at en Større har ledet hans fot til nu.
#
# AABB
# ABBC
# - Hvem frelste mitt liv? Hvem våket vel over
# kisten som fløt på Nilens vover?
# Hvem ledet den unge kongsdatters fjed
# i rette stund til det rette sted?
#
# ABBA
# ABBC
# Gud Herren, som skapte himmel og jord,
# som bar våre fedre på sterke hender,
# han som den minste av sine kjenner,
# han hørte i miskunn den bedende mor.
#
# ABAB
# ABCB
# Å ligge og høre på hjulenes sangkor
# og skinnenes jublende jern,
# hvis sang er den samme ved Moss og ved Magnor
# som ute ved Briissel og Bern!
#
# ABAB
# ABCB
# Og reise mot fremmede steder,
# hvis navn er som løfter om alt der er skjønt
# en spådom om ukjente gleder,
# et blikk i en fremtid av solblått og grønt!
#
# ABAB
# ABAC
# Er veien ei den beneste,
# forgrenet gjennom alle her,
# så er den dog den eneste
# som kommer ganske nær.
#
# ABAA
# ABCC
# Å, gode hjerter, styrk hvert ord,
# så de må bli de eneste
# i hele kjærlighetens kor
# som hun av hjertet tror.
#
# ABAB
# ABCB
# Når først du er viss på han kommer ei bit
# med sine sår
# og fyller med sin så bestandige strid
# din stille gård!
#
# ABAB
# ABCB
# Men ikke her inn; for ditt rinnende blod
# kan plette vårt gulv.
# Lukk porten! Der er han igjen i din fot
# Germaniens ulv! »
#
# ABAB
# ABCB
# Men alt hva vi eiede der ombord,
# til havs er satt,
# hvert skjold og hvert minne  i dypet det för
# en vinter-natt.
#
# ABAB
# ABCD
# Den nordiske løve, den gamle grå
# gallions-figur,
# den hugdes i stykker, fregatten lå
# som en nedskutt mur.
#
# ABAB
# ABAC
# Den sattes i stand, og den sattes ut
# ved Tysklands fot,
# men sort-gult var flagget, en ørn slo ut
# hvor løven stod.
#
# ABAB
# AAAB
# Gav ingen salutt og gav intet hurra,
# vi var ei kjent.. .
# Nei, det er umulig, vi drømte kun da,
# det er aldri hendt!
#
# ABAB
# ABAC
# Da stod våre klipper i aftenglød
# som fyrtårn kun,
# som bad hver en seiler å vende for støt:
# Her er svikfull grunn!
#
# ABAB
# ABAC
# Da ble hver en vårflom mot Skageraks hav
# vår histories gråt;
# hver vilje her vokste, så straks sin grav,
# men aldri dåd!
#
# AABB
# AAAA
# Han prøvde å slite seg løs med et kast,
# men hånden i armen grep hårdere fast.
# Igjen gikk hans øyne fra blomst til blomst.
# Så sleptes han opp for å få sin bekomst.
#
# ABCC
# ABAA
# «Jeg så hvor åndens due blid
# kom over ham på vinge hvit.
# Der stod han, sterk og høy og mild,
# med glød og kraft og ungdoms ild.
#
# AABC
# AAAA
# den nye sol, et blodigt foster, velter
# seg ut av nattens buk, og havet smelter.
# Og se en såret sky, hvis gang forråder
# fødslens forferdelse og gryets gåter!
#
# AABC
# ABCD
# Inn i den sterke, befestede by
# som Filip, hans far, ga rikdom og ry,
# vandrer — fire århundreder etter
# en verdenserobrer med større krefter.
#
# AABB
# AAAB
# Vel synes hans rustning av ringe verd,
# en kappe hans brynje, en stav hans sverd,
# hans samlede styrke er ringe å se,
# foruten ham selv den telles i tre.
#
# ABCB
# ABCD
# Hver jordens skapning skjelver
# for livets gådemakt,
# i hjertets skjulte dybder
# er evigheten lagt.
#
# ABCB
# ABCD
# Mens morgensolen gyller
# den gamle krigerby,
# går Paulus og hans venner
# til elvebreddens ly.
#
# ABCB
# ABCA
# I hennes rike bolig
# han får en veltjent ro,
# mens han sin gjerning øver
# frimodig, glad og fro.
#
# ABBA
# ABBC
# Når fremgang og hell vår gjerning tilsmiler,
# når/higen og vilje og evne er ett,
# da faller det tungeste dagverk lett,
# og knapt vi merker hvor dagene iler.
#
# AABB
# ABCC
# Vokteren selv med undren stor
# tidt hadde hørt de fremmedes ord.
# Og sett at så manges angst og tvil
# forsvant som barnets for morens smil.
#
# ABBA
# ABCA
# Bygdene skifter; men ta dem i bolk:
# livlige sinn, som lengsler er lagt i,
# sangfulle dyp, men bølgeaktig':
# kaste-vinds-fjordene farget sitt folk.
#
# AABB
# AABC
# Det koster å løfte fjordenes arv
# fra vellystig favn til kraft i sin tarv.
# Det koster;  men den som kan det, blir mann.
# Jeg vet det går an.
#
# ABBA
# ABCA
# Her i uforstyrret ro
# vil han deres hjerter lede,
# for sitt rike dem berede,
# styrke deres ringe tro.
#
# ABCC
# AABC
# Du vil ned i graven stige,
# som skal reise Davids rike?»
# Jesus skjelver. Hvilken makt
# er i denne tale lagt !
#
# ABCB
# AABB
# De vil rose alt som var dårlig
# og glemme alt godt ved deg,
# og undres hvorledes det hele skal gå,
# og så vil de gå sin vei!
#
# ABCB
# ABCA
# Men stillere enn en sovende
# og fremmed og fjern å se
# røres du ikke av gråten;
# at det er kaldt hva gjør det»
#
# ABCB
# ABAC
# Men, leende, halvveis mot himlen,
# hvor blesten går til og fra,
# blandt stjernene kolde, der vil jeg holde
# din Ambarvalia!
#
# ABAC
# ABCD
# Fugler hilser deg fra gren,
# bygdesnakket viker,
# luften blir mere ren,
# høyere du stiger.
#
# ABAB
# ABAC
# Stanser, lytter du engang,
# vil du få høre
# ensomhedens store sang
# bruse til dit øre.
#
# ABAC
# ABAB
# Straks en fjellbek risler kvikt,
# straks en småsten ruller,
# føres hit din glemte plikt
# med en verdens bulder.
#
# ABAB
# ABAC
# To er brudens kjoler
# av verdensveven gjort.
# vår evighets symboler
# er bare hvitt og sort.
#
# ABBA
# ABBC
# Intet skal deg gjøre men,
# ingen fare deg skal finne,
# ei din fot du noensinne
# støte skal på minste sten.
#
# ABAB
# ABAC
# Millioner av år er rundet
# siden den lagdes her,
# men de hviler tryllebundet
# i dette havblå skjær.
#
# AABB
# ABCC
# Hun kastet seg ned,
# hun gret og hun gret,
# sitt livs-håp, det skulle hun miste.
# Men det var der ingen som visste.
#
# ABAB
# ABAC
# Så saml oss da! vi er parat
# Hans isblikk vender seg og ser:
# Den som er god, skal hate hat,
# og ingen fler.
#
# AABB
# ABCC
# Det er til større strid enn den,
# han kaller våre unge menn.
# Det er til strid mot eget sinn
# hans flammesverd har vidd oss inn.
#
# ABAB
# ABAC
# Hans liv skal blende vårt, som skam
# i sorg og lengsel skal vi si:
# Vi kjender ham, vi elsker ham,
# men hvem er vi?
#
# ABAB
# ABAC
# Han dyrket ilden til den gav
# den største flammen verden vet:
# Den brente over fjerne hav
# barmhjertighet.
#
# ABAB
# ABAC
# Når brente vi mot ett: at gi,
# vår ild, vårt lys mot stormens vær?
# En slekt på film, en slekt på ski
# er alt vi er.
#
# ABAB
# ABCB
# Men der er håp: en slekt på ski!
# Her er vår egen kraft som flyr,
# lik stål og sang, her suser fri
# vårt eventyr!
#
# AABB
# AABC
# Nå er det oss! Mot stormen blind
# brøyt løypen i vårt eget sinn.
# Og stuper vi, hent kraft hos en
# som gikk der før, mens natten hven.
#
# ABAB
# ABCB
# For over øde fjeld og hei
# vi skimter foran oss en mann.
# Hans spor skal føre inn til deg,
# vår fremtids land
#
# ABAB
# ABCA
# De svarte jorder glinser under plogen,
# som tusen funker flyr det korn man sår,
# i flammer skyene! Og hør, der går
# en foss av fuglerøster dypt i skogen!
#
# ABAB
# ABCB
# Å lykke, når verset blir til!
# Det stiger av damp
# som soler i susende ild.
# Avsindige kamp!
#
# AAA
# ABA
# Og har det en sjel vil det fly
# av graven, av hjertet på ny!
# Opstandelsens morgen vil gry.
#
# AABB
# AABC
# Her lar jeg dem falle,
# tindene, alle, alle.
# O hvilken sorg å se
# dem synke langsomt ned!
#
# ABAB
# ABAC
# Som en prins er det kledt, og dets øyne er blå,
# så blå som de nylig i himlen ble tente.
# Og det kjennes så lett som om ennå det lå
# på de stråler som hit ned til jorden har sendt det.
#
# ABAB
# ABCB
# Ja, en himlenes sønn er den vesle som her
# blir døpt til sin vandring i dødsskyggens rike.
# I sitt evige ord er den visselig nær
# den almakt som gjør ham til åndenes like.
#
# ABAB
# ABCB
# Ned i det er vi senket, og vi vet det så vel
# at alt det der ute i drømmenes lande,
# våre huser, vår jord og de skinnende fjell,
# det er skygger som står mellom oss og det sande.
#
# ABAB
# ABCB
# Hvo vil ikke gjerne høre
# deg som vet og kjenner alt,
# for vårt hjerte, ånd og øre
# ingen slike ord har talt.
#
# AABB
# AABC
# Dokkvarterets gademunder spydde all sin kvalme
# i havnen, så dens oljeglans tog langsomt til at falme.
# Man så kun noen hunder mellom gitrene kretse,
# det så ut somom portene var lukkede for stedse.
#
# ABAB
# ABCD
# Slik har jeg alltid visst du var
# så ny og dog med duft av ahner
# med gammel glans av gud tsar
# og nytendt ild i flagg og faner!
#
# ABCD
# ABCB
# Og mangt et bud ham engstet,
# fra leiet søvnen vek,
# og fryktens mørke syner
# fra sjelens grunne steg.
#
# ABCB
# ABAB
# Det lyser og det glitrer
# som sol i morgenstund,
# når atter han betreder
# Fililppis gamle grunn.
#
# ABCB
# ABCD
# Han hilser venneskaren,
# han bringer nådens ord,
# og gledes når han finner
# sin grøde rik og stor.
#
# ABCB
# ABCD
# Korint dog først av alle
# hans hjerte ligger nær.
# Og akk, hva tidt han fryktet,
# med sorg han skauer der.
#
# ABCB
# ABAB
# Hårdt har det onde herjet
# hva engang blomstret smukt.
# Den svake hjord er splittet,
# her trenges trøst og tukt.
#
# ABCB
# ABCD
# Han går hvor Herren kaller,
# sinVei, sitt mål han vet.
# Hva enn vil skje, ham bærer
# Guds sterke kjærlighet.
#
# AABB
# AABC
# Paulus speider over havets bølger,
# øyets retning hjertets lengsel følger
# langt derute  der hvor sol går ned,
# der er Rom, hans lengsels mål og med.
#
# AABB
# ABCD
# tvende navne klinger i hans hu:
# Rom — Jerusalem.  En gang ennu,
# før hans øye lukkes, må han se
# skueplassen for sin mesters ve.
#
# ABBA
# ABCA
# Deres morderanslag nå ham tvinger
# til å velge skjulte stiers spor,
# ei til havs, men over land mot nord
# ham hans venner snart i trygghet bringer.
#
# ABAB
# ABAC
# Men det korte samværs stille hygge
# er et flyktig lite solstreif kun
# over avskjedsstundens dystre skygge,
# tungt den senker seg i sjelens grunn.
#
# ABAB
# ABAC
# Der er vemod i de varme hender,
# sorgen skjelver i de stille ord;
# ufødt dag ei jordens sønner kjenner,
# Gud alene holder tidens ror.
#
# ABAB
# ABAC
# Og hva tiden binder, tiden river,
# uten skånsel er dens hårde hand.
# Rene sjelers samspill dog forbliver,
# aldri rives evighetens bånd.
#
# AABB
# AABC
# Også her behøves råd og trøst.
# Gjerne hører de den kjæres røst
# dagen ut, ja langt på natten med,
# siden må med hast han ta avsted.
#
# ABAB
# ABAC
# Å hvor gjerne steg han nå fra borde
# for 'de kjære steder å få se;
# lengslen dog ei komme får tilorde,
# reisens større krav må fyldest skje.
#
# ABAB
# ABAC
# Men mitt liv er dog en skatt så ringe,
# kan kun livets endemål jeg nå,
# har min sjel kun evighetens vinge,
# støvets hytte gjerne falle må.
#
# ABAB
# ABCB
# Hen over breens fjerne sne
# går nordlysbåndets streker,
# i all sin stråleprakt å se
# som tusen harpeleker !
#
# ABAB
# ABAC
# Til stjerneskriftens notetegn
# jeg kan i natten høre,
# den fjerne stillhets toneregn
# bli levende for øret!
#
# ABAB
# ABAC
# Jeg skriver til propellens bank
# og må med skriften kave,
# mens månestripen legger blank
# sin gullpenn over havet.
#
# ABAB
# ABCB
# Som den av solens lys jeg tar
# om lyset ikke blender,
# som den jeg også skrevet har
# mitt dikt langs hav og strender.
#
# ABAB
# ABCB
# Det går i årets døgn mot natt
# skjønt stjernene står tente,
# og vidner over mørket at
# en vårtid er i vente
#
# ABAB
# ABAC
# Og jeg kan ennu føle kuldegyset
# som gikk i oss, da vi ble stanset der.
# Vi svor å sprenge oss en vei mot lyset:
# en plass i sol for alle dem som lever her!
#
# ABCB
# ABAB
# da han skapte denne klode og ga den på sin flukt
# dagen og natten til vinger
# og gjorde at vi her i en brusende bukt
# kan høre hvordan sfærene klinger.
#
# ABBA
# ABCA
# Og Saulus selv! Grepet, bøyet,
# står han i klyngen av ukjente frender,
# åpner sitt hjerte, skrifter, bekjenner,
# mens angerens tårer skjelver i øyet.
#
# ABCB
# ABAC
# Ei barn har noensinne
# slik lyttet til sin mor,
# som denne rabbi hørte
# den ringe fiskers ord.
#
# ABCB
# ABAB
# «Her var det! — Her han segnet
# i angst på marken ned.
# Her stred han hårdt med døden,
# her ble som blod hans sved.
#
# ABCB
# ABAB
# Vi så i fakkelskjæret
# hans vilt forvredne munn
# idet han Herren kysset,
# O, redselsfulle stund.
#
# ABCB
# ABCA
# Ingeborg i Fagerlia,
# bedre terne så du ei.
# Gikk hun først på sæterstien,
# ble den snart en alfarveg.
#
# ABCB
# ABAB
# Tiden svant til ut på høsten,
# sæterhytta stod forlatt,
# da ble Gudmund reiselysten,
# og så tok han skreppa fatt.
#
# AABC
# AABB
# Mens han drog på salg og kjøp,
# Gudmund fra sin lykke løp.
# Knut Labeit hvis fart var liten,
# passet desto bedre tiden.
#
# ABB
# ABC
# vent, det finnes vel et råd,
# råd for uråd, om ei førenn
# du skal inn ad kirkedøren.»
#
# ABCC
# AABB
# Foran spillemannen drog,
# så kom bruden med sitt tog;
# først bak den som slo på tromme,
# så man Knut med følge komme.
#
# AABC
# AABB
# Klokt han passet sine skritt
# så han fulgte brudens ritt,
# og da var det intet uten
# krattet mellom ham og bruden.
#
# ABAB
# ABAC
# Sådan gikk det fram til nesset,
# der hvor elva bøyde av.
# Her stod flommen over gresset
# opp til sti og gjerdestav.
#
# ABAB
# ABCB
# «Hvem tør våge å va over?»
# ropte i sin vånde Knut;
# «Den, som prøver det jeg lover
# Viumsåsens beste stut.»
#
# ABAB
# ABAC
# Folk på dette kirkestevne
# lovet høyt og hellig det,
# at hver mann med all sin evne
# skulle stå på Gudmunds rett.
#
# ABCB
# ABCD
# I fjor fikk vi tyve kroner
# å feire hans komme med.
# Det skjærer dem ennå i hjertet
# å tenke på det:
#
# ABCB
# ABCD
# I fjor fikk vi tyve kroner
# til måltid og juletre.
# I år har vi bare det glade budskap
# å trøste oss med.
#
# ABAB
# ABAA
# Slett intet gull du fikk i arv;
# men se, du fikk min fiende-flokk!
# Og den har trelet for ditt tarv,
# og den har gitt deg venner nok.
#
# ABCB
# ABCD
# De kommer glad og villig
# både fra fjern og nær.
# De kommer for å vise
# de har sin konge kjær.
#
# ABCB
# ABAB
# Farshjertet blør i barmen
# ved tanken på sin sønn.
# Hans høvdinger med beven
# forstår hans hjertes bønn:
#
# ABCB
# ABBB
# Betving din sorgl Ta vare
# på dine stridsmenns tarv.
# Hvis ikke, går vi fra deg,
# og døden blir din arv.»
#
# ABCB
# AABC
# Og kvinnfolka bar seg og bælja
# om hjælp som en frelsesarmé,
# og Dokka sang sjælveste Gloria,
# men ikke en purk å se.
#
# ABCB
# ABAB
# For når du kan trenge te polti
# er terrenget støtt blåst reint,
# men ellers så lyser det messing
# i gatene tilig og seint!
#
# ABCB
# AABA
# Men nok a det. Keisern blei bærja
# a noen som kom forbi.
# Døm halte'n iland med ei hake
# og sleit, så du slette ti!
#
# AABB
# ABCC
# Intet ringe offer krevet Paulus av hans mor
# hennes alderdoms forhåbning, hennes rikdom stor.
# Glad og villig dog hun gav ham til sin venn og Gud.
# og begeistret fulgte han sin store mesters bud.
#
# AABB
# AABC
# Og nå stod han her som fremmed i et fremmed land,
# ved Egeerhavets vene, vidt besungne strand.
# Langt og lenge blikket svevet over havets blå,
# hvor i solens dis som skyer fjerne land han så.
# (1877, 5158)
